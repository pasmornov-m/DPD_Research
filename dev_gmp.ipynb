# %%
# %load_ext autoreload
# %autoreload 2

# %%
from modules import data_loader, metrics, learning, plotting, utils, params, pipelines
from modules.gmp_model import GMP
import matplotlib.pyplot as plt
import numpy as np
import torch

# %% [markdown]
# Load data from files and init acpr meter

# %%
data = data_loader.load_data("DPA_200MHz")

config = data["config"]
fs = config["input_signal_fs"]
bw_main_ch = config["bw_main_ch"]
bw_sub_ch = config["bw_sub_ch"]
n_sub_ch = config["n_sub_ch"]
sub_ch = config["sub_ch"]
nperseg = config["nperseg"]

x_train = data["train_input"]
y_train = data["train_output"]
x_val = data["val_input"]
y_val = data["val_output"]

gain = metrics.calculate_gain_complex(x_train, y_train)
print(f"Gain of PA = {gain:.2f}")
y_train_target = gain * x_train
y_val_target = gain * x_val

data['y_train_target'] = y_train_target
data['y_val_target'] = y_val_target


acpr_meter = metrics.ACPR(
        sample_rate=fs,
        main_measurement_bandwidth=bw_main_ch,
        adjacent_channel_offset=[-sub_ch, sub_ch],
        segment_length=nperseg,
        overlap_percentage=60,
        window='blackmanharris',
        fft_length=nperseg,
        power_units='dBW',
        return_main_power=True,
        return_adjacent_powers=True
    )
# Out:
# Gain of PA = 2.52

# %%
pa_train_loader = [(x_train, y_train)]
pa_val_loader = [(x_val, y_val)]
criterion = metrics.compute_mse
metric_criterion = metrics.compute_nmse

pa_degree = 5
pa_config = params.make_gmp_params(
    Ka=pa_degree,
    La=pa_degree,
    Kb=pa_degree,
    Lb=pa_degree,
    Mb=pa_degree,
    Kc=pa_degree,
    Lc=pa_degree,
    Mc=pa_degree,
)

pa_model = GMP(**pa_config, model_name="pa_grad")

epochs = 10000
lr = 0.001

optimizer = torch.optim.Adam(pa_model.parameters(), lr=lr)

if not pa_model.load_weights():
      learning.train(net=pa_model, 
            criterion=criterion, 
            optimizer=optimizer, 
            train_loader=pa_train_loader, 
            val_loader=pa_val_loader, 
            n_epochs=epochs, 
            metric_criterion=metric_criterion)
      pa_model.save_weights()
utils.freeze_pa_model(pa_model)

y_val_pa = learning.net_inference(net=pa_model, x=x_val)
pa_nmse = metrics.compute_nmse(y_val_pa, y_val)
print(f"Model NMSE: {pa_nmse:.2f}")
# Out:
# Coefficients loaded from model_params/pa_grad_gmp_model_Ka5_La5_Kb5_Lb5_Mb5_Kc5_Lc5_Mc5.pt
# Model NMSE: -33.16

# %% [markdown]
# PA model

# %%
freqs, spectrum_y_in = metrics.power_spectrum(x_val, fs, nperseg)
_, spectrum_y_out = metrics.power_spectrum(y_val, fs, nperseg)
_, spectrum_y_val_pa = metrics.power_spectrum(y_val_pa, fs, nperseg)

xlabel="Частота (МГц)"
ylabel= "Спектральная плотность мощности (дБ)"
fontsize = 12
figsize=(12, 6)

plt.figure(figsize=figsize)

plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_y_in)), color='grey', label='Входной сигнал')
plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_y_out)), color='black', label='Выходной сигнал')
plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_y_val_pa)), color='gold', label='Выходной сигнал PA')

plt.xlabel(xlabel, fontsize=fontsize)
plt.ylabel(ylabel, fontsize=fontsize)
plt.legend()
plt.grid()
plt.show()
# Out:
# c:\Users\maximp\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\signal\_spectral_py.py:652: UserWarning: Input data is complex, switching to return_onesided=False
#   freqs, Pxx = csd(x, x, fs=fs, window=window, nperseg=nperseg,

# %% [markdown]
# DLA DPD grad

# %%
dla_train_loader = [(x_train, y_train_target)]
dla_val_loader = [(x_val, y_val_target)]

epochs = 1000
lr = 0.001

dla_degree = 6
dla_config = params.make_gmp_params(
    Ka=dla_degree,
    La=dla_degree,
    Kb=dla_degree,
    Lb=dla_degree,
    Mb=dla_degree,
    Kc=dla_degree,
    Lc=dla_degree,
    Mc=dla_degree,
)
dpd_model_dla = GMP(**dla_config, model_name="dpd_dla_grad")
is_load = dpd_model_dla.load_weights()
casc_dla = utils.CascadeModel(model_1=dpd_model_dla, model_2=pa_model, cascade_type="dla")

optimizer_dla = torch.optim.Adam(casc_dla.parameters(), lr=lr)

if not is_load:
    learning.train(net=casc_dla, 
                   criterion=criterion, 
                   optimizer=optimizer_dla, 
                   train_loader=dla_train_loader, 
                   val_loader=dla_val_loader, 
                   grad_clip_val=0, 
                   n_epochs=epochs, 
                   metric_criterion=metric_criterion)
    dpd_model_dla.save_weights()

y_val_dla = learning.net_inference(net=casc_dla, x=x_val)
nmse_dla = metrics.compute_nmse(y_val_dla, y_val_target)
print(f"Model NMSE: {nmse_dla:.2f}")
# Out:
# Coefficients loaded from model_params/dpd_dla_grad_gmp_model_Ka6_La6_Kb6_Lb6_Mb6_Kc6_Lc6_Mc6.pt
# Model NMSE: -42.10

# %% [markdown]
# ILA DPD grad

# %%
ila_train_loader = [(x_train, x_train)]
ila_val_loader = [(x_val, x_val)]

epochs = 1000
lr = 0.001

ila_degree = 6
ila_config = params.make_gmp_params(
    Ka=ila_degree,
    La=ila_degree,
    Kb=ila_degree,
    Lb=ila_degree,
    Mb=ila_degree,
    Kc=ila_degree,
    Lc=ila_degree,
    Mc=ila_degree,
)
dpd_model_ila = GMP(**ila_config, model_name="dpd_ila_grad")

is_load = dpd_model_ila.load_weights()
casc_ila_train = utils.CascadeModel(model_2=dpd_model_ila, model_1=pa_model, gain=gain, cascade_type="ila")
casc_ila_eval = utils.CascadeModel(model_1=dpd_model_ila, model_2=pa_model, cascade_type="dla")

optimizer = torch.optim.Adam(casc_ila_train.parameters(), lr=lr)

if not is_load:
    learning.train(net=casc_ila_train, 
                   criterion=criterion, 
                   optimizer=optimizer, 
                   train_loader=ila_train_loader, 
                   val_loader=ila_val_loader, 
                   grad_clip_val=0, 
                   n_epochs=epochs, 
                   metric_criterion=metric_criterion)
    dpd_model_ila.save_weights()

y_val_ila = learning.net_inference(net=casc_ila_eval, x=x_val)
nmse_ila = metrics.compute_nmse(y_val_ila, y_val_target)
print(f"Model NMSE: {nmse_ila:.2f}")
# Out:
# Coefficients loaded from model_params/dpd_ila_grad_gmp_model_Ka6_La6_Kb6_Lb6_Mb6_Kc6_Lc6_Mc6.pt
# Model NMSE: -40.17

# %% [markdown]
# ILC DPD grad

# %%
u_k_train = learning.ilc_signal(x_train, y_train_target, pa_model, epochs=1000, learning_rate=0.001)
u_k_val = learning.ilc_signal(x_val, y_val_target, pa_model, epochs=1000, learning_rate=0.001)
u_k_pa = pa_model.forward(u_k_train).detach()

data["ilc_train_output"] = u_k_train
data["ilc_val_output"] = u_k_val

ilc_train_loader = [(x_train, u_k_train)]
ilc_val_loader = [(x_val, u_k_val)]
# Out:
# Epoch [0/1000], Loss: 0.030526617541909218
# Epoch [100/1000], Loss: 0.0010766324121505022
# Epoch [200/1000], Loss: 3.088106677751057e-05
# Epoch [300/1000], Loss: 1.1305234011160792e-06
# Epoch [400/1000], Loss: 2.0149145996128937e-07
# Epoch [500/1000], Loss: 9.494502251072845e-08
# Epoch [600/1000], Loss: 5.966557381498205e-08
# Epoch [700/1000], Loss: 4.290076560664602e-08
# Epoch [800/1000], Loss: 3.3465212823102775e-08
# Epoch [900/1000], Loss: 2.763145445783266e-08
# Epoch [0/1000], Loss: 0.03022262267768383
# Epoch [100/1000], Loss: 0.0010722114238888025
# Epoch [200/1000], Loss: 3.105450014118105e-05
# Epoch [300/1000], Loss: 1.0806695627252338e-06
# Epoch [400/1000], Loss: 2.122191773423765e-07
# Epoch [500/1000], Loss: 1.18023400830225e-07
# Epoch [600/1000], Loss: 8.437982046416437e-08
# Epoch [700/1000], Loss: 6.705914046278849e-08
# Epoch [800/1000], Loss: 5.7004982068065146e-08
# Epoch [900/1000], Loss: 5.083052556642542e-08

# %%
epochs = 1000
lr = 0.001

ilc_degree = 6
ilc_config = params.make_gmp_params(
    Ka=ilc_degree,
    La=ilc_degree,
    Kb=ilc_degree,
    Lb=ilc_degree,
    Mb=ilc_degree,
    Kc=ilc_degree,
    Lc=ilc_degree,
    Mc=ilc_degree,
)

dpd_model_ilc = GMP(**ilc_config, model_name="dpd_ilc_grad")
is_load = dpd_model_ilc.load_weights()
optimizer = torch.optim.Adam(dpd_model_ilc.parameters(), lr=lr)

if not is_load:
    learning.train(net=dpd_model_ilc, 
                   criterion=criterion, 
                   optimizer=optimizer, 
                   train_loader=ilc_train_loader, 
                   val_loader=ilc_val_loader, 
                   grad_clip_val=0, 
                   n_epochs=epochs, 
                   metric_criterion=metric_criterion)
    dpd_model_ilc.save_weights()

casc_ilc_eval = utils.CascadeModel(model_1=dpd_model_ilc, model_2=pa_model, cascade_type="dla")
y_val_ilc = learning.net_inference(net=casc_ilc_eval, x=x_val)
nmse_ilc = metrics.compute_nmse(y_val_ilc, y_val_target)
print(f"Model NMSE: {nmse_ilc:.2f}")
# Out:
# No saved coefficients found at model_params/dpd_ilc_grad_gmp_model_Ka6_La6_Kb6_Lb6_Mb6_Kc6_Lc6_Mc6.pt, initializing new parameters.
# ===Start training===
# Epoch 00 — train_loss: 0.038153, val_loss: 0.032611, val_NMSE: -3.76
# Epoch 01 — train_loss: 0.031808, val_loss: 0.026950, val_NMSE: -4.59
# Epoch 02 — train_loss: 0.026294, val_loss: 0.022066, val_NMSE: -5.46
# Epoch 03 — train_loss: 0.021509, val_loss: 0.017961, val_NMSE: -6.35
# Epoch 04 — train_loss: 0.017519, val_loss: 0.014566, val_NMSE: -7.26
# Epoch 05 — train_loss: 0.014262, val_loss: 0.011910, val_NMSE: -8.14
# Epoch 06 — train_loss: 0.011737, val_loss: 0.009970, val_NMSE: -8.91
# Epoch 07 — train_loss: 0.009885, val_loss: 0.008625, val_NMSE: -9.54
# Epoch 08 — train_loss: 0.008574, val_loss: 0.007768, val_NMSE: -9.99
# Epoch 09 — train_loss: 0.007710, val_loss: 0.007315, val_NMSE: -10.26
# Epoch 10 — train_loss: 0.007228, val_loss: 0.007151, val_NMSE: -10.35
# Epoch 11 — train_loss: 0.007032, val_loss: 0.007123, val_NMSE: -10.37
# Epoch 12 — train_loss: 0.006987, val_loss: 0.007114, val_NMSE: -10.38
# Epoch 13 — train_loss: 0.006981, val_loss: 0.007076, val_NMSE: -10.40
# Epoch 14 — train_loss: 0.006961, val_loss: 0.006988, val_NMSE: -10.45
# Epoch 15 — train_loss: 0.006899, val_loss: 0.006828, val_NMSE: -10.55
# Epoch 16 — train_loss: 0.006766, val_loss: 0.006582, val_NMSE: -10.71
# Epoch 17 — train_loss: 0.006541, val_loss: 0.006251, val_NMSE: -10.94
# Epoch 18 — train_loss: 0.006220, val_loss: 0.005848, val_NMSE: -11.23
# Epoch 19 — train_loss: 0.005817, val_loss: 0.005392, val_NMSE: -11.58
# Epoch 20 — train_loss: 0.005352, val_loss: 0.004902, val_NMSE: -11.99
# Epoch 21 — train_loss: 0.004850, val_loss: 0.004403, val_NMSE: -12.46
# Epoch 22 — train_loss: 0.004342, val_loss: 0.003912, val_NMSE: -12.97
# Epoch 23 — train_loss: 0.003850, val_loss: 0.003442, val_NMSE: -13.53
# Epoch 24 — train_loss: 0.003386, val_loss: 0.003006, val_NMSE: -14.12
# Epoch 25 — train_loss: 0.002964, val_loss: 0.002627, val_NMSE: -14.70
# Epoch 26 — train_loss: 0.002601, val_loss: 0.002321, val_NMSE: -15.24
# Epoch 27 — train_loss: 0.002308, val_loss: 0.002086, val_NMSE: -15.71
# Epoch 28 — train_loss: 0.002081, val_loss: 0.001912, val_NMSE: -16.08
# Epoch 29 — train_loss: 0.001911, val_loss: 0.001791, val_NMSE: -16.37
# Epoch 30 — train_loss: 0.001789, val_loss: 0.001712, val_NMSE: -16.56
# Epoch 31 — train_loss: 0.001708, val_loss: 0.001663, val_NMSE: -16.69
# Epoch 32 — train_loss: 0.001656, val_loss: 0.001628, val_NMSE: -16.78
# Epoch 33 — train_loss: 0.001621, val_loss: 0.001598, val_NMSE: -16.86
# Epoch 34 — train_loss: 0.001592, val_loss: 0.001562, val_NMSE: -16.96
# Epoch 35 — train_loss: 0.001557, val_loss: 0.001514, val_NMSE: -17.10
# Epoch 36 — train_loss: 0.001512, val_loss: 0.001455, val_NMSE: -17.27
# Epoch 37 — train_loss: 0.001456, val_loss: 0.001387, val_NMSE: -17.48
# Epoch 38 — train_loss: 0.001389, val_loss: 0.001310, val_NMSE: -17.72
# Epoch 39 — train_loss: 0.001313, val_loss: 0.001227, val_NMSE: -18.01
# Epoch 40 — train_loss: 0.001229, val_loss: 0.001142, val_NMSE: -18.32
# Epoch 256 — train_loss: 0.000075, val_loss: 0.000078, val_NMSE: -29.97
# Epoch 257 — train_loss: 0.000074, val_loss: 0.000078, val_NMSE: -30.00
# Epoch 258 — train_loss: 0.000074, val_loss: 0.000077, val_NMSE: -30.02
# Epoch 259 — train_loss: 0.000073, val_loss: 0.000077, val_NMSE: -30.05
# Epoch 260 — train_loss: 0.000073, val_loss: 0.000076, val_NMSE: -30.07
# Epoch 261 — train_loss: 0.000072, val_loss: 0.000076, val_NMSE: -30.10
# Epoch 262 — train_loss: 0.000072, val_loss: 0.000075, val_NMSE: -30.12
# Epoch 263 — train_loss: 0.000072, val_loss: 0.000075, val_NMSE: -30.15
# Epoch 264 — train_loss: 0.000071, val_loss: 0.000075, val_NMSE: -30.17
# Epoch 265 — train_loss: 0.000071, val_loss: 0.000074, val_NMSE: -30.20
# Epoch 266 — train_loss: 0.000070, val_loss: 0.000074, val_NMSE: -30.22
# Epoch 267 — train_loss: 0.000070, val_loss: 0.000073, val_NMSE: -30.25
# Epoch 268 — train_loss: 0.000070, val_loss: 0.000073, val_NMSE: -30.27
# Epoch 269 — train_loss: 0.000069, val_loss: 0.000072, val_NMSE: -30.30
# Epoch 270 — train_loss: 0.000069, val_loss: 0.000072, val_NMSE: -30.32
# Epoch 271 — train_loss: 0.000068, val_loss: 0.000072, val_NMSE: -30.35
# Epoch 272 — train_loss: 0.000068, val_loss: 0.000071, val_NMSE: -30.37
# Epoch 273 — train_loss: 0.000068, val_loss: 0.000071, val_NMSE: -30.40
# Epoch 274 — train_loss: 0.000067, val_loss: 0.000070, val_NMSE: -30.42
# Epoch 275 — train_loss: 0.000067, val_loss: 0.000070, val_NMSE: -30.45
# Epoch 276 — train_loss: 0.000066, val_loss: 0.000070, val_NMSE: -30.47
# Epoch 277 — train_loss: 0.000066, val_loss: 0.000069, val_NMSE: -30.50
# Epoch 278 — train_loss: 0.000066, val_loss: 0.000069, val_NMSE: -30.52
# Epoch 279 — train_loss: 0.000065, val_loss: 0.000068, val_NMSE: -30.55
# Epoch 280 — train_loss: 0.000065, val_loss: 0.000068, val_NMSE: -30.57
# Epoch 281 — train_loss: 0.000064, val_loss: 0.000068, val_NMSE: -30.60
# Epoch 282 — train_loss: 0.000064, val_loss: 0.000067, val_NMSE: -30.62
# Epoch 283 — train_loss: 0.000064, val_loss: 0.000067, val_NMSE: -30.65
# Epoch 284 — train_loss: 0.000063, val_loss: 0.000066, val_NMSE: -30.67
# Epoch 285 — train_loss: 0.000063, val_loss: 0.000066, val_NMSE: -30.70
# Epoch 286 — train_loss: 0.000063, val_loss: 0.000066, val_NMSE: -30.72
# Epoch 287 — train_loss: 0.000062, val_loss: 0.000065, val_NMSE: -30.75
# Epoch 288 — train_loss: 0.000062, val_loss: 0.000065, val_NMSE: -30.77
# Epoch 289 — train_loss: 0.000062, val_loss: 0.000065, val_NMSE: -30.80
# Epoch 290 — train_loss: 0.000061, val_loss: 0.000064, val_NMSE: -30.82
# Epoch 291 — train_loss: 0.000061, val_loss: 0.000064, val_NMSE: -30.85
# Epoch 400 — train_loss: 0.000033, val_loss: 0.000035, val_NMSE: -33.48
# Epoch 401 — train_loss: 0.000033, val_loss: 0.000035, val_NMSE: -33.50
# Epoch 402 — train_loss: 0.000033, val_loss: 0.000034, val_NMSE: -33.53
# Epoch 403 — train_loss: 0.000032, val_loss: 0.000034, val_NMSE: -33.55
# Epoch 404 — train_loss: 0.000032, val_loss: 0.000034, val_NMSE: -33.57
# Epoch 405 — train_loss: 0.000032, val_loss: 0.000034, val_NMSE: -33.60
# Epoch 406 — train_loss: 0.000032, val_loss: 0.000034, val_NMSE: -33.62
# Epoch 407 — train_loss: 0.000032, val_loss: 0.000034, val_NMSE: -33.64
# Epoch 408 — train_loss: 0.000032, val_loss: 0.000033, val_NMSE: -33.67
# Epoch 409 — train_loss: 0.000031, val_loss: 0.000033, val_NMSE: -33.69
# Epoch 410 — train_loss: 0.000031, val_loss: 0.000033, val_NMSE: -33.71
# Epoch 411 — train_loss: 0.000031, val_loss: 0.000033, val_NMSE: -33.73
# Epoch 412 — train_loss: 0.000031, val_loss: 0.000033, val_NMSE: -33.76
# Epoch 413 — train_loss: 0.000031, val_loss: 0.000032, val_NMSE: -33.78
# Epoch 414 — train_loss: 0.000031, val_loss: 0.000032, val_NMSE: -33.80
# Epoch 415 — train_loss: 0.000030, val_loss: 0.000032, val_NMSE: -33.83
# Epoch 416 — train_loss: 0.000030, val_loss: 0.000032, val_NMSE: -33.85
# Epoch 417 — train_loss: 0.000030, val_loss: 0.000032, val_NMSE: -33.87
# Epoch 418 — train_loss: 0.000030, val_loss: 0.000032, val_NMSE: -33.89
# Epoch 419 — train_loss: 0.000030, val_loss: 0.000031, val_NMSE: -33.92
# Epoch 420 — train_loss: 0.000030, val_loss: 0.000031, val_NMSE: -33.94
# Epoch 421 — train_loss: 0.000030, val_loss: 0.000031, val_NMSE: -33.96
# Epoch 422 — train_loss: 0.000029, val_loss: 0.000031, val_NMSE: -33.98
# Epoch 423 — train_loss: 0.000029, val_loss: 0.000031, val_NMSE: -34.01
# Epoch 424 — train_loss: 0.000029, val_loss: 0.000031, val_NMSE: -34.03
# Epoch 425 — train_loss: 0.000029, val_loss: 0.000031, val_NMSE: -34.05
# Epoch 426 — train_loss: 0.000029, val_loss: 0.000030, val_NMSE: -34.07
# Epoch 427 — train_loss: 0.000029, val_loss: 0.000030, val_NMSE: -34.10
# Epoch 428 — train_loss: 0.000028, val_loss: 0.000030, val_NMSE: -34.12
# Epoch 429 — train_loss: 0.000028, val_loss: 0.000030, val_NMSE: -34.14
# Epoch 430 — train_loss: 0.000028, val_loss: 0.000030, val_NMSE: -34.16
# Epoch 431 — train_loss: 0.000028, val_loss: 0.000030, val_NMSE: -34.19
# Epoch 432 — train_loss: 0.000028, val_loss: 0.000029, val_NMSE: -34.21
# Epoch 433 — train_loss: 0.000028, val_loss: 0.000029, val_NMSE: -34.23
# Epoch 434 — train_loss: 0.000028, val_loss: 0.000029, val_NMSE: -34.25
# Epoch 435 — train_loss: 0.000027, val_loss: 0.000029, val_NMSE: -34.27
# Epoch 615 — train_loss: 0.000013, val_loss: 0.000013, val_NMSE: -37.64
# Epoch 616 — train_loss: 0.000012, val_loss: 0.000013, val_NMSE: -37.66
# Epoch 617 — train_loss: 0.000012, val_loss: 0.000013, val_NMSE: -37.67
# Epoch 618 — train_loss: 0.000012, val_loss: 0.000013, val_NMSE: -37.69
# Epoch 619 — train_loss: 0.000012, val_loss: 0.000013, val_NMSE: -37.70
# Epoch 620 — train_loss: 0.000012, val_loss: 0.000013, val_NMSE: -37.72
# Epoch 621 — train_loss: 0.000012, val_loss: 0.000013, val_NMSE: -37.73
# Epoch 622 — train_loss: 0.000012, val_loss: 0.000013, val_NMSE: -37.75
# Epoch 623 — train_loss: 0.000012, val_loss: 0.000013, val_NMSE: -37.76
# Epoch 624 — train_loss: 0.000012, val_loss: 0.000013, val_NMSE: -37.78
# Epoch 625 — train_loss: 0.000012, val_loss: 0.000013, val_NMSE: -37.79
# Epoch 626 — train_loss: 0.000012, val_loss: 0.000013, val_NMSE: -37.81
# Epoch 627 — train_loss: 0.000012, val_loss: 0.000013, val_NMSE: -37.82
# Epoch 628 — train_loss: 0.000012, val_loss: 0.000013, val_NMSE: -37.84
# Epoch 629 — train_loss: 0.000012, val_loss: 0.000013, val_NMSE: -37.85
# Epoch 630 — train_loss: 0.000012, val_loss: 0.000013, val_NMSE: -37.87
# Epoch 631 — train_loss: 0.000012, val_loss: 0.000013, val_NMSE: -37.88
# Epoch 632 — train_loss: 0.000012, val_loss: 0.000013, val_NMSE: -37.89
# Epoch 633 — train_loss: 0.000012, val_loss: 0.000013, val_NMSE: -37.91
# Epoch 634 — train_loss: 0.000012, val_loss: 0.000013, val_NMSE: -37.92
# Epoch 635 — train_loss: 0.000012, val_loss: 0.000012, val_NMSE: -37.94
# Epoch 636 — train_loss: 0.000012, val_loss: 0.000012, val_NMSE: -37.95
# Epoch 637 — train_loss: 0.000012, val_loss: 0.000012, val_NMSE: -37.97
# Epoch 638 — train_loss: 0.000012, val_loss: 0.000012, val_NMSE: -37.98
# Epoch 639 — train_loss: 0.000012, val_loss: 0.000012, val_NMSE: -38.00
# Epoch 640 — train_loss: 0.000011, val_loss: 0.000012, val_NMSE: -38.01
# Epoch 641 — train_loss: 0.000011, val_loss: 0.000012, val_NMSE: -38.02
# Epoch 642 — train_loss: 0.000011, val_loss: 0.000012, val_NMSE: -38.04
# Epoch 643 — train_loss: 0.000011, val_loss: 0.000012, val_NMSE: -38.05
# Epoch 644 — train_loss: 0.000011, val_loss: 0.000012, val_NMSE: -38.07
# Epoch 645 — train_loss: 0.000011, val_loss: 0.000012, val_NMSE: -38.08
# Epoch 646 — train_loss: 0.000011, val_loss: 0.000012, val_NMSE: -38.09
# Epoch 647 — train_loss: 0.000011, val_loss: 0.000012, val_NMSE: -38.11
# Epoch 648 — train_loss: 0.000011, val_loss: 0.000012, val_NMSE: -38.12
# Epoch 649 — train_loss: 0.000011, val_loss: 0.000012, val_NMSE: -38.14
# Epoch 650 — train_loss: 0.000011, val_loss: 0.000012, val_NMSE: -38.15
# Epoch 789 — train_loss: 0.000008, val_loss: 0.000008, val_NMSE: -39.77
# Epoch 790 — train_loss: 0.000008, val_loss: 0.000008, val_NMSE: -39.78
# Epoch 791 — train_loss: 0.000008, val_loss: 0.000008, val_NMSE: -39.79
# Epoch 792 — train_loss: 0.000008, val_loss: 0.000008, val_NMSE: -39.80
# Epoch 793 — train_loss: 0.000008, val_loss: 0.000008, val_NMSE: -39.81
# Epoch 794 — train_loss: 0.000007, val_loss: 0.000008, val_NMSE: -39.82
# Epoch 795 — train_loss: 0.000007, val_loss: 0.000008, val_NMSE: -39.83
# Epoch 796 — train_loss: 0.000007, val_loss: 0.000008, val_NMSE: -39.84
# Epoch 797 — train_loss: 0.000007, val_loss: 0.000008, val_NMSE: -39.85
# Epoch 798 — train_loss: 0.000007, val_loss: 0.000008, val_NMSE: -39.86
# Epoch 799 — train_loss: 0.000007, val_loss: 0.000008, val_NMSE: -39.87
# Epoch 800 — train_loss: 0.000007, val_loss: 0.000008, val_NMSE: -39.88
# Epoch 801 — train_loss: 0.000007, val_loss: 0.000008, val_NMSE: -39.89
# Epoch 802 — train_loss: 0.000007, val_loss: 0.000008, val_NMSE: -39.90
# Epoch 803 — train_loss: 0.000007, val_loss: 0.000008, val_NMSE: -39.91
# Epoch 804 — train_loss: 0.000007, val_loss: 0.000008, val_NMSE: -39.91
# Epoch 805 — train_loss: 0.000007, val_loss: 0.000008, val_NMSE: -39.92
# Epoch 806 — train_loss: 0.000007, val_loss: 0.000008, val_NMSE: -39.93
# Epoch 807 — train_loss: 0.000007, val_loss: 0.000008, val_NMSE: -39.94
# Epoch 808 — train_loss: 0.000007, val_loss: 0.000008, val_NMSE: -39.95
# Epoch 809 — train_loss: 0.000007, val_loss: 0.000008, val_NMSE: -39.96
# Epoch 810 — train_loss: 0.000007, val_loss: 0.000008, val_NMSE: -39.97
# Epoch 811 — train_loss: 0.000007, val_loss: 0.000008, val_NMSE: -39.98
# Epoch 812 — train_loss: 0.000007, val_loss: 0.000008, val_NMSE: -39.99
# Epoch 813 — train_loss: 0.000007, val_loss: 0.000008, val_NMSE: -40.00
# Epoch 814 — train_loss: 0.000007, val_loss: 0.000008, val_NMSE: -40.01
# Epoch 815 — train_loss: 0.000007, val_loss: 0.000008, val_NMSE: -40.02
# Epoch 816 — train_loss: 0.000007, val_loss: 0.000008, val_NMSE: -40.03
# Epoch 817 — train_loss: 0.000007, val_loss: 0.000008, val_NMSE: -40.04
# Epoch 818 — train_loss: 0.000007, val_loss: 0.000008, val_NMSE: -40.04
# Epoch 819 — train_loss: 0.000007, val_loss: 0.000008, val_NMSE: -40.05
# Epoch 820 — train_loss: 0.000007, val_loss: 0.000008, val_NMSE: -40.06
# Epoch 821 — train_loss: 0.000007, val_loss: 0.000008, val_NMSE: -40.07
# Epoch 822 — train_loss: 0.000007, val_loss: 0.000008, val_NMSE: -40.08
# Epoch 823 — train_loss: 0.000007, val_loss: 0.000008, val_NMSE: -40.09
# Epoch 824 — train_loss: 0.000007, val_loss: 0.000008, val_NMSE: -40.10
# Epoch 825 — train_loss: 0.000007, val_loss: 0.000008, val_NMSE: -40.11
# Epoch 826 — train_loss: 0.000007, val_loss: 0.000008, val_NMSE: -40.12
# Epoch 827 — train_loss: 0.000007, val_loss: 0.000008, val_NMSE: -40.13
# Epoch 828 — train_loss: 0.000007, val_loss: 0.000008, val_NMSE: -40.13
# Epoch 829 — train_loss: 0.000007, val_loss: 0.000008, val_NMSE: -40.14
# Epoch 830 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -40.15
# Epoch 831 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -40.16
# Epoch 832 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -40.17
# Epoch 833 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -40.18
# Epoch 834 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -40.19
# Epoch 835 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -40.20
# Epoch 836 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -40.21
# Epoch 837 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -40.21
# Epoch 838 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -40.22
# Epoch 839 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -40.23
# Epoch 840 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -40.24
# Epoch 841 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -40.25
# Epoch 842 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -40.26
# Epoch 843 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -40.27
# Epoch 844 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -40.27
# Epoch 845 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -40.28
# Epoch 846 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -40.29
# Epoch 847 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -40.30
# Epoch 848 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -40.31
# Epoch 849 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -40.32
# Epoch 850 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -40.33
# Epoch 851 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -40.33
# Epoch 852 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -40.34
# Epoch 853 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -40.35
# Epoch 854 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -40.36
# Epoch 855 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -40.37
# Epoch 856 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -40.38
# Epoch 857 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -40.38
# Epoch 858 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -40.39
# Epoch 859 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -40.40
# Epoch 860 — train_loss: 0.000006, val_loss: 0.000007, val_NMSE: -40.41
# Epoch 861 — train_loss: 0.000006, val_loss: 0.000007, val_NMSE: -40.42
# Epoch 862 — train_loss: 0.000006, val_loss: 0.000007, val_NMSE: -40.43
# Epoch 863 — train_loss: 0.000006, val_loss: 0.000007, val_NMSE: -40.43
# Epoch 864 — train_loss: 0.000006, val_loss: 0.000007, val_NMSE: -40.44
# Epoch 865 — train_loss: 0.000006, val_loss: 0.000007, val_NMSE: -40.45
# Epoch 866 — train_loss: 0.000006, val_loss: 0.000007, val_NMSE: -40.46
# Epoch 867 — train_loss: 0.000006, val_loss: 0.000007, val_NMSE: -40.47
# Epoch 868 — train_loss: 0.000006, val_loss: 0.000007, val_NMSE: -40.47
# Epoch 869 — train_loss: 0.000006, val_loss: 0.000007, val_NMSE: -40.48
# Epoch 870 — train_loss: 0.000006, val_loss: 0.000007, val_NMSE: -40.49
# Epoch 871 — train_loss: 0.000006, val_loss: 0.000007, val_NMSE: -40.50
# Epoch 872 — train_loss: 0.000006, val_loss: 0.000007, val_NMSE: -40.51
# Epoch 873 — train_loss: 0.000006, val_loss: 0.000007, val_NMSE: -40.51
# Epoch 874 — train_loss: 0.000006, val_loss: 0.000007, val_NMSE: -40.52
# Epoch 875 — train_loss: 0.000006, val_loss: 0.000007, val_NMSE: -40.53
# Epoch 876 — train_loss: 0.000006, val_loss: 0.000007, val_NMSE: -40.54
# Epoch 877 — train_loss: 0.000006, val_loss: 0.000007, val_NMSE: -40.55
# Epoch 878 — train_loss: 0.000006, val_loss: 0.000007, val_NMSE: -40.55
# Epoch 879 — train_loss: 0.000006, val_loss: 0.000007, val_NMSE: -40.56
# Epoch 880 — train_loss: 0.000006, val_loss: 0.000007, val_NMSE: -40.57
# Epoch 881 — train_loss: 0.000006, val_loss: 0.000007, val_NMSE: -40.58
# Epoch 882 — train_loss: 0.000006, val_loss: 0.000007, val_NMSE: -40.59
# Epoch 883 — train_loss: 0.000006, val_loss: 0.000007, val_NMSE: -40.59
# Epoch 884 — train_loss: 0.000006, val_loss: 0.000007, val_NMSE: -40.60
# Epoch 885 — train_loss: 0.000006, val_loss: 0.000007, val_NMSE: -40.61
# Epoch 886 — train_loss: 0.000006, val_loss: 0.000007, val_NMSE: -40.62
# Epoch 887 — train_loss: 0.000006, val_loss: 0.000007, val_NMSE: -40.63
# Epoch 888 — train_loss: 0.000006, val_loss: 0.000007, val_NMSE: -40.63
# Epoch 889 — train_loss: 0.000006, val_loss: 0.000007, val_NMSE: -40.64
# Epoch 890 — train_loss: 0.000006, val_loss: 0.000007, val_NMSE: -40.65
# Epoch 891 — train_loss: 0.000006, val_loss: 0.000007, val_NMSE: -40.66
# Epoch 892 — train_loss: 0.000006, val_loss: 0.000007, val_NMSE: -40.66
# Epoch 893 — train_loss: 0.000006, val_loss: 0.000007, val_NMSE: -40.67
# Epoch 894 — train_loss: 0.000006, val_loss: 0.000007, val_NMSE: -40.68
# Epoch 895 — train_loss: 0.000006, val_loss: 0.000007, val_NMSE: -40.69
# Epoch 896 — train_loss: 0.000006, val_loss: 0.000007, val_NMSE: -40.69
# Epoch 897 — train_loss: 0.000006, val_loss: 0.000007, val_NMSE: -40.70
# Epoch 898 — train_loss: 0.000006, val_loss: 0.000007, val_NMSE: -40
— train_loss: 0.000006, val_loss: 0.000007, val_NMSE: -40.75
# Epoch 947 — train_loss: 0.000006, val_loss: 0.000007, val_NMSE: -40.70
# Epoch 948 — train_loss: 0.000006, val_loss: 0.000006, val_NMSE: -40.93
# Epoch 949 — train_loss: 0.000006, val_loss: 0.000006, val_NMSE: -41.06
# Epoch 950 — train_loss: 0.000006, val_loss: 0.000006, val_NMSE: -40.89
# Epoch 951 — train_loss: 0.000006, val_loss: 0.000006, val_NMSE: -40.81
# Epoch 952 — train_loss: 0.000006, val_loss: 0.000006, val_NMSE: -41.03
# Epoch 953 — train_loss: 0.000006, val_loss: 0.000006, val_NMSE: -41.09
# Epoch 954 — train_loss: 0.000005, val_loss: 0.000006, val_NMSE: -40.95
# Epoch 955 — train_loss: 0.000006, val_loss: 0.000006, val_NMSE: -40.96
# Epoch 956 — train_loss: 0.000006, val_loss: 0.000006, val_NMSE: -41.07
# Epoch 957 — train_loss: 0.000005, val_loss: 0.000006, val_NMSE: -41.11
# Epoch 958 — train_loss: 0.000005, val_loss: 0.000006, val_NMSE: -41.04
# Epoch 959 — train_loss: 0.000006, val_loss: 0.000006, val_NMSE: -41.01
# Epoch 960 — train_loss: 0.000006, val_loss: 0.000006, val_NMSE: -41.12
# Epoch 961 — train_loss: 0.000005, val_loss: 0.000006, val_NMSE: -41.15
# Epoch 962 — train_loss: 0.000005, val_loss: 0.000006, val_NMSE: -41.08
# Epoch 963 — train_loss: 0.000005, val_loss: 0.000006, val_NMSE: -41.10
# Epoch 964 — train_loss: 0.000005, val_loss: 0.000006, val_NMSE: -41.15
# Epoch 965 — train_loss: 0.000005, val_loss: 0.000006, val_NMSE: -41.17
# Epoch 966 — train_loss: 0.000005, val_loss: 0.000006, val_NMSE: -41.15
# Epoch 967 — train_loss: 0.000005, val_loss: 0.000006, val_NMSE: -41.13
# Epoch 968 — train_loss: 0.000005, val_loss: 0.000006, val_NMSE: -41.19
# Epoch 969 — train_loss: 0.000005, val_loss: 0.000006, val_NMSE: -41.20
# Epoch 970 — train_loss: 0.000005, val_loss: 0.000006, val_NMSE: -41.18
# Epoch 971 — train_loss: 0.000005, val_loss: 0.000006, val_NMSE: -41.19
# Epoch 972 — train_loss: 0.000005, val_loss: 0.000006, val_NMSE: -41.20
# Epoch 973 — train_loss: 0.000005, val_loss: 0.000006, val_NMSE: -41.23
# Epoch 974 — train_loss: 0.000005, val_loss: 0.000006, val_NMSE: -41.22
# Epoch 975 — train_loss: 0.000005, val_loss: 0.000006, val_NMSE: -41.21
# Epoch 976 — train_loss: 0.000005, val_loss: 0.000006, val_NMSE: -41.24
# Epoch 977 — train_loss: 0.000005, val_loss: 0.000006, val_NMSE: -41.25
# Epoch 978 — train_loss: 0.000005, val_loss: 0.000006, val_NMSE: -41.25
# Epoch 979 — train_loss: 0.000005, val_loss: 0.000006, val_NMSE: -41.26
# Epoch 980 — train_loss: 0.000005, val_loss: 0.000006, val_NMSE: -41.26
# Epoch 981 — train_loss: 0.000005, val_loss: 0.000006, val_NMSE: -41.28
# Epoch 982 — train_loss: 0.000005, val_loss: 0.000006, val_NMSE: -41.28
# Epoch 983 — train_loss: 0.000005, val_loss: 0.000006, val_NMSE: -41.28
# Epoch 984 — train_loss: 0.000005, val_loss: 0.000006, val_NMSE: -41.29
# Epoch 985 — train_loss: 0.000005, val_loss: 0.000006, val_NMSE: -41.30
# Epoch 986 — train_loss: 0.000005, val_loss: 0.000006, val_NMSE: -41.31
# Epoch 987 — train_loss: 0.000005, val_loss: 0.000006, val_NMSE: -41.31
# Epoch 988 — train_loss: 0.000005, val_loss: 0.000006, val_NMSE: -41.31
# Epoch 989 — train_loss: 0.000005, val_loss: 0.000006, val_NMSE: -41.33
# Epoch 990 — train_loss: 0.000005, val_loss: 0.000006, val_NMSE: -41.33
# Epoch 991 — train_loss: 0.000005, val_loss: 0.000006, val_NMSE: -41.34
# Epoch 992 — train_loss: 0.000005, val_loss: 0.000006, val_NMSE: -41.34
# Epoch 993 — train_loss: 0.000005, val_loss: 0.000006, val_NMSE: -41.35
# Epoch 994 — train_loss: 0.000005, val_loss: 0.000006, val_NMSE: -41.36
# Epoch 995 — train_loss: 0.000005, val_loss: 0.000006, val_NMSE: -41.37
# Epoch 996 — train_loss: 0.000005, val_loss: 0.000006, val_NMSE: -41.37
# Epoch 997 — train_loss: 0.000005, val_loss: 0.000006, val_NMSE: -41.38
# Epoch 998 — train_loss: 0.000005, val_loss: 0.000006, val_NMSE: -41.38
# Epoch 999 — train_loss: 0.000005, val_loss: 0.000006, val_NMSE: -41.39
# ===Training complete===
# Coefficients saved to model_params/dpd_ilc_grad_gmp_model_Ka6_La6_Kb6_Lb6_Mb6_Kc6_Lc6_Mc6.pt
# Model NMSE: -42.33

# %% [markdown]
# Metrics

# %%
nmse_after_pa = metrics.compute_nmse(y_val_pa, y_val_target)

print(f"NMSE на выходе усилителя (без DPD): {nmse_after_pa:.2f} db")

print(f"NMSE на выходе усилителя (DLA DPD): {nmse_dla:.2f} db")

print(f"NMSE на выходе усилителя (ILA DPD): {nmse_ila:.2f} db")

print(f"NMSE на выходе усилителя (ILC DPD): {nmse_ilc:.2f} db")
# Out:
# NMSE на выходе усилителя (без DPD): -14.12 db
# NMSE на выходе усилителя (DLA DPD): -42.10 db
# NMSE на выходе усилителя (ILA DPD): -40.17 db
# NMSE на выходе усилителя (ILC DPD): -42.33 db

# %%
x_val_acpr = metrics.calculate_acpr(x_val, acpr_meter)
y_val_acpr = metrics.calculate_acpr(y_val, acpr_meter)
y_val_pa_acpr = metrics.calculate_acpr(y_val_pa, acpr_meter)
y_val_target_acpr = metrics.calculate_acpr(y_val_target, acpr_meter)

y_lin_dla_acpr = metrics.calculate_acpr(y_val_dla, acpr_meter)
y_lin_ila_acpr = metrics.calculate_acpr(y_val_ila, acpr_meter)
y_lin_ilc_acpr = metrics.calculate_acpr(y_val_ilc, acpr_meter)

print(f"x_val_acpr: {x_val_acpr}")
print(f"y_val_acpr: {y_val_acpr}")
print(f"y_val_pa_acpr: {y_val_pa_acpr}")
print(f"y_val_target_acpr: {y_val_target_acpr}")

print(f"lin_dla_acpr: {y_lin_dla_acpr}")
print(f"lin_ila_acpr: {y_lin_ila_acpr}")
print(f"lin_ilc_acpr: {y_lin_ilc_acpr}")
# Out:
# x_val_acpr: [-48.08083195 -48.40122574]
# y_val_acpr: [-40.60778184 -38.20237847]
# y_val_pa_acpr: [-43.92654548 -41.00424439]
# y_val_target_acpr: [-48.08083304 -48.40122404]
# lin_dla_acpr: [-49.40306527 -49.83722565]
# lin_ila_acpr: [-48.85954811 -47.86422928]
# lin_ilc_acpr: [-48.99611814 -48.34863677]

# %%
nmse_uk_pa = metrics.compute_nmse(u_k_pa, y_train_target)
print(f"NMSE на выходе усилителя (ILC): {nmse_uk_pa:.2f} db")

u_k_acpr = metrics.calculate_acpr(u_k_val, acpr_meter)
u_k_pa_acpr = metrics.calculate_acpr(u_k_pa, acpr_meter)

print(f"u_k_acpr: {u_k_acpr}")
print(f"u_k_pa_acpr: {u_k_pa_acpr}")
# Out:
# NMSE на выходе усилителя (ILC): -75.05 db
# u_k_acpr: [-40.28516205 -45.78635878]
# u_k_pa_acpr: [-50.92436621 -50.3568662 ]

# %% [markdown]
# Spectrum

# %%
freqs, spectrum_y_in = metrics.power_spectrum(x_val, fs, nperseg)
_, spectrum_y_out = metrics.power_spectrum(y_val, fs, nperseg)
_, spectrum_y_val_pa = metrics.power_spectrum(y_val_pa, fs, nperseg)
_, spectrum_y_val_target = metrics.power_spectrum(y_val_target, fs, nperseg)

# _, spectrum_y_dpd_dla = metrics.power_spectrum(y_dpd_dla, fs, nperseg)
# _, spectrum_y_dpd_ila = metrics.power_spectrum(y_dpd_ila, fs, nperseg)
# _, spectrum_y_dpd_ilc = metrics.power_spectrum(y_dpd_ilc, fs, nperseg)

_, spectrum_y_val_dla = metrics.power_spectrum(y_val_dla, fs, nperseg)
_, spectrum_y_val_ila = metrics.power_spectrum(y_val_ila, fs, nperseg)
_, spectrum_y_val_ilc = metrics.power_spectrum(y_val_ilc, fs, nperseg)


_, spectrum_u_k = metrics.power_spectrum(u_k_val, fs, nperseg)
_, spectrum_u_k_pa = metrics.power_spectrum(u_k_pa, fs, nperseg)
# Out:
# c:\Users\maximp\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\signal\_spectral_py.py:652: UserWarning: Input data is complex, switching to return_onesided=False
#   freqs, Pxx = csd(x, x, fs=fs, window=window, nperseg=nperseg,

# %%
# построение спектра

xlabel="Частота (МГц)"
ylabel= "Спектральная плотность мощности (дБ)"
fontsize = 12
figsize=(12, 6)

plt.figure(figsize=figsize)

plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_y_in)), color='grey', label='Входной сигнал')
plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_y_val_pa)), color='gold', label='Выходной сигнал')
plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_u_k_pa)), color='red', label='Оптимальный сигнал ILC')
plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_y_val_dla)), color='darkorange', label='Сигнал с предыскажением DLA')
plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_y_val_ila)), color='limegreen', label='Сигнал с предыскажением ILA')
plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_y_val_ilc)), color='lightcoral', label='Сигнал с предыскажением ILC')


plt.xlabel(xlabel, fontsize=fontsize)
plt.ylabel(ylabel, fontsize=fontsize)
plt.legend()
plt.grid()
plt.show()

# %%
# moving_average
window_size = 60

freqs_s, spectrum_y_in_s = utils.moving_average(spectrum_y_in, freqs, fs, window_size)
_, spectrum_y_out_s = utils.moving_average(spectrum_y_out, freqs, fs, window_size)
_, spectrum_y_val_pa_s = utils.moving_average(spectrum_y_val_pa, freqs, fs, window_size)
_, spectrum_y_val_target_s = utils.moving_average(spectrum_y_val_target, freqs, fs, window_size)

# _, spectrum_y_val_dla_s = utils.moving_average(spectrum_y_val_dla, freqs, fs, window_size)
# _, spectrum_y_val_ila_s = utils.moving_average(spectrum_y_val_ila, freqs, fs, window_size)
# _, spectrum_y_dpd_ilc_grad_s = utils.moving_average(spectrum_y_dpd_ilc_grad, freqs, fs, window_size)

_, spectrum_y_val_dla_s = utils.moving_average(spectrum_y_val_dla, freqs, fs, window_size)
_, spectrum_y_val_ila_s = utils.moving_average(spectrum_y_val_ila, freqs, fs, window_size)
_, spectrum_y_val_ilc_s = utils.moving_average(spectrum_y_val_ilc, freqs, fs, window_size)

_, spectrum_u_k_s = utils.moving_average(spectrum_u_k, freqs, fs, window_size)
_, spectrum_u_k_pa_s = utils.moving_average(spectrum_u_k_pa, freqs, fs, window_size)

# %%
# (сглаженный) построение спектра

xlabel="Частота, МГц"
ylabel= "Спектральная плотность мощности, дБВт/Гц"
fontsize = 12
figsize=(12, 8)
markersize=8

plt.figure(figsize=figsize)

# plt.plot(freqs_s / 1e6, 10 * np.log10(np.abs(spectrum_y_in_s)), 
#          color='grey', label='Входной сигнал',marker = '*', markevery=90, markersize=markersize)
plt.plot(freqs_s / 1e6, 10 * np.log10(np.abs(spectrum_y_val_target_s)), 
         color='black', label='Выходной сигнал\n(линейный усилитель)',marker = '*', markevery=90, markersize=markersize)
plt.plot(freqs_s / 1e6, 10 * np.log10(np.abs(spectrum_y_val_pa_s)), 
         color='gold', label='Выходной сигнал\n(реальный усилитель)', marker='o', markevery=90, markersize=markersize)
plt.plot(freqs_s / 1e6, 10 * np.log10(np.abs(spectrum_u_k_pa_s)), 
         color='red', label='Оптимальный сигнал ILC', marker='v', markevery=95, markersize=markersize)
plt.plot(freqs_s / 1e6, 10 * np.log10(np.abs(spectrum_y_val_dla_s)), 
         color='darkorange', label='Сигнал с предыскажением DLA', marker='D', markevery=90, markersize=markersize)
plt.plot(freqs_s / 1e6, 10 * np.log10(np.abs(spectrum_y_val_ila_s)), 
         color='limegreen', label='Сигнал с предыскажением ILA', marker='X', markevery=110, markersize=markersize)
plt.plot(freqs_s / 1e6, 10 * np.log10(np.abs(spectrum_y_val_ilc_s)), 
         color='lightcoral', label='Сигнал с предыскажением ILC', marker='s', markevery=120, markersize=markersize)

plt.xlabel(xlabel, fontsize=fontsize)
plt.ylabel(ylabel, fontsize=fontsize)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# AM/AM & AM/PM

# %%
y_in_am_am, y_out_am_am = metrics.calculate_am_am(x_val, y_val)
y_in_am_pm, y_in_phase_am_pm = metrics.calculate_am_pm(x_val, y_val)

_, y_pa_am_am = metrics.calculate_am_am(x_val, y_val_pa)
_, y_pa_phase_am_pm = metrics.calculate_am_pm(x_val, y_val_pa)

_, y_val_target_am_am = metrics.calculate_am_am(x_val, y_val_target)
_, y_val_target_phase_am_pm = metrics.calculate_am_pm(x_val, y_val_target)

# x_in_am_am, u_k_am_am = metrics.calculate_am_am(x_train, u_k)
# x_in_am_pm, u_k_phase_am_pm = metrics.calculate_am_pm(x_train, u_k)

# _, u_k_pa_am_am = metrics.calculate_am_am(x_train, u_k_pa)
# _, u_k_pa_phase_am_pm = metrics.calculate_am_pm(x_train, u_k_pa)

#linearized
_, y_val_dla_am_am = metrics.calculate_am_am(x_val, y_val_dla)
_, y_val_dla_phase_am_pm = metrics.calculate_am_pm(x_val, y_val_dla)

_, y_val_ila_am_am = metrics.calculate_am_am(x_val, y_val_ila)
_, y_val_ila_phase_am_pm = metrics.calculate_am_pm(x_val, y_val_ila)

_, y_val_ilc_am_am = metrics.calculate_am_am(x_val, y_val_ilc)
_, y_val_ilc_phase_am_pm = metrics.calculate_am_pm(x_val, y_val_ilc)

# %%
#DLA

am_am_data = [
    (y_in_am_am, y_pa_am_am, 'gold', 'Выходной сигнал'),
    # (y_in_am_am, y_val_dla_am_am, 'magenta', 'Сигнал на выходе DPD'),
    (y_in_am_am, y_val_dla_am_am, 'darkorange', 'Сигнал с предыскажением'),
]

am_pm_data = [
    (y_in_am_pm, y_pa_phase_am_pm, 'gold', 'Выходной сигнал'),
    (y_in_am_pm, y_val_dla_phase_am_pm, 'darkorange', 'Сигнал с предыскажением'),
]

plotting.plot_am_am_pm(
    am_am_data=am_am_data,
    am_pm_data=am_pm_data,
    figsize=(12, 6),
    titles=("AM/AM DLA", "AM/PM DLA"),
    xlabels=("Амплитуда на входе", "Амплитуда на входе"),
    ylabels=("Амплитуда на выходе", "Фазовый сдвиг на выходе (градусы)")
)

# %%
#ILA

am_am_data = [
    (y_in_am_am, y_pa_am_am, 'gold', 'Выходной сигнал'),
    # (y_in_am_am, y_val_ila_am_am, 'magenta', 'Сигнал на выходе DPD'),
    (y_in_am_am, y_val_ila_am_am, 'darkorange', 'Сигнал с предыскажением'),
]

am_pm_data = [
    (y_in_am_pm, y_pa_phase_am_pm, 'gold', 'Выходной сигнал'),
    (y_in_am_pm, y_val_ila_phase_am_pm, 'darkorange', 'Сигнал с предыскажением'),
]

plotting.plot_am_am_pm(
    am_am_data=am_am_data,
    am_pm_data=am_pm_data,
    figsize=(12, 6),
    titles=("AM/AM ILA", "AM/PM ILA"),
    xlabels=("Амплитуда на входе", "Амплитуда на входе"),
    ylabels=("Амплитуда на выходе", "Фазовый сдвиг на выходе (градусы)")
)

# %%
#ILC

am_am_data = [
    (y_in_am_am, y_pa_am_am, 'gold', 'Выходной сигнал'),
    # (y_in_am_am, y_dpd_ilc_grad_am_am, 'magenta', 'Сигнал на выходе корректора'),
    (y_in_am_am, y_val_ilc_am_am, 'darkorange', 'Сигнал с предыскажением'),
]

am_pm_data = [
    (y_in_am_pm, y_pa_phase_am_pm, 'gold', 'Выходной сигнал'),
    (y_in_am_pm, y_val_ilc_phase_am_pm, 'darkorange', 'Сигнал с предыскажением'),
]

plotting.plot_am_am_pm(
    am_am_data=am_am_data,
    am_pm_data=am_pm_data,
    figsize=(12, 6),
    titles=("AM/AM ILC", "AM/PM ILC"),
    xlabels=("Амплитуда на входе", "Амплитуда на входе"),
    ylabels=("Амплитуда на выходе", "Фазовый сдвиг на выходе (градусы)")
)

# %% [markdown]
# Add noise

# %%
snr_range = list(range(20, 61, 10))

epochs = 500
lr = 0.01
num_realizations = 200

snr_params = params.make_snr_params(
    snr_range=snr_range,
    num_realizations=num_realizations,
    fs=fs,
    bw_main_ch=bw_sub_ch,
    epochs=epochs,
    learning_rate=lr,
    acpr_meter=acpr_meter,
    pa_model=pa_model,
    gain=gain
)

gmp_degree = 5
gmp_config = params.make_gmp_params(
    Ka=gmp_degree,
    La=gmp_degree,
    Kb=gmp_degree,
    Lb=gmp_degree,
    Mb=gmp_degree,
    Kc=gmp_degree,
    Lc=gmp_degree,
    Mc=gmp_degree
)

snr_metrics_runner = pipelines.SnrPipeline(base_model=GMP, model_params=gmp_config, data_dict=data, snr_params=snr_params)

# %%
snr_metrics_runner.run(arch_name="DLA")
# Out:
# SNR: 20
# ===Start training===
# Epoch 0000 — train_loss: 0.381655, val_loss: 0.751708, val_NMSE: -0.16
# Epoch 0100 — train_loss: 0.109376, val_loss: 0.112445, val_NMSE: -8.41
# Epoch 0200 — train_loss: 0.108286, val_loss: 0.113450, val_NMSE: -8.37
# Epoch 0300 — train_loss: 0.108824, val_loss: 0.110884, val_NMSE: -8.47
# Epoch 0400 — train_loss: 0.110026, val_loss: 0.113678, val_NMSE: -8.36

# %%
snr_metrics_runner.run(arch_name="ILA")

# %%
snr_metrics_runner.run(arch_name="ILC")

# %%
results = snr_metrics_runner.get_results()

snr_range = results["snr_range"]

nmse_dla_list = results["dla"]["nmse"]
acpr_left_dla_list = results["dla"]["acpr_left"]
acpr_right_dla_list = results["dla"]["acpr_right"]

nmse_ila_list = results["ila"]["nmse"]
acpr_left_ila_list = results["ila"]["acpr_left"]
acpr_right_ila_list = results["ila"]["acpr_right"]

nmse_ilc_list = results["ilc"]["nmse"]
acpr_left_ilc_list = results["ilc"]["acpr_left"]
acpr_right_ilc_list = results["ilc"]["acpr_right"]

nmse_uk_list = results["uk"]["nmse"]
acpr_left_uk_list = results["uk"]["acpr_left"]
acpr_right_uk_list = results["uk"]["acpr_right"]

# %%
print(f"snr_range = {snr_range}")
print()

print(f"nmse_dla_list = {(nmse_dla_list)}")
print(f"acpr_left_dla_list = {acpr_left_dla_list}")
print(f"acpr_right_dla_list = {acpr_right_dla_list}")
print()

print(f"nmse_ila_list = {nmse_ila_list}")
print(f"acpr_left_ila_list = {acpr_left_ila_list}")
print(f"acpr_right_ila_list = {acpr_right_ila_list}")
print()

print(f"nmse_ilc_list = {nmse_ilc_list}")
print(f"acpr_left_ilc_list = {acpr_left_ilc_list}")
print(f"acpr_right_ilc_list = {acpr_right_ilc_list}")
print()

print(f"nmse_uk_list = {nmse_uk_list}")
print(f"acpr_left_uk_list = {acpr_left_uk_list}")
print(f"acpr_right_uk_list = {acpr_right_uk_list}")
# Out:
# snr_range = [20, 22, 24, 26, 28, 30, 32, 34, 36, 38, 40, 42, 44, 46, 48, 50, 52, 54, 56, 58, 
acpr_right_uk_list = [np.float64(-19.908159326520842), np.float64(-21.85695263610488), np.float64(-23.818630432812846), np.float64(-25.74280605561588), np.float64(-27.685123164021324), np.float64(-29.597578780431057), np.float64(-31.50956145186845), np.float64(-33.408043631235536), np.float64(-35.2641539488935), np.float64(-37.11290256809776), np.float64(-38.87993901305795), np.float64(-40.61697803065708), np.float64(-42.25138725427255), np.float64(-43.7730148204967), np.float64(-45.139205723386205), np.float64(-46.40286494928455), np.float64(-47.41226707888618), np.float64(-48.2239296586826), np.float64(-48.8718445889375), np.float64(-49.305717773680755), np.float64(-49.67857146555004)]

# %%
markersize = 8
plt.figure(figsize=(9, 5))
plt.plot(snr_range, nmse_dla_list,color='blue', linestyle='-', label="Сигнал с предыскажением DLA",
         marker='o', markersize=markersize)
plt.plot(snr_range, nmse_ila_list, color='orange', linestyle='--', label="Сигнал с предыскажением ILA",
         marker='s', markersize=markersize)
plt.plot(snr_range, nmse_ilc_list, color='green', linestyle='-.', label="Сигнал с предыскажением ILC",
         marker='d', markersize=markersize)
plt.plot(snr_range, nmse_uk_list, color='red', linestyle='-.', label="Оптимальный сигнал ILC",
         marker='*', markersize=markersize)

plt.xlabel("ОСШ, дБ", fontsize=12)
plt.ylabel("NMSE, дБ", fontsize=12)
# plt.title("Зависимость NMSE от ОСШ")
plt.xticks(range(20, 61, 5))
plt.yticks(range(-55, -9, 5))
plt.legend()
plt.grid(True)

plt.show()

# %%
markersize=8
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(snr_range, acpr_left_dla_list, color='blue', linestyle='-', label="Сигнал с предыскажением DLA", 
         marker='o', markersize=markersize)
plt.plot(snr_range, acpr_left_ila_list, color='orange', linestyle='--', label="Сигнал с предыскажением ILA", 
         marker='s', markersize=markersize)
plt.plot(snr_range, acpr_left_ilc_list, color='green', linestyle='-.', label="Сигнал с предыскажением ILC", 
         marker='d', markersize=markersize)
plt.plot(snr_range, acpr_left_uk_list, color='red', linestyle='-.', label="Оптимальный сигнал ILC", 
         marker='*', markersize=markersize)
plt.title('Левый канал', fontsize=12)
plt.xlabel('ОСШ, дБ', fontsize=12)
plt.ylabel('ACPR, дБ', fontsize=12)
plt.xticks(range(20, 61, 5))
plt.yticks(range(-55, -14, 5))
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(snr_range, acpr_right_dla_list, color='blue', linestyle='-', label="Сигнал с предыскажением DLA", 
         marker='o', markersize=markersize)
plt.plot(snr_range, acpr_right_ila_list, color='orange', linestyle='--', label="Сигнал с предыскажением ILA", 
         marker='s', markersize=markersize)
plt.plot(snr_range, acpr_right_ilc_list, color='green', linestyle='-.', label="Сигнал с предыскажением ILC", 
         marker='d', markersize=markersize)
plt.plot(snr_range, acpr_right_uk_list, color='red', linestyle='-.', label="Оптимальный сигнал ILC", 
         marker='*', markersize=markersize)
plt.title('Правый канал', fontsize=12)
plt.xlabel('ОСШ, дБ', fontsize=12)
plt.ylabel('ACPR, дБ', fontsize=12)
plt.xticks(range(20, 61, 5))
plt.yticks(range(-55, -14, 5))
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
