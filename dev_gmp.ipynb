# %%
# %load_ext autoreload
# %autoreload 2

# %%
from modules import data_loader, metrics, learning, plotting, utils, params, pipelines
from modules.gmp_model import GMP
import matplotlib.pyplot as plt
import numpy as np
import torch

# %% [markdown]
# Load data from files and init acpr meter

# %%
data = data_loader.load_data("DPA_200MHz")

config = data["config"]
fs = config["input_signal_fs"]
bw_main_ch = config["bw_main_ch"]
bw_sub_ch = config["bw_sub_ch"]
n_sub_ch = config["n_sub_ch"]
sub_ch = config["sub_ch"]
nperseg = config["nperseg"]

x_train = data["train_input"]
y_train = data["train_output"]
x_val = data["val_input"]
y_val = data["val_output"]

gain = metrics.calculate_gain_complex(x_train, y_train)
print(f"Gain of PA = {gain:.2f}")
y_train_target = gain * x_train
y_val_target = gain * x_val

data['y_train_target'] = y_train_target
data['y_val_target'] = y_val_target


acpr_meter = metrics.ACPR(
        sample_rate=fs,
        main_measurement_bandwidth=bw_main_ch,
        adjacent_channel_offset=[-sub_ch, sub_ch],
        segment_length=nperseg,
        overlap_percentage=60,
        window='blackmanharris',
        fft_length=nperseg,
        power_units='dBW',
        return_main_power=True,
        return_adjacent_powers=True
    )
# Out:
# Gain of PA = 2.52

# %% [markdown]
# PA model

# %%
pa_train_loader = [(x_train, y_train)]
# pa_val_loader = [(x_val, y_val)]
pa_val_loader = pa_train_loader

criterion = metrics.compute_mse
metric_criterion = metrics.compute_nmse

pa_degree = 2
pa_config = params.make_gmp_params(
    Ka=pa_degree,
    La=pa_degree,
    Kb=pa_degree,
    Lb=pa_degree,
    Mb=pa_degree,
    Kc=pa_degree,
    Lc=pa_degree,
    Mc=pa_degree,
)

pa_model = GMP(**pa_config, model_name="pa")

epochs = 10000
lr = 0.001

optimizer = torch.optim.Adam(pa_model.parameters(), lr=lr)

if not pa_model.load_weights():
      learning.train(net=pa_model, 
            criterion=criterion, 
            optimizer=optimizer, 
            train_loader=pa_train_loader, 
            val_loader=pa_val_loader, 
            n_epochs=epochs, 
            metric_criterion=metric_criterion)
      pa_model.save_weights()
utils.freeze_pa_model(pa_model)

y_val_pa = learning.net_inference(net=pa_model, x=x_val)
pa_nmse = metrics.compute_nmse(y_val_pa, y_val)
print(f"Model NMSE: {pa_nmse:.2f}")
# Out:
# Coefficients loaded from model_params/pa_gmp_model_Ka2_La2_Kb2_Lb2_Mb2_Kc2_Lc2_Mc2.pt
# Model NMSE: -29.95

# %%
pa_model.count_params()
# Out:
# 20

# %%
with torch.autograd.profiler.profile(use_cuda=False) as prof:
    with torch.no_grad():
        output = pa_model(x_val)

print(prof.key_averages().table(sort_by="cpu_time_total", row_limit=20))
# Out:
# -----------------------  ------------  ------------  ------------  ------------  ------------  ------------
#                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg    # of Calls
# -----------------------  ------------  ------------  ------------  ------------  ------------  ------------
#               aten::abs        13.28%     548.200us        31.49%       1.301ms     216.750us             6
#               aten::pow        28.93%       1.195ms        29.62%       1.223ms     407.667us             3
#               aten::mul        22.50%     929.000us        22.50%     929.000us     309.667us             3
#            aten::einsum         1.54%      63.400us        12.11%     500.000us     166.667us             3
#             aten::copy_        10.27%     424.100us        10.27%     424.100us      35.342us            12
#           aten::reshape         0.66%      27.200us         7.11%     293.500us      24.458us            12
#             aten::index         6.02%     248.400us         6.45%     266.400us      44.400us             6
#             aten::clone         0.28%      11.500us         5.95%     245.800us      81.933us             3
#                aten::to         0.26%      10.900us         4.19%     173.000us      15.727us            11
#          aten::_to_copy         0.51%      21.100us         3.93%     162.100us      27.017us             6
#               aten::sub         3.57%     147.400us         3.57%     147.400us      24.567us             6
#               aten::bmm         2.41%      99.400us         2.45%     101.100us      33.700us             3
#             aten::clamp         1.96%      81.000us         2.01%      82.800us      16.560us             5
#         aten::unsqueeze         1.47%      60.800us         1.85%      76.400us       4.775us            16
#            aten::arange         0.61%      25.300us         1.56%      64.400us      32.200us             2
#               aten::add         1.51%      62.200us         1.51%      62.200us      20.733us             3
#           aten::permute         0.83%      34.200us         1.04%      42.800us       2.853us            15
#              aten::real         0.29%      11.800us         0.77%      31.700us      10.567us             3
#        aten::as_strided         0.75%      31.000us         0.75%      31.000us       0.775us            40
#        aten::empty_like         0.33%      13.500us         0.62%      25.800us       4.300us             6
# -----------------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 4.129ms

# %%
freqs, spectrum_y_in = metrics.power_spectrum(x_val, fs, nperseg)
_, spectrum_y_out = metrics.power_spectrum(y_val, fs, nperseg)
_, spectrum_y_val_pa = metrics.power_spectrum(y_val_pa, fs, nperseg)

xlabel="Частота (МГц)"
ylabel= "Спектральная плотность мощности (дБ)"
fontsize = 12
figsize=(12, 6)

plt.figure(figsize=figsize)

plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_y_in)), color='grey', label='Входной сигнал')
plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_y_out)), color='black', label='Выходной сигнал')
plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_y_val_pa)), color='gold', label='Выходной сигнал PA')

plt.xlabel(xlabel, fontsize=fontsize)
plt.ylabel(ylabel, fontsize=fontsize)
plt.legend()
plt.grid()
plt.show()
# Out:
# c:\Users\maximp\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\signal\_spectral_py.py:652: UserWarning: Input data is complex, switching to return_onesided=False
#   freqs, Pxx = csd(x, x, fs=fs, window=window, nperseg=nperseg,

# %% [markdown]
# DLA DPD grad

# %%
dla_train_loader = [(x_train, y_train_target)]
# dla_val_loader = [(x_val, y_val_target)]
dla_val_loader = dla_train_loader

epochs = 1000
lr = 0.001

dla_degree = 2
dla_config = params.make_gmp_params(
    Ka=dla_degree,
    La=dla_degree,
    Kb=dla_degree,
    Lb=dla_degree,
    Mb=dla_degree,
    Kc=dla_degree,
    Lc=dla_degree,
    Mc=dla_degree,
)
dpd_model_dla = GMP(**dla_config, model_name="dla")
is_load = dpd_model_dla.load_weights()
casc_dla = utils.CascadeModel(model_1=dpd_model_dla, model_2=pa_model)

optimizer_dla = torch.optim.Adam(casc_dla.parameters(), lr=lr)

if not is_load:
    learning.train(net=casc_dla, 
                   criterion=criterion, 
                   optimizer=optimizer_dla, 
                   train_loader=dla_train_loader, 
                   val_loader=dla_val_loader, 
                   grad_clip_val=0, 
                   n_epochs=epochs, 
                   metric_criterion=metric_criterion)
    dpd_model_dla.save_weights()

y_val_dla = learning.net_inference(net=casc_dla, x=x_val)
nmse_dla = metrics.compute_nmse(y_val_dla, y_val_target)
print(f"Model NMSE: {nmse_dla:.2f}")
# Out:
# No saved coefficients found at model_params/dla_gmp_model_Ka2_La2_Kb2_Lb2_Mb2_Kc2_Lc2_Mc2.pt, initializing new parameters.
# ===Start training===
# Epoch 0000 — train_loss: 0.382076, val_loss: 0.367087, val_NMSE: -3.17
# Epoch 0001 — train_loss: 0.367087, val_loss: 0.352770, val_NMSE: -3.34
# Epoch 0002 — train_loss: 0.352770, val_loss: 0.339091, val_NMSE: -3.52
# Epoch 0003 — train_loss: 0.339091, val_loss: 0.325961, val_NMSE: -3.69
# Epoch 0004 — train_loss: 0.325961, val_loss: 0.313247, val_NMSE: -3.86
# Epoch 0005 — train_loss: 0.313247, val_loss: 0.300846, val_NMSE: -4.04
# Epoch 0006 — train_loss: 0.300846, val_loss: 0.288721, val_NMSE: -4.22
# Epoch 0007 — train_loss: 0.288721, val_loss: 0.276878, val_NMSE: -4.40
# Epoch 0008 — train_loss: 0.276878, val_loss: 0.265343, val_NMSE: -4.58
# Epoch 0009 — train_loss: 0.265343, val_loss: 0.254145, val_NMSE: -4.77
# Epoch 0010 — train_loss: 0.254145, val_loss: 0.243311, val_NMSE: -4.96
# Epoch 0011 — train_loss: 0.243311, val_loss: 0.232853, val_NMSE: -5.15
# Epoch 0012 — train_loss: 0.232853, val_loss: 0.222774, val_NMSE: -5.34
# Epoch 0013 — train_loss: 0.222774, val_loss: 0.213064, val_NMSE: -5.53
# Epoch 0014 — train_loss: 0.213064, val_loss: 0.203707, val_NMSE: -5.73
# Epoch 0015 — train_loss: 0.203707, val_loss: 0.194684, val_NMSE: -5.93
# Epoch 0016 — train_loss: 0.194684, val_loss: 0.185978, val_NMSE: -6.13
# Epoch 0017 — train_loss: 0.185978, val_loss: 0.177580, val_NMSE: -6.33
# Epoch 0018 — train_loss: 0.177580, val_loss: 0.169487, val_NMSE: -6.53
# Epoch 0019 — train_loss: 0.169487, val_loss: 0.161700, val_NMSE: -6.73
# Epoch 0020 — train_loss: 0.161700, val_loss: 0.154222, val_NMSE: -6.94
# Epoch 0021 — train_loss: 0.154222, val_loss: 0.147053, val_NMSE: -7.15
# Epoch 0022 — train_loss: 0.147053, val_loss: 0.140191, val_NMSE: -7.35
# Epoch 0023 — train_loss: 0.140191, val_loss: 0.133628, val_NMSE: -7.56
# Epoch 0024 — train_loss: 0.133628, val_loss: 0.127354, val_NMSE: -7.77
# Epoch 0025 — train_loss: 0.127354, val_loss: 0.121355, val_NMSE: -7.98
# Epoch 0026 — train_loss: 0.121355, val_loss: 0.115621, val_NMSE: -8.19
# Epoch 0027 — train_loss: 0.115621, val_loss: 0.110140, val_NMSE: -8.40
# Epoch 0028 — train_loss: 0.110140, val_loss: 0.104905, val_NMSE: -8.61
# Epoch 0029 — train_loss: 0.104905, val_loss: 0.099910, val_NMSE: -8.82
# Epoch 0030 — train_loss: 0.099910, val_loss: 0.095151, val_NMSE: -9.04
# Epoch 0031 — train_loss: 0.095151, val_loss: 0.090623, val_NMSE: -9.25
# Epoch 0137 — train_loss: 0.014547, val_loss: 0.014474, val_NMSE: -17.21
# Epoch 0138 — train_loss: 0.014474, val_loss: 0.014401, val_NMSE: -17.24
# Epoch 0139 — train_loss: 0.014401, val_loss: 0.014328, val_NMSE: -17.26
# Epoch 0140 — train_loss: 0.014328, val_loss: 0.014256, val_NMSE: -17.28
# Epoch 0141 — train_loss: 0.014256, val_loss: 0.014183, val_NMSE: -17.30
# Epoch 0142 — train_loss: 0.014183, val_loss: 0.014111, val_NMSE: -17.32
# Epoch 0143 — train_loss: 0.014111, val_loss: 0.014039, val_NMSE: -17.35
# Epoch 0144 — train_loss: 0.014039, val_loss: 0.013967, val_NMSE: -17.37
# Epoch 0145 — train_loss: 0.013967, val_loss: 0.013895, val_NMSE: -17.39
# Epoch 0146 — train_loss: 0.013895, val_loss: 0.013823, val_NMSE: -17.41
# Epoch 0147 — train_loss: 0.013823, val_loss: 0.013751, val_NMSE: -17.44
# Epoch 0148 — train_loss: 0.013751, val_loss: 0.013680, val_NMSE: -17.46
# Epoch 0149 — train_loss: 0.013680, val_loss: 0.013608, val_NMSE: -17.48
# Epoch 0150 — train_loss: 0.013608, val_loss: 0.013537, val_NMSE: -17.50
# Epoch 0151 — train_loss: 0.013537, val_loss: 0.013466, val_NMSE: -17.53
# Epoch 0152 — train_loss: 0.013466, val_loss: 0.013395, val_NMSE: -17.55
# Epoch 0153 — train_loss: 0.013395, val_loss: 0.013324, val_NMSE: -17.57
# Epoch 0154 — train_loss: 0.013324, val_loss: 0.013254, val_NMSE: -17.60
# Epoch 0155 — train_loss: 0.013254, val_loss: 0.013183, val_NMSE: -17.62
# Epoch 0156 — train_loss: 0.013183, val_loss: 0.013113, val_NMSE: -17.64
# Epoch 0157 — train_loss: 0.013113, val_loss: 0.013043, val_NMSE: -17.67
# Epoch 0158 — train_loss: 0.013043, val_loss: 0.012973, val_NMSE: -17.69
# Epoch 0159 — train_loss: 0.012973, val_loss: 0.012904, val_NMSE: -17.71
# Epoch 0160 — train_loss: 0.012904, val_loss: 0.012834, val_NMSE: -17.74
# Epoch 0161 — train_loss: 0.012834, val_loss: 0.012765, val_NMSE: -17.76
# Epoch 0162 — train_loss: 0.012765, val_loss: 0.012695, val_NMSE: -17.78
# Epoch 0163 — train_loss: 0.012695, val_loss: 0.012626, val_NMSE: -17.81
# Epoch 0164 — train_loss: 0.012626, val_loss: 0.012558, val_NMSE: -17.83
# Epoch 0165 — train_loss: 0.012558, val_loss: 0.012489, val_NMSE: -17.85
# Epoch 0166 — train_loss: 0.012489, val_loss: 0.012420, val_NMSE: -17.88
# Epoch 0167 — train_loss: 0.012420, val_loss: 0.012352, val_NMSE: -17.90
# Epoch 0168 — train_loss: 0.012352, val_loss: 0.012284, val_NMSE: -17.93
# Epoch 0169 — train_loss: 0.012284, val_loss: 0.012216, val_NMSE: -17.95
# Epoch 0170 — train_loss: 0.012216, val_loss: 0.012149, val_NMSE: -17.97
# Epoch 0171 — train_loss: 0.012149, val_loss: 0.012081, val_NMSE: -18.00
# Epoch 0417 — train_loss: 0.002419, val_loss: 0.002403, val_NMSE: -25.01
# Epoch 0418 — train_loss: 0.002403, val_loss: 0.002387, val_NMSE: -25.04
# Epoch 0419 — train_loss: 0.002387, val_loss: 0.002371, val_NMSE: -25.07
# Epoch 0420 — train_loss: 0.002371, val_loss: 0.002355, val_NMSE: -25.10
# Epoch 0421 — train_loss: 0.002355, val_loss: 0.002340, val_NMSE: -25.13
# Epoch 0422 — train_loss: 0.002340, val_loss: 0.002324, val_NMSE: -25.16
# Epoch 0423 — train_loss: 0.002324, val_loss: 0.002309, val_NMSE: -25.19
# Epoch 0424 — train_loss: 0.002309, val_loss: 0.002294, val_NMSE: -25.21
# Epoch 0425 — train_loss: 0.002294, val_loss: 0.002279, val_NMSE: -25.24
# Epoch 0426 — train_loss: 0.002279, val_loss: 0.002264, val_NMSE: -25.27
# Epoch 0427 — train_loss: 0.002264, val_loss: 0.002249, val_NMSE: -25.30
# Epoch 0428 — train_loss: 0.002249, val_loss: 0.002234, val_NMSE: -25.33
# Epoch 0429 — train_loss: 0.002234, val_loss: 0.002220, val_NMSE: -25.36
# Epoch 0430 — train_loss: 0.002220, val_loss: 0.002205, val_NMSE: -25.39
# Epoch 0431 — train_loss: 0.002205, val_loss: 0.002191, val_NMSE: -25.41
# Epoch 0432 — train_loss: 0.002191, val_loss: 0.002177, val_NMSE: -25.44
# Epoch 0433 — train_loss: 0.002177, val_loss: 0.002163, val_NMSE: -25.47
# Epoch 0434 — train_loss: 0.002163, val_loss: 0.002149, val_NMSE: -25.50
# Epoch 0435 — train_loss: 0.002149, val_loss: 0.002135, val_NMSE: -25.53
# Epoch 0436 — train_loss: 0.002135, val_loss: 0.002121, val_NMSE: -25.55
# Epoch 0437 — train_loss: 0.002121, val_loss: 0.002107, val_NMSE: -25.58
# Epoch 0438 — train_loss: 0.002107, val_loss: 0.002094, val_NMSE: -25.61
# Epoch 0439 — train_loss: 0.002094, val_loss: 0.002080, val_NMSE: -25.64
# Epoch 0440 — train_loss: 0.002080, val_loss: 0.002067, val_NMSE: -25.67
# Epoch 0441 — train_loss: 0.002067, val_loss: 0.002053, val_NMSE: -25.70
# Epoch 0442 — train_loss: 0.002053, val_loss: 0.002040, val_NMSE: -25.72
# Epoch 0443 — train_loss: 0.002040, val_loss: 0.002027, val_NMSE: -25.75
# Epoch 0444 — train_loss: 0.002027, val_loss: 0.002014, val_NMSE: -25.78
# Epoch 0445 — train_loss: 0.002014, val_loss: 0.002001, val_NMSE: -25.81
# Epoch 0446 — train_loss: 0.002001, val_loss: 0.001989, val_NMSE: -25.83
# Epoch 0447 — train_loss: 0.001989, val_loss: 0.001976, val_NMSE: -25.86
# Epoch 0448 — train_loss: 0.001976, val_loss: 0.001963, val_NMSE: -25.89
# Epoch 0449 — train_loss: 0.001963, val_loss: 0.001951, val_NMSE: -25.92
# Epoch 0450 — train_loss: 0.001951, val_loss: 0.001939, val_NMSE: -25.94
# Epoch 0451 — train_loss: 0.001939, val_loss: 0.001926, val_NMSE: -25.97
# Epoch 0986 — train_loss: 0.000299, val_loss: 0.000298, val_NMSE: -34.07
# Epoch 0987 — train_loss: 0.000298, val_loss: 0.000298, val_NMSE: -34.08
# Epoch 0988 — train_loss: 0.000298, val_loss: 0.000297, val_NMSE: -34.09
# Epoch 0989 — train_loss: 0.000297, val_loss: 0.000297, val_NMSE: -34.10
# Epoch 0990 — train_loss: 0.000297, val_loss: 0.000296, val_NMSE: -34.11
# Epoch 0991 — train_loss: 0.000296, val_loss: 0.000295, val_NMSE: -34.11
# Epoch 0992 — train_loss: 0.000295, val_loss: 0.000295, val_NMSE: -34.12
# Epoch 0993 — train_loss: 0.000295, val_loss: 0.000294, val_NMSE: -34.13
# Epoch 0994 — train_loss: 0.000294, val_loss: 0.000294, val_NMSE: -34.14
# Epoch 0995 — train_loss: 0.000294, val_loss: 0.000293, val_NMSE: -34.15
# Epoch 0996 — train_loss: 0.000293, val_loss: 0.000293, val_NMSE: -34.16
# Epoch 0997 — train_loss: 0.000293, val_loss: 0.000292, val_NMSE: -34.17
# Epoch 0998 — train_loss: 0.000292, val_loss: 0.000291, val_NMSE: -34.17
# Epoch 0999 — train_loss: 0.000291, val_loss: 0.000291, val_NMSE: -34.18
# Время обучения: 0:00:44
# ===Training complete===
# Coefficients saved to model_params/dla_gmp_model_Ka2_La2_Kb2_Lb2_Mb2_Kc2_Lc2_Mc2.pt
# Model NMSE: -34.30

# %% [markdown]
# ILA DPD grad

# %%
ila_train_loader = [(x_train, x_train)]
ila_val_loader = [(x_val, x_val)]

epochs = 1000
lr = 0.001

ila_degree = 5
ila_config = params.make_gmp_params(
    Ka=ila_degree,
    La=ila_degree,
    Kb=ila_degree,
    Lb=ila_degree,
    Mb=ila_degree,
    Kc=ila_degree,
    Lc=ila_degree,
    Mc=ila_degree,
)
dpd_model_ila = GMP(**ila_config, model_name="ila")

is_load = dpd_model_ila.load_weights()
casc_ila_train = utils.CascadeModel(model_2=dpd_model_ila, model_1=pa_model, gain=gain, cascade_type="ila")
casc_ila_eval = utils.CascadeModel(model_1=dpd_model_ila, model_2=pa_model)

optimizer = torch.optim.Adam(casc_ila_train.parameters(), lr=lr)

if not is_load:
    learning.train(net=casc_ila_train, 
                   criterion=criterion, 
                   optimizer=optimizer, 
                   train_loader=ila_train_loader, 
                   val_loader=ila_val_loader, 
                   grad_clip_val=0, 
                   n_epochs=epochs, 
                   metric_criterion=metric_criterion)
    dpd_model_ila.save_weights()

y_val_ila = learning.net_inference(net=casc_ila_eval, x=x_val)
nmse_ila = metrics.compute_nmse(y_val_ila, y_val_target)
print(f"Model NMSE: {nmse_ila:.2f}")
# Out:
# Coefficients loaded from model_params/ila_gmp_model_Ka5_La5_Kb5_Lb5_Mb5_Kc5_Lc5_Mc5.pt
# Model NMSE: -47.57

# %% [markdown]
# ILC DPD grad

# %%
u_k_train = learning.ilc_signal(x_train, y_train_target, pa_model, epochs=1000, learning_rate=0.001)
u_k_val = learning.ilc_signal(x_val, y_val_target, pa_model, epochs=1000, learning_rate=0.001)
u_k_pa = pa_model.forward(u_k_train).detach()

data["ilc_train_output"] = u_k_train
data["ilc_val_output"] = u_k_val

ilc_train_loader = [(x_train, u_k_train)]
ilc_val_loader = [(x_val, u_k_val)]
# Out:
# Epoch [0/1000], Loss: 0.030477918684482574
# Epoch [100/1000], Loss: 0.0010683428263291717
# Epoch [200/1000], Loss: 2.9619668566738255e-05
# Epoch [300/1000], Loss: 6.954932700864447e-07
# Epoch [400/1000], Loss: 3.9306566890218164e-08
# Epoch [500/1000], Loss: 1.1716266179462309e-08
# Epoch [600/1000], Loss: 7.97405075303459e-09
# Epoch [700/1000], Loss: 6.854731893213284e-09
# Epoch [800/1000], Loss: 6.308487510153782e-09
# Epoch [900/1000], Loss: 6.004321040364857e-09
# Epoch [999/1000], Loss: 5.8344444830993325e-09
# Время расчёта ilc_signal: 0:02:38
# Epoch [0/1000], Loss: 0.03021436184644699
# Epoch [100/1000], Loss: 0.0010643481509760022
# Epoch [200/1000], Loss: 3.04563782265177e-05
# Epoch [300/1000], Loss: 7.428039339174575e-07
# Epoch [400/1000], Loss: 5.5598114556687506e-08
# Epoch [500/1000], Loss: 1.7859653311802504e-08
# Epoch [600/1000], Loss: 9.977293657925657e-09
# Epoch [700/1000], Loss: 7.113897915189682e-09
# Epoch [800/1000], Loss: 5.698900462647316e-09
# Epoch [900/1000], Loss: 4.886136828474719e-09
# Epoch [999/1000], Loss: 4.3887244949303295e-09
# Время расчёта ilc_signal: 0:01:03

# %%
epochs = 1000
lr = 0.001

ilc_degree = 5
ilc_config = params.make_gmp_params(
    Ka=ilc_degree,
    La=ilc_degree,
    Kb=ilc_degree,
    Lb=ilc_degree,
    Mb=ilc_degree,
    Kc=ilc_degree,
    Lc=ilc_degree,
    Mc=ilc_degree,
)

dpd_model_ilc = GMP(**ilc_config, model_name="ilc")
is_load = dpd_model_ilc.load_weights()
optimizer = torch.optim.Adam(dpd_model_ilc.parameters(), lr=lr)

if not is_load:
    learning.train(net=dpd_model_ilc, 
                   criterion=criterion, 
                   optimizer=optimizer, 
                   train_loader=ilc_train_loader, 
                   val_loader=ilc_val_loader, 
                   grad_clip_val=0, 
                   n_epochs=epochs, 
                   metric_criterion=metric_criterion)
    dpd_model_ilc.save_weights()

casc_ilc_eval = utils.CascadeModel(model_1=dpd_model_ilc, model_2=pa_model)
y_val_ilc = learning.net_inference(net=casc_ilc_eval, x=x_val)
nmse_ilc = metrics.compute_nmse(y_val_ilc, y_val_target)
print(f"Model NMSE: {nmse_ilc:.2f}")
# Out:
# Coefficients loaded from model_params/ilc_gmp_model_Ka5_La5_Kb5_Lb5_Mb5_Kc5_Lc5_Mc5.pt
# Model NMSE: -49.25

# %% [markdown]
# Metrics

# %%
nmse_after_pa = metrics.compute_nmse(y_val_pa, y_val_target)

print(f"NMSE на выходе усилителя (без DPD): {nmse_after_pa:.2f} db")

print(f"NMSE на выходе усилителя (DLA DPD): {nmse_dla:.2f} db")

print(f"NMSE на выходе усилителя (ILA DPD): {nmse_ila:.2f} db")

print(f"NMSE на выходе усилителя (ILC DPD): {nmse_ilc:.2f} db")
# Out:
# NMSE на выходе усилителя (без DPD): -14.12 db
# NMSE на выходе усилителя (DLA DPD): -49.59 db
# NMSE на выходе усилителя (ILA DPD): -47.57 db
# NMSE на выходе усилителя (ILC DPD): -49.25 db

# %%
x_val_acpr = metrics.calculate_acpr(x_val, acpr_meter)
y_val_acpr = metrics.calculate_acpr(y_val, acpr_meter)
y_val_pa_acpr = metrics.calculate_acpr(y_val_pa, acpr_meter)
y_val_target_acpr = metrics.calculate_acpr(y_val_target, acpr_meter)

y_lin_dla_acpr = metrics.calculate_acpr(y_val_dla, acpr_meter)
y_lin_ila_acpr = metrics.calculate_acpr(y_val_ila, acpr_meter)
y_lin_ilc_acpr = metrics.calculate_acpr(y_val_ilc, acpr_meter)

print(f"x_val_acpr: {x_val_acpr}")
print(f"y_val_acpr: {y_val_acpr}")
print(f"y_val_pa_acpr: {y_val_pa_acpr}")
print(f"y_val_target_acpr: {y_val_target_acpr}")

print(f"lin_dla_acpr: {y_lin_dla_acpr}")
print(f"lin_ila_acpr: {y_lin_ila_acpr}")
print(f"lin_ilc_acpr: {y_lin_ilc_acpr}")
# Out:
# x_val_acpr: [-48.08083195 -48.40122574]
# y_val_acpr: [-40.60778184 -38.20237847]
# y_val_pa_acpr: [-43.6778176 -41.4680787]
# y_val_target_acpr: [-48.08083304 -48.40122404]
# lin_dla_acpr: [-47.57345618 -48.00886752]
# lin_ila_acpr: [-47.26684709 -47.72345492]
# lin_ilc_acpr: [-47.23755007 -48.15639658]

# %%
nmse_uk_pa = metrics.compute_nmse(u_k_pa, y_train_target)
print(f"NMSE на выходе усилителя (ILC): {nmse_uk_pa:.2f} db")

u_k_acpr = metrics.calculate_acpr(u_k_val, acpr_meter)
u_k_pa_acpr = metrics.calculate_acpr(u_k_pa, acpr_meter)

print(f"u_k_acpr: {u_k_acpr}")
print(f"u_k_pa_acpr: {u_k_pa_acpr}")
# Out:
# NMSE на выходе усилителя (ILC): -81.16 db
# u_k_acpr: [-42.89563798 -46.75625965]
# u_k_pa_acpr: [-50.93481621 -50.36949334]

# %% [markdown]
# Spectrum

# %%
freqs, spectrum_y_in = metrics.power_spectrum(x_val, fs, nperseg)
_, spectrum_y_out = metrics.power_spectrum(y_val, fs, nperseg)
_, spectrum_y_val_pa = metrics.power_spectrum(y_val_pa, fs, nperseg)
_, spectrum_y_val_target = metrics.power_spectrum(y_val_target, fs, nperseg)

# _, spectrum_y_dpd_dla = metrics.power_spectrum(y_dpd_dla, fs, nperseg)
# _, spectrum_y_dpd_ila = metrics.power_spectrum(y_dpd_ila, fs, nperseg)
# _, spectrum_y_dpd_ilc = metrics.power_spectrum(y_dpd_ilc, fs, nperseg)

_, spectrum_y_val_dla = metrics.power_spectrum(y_val_dla, fs, nperseg)
_, spectrum_y_val_ila = metrics.power_spectrum(y_val_ila, fs, nperseg)
_, spectrum_y_val_ilc = metrics.power_spectrum(y_val_ilc, fs, nperseg)


# _, spectrum_u_k = metrics.power_spectrum(u_k_val, fs, nperseg)
# _, spectrum_u_k_pa = metrics.power_spectrum(u_k_pa, fs, nperseg)

# %%
# построение спектра

xlabel="Частота (МГц)"
ylabel= "Спектральная плотность мощности (дБ)"
fontsize = 12
figsize=(12, 6)

plt.figure(figsize=figsize)

plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_y_in)), color='grey', label='Входной сигнал')
plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_y_val_pa)), color='gold', label='Выходной сигнал')
# plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_u_k_pa)), color='red', label='Оптимальный сигнал ILC')
plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_y_val_dla)), color='darkorange', label='Сигнал с предыскажением DLA')
plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_y_val_ila)), color='limegreen', label='Сигнал с предыскажением ILA')
plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_y_val_ilc)), color='lightcoral', label='Сигнал с предыскажением ILC')


plt.xlabel(xlabel, fontsize=fontsize)
plt.ylabel(ylabel, fontsize=fontsize)
plt.legend()
plt.grid()
plt.show()

# %%
# moving_average
window_size = 60

freqs_s, spectrum_y_in_s = utils.moving_average(spectrum_y_in, freqs, fs, window_size)
_, spectrum_y_out_s = utils.moving_average(spectrum_y_out, freqs, fs, window_size)
_, spectrum_y_val_pa_s = utils.moving_average(spectrum_y_val_pa, freqs, fs, window_size)
_, spectrum_y_val_target_s = utils.moving_average(spectrum_y_val_target, freqs, fs, window_size)

# _, spectrum_y_val_dla_s = utils.moving_average(spectrum_y_val_dla, freqs, fs, window_size)
# _, spectrum_y_val_ila_s = utils.moving_average(spectrum_y_val_ila, freqs, fs, window_size)
# _, spectrum_y_dpd_ilc_grad_s = utils.moving_average(spectrum_y_dpd_ilc_grad, freqs, fs, window_size)

_, spectrum_y_val_dla_s = utils.moving_average(spectrum_y_val_dla, freqs, fs, window_size)
_, spectrum_y_val_ila_s = utils.moving_average(spectrum_y_val_ila, freqs, fs, window_size)
_, spectrum_y_val_ilc_s = utils.moving_average(spectrum_y_val_ilc, freqs, fs, window_size)

# _, spectrum_u_k_s = utils.moving_average(spectrum_u_k, freqs, fs, window_size)
# _, spectrum_u_k_pa_s = utils.moving_average(spectrum_u_k_pa, freqs, fs, window_size)

# %%
# (сглаженный) построение спектра

xlabel="Частота, МГц"
ylabel= "Спектральная плотность мощности, дБВт/Гц"
fontsize = 12
figsize=(12, 8)
markersize=8

plt.figure(figsize=figsize)

# plt.plot(freqs_s / 1e6, 10 * np.log10(np.abs(spectrum_y_in_s)), 
#          color='grey', label='Входной сигнал',marker = '*', markevery=90, markersize=markersize)
plt.plot(freqs_s / 1e6, 10 * np.log10(np.abs(spectrum_y_val_target_s)), 
         color='black', label='Выходной сигнал\n(линейный усилитель)',marker = '*', markevery=90, markersize=markersize)
plt.plot(freqs_s / 1e6, 10 * np.log10(np.abs(spectrum_y_val_pa_s)), 
         color='gold', label='Выходной сигнал\n(реальный усилитель)', marker='o', markevery=90, markersize=markersize)
# plt.plot(freqs_s / 1e6, 10 * np.log10(np.abs(spectrum_u_k_pa_s)), 
#          color='red', label='Оптимальный сигнал ILC', marker='v', markevery=95, markersize=markersize)
plt.plot(freqs_s / 1e6, 10 * np.log10(np.abs(spectrum_y_val_dla_s)), 
         color='darkorange', label='Сигнал с предыскажением DLA', marker='D', markevery=90, markersize=markersize)
plt.plot(freqs_s / 1e6, 10 * np.log10(np.abs(spectrum_y_val_ila_s)), 
         color='limegreen', label='Сигнал с предыскажением ILA', marker='X', markevery=110, markersize=markersize)
plt.plot(freqs_s / 1e6, 10 * np.log10(np.abs(spectrum_y_val_ilc_s)), 
         color='lightcoral', label='Сигнал с предыскажением ILC', marker='s', markevery=120, markersize=markersize)

plt.xlabel(xlabel, fontsize=fontsize)
plt.ylabel(ylabel, fontsize=fontsize)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# AM/AM & AM/PM

# %%
y_in_am_am, y_out_am_am = metrics.calculate_am_am(x_val, y_val)
y_in_am_pm, y_in_phase_am_pm = metrics.calculate_am_pm(x_val, y_val)

_, y_pa_am_am = metrics.calculate_am_am(x_val, y_val_pa)
_, y_pa_phase_am_pm = metrics.calculate_am_pm(x_val, y_val_pa)

_, y_val_target_am_am = metrics.calculate_am_am(x_val, y_val_target)
_, y_val_target_phase_am_pm = metrics.calculate_am_pm(x_val, y_val_target)

# x_in_am_am, u_k_am_am = metrics.calculate_am_am(x_train, u_k)
# x_in_am_pm, u_k_phase_am_pm = metrics.calculate_am_pm(x_train, u_k)

# _, u_k_pa_am_am = metrics.calculate_am_am(x_train, u_k_pa)
# _, u_k_pa_phase_am_pm = metrics.calculate_am_pm(x_train, u_k_pa)

#linearized
_, y_val_dla_am_am = metrics.calculate_am_am(x_val, y_val_dla)
_, y_val_dla_phase_am_pm = metrics.calculate_am_pm(x_val, y_val_dla)

_, y_val_ila_am_am = metrics.calculate_am_am(x_val, y_val_ila)
_, y_val_ila_phase_am_pm = metrics.calculate_am_pm(x_val, y_val_ila)

_, y_val_ilc_am_am = metrics.calculate_am_am(x_val, y_val_ilc)
_, y_val_ilc_phase_am_pm = metrics.calculate_am_pm(x_val, y_val_ilc)

# %%
#DLA

am_am_data = [
    (y_in_am_am, y_pa_am_am, 'gold', 'Выходной сигнал'),
    # (y_in_am_am, y_val_dla_am_am, 'magenta', 'Сигнал на выходе DPD'),
    (y_in_am_am, y_val_dla_am_am, 'darkorange', 'Сигнал с предыскажением'),
]

am_pm_data = [
    (y_in_am_pm, y_pa_phase_am_pm, 'gold', 'Выходной сигнал'),
    (y_in_am_pm, y_val_dla_phase_am_pm, 'darkorange', 'Сигнал с предыскажением'),
]

plotting.plot_am_am_pm(
    am_am_data=am_am_data,
    am_pm_data=am_pm_data,
    figsize=(12, 6),
    titles=("AM/AM DLA", "AM/PM DLA"),
    xlabels=("Амплитуда на входе", "Амплитуда на входе"),
    ylabels=("Амплитуда на выходе", "Фазовый сдвиг на выходе (градусы)")
)

# %%
#ILA

am_am_data = [
    (y_in_am_am, y_pa_am_am, 'gold', 'Выходной сигнал'),
    # (y_in_am_am, y_val_ila_am_am, 'magenta', 'Сигнал на выходе DPD'),
    (y_in_am_am, y_val_ila_am_am, 'darkorange', 'Сигнал с предыскажением'),
]

am_pm_data = [
    (y_in_am_pm, y_pa_phase_am_pm, 'gold', 'Выходной сигнал'),
    (y_in_am_pm, y_val_ila_phase_am_pm, 'darkorange', 'Сигнал с предыскажением'),
]

plotting.plot_am_am_pm(
    am_am_data=am_am_data,
    am_pm_data=am_pm_data,
    figsize=(12, 6),
    titles=("AM/AM ILA", "AM/PM ILA"),
    xlabels=("Амплитуда на входе", "Амплитуда на входе"),
    ylabels=("Амплитуда на выходе", "Фазовый сдвиг на выходе (градусы)")
)

# %%
#ILC

am_am_data = [
    (y_in_am_am, y_pa_am_am, 'gold', 'Выходной сигнал'),
    # (y_in_am_am, y_dpd_ilc_grad_am_am, 'magenta', 'Сигнал на выходе корректора'),
    (y_in_am_am, y_val_ilc_am_am, 'darkorange', 'Сигнал с предыскажением'),
]

am_pm_data = [
    (y_in_am_pm, y_pa_phase_am_pm, 'gold', 'Выходной сигнал'),
    (y_in_am_pm, y_val_ilc_phase_am_pm, 'darkorange', 'Сигнал с предыскажением'),
]

plotting.plot_am_am_pm(
    am_am_data=am_am_data,
    am_pm_data=am_pm_data,
    figsize=(12, 6),
    titles=("AM/AM ILC", "AM/PM ILC"),
    xlabels=("Амплитуда на входе", "Амплитуда на входе"),
    ylabels=("Амплитуда на выходе", "Фазовый сдвиг на выходе (градусы)")
)

# %% [markdown]
# Add noise

# %%
snr_range = list(range(20, 61, 5))

epochs = 500
lr = 0.01
num_realizations = 500

snr_params = params.make_snr_params(
    snr_range=snr_range,
    num_realizations=num_realizations,
    fs=fs,
    bw_main_ch=bw_main_ch,
    epochs=epochs,
    learning_rate=lr,
    acpr_meter=acpr_meter,
    pa_model=pa_model,
    gain=gain
)

gmp_degree = 5
gmp_params = {"gmp_degree": gmp_degree}

snr_metrics_runner = pipelines.SnrPipeline(base_model=GMP, 
                                           input_model_params=gmp_params, 
                                           data_dict=data, 
                                           snr_params=snr_params)

# %%
snr_metrics_runner.run_dla_noise()
# Out:
# SNR: 20
# ===Start training===
# Epoch 0000 — train_loss: 0.378711, val_loss: 0.516984, val_NMSE: -1.79
# Epoch 0100 — train_loss: 0.014913, val_loss: 0.015251, val_NMSE: -17.09
# Epoch 0200 — train_loss: 0.014888, val_loss: 0.015069, val_NMSE: -17.14
# Epoch 0300 — train_loss: 0.014815, val_loss: 0.015087, val_NMSE: -17.14
# Epoch 0400 — train_loss: 0.014569, val_loss: 0.014973, val_NMSE: -17.17
# Epoch 0499 — train_loss: 0.014491, val_loss: 0.014971, val_NMSE: -17.17
# Время обучения: 0:02:07
# ===Training complete===
# SNR: 25
# ===Start training===
# Epoch 0000 — train_loss: 0.381326, val_loss: 0.498990, val_NMSE: -1.94
# Epoch 0100 — train_loss: 0.004938, val_loss: 0.005082, val_NMSE: -21.86
# Epoch 0200 — train_loss: 0.004860, val_loss: 0.004920, val_NMSE: -22.00
# Epoch 0300 — train_loss: 0.004767, val_loss: 0.004979, val_NMSE: -21.95
# Epoch 0400 — train_loss: 0.004833, val_loss: 0.004956, val_NMSE: -21.97
# Epoch 0499 — train_loss: 0.004820, val_loss: 0.004888, val_NMSE: -22.03
# Время обучения: 0:02:06
# ===Training complete===
# SNR: 30
# ===Start training===
# Epoch 0000 — train_loss: 0.383321, val_loss: 0.484576, val_NMSE: -2.07
# Epoch 0100 — train_loss: 0.001753, val_loss: 0.001802, val_NMSE: -26.36
# Epoch 0200 — train_loss: 0.001589, val_loss: 0.001633, val_NMSE: -26.79
# Epoch 0300 — train_loss: 0.001553, val_loss: 0.001576, val_NMSE: -26.95
# Epoch 0400 — train_loss: 0.001530, val_loss: 0.001579, val_NMSE: -26.94
# Epoch 0499 — train_loss: 0.001554, val_loss: 0.001606, val_NMSE: -26.86
# Время обучения: 0:02:06
# ===Training complete===
# SNR: 35
# ===Start training===
# Epoch 0000 — train_loss: 0.378763, val_loss: 0.488800, val_NMSE: -2.03
# Epoch 0100 — train_loss: 0.000717, val_loss: 0.000730, val_NMSE: -30.29
# Epoch 0200 — train_loss: 0.000567, val_loss: 0.000580, val_NMSE: -31.28
# Epoch 0300 — train_loss: 0.000522, val_loss: 0.000534, val_NMSE: -31.64
# Epoch 0400 — train_loss: 0.000507, val_loss: 0.000524, val_NMSE: -31.72
# Epoch 0499 — train_loss: 0.000498, val_loss: 0.000501, val_NMSE: -31.92
# Время обучения: 0:02:07
# ===Training complete===
# SNR: 40
# ===Start training===
# Epoch 0000 — train_loss: 0.377837, val_loss: 0.488485, val_NMSE: -2.03
# Epoch 0100 — train_loss: 0.000388, val_loss: 0.000396, val_NMSE: -32.94
# Epoch 0200 — train_loss: 0.000235, val_loss: 0.000236, val_NMSE: -35.19
# Epoch 0300 — train_loss: 0.000192, val_loss: 0.000197, val_NMSE: -35.98
# Epoch 0400 — train_loss: 0.000178, val_loss: 0.000185, val_NMSE: -36.26
# Epoch 0499 — train_loss: 0.000170, val_loss: 0.000173, val_NMSE: -36.54
# Время обучения: 0:02:02
# ===Training complete===
# SNR: 45
# ===Start training===
# Epoch 0000 — train_loss: 0.383093, val_loss: 0.486142, val_NMSE: -2.05
# Epoch 0100 — train_loss: 0.000290, val_loss: 0.000284, val_NMSE: -34.39
# Epoch 0200 — train_loss: 0.000134, val_loss: 0.000131, val_NMSE: -37.74
# Epoch 0300 — train_loss: 0.000090, val_loss: 0.000092, val_NMSE: -39.30
# Epoch 0400 — train_loss: 0.000072, val_loss: 0.000075, val_NMSE: -40.17
# Epoch 0499 — train_loss: 0.000065, val_loss: 0.000068, val_NMSE: -40.62
# Время обучения: 0:02:00
# ===Training complete===
# SNR: 50
# ===Start training===
# Epoch 0000 — train_loss: 0.384450, val_loss: 0.485479, val_NMSE: -2.06
# Epoch 0100 — train_loss: 0.000261, val_loss: 0.000257, val_NMSE: -34.82
# Epoch 0200 — train_loss: 0.000102, val_loss: 0.000099, val_NMSE: -38.95
# Epoch 0300 — train_loss: 0.000057, val_loss: 0.000057, val_NMSE: -41.39
# Epoch 0400 — train_loss: 0.000040, val_loss: 0.000041, val_NMSE: -42.78
# Epoch 0499 — train_loss: 0.000033, val_loss: 0.000034, val_NMSE: -43.65
# Время обучения: 0:02:01
# ===Training complete===
# SNR: 55
# ===Start training===
# Epoch 0000 — train_loss: 0.381152, val_loss: 0.488308, val_NMSE: -2.03
# Epoch 0100 — train_loss: 0.000247, val_loss: 0.000243, val_NMSE: -35.07
# Epoch 0200 — train_loss: 0.000090, val_loss: 0.000086, val_NMSE: -39.57
# Epoch 0300 — train_loss: 0.000047, val_loss: 0.000046, val_NMSE: -42.29
# Epoch 0400 — train_loss: 0.000030, val_loss: 0.000030, val_NMSE: -44.10
# Epoch 0499 — train_loss: 0.000022, val_loss: 0.000023, val_NMSE: -45.31
# Время обучения: 0:02:00
# ===Training complete===
# SNR: 60
# ===Start training===
# Epoch 0000 — train_loss: 0.380701, val_loss: 0.486765, val_NMSE: -2.05
# Epoch 0100 — train_loss: 0.000246, val_loss: 0.000241, val_NMSE: -35.10
# Epoch 0200 — train_loss: 0.000087, val_loss: 0.000084, val_NMSE: -39.65
# Epoch 0300 — train_loss: 0.000044, val_loss: 0.000043, val_NMSE: -42.60
# Epoch 0400 — train_loss: 0.000027, val_loss: 0.000027, val_NMSE: -44.61
# Epoch 0499 — train_loss: 0.000019, val_loss: 0.000020, val_NMSE: -45.99
# Время обучения: 0:02:00
# ===Training complete===

# %%
snr_metrics_runner.run_ila_noise()
# Out:
# SNR: 20
# ===Start training===
# Epoch 0000 — train_loss: 0.059848, val_loss: 0.081936, val_NMSE: -1.76
# Epoch 0100 — train_loss: 0.001612, val_loss: 0.001666, val_NMSE: -18.67
# Epoch 0200 — train_loss: 0.001570, val_loss: 0.001626, val_NMSE: -18.78
# Epoch 0300 — train_loss: 0.001572, val_loss: 0.001608, val_NMSE: -18.83
# Epoch 0400 — train_loss: 0.001557, val_loss: 0.001562, val_NMSE: -18.95
# Epoch 0499 — train_loss: 0.001543, val_loss: 0.001567, val_NMSE: -18.94
# Время обучения: 0:01:14
# ===Training complete===
# SNR: 25
# ===Start training===
# Epoch 0000 — train_loss: 0.059314, val_loss: 0.097127, val_NMSE: -1.02
# Epoch 0100 — train_loss: 0.000611, val_loss: 0.000626, val_NMSE: -22.92
# Epoch 0200 — train_loss: 0.000581, val_loss: 0.000595, val_NMSE: -23.14
# Epoch 0300 — train_loss: 0.000569, val_loss: 0.000595, val_NMSE: -23.15
# Epoch 0400 — train_loss: 0.000564, val_loss: 0.000592, val_NMSE: -23.17
# Epoch 0499 — train_loss: 0.000557, val_loss: 0.000590, val_NMSE: -23.18
# Время обучения: 0:01:14
# ===Training complete===
# SNR: 30
# ===Start training===
# Epoch 0000 — train_loss: 0.059866, val_loss: 0.075397, val_NMSE: -2.12
# Epoch 0100 — train_loss: 0.000239, val_loss: 0.000245, val_NMSE: -26.99
# Epoch 0200 — train_loss: 0.000213, val_loss: 0.000215, val_NMSE: -27.57
# Epoch 0300 — train_loss: 0.000206, val_loss: 0.000214, val_NMSE: -27.58
# Epoch 0400 — train_loss: 0.000205, val_loss: 0.000209, val_NMSE: -27.70
# Epoch 0499 — train_loss: 0.000197, val_loss: 0.000203, val_NMSE: -27.82
# Время обучения: 0:01:15
# ===Training complete===
# SNR: 35
# ===Start training===
# Epoch 0000 — train_loss: 0.060001, val_loss: 0.075433, val_NMSE: -2.11
# Epoch 0100 — train_loss: 0.000111, val_loss: 0.000108, val_NMSE: -30.54
# Epoch 0200 — train_loss: 0.000084, val_loss: 0.000084, val_NMSE: -31.64
# Epoch 0300 — train_loss: 0.000078, val_loss: 0.000078, val_NMSE: -31.99
# Epoch 0400 — train_loss: 0.000076, val_loss: 0.000076, val_NMSE: -32.08
# Epoch 0499 — train_loss: 0.000074, val_loss: 0.000076, val_NMSE: -32.09
# Время обучения: 0:01:15
# ===Training complete===
# SNR: 40
# ===Start training===
# Epoch 0000 — train_loss: 0.059537, val_loss: 0.098361, val_NMSE: -0.96
# Epoch 0100 — train_loss: 0.000068, val_loss: 0.000068, val_NMSE: -32.59
# Epoch 0200 — train_loss: 0.000042, val_loss: 0.000041, val_NMSE: -34.75
# Epoch 0300 — train_loss: 0.000035, val_loss: 0.000035, val_NMSE: -35.48
# Epoch 0400 — train_loss: 0.000032, val_loss: 0.000032, val_NMSE: -35.80
# Epoch 0499 — train_loss: 0.000029, val_loss: 0.000030, val_NMSE: -36.11
# Время обучения: 0:01:14
# ===Training complete===
# SNR: 45
# ===Start training===
# Epoch 0000 — train_loss: 0.060041, val_loss: 0.075214, val_NMSE: -2.13
# Epoch 0100 — train_loss: 0.000055, val_loss: 0.000053, val_NMSE: -33.64
# Epoch 0200 — train_loss: 0.000028, val_loss: 0.000027, val_NMSE: -36.59
# Epoch 0300 — train_loss: 0.000019, val_loss: 0.000020, val_NMSE: -37.90
# Epoch 0400 — train_loss: 0.000016, val_loss: 0.000016, val_NMSE: -38.81
# Epoch 0499 — train_loss: 0.000014, val_loss: 0.000015, val_NMSE: -39.21
# Время обучения: 0:01:14
# ===Training complete===
# SNR: 50
# ===Start training===
# Epoch 0000 — train_loss: 0.060424, val_loss: 0.074536, val_NMSE: -2.17
# Epoch 0100 — train_loss: 0.000051, val_loss: 0.000050, val_NMSE: -33.94
# Epoch 0200 — train_loss: 0.000023, val_loss: 0.000023, val_NMSE: -37.33
# Epoch 0300 — train_loss: 0.000015, val_loss: 0.000015, val_NMSE: -39.09
# Epoch 0400 — train_loss: 0.000011, val_loss: 0.000011, val_NMSE: -40.29
# Epoch 0499 — train_loss: 0.000009, val_loss: 0.000010, val_NMSE: -40.92
# Время обучения: 0:01:15
# ===Training complete===
# SNR: 55
# ===Start training===
# Epoch 0000 — train_loss: 0.059847, val_loss: 0.098678, val_NMSE: -0.95
# Epoch 0100 — train_loss: 0.000049, val_loss: 0.000047, val_NMSE: -34.14
# Epoch 0200 — train_loss: 0.000022, val_loss: 0.000021, val_NMSE: -37.64
# Epoch 0300 — train_loss: 0.000014, val_loss: 0.000014, val_NMSE: -39.42
# Epoch 0400 — train_loss: 0.000010, val_loss: 0.000010, val_NMSE: -40.68
# Epoch 0499 — train_loss: 0.000008, val_loss: 0.000009, val_NMSE: -41.54
# Время обучения: 0:01:15
# ===Training complete===
# SNR: 60
# ===Start training===
# Epoch 0000 — train_loss: 0.061038, val_loss: 0.076367, val_NMSE: -2.06
# Epoch 0100 — train_loss: 0.000050, val_loss: 0.000048, val_NMSE: -34.03
# Epoch 0200 — train_loss: 0.000022, val_loss: 0.000021, val_NMSE: -37.65
# Epoch 0300 — train_loss: 0.000013, val_loss: 0.000013, val_NMSE: -39.61
# Epoch 0400 — train_loss: 0.000009, val_loss: 0.000010, val_NMSE: -40.99
# Epoch 0499 — train_loss: 0.000007, val_loss: 0.000008, val_NMSE: -41.89
# Время обучения: 0:01:15
# ===Training complete===

# %%
snr_metrics_runner.run_ilc_noise()
# Out:
# SNR: 20
# Epoch [0/500], Loss: 0.05481655150651932
# Epoch [100/500], Loss: 0.018765931949019432
# Epoch [200/500], Loss: 0.014988327398896217
# Epoch [300/500], Loss: 0.014843262732028961
# Epoch [400/500], Loss: 0.014706596732139587
# Epoch [499/500], Loss: 0.014754110015928745
# Время расчёта ilc_signal: 0:01:14
# ===Start training===
# Epoch 0000 — train_loss: 0.035044, val_loss: 0.028912, val_NMSE: -3.81
# Epoch 0100 — train_loss: 0.000031, val_loss: 0.000031, val_NMSE: -33.49
# Epoch 0200 — train_loss: 0.000021, val_loss: 0.000020, val_NMSE: -35.31
# Epoch 0300 — train_loss: 0.000018, val_loss: 0.000018, val_NMSE: -35.93
# Epoch 0400 — train_loss: 0.000017, val_loss: 0.000017, val_NMSE: -36.21
# Epoch 0499 — train_loss: 0.000016, val_loss: 0.000016, val_NMSE: -36.35
# Время обучения: 0:00:58
# ===Training complete===
# SNR: 25
# Epoch [0/500], Loss: 0.03817254304885864
# Epoch [100/500], Loss: 0.006577697116881609
# Epoch [200/500], Loss: 0.004973146133124828
# Epoch [300/500], Loss: 0.004793424159288406
# Epoch [400/500], Loss: 0.004835061263293028
# Epoch [499/500], Loss: 0.004866930190473795
# Время расчёта ilc_signal: 0:01:14
# ===Start training===
# Epoch 0000 — train_loss: 0.036354, val_loss: 0.029019, val_NMSE: -4.04
# Epoch 0100 — train_loss: 0.000026, val_loss: 0.000027, val_NMSE: -34.40
# Epoch 0200 — train_loss: 0.000015, val_loss: 0.000015, val_NMSE: -36.94
# Epoch 0300 — train_loss: 0.000012, val_loss: 0.000012, val_NMSE: -37.90
# Epoch 0400 — train_loss: 0.000011, val_loss: 0.000011, val_NMSE: -38.37
# Epoch 0499 — train_loss: 0.000010, val_loss: 0.000010, val_NMSE: -38.62
# Время обучения: 0:00:58
# ===Training complete===
# SNR: 30
# Epoch [0/500], Loss: 0.03279691934585571
# Epoch [100/500], Loss: 0.0028426661156117916
# Epoch [200/500], Loss: 0.0016168872825801373
# Epoch [300/500], Loss: 0.0015573921846225858
# Epoch [400/500], Loss: 0.0015769460005685687
# Epoch [499/500], Loss: 0.0015687770210206509
# Время расчёта ilc_signal: 0:01:14
# ===Start training===
# Epoch 0000 — train_loss: 0.037541, val_loss: 0.029196, val_NMSE: -4.09
# Epoch 0100 — train_loss: 0.000023, val_loss: 0.000023, val_NMSE: -35.04
# Epoch 0200 — train_loss: 0.000011, val_loss: 0.000011, val_NMSE: -38.19
# Epoch 0300 — train_loss: 0.000008, val_loss: 0.000008, val_NMSE: -39.57
# Epoch 0400 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -40.31
# Epoch 0499 — train_loss: 0.000006, val_loss: 0.000006, val_NMSE: -40.70
# Время обучения: 0:00:58
# ===Training complete===
# SNR: 35
# Epoch [0/500], Loss: 0.031205661594867706
# Epoch [100/500], Loss: 0.0016312811058014631
# Epoch [200/500], Loss: 0.0005373336607590318
# Epoch [300/500], Loss: 0.0005056122899986804
# Epoch [400/500], Loss: 0.0005162161542102695
# Epoch [499/500], Loss: 0.0005061766132712364
# Время расчёта ilc_signal: 0:01:14
# ===Start training===
# Epoch 0000 — train_loss: 0.038151, val_loss: 0.029826, val_NMSE: -4.02
# Epoch 0100 — train_loss: 0.000021, val_loss: 0.000022, val_NMSE: -35.42
# Epoch 0200 — train_loss: 0.000009, val_loss: 0.000009, val_NMSE: -39.08
# Epoch 0300 — train_loss: 0.000006, val_loss: 0.000006, val_NMSE: -40.89
# Epoch 0400 — train_loss: 0.000005, val_loss: 0.000005, val_NMSE: -41.94
# Epoch 0499 — train_loss: 0.000004, val_loss: 0.000004, val_NMSE: -42.54
# Время обучения: 0:00:58
# ===Training complete===
# SNR: 40
# Epoch [0/500], Loss: 0.030763790011405945
# Epoch [100/500], Loss: 0.0012514161644503474
# Epoch [200/500], Loss: 0.00019459206669125706
# Epoch [300/500], Loss: 0.000164226716151461
# Epoch [400/500], Loss: 0.00016362925816792995
# Epoch [499/500], Loss: 0.00016435881843790412
# Время расчёта ilc_signal: 0:01:14
# ===Start training===
# Epoch 0000 — train_loss: 0.038475, val_loss: 0.029715, val_NMSE: -4.04
# Epoch 0100 — train_loss: 0.000020, val_loss: 0.000020, val_NMSE: -35.68
# Epoch 0200 — train_loss: 0.000008, val_loss: 0.000008, val_NMSE: -39.61
# Epoch 0300 — train_loss: 0.000005, val_loss: 0.000005, val_NMSE: -41.71
# Epoch 0400 — train_loss: 0.000004, val_loss: 0.000004, val_NMSE: -43.02
# Epoch 0499 — train_loss: 0.000003, val_loss: 0.000003, val_NMSE: -43.81
# Время обучения: 0:00:58
# ===Training complete===
# SNR: 45
# Epoch [0/500], Loss: 0.030568702146410942
# Epoch [100/500], Loss: 0.0011276033474132419
# Epoch [200/500], Loss: 8.217983122449368e-05
# Epoch [300/500], Loss: 5.3550458687823266e-05
# Epoch [400/500], Loss: 5.33772908966057e-05
# Epoch [499/500], Loss: 5.405112824519165e-05
# Время расчёта ilc_signal: 0:01:14
# ===Start training===
# Epoch 0000 — train_loss: 0.037436, val_loss: 0.029644, val_NMSE: -4.05
# Epoch 0100 — train_loss: 0.000020, val_loss: 0.000020, val_NMSE: -35.82
# Epoch 0200 — train_loss: 0.000008, val_loss: 0.000008, val_NMSE: -39.92
# Epoch 0300 — train_loss: 0.000005, val_loss: 0.000005, val_NMSE: -42.22
# Epoch 0400 — train_loss: 0.000003, val_loss: 0.000003, val_NMSE: -43.70
# Epoch 0499 — train_loss: 0.000003, val_loss: 0.000003, val_NMSE: -44.64
# Время обучения: 0:00:58
# ===Training complete===
# SNR: 50
# Epoch [0/500], Loss: 0.030510419979691505
# Epoch [100/500], Loss: 0.0010877472814172506
# Epoch [200/500], Loss: 4.665843152906746e-05
# Epoch [300/500], Loss: 1.77346846612636e-05
# Epoch [400/500], Loss: 1.750207957229577e-05
# Epoch [499/500], Loss: 1.768688343872782e-05
# Время расчёта ilc_signal: 0:01:13
# ===Start training===
# Epoch 0000 — train_loss: 0.037823, val_loss: 0.028641, val_NMSE: -4.20
# Epoch 0100 — train_loss: 0.000020, val_loss: 0.000019, val_NMSE: -35.91
# Epoch 0200 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -40.14
# Epoch 0300 — train_loss: 0.000004, val_loss: 0.000004, val_NMSE: -42.56
# Epoch 0400 — train_loss: 0.000003, val_loss: 0.000003, val_NMSE: -44.14
# Epoch 0499 — train_loss: 0.000002, val_loss: 0.000002, val_NMSE: -45.17
# Время обучения: 0:00:59
# ===Training complete===
# SNR: 55
# Epoch [0/500], Loss: 0.030490567907691002
# Epoch [100/500], Loss: 0.0010749859502539039
# Epoch [200/500], Loss: 3.513009141897783e-05
# Epoch [300/500], Loss: 6.256213509914232e-06
# Epoch [400/500], Loss: 5.638692528009415e-06
# Epoch [499/500], Loss: 5.718673037335975e-06
# Время расчёта ilc_signal: 0:01:13
# ===Start training===
# Epoch 0000 — train_loss: 0.037942, val_loss: 0.029391, val_NMSE: -4.09
# Epoch 0100 — train_loss: 0.000019, val_loss: 0.000019, val_NMSE: -35.88
# Epoch 0200 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -40.18
# Epoch 0300 — train_loss: 0.000004, val_loss: 0.000004, val_NMSE: -42.62
# Epoch 0400 — train_loss: 0.000003, val_loss: 0.000003, val_NMSE: -44.25
# Epoch 0499 — train_loss: 0.000002, val_loss: 0.000002, val_NMSE: -45.32
# Время обучения: 0:00:58
# ===Training complete===
# SNR: 60
# Epoch [0/500], Loss: 0.030479632318019867
# Epoch [100/500], Loss: 0.0010703527368605137
# Epoch [200/500], Loss: 3.141530032735318e-05
# Epoch [300/500], Loss: 2.5014817310875515e-06
# Epoch [400/500], Loss: 1.905332851492858e-06
# Epoch [499/500], Loss: 1.909884304041043e-06
# Время расчёта ilc_signal: 0:01:13
# ===Start training===
# Epoch 0000 — train_loss: 0.037370, val_loss: 0.028831, val_NMSE: -4.18
# Epoch 0100 — train_loss: 0.000020, val_loss: 0.000019, val_NMSE: -35.89
# Epoch 0200 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -40.18
# Epoch 0300 — train_loss: 0.000004, val_loss: 0.000004, val_NMSE: -42.66
# Epoch 0400 — train_loss: 0.000003, val_loss: 0.000003, val_NMSE: -44.32
# Epoch 0499 — train_loss: 0.000002, val_loss: 0.000002, val_NMSE: -45.41
# Время обучения: 0:00:58
# ===Training complete===

# %%
results = snr_metrics_runner.get_results()

snr_range = results["snr_range"]

nmse_dla_list = results["dla"]["nmse"]
acpr_left_dla_list = results["dla"]["acpr_left"]
acpr_right_dla_list = results["dla"]["acpr_right"]

nmse_ila_list = results["ila"]["nmse"]
acpr_left_ila_list = results["ila"]["acpr_left"]
acpr_right_ila_list = results["ila"]["acpr_right"]

nmse_ilc_list = results["ilc"]["nmse"]
acpr_left_ilc_list = results["ilc"]["acpr_left"]
acpr_right_ilc_list = results["ilc"]["acpr_right"]

nmse_uk_list = results["uk"]["nmse"]
acpr_left_uk_list = results["uk"]["acpr_left"]
acpr_right_uk_list = results["uk"]["acpr_right"]

# %%
print(f"snr_range = {snr_range}")
print()

print(f"nmse_dla_list = {(nmse_dla_list)}")
print(f"acpr_left_dla_list = {acpr_left_dla_list}")
print(f"acpr_right_dla_list = {acpr_right_dla_list}")
print()

print(f"nmse_ila_list = {nmse_ila_list}")
print(f"acpr_left_ila_list = {acpr_left_ila_list}")
print(f"acpr_right_ila_list = {acpr_right_ila_list}")
print()

print(f"nmse_ilc_list = {nmse_ilc_list}")
print(f"acpr_left_ilc_list = {acpr_left_ilc_list}")
print(f"acpr_right_ilc_list = {acpr_right_ilc_list}")
print()

print(f"nmse_uk_list = {nmse_uk_list}")
print(f"acpr_left_uk_list = {acpr_left_uk_list}")
print(f"acpr_right_uk_list = {acpr_right_uk_list}")
# Out:
# snr_range = [20, 25, 30, 35, 40, 45, 50, 55, 60]
#
# nmse_dla_list = [-17.148632049560547, -22.024913787841797, -26.938125610351562, -31.83021354675293, -36.51686096191406, -40.62764358520508, -43.64088821411133, -45.28367233276367, -45.97032928466797]
# acpr_left_dla_list = [np.float64(-20.02928768602456), np.float64(-24.982584759640396), np.float64(-29.94026217788973), np.float64(-34.790795872739075), np.float64(-39.38424284115534), np.float64(-43.27951405106335), np.float64(-45.91862097413965), np.float64(-47.333822464193716), np.float64(-47.83152138893719)]
# acpr_right_dla_list = [np.float64(-20.042172905027773), np.float64(-25.000703280641286), np.float64(-29.94555560855832), np.float64(-34.80382540388212), np.float64(-39.38523604062279), np.float64(-43.28755626930241), np.float64(-45.98511389366253), np.float64(-47.36026912001858), np.float64(-47.90736568475759)]
#
# nmse_ila_list = [-16.83725929260254, -21.696548461914062, -26.669509887695312, -31.488346099853516, -36.02500915527344, -39.879154205322266, -42.40645217895508, -43.42716979980469, -43.93549346923828]
# acpr_left_ila_list = [np.float64(-20.00222177006019), np.float64(-24.971782017744154), np.float64(-29.923676246124597), np.float64(-34.80161732949249), np.float64(-39.42496900898496), np.float64(-43.28975773398101), np.float64(-45.873289415878496), np.float64(-47.202136411878605), np.float64(-47.756956490565976)]
# acpr_right_ila_list = [np.float64(-19.993474395769827), np.float64(-24.971225060341276), np.float64(-29.892187352223697), np.float64(-34.74605686633869), np.float64(-39.33391505070409), np.float64(-43.2264451233586), np.float64(-45.85228436821109), np.float64(-47.18489131799368), np.float64(-47.6152281122493)]
#
# nmse_ilc_list = [-17.158906936645508, -22.031850814819336, -26.965087890625, -31.861326217651367, -36.56019592285156, -40.75254440307617, -43.91820526123047, -45.680294036865234, -46.44440460205078]
# acpr_left_ilc_list = [np.float64(-20.044396458130798), np.float64(-24.993578868965155), np.float64(-29.9372842180529), np.float64(-34.772924693359265), np.float64(-39.31178774909315), np.float64(-43.099510420284886), np.float64(-45.61383020944608), np.float64(-46.92524581800085), np.float64(-47.35796834667576)]
# acpr_right_ilc_list = [np.float64(-20.040459827433555), np.float64(-24.992806883037694), np.float64(-29.944472317953025), np.float64(-34.81252600026537), np.float64(-39.403898012451755), np.float64(-43.3101146452194), np.float64(-46.009645430692416), np.float64(-47.33800239352745), np.float64(-47.92661068555603)]
#
# nmse_uk_list = [-17.104299545288086, -21.947444915771484, -26.852418899536133, -31.760339736938477, -36.646244049072266, -41.51726150512695, -46.37682342529297, -51.21725082397461, -56.03969192504883]
# acpr_left_uk_list = [np.float64(-19.998647945394534), np.float64(-24.925774868876385), np.float64(-29.859171441485117), np.float64(-34.72613479202458), np.float64(-39.43138138529091), np.float64(-43.75281378471498), np.float64(-47.17010201888079), np.float64(-49.318533219410455), np.float64(-50.34103656182335)]
# acpr_right_uk_list = [np.float64(-19.95078639388352), np.float64(-24.84866152192613), np.float64(-29.723849726576287), np.float64(-34.526383917218666), np.float64(-39.1178723599403), np.float64(-43.31461094685448), np.float64(-46.65804885579808), np.float64(-48.72905610711496), np.float64(-49.792518163401525)]

# %%
# # значения в виде списков чтобы не рассчитывать снова все значения

# snr_range = [20, 22, 24, 26, 28, 30, 32, 34, 36, 38, 40, 42, 44, 46, 48, 50, 52, 54, 56, 58, 
# acpr_right_uk_list = [np.float64(-19.908159326520842), np.float64(-21.85695263610488), np.float64(-23.818630432812846), np.float64(-25.74280605561588), np.float64(-27.685123164021324), np.float64(-29.597578780431057), np.float64(-31.50956145186845), np.float64(-33.408043631235536), np.float64(-35.2641539488935), np.float64(-37.11290256809776), np.float64(-38.87993901305795), np.float64(-40.61697803065708), np.float64(-42.25138725427255), np.float64(-43.7730148204967), np.float64(-45.139205723386205), np.float64(-46.40286494928455), np.float64(-47.41226707888618), np.float64(-48.2239296586826), np.float64(-48.8718445889375), np.float64(-49.305717773680755), np.float64(-49.67857146555004)]

# %%
markersize = 8
plt.figure(figsize=(9, 5))
plt.plot(snr_range, nmse_dla_list,color='blue', linestyle='-', label="Сигнал с предыскажением DLA",
         marker='o', markersize=markersize)
plt.plot(snr_range, nmse_ila_list, color='orange', linestyle='--', label="Сигнал с предыскажением ILA",
         marker='s', markersize=markersize)
plt.plot(snr_range, nmse_ilc_list, color='green', linestyle='-.', label="Сигнал с предыскажением ILC",
         marker='d', markersize=markersize)
plt.plot(snr_range, nmse_uk_list, color='red', linestyle='-.', label="Оптимальный сигнал ILC",
         marker='*', markersize=markersize)

plt.xlabel("ОСШ, дБ", fontsize=12)
plt.ylabel("NMSE, дБ", fontsize=12)
# plt.title("Зависимость NMSE от ОСШ")
plt.xticks(range(20, 61, 5))
plt.yticks(range(-55, -9, 5))
plt.legend()
plt.grid(True)

plt.show()

# %%
markersize=8
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(snr_range, acpr_left_dla_list, color='blue', linestyle='-', label="Сигнал с предыскажением DLA", 
         marker='o', markersize=markersize)
plt.plot(snr_range, acpr_left_ila_list, color='orange', linestyle='--', label="Сигнал с предыскажением ILA", 
         marker='s', markersize=markersize)
plt.plot(snr_range, acpr_left_ilc_list, color='green', linestyle='-.', label="Сигнал с предыскажением ILC", 
         marker='d', markersize=markersize)
plt.plot(snr_range, acpr_left_uk_list, color='red', linestyle='-.', label="Оптимальный сигнал ILC", 
         marker='*', markersize=markersize)
plt.title('Левый канал', fontsize=12)
plt.xlabel('ОСШ, дБ', fontsize=12)
plt.ylabel('ACPR, дБ', fontsize=12)
plt.xticks(range(20, 61, 5))
plt.yticks(range(-55, -14, 5))
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(snr_range, acpr_right_dla_list, color='blue', linestyle='-', label="Сигнал с предыскажением DLA", 
         marker='o', markersize=markersize)
plt.plot(snr_range, acpr_right_ila_list, color='orange', linestyle='--', label="Сигнал с предыскажением ILA", 
         marker='s', markersize=markersize)
plt.plot(snr_range, acpr_right_ilc_list, color='green', linestyle='-.', label="Сигнал с предыскажением ILC", 
         marker='d', markersize=markersize)
plt.plot(snr_range, acpr_right_uk_list, color='red', linestyle='-.', label="Оптимальный сигнал ILC", 
         marker='*', markersize=markersize)
plt.title('Правый канал', fontsize=12)
plt.xlabel('ОСШ, дБ', fontsize=12)
plt.ylabel('ACPR, дБ', fontsize=12)
plt.xticks(range(20, 61, 5))
plt.yticks(range(-55, -14, 5))
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
