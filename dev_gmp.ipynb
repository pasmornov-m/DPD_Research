# %%
# %load_ext autoreload
# %autoreload 2

# %%
from modules import data_loader, metrics, learning, plotting, utils, params, pipelines
from modules.gmp_model import ClassicGMP, BatchGMP
import matplotlib.pyplot as plt
import numpy as np
import torch

# %% [markdown]
# Load data from files and init acpr meter

# %%
data = data_loader.load_data("DPA_200MHz")

config = data["config"]
fs = config["input_signal_fs"]
bw_main_ch = config["bw_main_ch"]
bw_sub_ch = config["bw_sub_ch"]
n_sub_ch = config["n_sub_ch"]
sub_ch = config["sub_ch"]
nperseg = config["nperseg"]

x_train = data["train_input"]
y_train = data["train_output"]
x_val = data["val_input"]
y_val = data["val_output"]

gain = metrics.calculate_gain_complex(x_train, y_train)
print(f"Gain of PA = {gain:.2f}")
y_train_target = gain * x_train
y_val_target = gain * x_val

data['y_train_target'] = y_train_target
data['y_val_target'] = y_val_target


acpr_meter = metrics.ACPR(
        sample_rate=fs,
        main_measurement_bandwidth=bw_main_ch,
        adjacent_channel_offset=[-sub_ch, sub_ch],
        segment_length=nperseg,
        overlap_percentage=60,
        window='blackmanharris',
        fft_length=nperseg,
        power_units='dBW',
        return_main_power=True,
        return_adjacent_powers=True
    )
# Out:
# Gain of PA = 2.52

# %%
frame_length = 64
batch_size = 256
batch_size_eval = 2048

pa_train_loader, pa_val_loader = data_loader.build_dataloaders(data_dict=data, frame_length=frame_length, batch_size=batch_size, batch_size_eval=batch_size_eval)
dla_train_loader, dla_val_loader = data_loader.build_dataloaders(data_dict=data, frame_length=frame_length, batch_size=batch_size, batch_size_eval=batch_size_eval, arch="dla")
ila_train_loader, ila_val_loader = data_loader.build_dataloaders(data_dict=data, frame_length=frame_length, batch_size=batch_size, batch_size_eval=batch_size_eval, arch="ila")

criterion = metrics.compute_mse
metric_criterion = metrics.compute_nmse

# %% [markdown]
# PA model

# %%
# pa_train_loader = [(x_train, y_train)]
# pa_val_loader = [(x_val, y_val)]
# pa_val_loader = pa_train_loader


pa_degree = 2
pa_config = params.make_gmp_params(
    Ka=pa_degree,
    La=pa_degree,
    Kb=pa_degree,
    Lb=pa_degree,
    Mb=pa_degree,
    Kc=pa_degree,
    Lc=pa_degree,
    Mc=pa_degree,
)

pa_model = BatchGMP(**pa_config, model_name="pa")


print(f"total_params: {pa_model.count_params()}")

epochs = 50
lr = 0.01

optimizer = torch.optim.AdamW(pa_model.parameters(), lr=lr)

if not pa_model.load_weights():
      learning.train(net=pa_model, 
            criterion=criterion, 
            optimizer=optimizer, 
            train_loader=pa_train_loader, 
            val_loader=pa_val_loader, 
            n_epochs=epochs, 
            metric_criterion=metric_criterion)
      pa_model.save_weights()
utils.freeze_pa_model(pa_model)

y_val_pa = learning.net_inference(net=pa_model, x=x_val)
pa_nmse = metrics.compute_nmse(y_val_pa, y_val)
print(f"Model NMSE: {pa_nmse:.2f}")
# Out:
# total_params: 40
# Coefficients loaded from model_params/pa_BatchGMP_Ka2_La2_Kb2_Lb2_Mb2_Kc2_Lc2_Mc2.pt
# Model NMSE: -27.77

# %%
with torch.autograd.profiler.profile(use_cuda=False) as prof:
    with torch.no_grad():
        output = pa_model.forward(x_val)

print(prof.key_averages().table(sort_by="cpu_time_total", row_limit=20))
# Out:
# -------------------------  ------------  ------------  ------------  ------------  ------------  ------------
#                      Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg    # of Calls
# -------------------------  ------------  ------------  ------------  ------------  ------------  ------------
#                 aten::pow        24.72%     953.600us        24.78%     955.800us     106.200us             9
#                 aten::mul        18.69%     721.000us        19.22%     741.400us     185.350us             4
#              aten::einsum         1.84%      70.900us        16.35%     630.800us     210.267us             3
#               aten::copy_        15.57%     600.600us        15.57%     600.600us      28.600us            21
#              aten::gather        12.47%     481.100us        12.47%     481.100us      96.220us             5
#                  aten::to         0.48%      18.500us         9.76%     376.600us      15.692us            24
#             aten::reshape         0.43%      16.500us         9.43%     363.800us      60.633us             6
#            aten::_to_copy         1.23%      47.600us         9.28%     358.100us      19.894us            18
#               aten::clone         0.23%       8.900us         8.51%     328.200us     109.400us             3
#                 aten::sub         1.96%      75.700us         3.93%     151.700us      21.671us             7
#                aten::sqrt         3.35%     129.200us         3.35%     129.200us      43.067us             3
#           aten::unsqueeze         2.41%      93.100us         3.01%     116.200us       2.979us            39
#                 aten::add         2.74%     105.500us         2.98%     115.100us      28.775us             4
#                 aten::bmm         2.93%     113.100us         2.95%     113.700us      37.900us             3
#              aten::arange         0.94%      36.100us         2.04%      78.500us      13.083us             6
#             aten::permute         1.17%      45.200us         1.40%      53.900us       3.593us            15
#          aten::as_strided         1.23%      47.600us         1.23%      47.600us       0.573us            83
#                aten::view         1.16%      44.600us         1.16%      44.600us       2.347us            19
#                 aten::cat         0.91%      35.200us         1.07%      41.300us      41.300us             1
#               aten::slice         0.75%      29.100us         0.88%      33.800us       3.756us             9
# -------------------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 3.857ms

# %%
window_size = 50

freqs, spectrum_y_in = metrics.power_spectrum(x_val, fs, nperseg, window_size)
_, spectrum_y_out = metrics.power_spectrum(y_val, fs, nperseg, window_size)
_, spectrum_y_val_pa = metrics.power_spectrum(y_val_pa, fs, nperseg, window_size)

xlabel="Частота (МГц)"
ylabel= "Спектральная плотность мощности (дБ)"
fontsize = 12
figsize=(12, 6)

plt.figure(figsize=figsize)

plt.plot(freqs / 1e6, spectrum_y_in, color='grey', label='Входной сигнал')
plt.plot(freqs / 1e6, spectrum_y_out, color='black', label='Выходной сигнал')
plt.plot(freqs / 1e6, spectrum_y_val_pa, color='gold', label='Выходной сигнал PA')

plt.xlabel(xlabel, fontsize=fontsize)
plt.ylabel(ylabel, fontsize=fontsize)
# plt.xlim(-400, 400)
plt.legend()
plt.grid()
plt.show()
# Out:
# c:\Users\maximp\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\signal\_spectral_py.py:652: UserWarning: Input data is complex, switching to return_onesided=False
#   freqs, Pxx = csd(x, x, fs=fs, window=window, nperseg=nperseg,

# %% [markdown]
# DLA DPD grad

# %%
# dla_train_loader = [(x_train, y_train_target)]
# # dla_val_loader = [(x_val, y_val_target)]
# dla_val_loader = dla_train_loader

epochs = 300
lr = 0.01

dla_degree = 2
dla_config = params.make_gmp_params(
    Ka=dla_degree,
    La=dla_degree,
    Kb=dla_degree,
    Lb=dla_degree,
    Mb=dla_degree,
    Kc=dla_degree,
    Lc=dla_degree,
    Mc=dla_degree,
)
dpd_model_dla = BatchGMP(**dla_config, model_name="dla")
print(f"total_params: {dpd_model_dla.count_params()}")

is_load = dpd_model_dla.load_weights()
casc_dla = utils.CascadeModel(model_1=dpd_model_dla, model_2=pa_model)

optimizer_dla = torch.optim.AdamW(casc_dla.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=10)

if not is_load:
    learning.train(net=casc_dla, 
                   criterion=criterion, 
                   optimizer=optimizer_dla, 
                   train_loader=dla_train_loader, 
                   val_loader=dla_val_loader, 
                   grad_clip_val=0, 
                   n_epochs=epochs, 
                   metric_criterion=metric_criterion,
                   scheduler=scheduler)
    dpd_model_dla.save_weights()

y_val_dla = learning.net_inference(net=casc_dla, x=x_val)
nmse_dla = metrics.compute_nmse(y_val_dla, y_val_target)
print(f"Model NMSE: {nmse_dla:.2f}")
# Out:
# total_params: 40
# No saved coefficients found at model_params/dla_BatchGMP_Ka2_La2_Kb2_Lb2_Mb2_Kc2_Lc2_Mc2.pt, initializing new parameters.
# ===Start training===
# Epoch 0000 — train_loss: 0.000458, val_loss: 0.000436, val_NMSE: -29.52, lr: 1.9073486328125e-08
# Epoch 0001 — train_loss: 0.000145, val_loss: 0.000132, val_NMSE: -34.70, lr: 1.9073486328125e-08
# Epoch 0002 — train_loss: 0.000072, val_loss: 0.000064, val_NMSE: -37.87, lr: 1.9073486328125e-08
# Epoch 0003 — train_loss: 0.000040, val_loss: 0.000035, val_NMSE: -40.53, lr: 1.9073486328125e-08
# Epoch 0004 — train_loss: 0.000026, val_loss: 0.000021, val_NMSE: -42.63, lr: 1.9073486328125e-08
# Epoch 0005 — train_loss: 0.000018, val_loss: 0.000014, val_NMSE: -44.40, lr: 1.9073486328125e-08
# Epoch 0006 — train_loss: 0.000014, val_loss: 0.000011, val_NMSE: -45.57, lr: 1.9073486328125e-08
# Epoch 0007 — train_loss: 0.000012, val_loss: 0.000009, val_NMSE: -46.35, lr: 1.9073486328125e-08
# Epoch 0008 — train_loss: 0.000010, val_loss: 0.000008, val_NMSE: -46.77, lr: 1.9073486328125e-08
# Epoch 0009 — train_loss: 0.000009, val_loss: 0.000008, val_NMSE: -46.97, lr: 1.9073486328125e-08
# Epoch 0010 — train_loss: 0.000010, val_loss: 0.000008, val_NMSE: -47.13, lr: 1.9073486328125e-08
# Epoch 0011 — train_loss: 0.000010, val_loss: 0.000007, val_NMSE: -47.24, lr: 1.9073486328125e-08
# Epoch 0012 — train_loss: 0.000009, val_loss: 0.000007, val_NMSE: -47.32, lr: 1.9073486328125e-08
# Epoch 0013 — train_loss: 0.000009, val_loss: 0.000007, val_NMSE: -47.33, lr: 1.9073486328125e-08
# Epoch 0014 — train_loss: 0.000009, val_loss: 0.000008, val_NMSE: -47.06, lr: 1.9073486328125e-08
# Epoch 0015 — train_loss: 0.000008, val_loss: 0.000007, val_NMSE: -47.36, lr: 1.9073486328125e-08
# Epoch 0016 — train_loss: 0.000013, val_loss: 0.000010, val_NMSE: -45.95, lr: 1.9073486328125e-08
# Epoch 0017 — train_loss: 0.000010, val_loss: 0.000008, val_NMSE: -47.05, lr: 1.9073486328125e-08
# Epoch 0018 — train_loss: 0.000011, val_loss: 0.000011, val_NMSE: -45.54, lr: 1.9073486328125e-08
# Epoch 0019 — train_loss: 0.000014, val_loss: 0.000009, val_NMSE: -46.23, lr: 1.9073486328125e-08
# Epoch 0020 — train_loss: 0.000016, val_loss: 0.000017, val_NMSE: -43.64, lr: 1.9073486328125e-08
# Epoch 0021 — train_loss: 0.000009, val_loss: 0.000007, val_NMSE: -47.22, lr: 1.9073486328125e-08
# Epoch 0022 — train_loss: 0.000009, val_loss: 0.000007, val_NMSE: -47.67, lr: 1.9073486328125e-08
# Epoch 0023 — train_loss: 0.000008, val_loss: 0.000007, val_NMSE: -47.74, lr: 1.9073486328125e-08
# Epoch 0024 — train_loss: 0.000008, val_loss: 0.000007, val_NMSE: -47.44, lr: 1.9073486328125e-08
# Epoch 0025 — train_loss: 0.000016, val_loss: 0.000052, val_NMSE: -38.76, lr: 1.9073486328125e-08
# Epoch 0026 — train_loss: 0.000008, val_loss: 0.000006, val_NMSE: -47.90, lr: 1.9073486328125e-08
# Epoch 0027 — train_loss: 0.000008, val_loss: 0.000006, val_NMSE: -47.92, lr: 1.9073486328125e-08
# Epoch 0028 — train_loss: 0.000009, val_loss: 0.000009, val_NMSE: -46.33, lr: 1.9073486328125e-08
# Epoch 0029 — train_loss: 0.000008, val_loss: 0.000006, val_NMSE: -47.79, lr: 1.9073486328125e-08
# Epoch 0030 — train_loss: 0.000009, val_loss: 0.000007, val_NMSE: -47.57, lr: 1.9073486328125e-08
# Epoch 0031 — train_loss: 0.000027, val_loss: 0.000026, val_NMSE: -41.68, lr: 1.9073486328125e-08
# Epoch 0032 — train_loss: 0.000021, val_loss: 0.000016, val_NMSE: -43.89, lr: 1.9073486328125e-08
# Epoch 0033 — train_loss: 0.000010, val_loss: 0.000007, val_NMSE: -47.47, lr: 1.9073486328125e-08
# Epoch 0034 — train_loss: 0.000029, val_loss: 0.000036, val_NMSE: -40.40, lr: 1.9073486328125e-08
# Epoch 0035 — train_loss: 0.000009, val_loss: 0.000008, val_NMSE: -46.91, lr: 1.9073486328125e-08
# Epoch 0036 — train_loss: 0.000012, val_loss: 0.000008, val_NMSE: -46.66, lr: 1.9073486328125e-08
# Epoch 0037 — train_loss: 0.000008, val_loss: 0.000006, val_NMSE: -48.06, lr: 1.9073486328125e-08
# Epoch 0038 — train_loss: 0.000026, val_loss: 0.000025, val_NMSE: -41.86, lr: 1.9073486328125e-08
# Epoch 0039 — train_loss: 0.000012, val_loss: 0.000012, val_NMSE: -45.21, lr: 1.9073486328125e-08
# Epoch 0040 — train_loss: 0.000012, val_loss: 0.000015, val_NMSE: -44.04, lr: 1.9073486328125e-08
# Epoch 0041 — train_loss: 0.000008, val_loss: 0.000009, val_NMSE: -46.32, lr: 1.9073486328125e-08
# Epoch 0042 — train_loss: 0.000009, val_loss: 0.000008, val_NMSE: -46.75, lr: 1.9073486328125e-08
# Epoch 0043 — train_loss: 0.000015, val_loss: 0.000010, val_NMSE: -45.73, lr: 1.9073486328125e-08
# Epoch 0044 — train_loss: 0.000018, val_loss: 0.000023, val_NMSE: -42.36, lr: 1.9073486328125e-08
# Epoch 0045 — train_loss: 0.000014, val_loss: 0.000010, val_NMSE: -46.02, lr: 1.9073486328125e-08
# Epoch 0046 — train_loss: 0.000013, val_loss: 0.000013, val_NMSE: -44.88, lr: 1.9073486328125e-08
# Epoch 0047 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.36, lr: 1.9073486328125e-08
# Epoch 0048 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -47.43, lr: 1.9073486328125e-08
# Epoch 0049 — train_loss: 0.000173, val_loss: 0.000083, val_NMSE: -36.71, lr: 1.9073486328125e-08
# Epoch 0050 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.07, lr: 1.9073486328125e-08
# Epoch 0051 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.35, lr: 1.9073486328125e-08
# Epoch 0052 — train_loss: 0.000063, val_loss: 0.000083, val_NMSE: -36.70, lr: 1.9073486328125e-08
# Epoch 0053 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.24, lr: 1.9073486328125e-08
# Epoch 0054 — train_loss: 0.000011, val_loss: 0.000010, val_NMSE: -45.78, lr: 1.9073486328125e-08
# Epoch 0055 — train_loss: 0.000016, val_loss: 0.000017, val_NMSE: -43.72, lr: 1.9073486328125e-08
# Epoch 0056 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.18, lr: 1.9073486328125e-08
# Epoch 0057 — train_loss: 0.000018, val_loss: 0.000013, val_NMSE: -44.72, lr: 1.9073486328125e-08
# Epoch 0058 — train_loss: 0.000012, val_loss: 0.000019, val_NMSE: -43.21, lr: 1.9073486328125e-08
# Epoch 0059 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -47.51, lr: 1.9073486328125e-08
# Epoch 0060 — train_loss: 0.000008, val_loss: 0.000007, val_NMSE: -47.69, lr: 1.9073486328125e-08
# Epoch 0061 — train_loss: 0.000008, val_loss: 0.000007, val_NMSE: -47.23, lr: 1.9073486328125e-08
# Epoch 0062 — train_loss: 0.000008, val_loss: 0.000007, val_NMSE: -47.58, lr: 1.9073486328125e-08
# Epoch 0063 — train_loss: 0.000021, val_loss: 0.000038, val_NMSE: -40.16, lr: 1.9073486328125e-08
# Epoch 0064 — train_loss: 0.000010, val_loss: 0.000008, val_NMSE: -46.78, lr: 1.9073486328125e-08
# Epoch 0065 — train_loss: 0.000010, val_loss: 0.000008, val_NMSE: -46.70, lr: 1.9073486328125e-08
# Epoch 0066 — train_loss: 0.000006, val_loss: 0.000006, val_NMSE: -48.32, lr: 1.9073486328125e-08
# Epoch 0067 — train_loss: 0.000009, val_loss: 0.000007, val_NMSE: -47.47, lr: 1.9073486328125e-08
# Epoch 0068 — train_loss: 0.000008, val_loss: 0.000008, val_NMSE: -46.91, lr: 1.9073486328125e-08
# Epoch 0069 — train_loss: 0.000014, val_loss: 0.000010, val_NMSE: -46.00, lr: 1.9073486328125e-08
# Epoch 0070 — train_loss: 0.000008, val_loss: 0.000008, val_NMSE: -46.90, lr: 1.9073486328125e-08
# Epoch 0071 — train_loss: 0.000009, val_loss: 0.000011, val_NMSE: -45.67, lr: 1.9073486328125e-08
# Epoch 0072 — train_loss: 0.000063, val_loss: 0.000039, val_NMSE: -40.03, lr: 1.9073486328125e-08
# Epoch 0073 — train_loss: 0.000007, val_loss: 0.000008, val_NMSE: -46.66, lr: 1.9073486328125e-08
# Epoch 0074 — train_loss: 0.000011, val_loss: 0.000009, val_NMSE: -46.59, lr: 1.9073486328125e-08
# Epoch 0075 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -47.99, lr: 1.9073486328125e-08
# Epoch 0076 — train_loss: 0.000007, val_loss: 0.000016, val_NMSE: -43.84, lr: 1.9073486328125e-08
# Epoch 0077 — train_loss: 0.000010, val_loss: 0.000007, val_NMSE: -47.38, lr: 1.9073486328125e-08
# Epoch 0078 — train_loss: 0.000019, val_loss: 0.000020, val_NMSE: -42.89, lr: 1.9073486328125e-08
# Epoch 0079 — train_loss: 0.000007, val_loss: 0.000009, val_NMSE: -46.50, lr: 1.9073486328125e-08
# Epoch 0080 — train_loss: 0.000009, val_loss: 0.000007, val_NMSE: -47.76, lr: 1.9073486328125e-08
# Epoch 0081 — train_loss: 0.000008, val_loss: 0.000008, val_NMSE: -47.02, lr: 1.9073486328125e-08
# Epoch 0082 — train_loss: 0.000508, val_loss: 0.000455, val_NMSE: -29.33, lr: 1.9073486328125e-08
# Epoch 0083 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.30, lr: 1.9073486328125e-08
# Epoch 0084 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.34, lr: 1.9073486328125e-08
# Epoch 0085 — train_loss: 0.000032, val_loss: 0.000024, val_NMSE: -42.05, lr: 1.9073486328125e-08
# Epoch 0086 — train_loss: 0.000031, val_loss: 0.000069, val_NMSE: -37.54, lr: 1.9073486328125e-08
# Epoch 0087 — train_loss: 0.000008, val_loss: 0.000007, val_NMSE: -47.66, lr: 1.9073486328125e-08
# Epoch 0088 — train_loss: 0.000013, val_loss: 0.000007, val_NMSE: -47.50, lr: 1.9073486328125e-08
# Epoch 0089 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.02, lr: 1.9073486328125e-08
# Epoch 0090 — train_loss: 0.000012, val_loss: 0.000010, val_NMSE: -45.79, lr: 1.9073486328125e-08
# Epoch 0091 — train_loss: 0.000026, val_loss: 0.000020, val_NMSE: -42.99, lr: 1.9073486328125e-08
# Epoch 0092 — train_loss: 0.000008, val_loss: 0.000006, val_NMSE: -48.10, lr: 1.9073486328125e-08
# Epoch 0093 — train_loss: 0.000012, val_loss: 0.000010, val_NMSE: -46.01, lr: 1.9073486328125e-08
# Epoch 0094 — train_loss: 0.000047, val_loss: 0.000061, val_NMSE: -38.03, lr: 1.9073486328125e-08
# Epoch 0095 — train_loss: 0.000071, val_loss: 0.000008, val_NMSE: -47.08, lr: 1.9073486328125e-08
# Epoch 0096 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.32, lr: 1.9073486328125e-08
# Epoch 0097 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.30, lr: 1.9073486328125e-08
# Epoch 0098 — train_loss: 0.000024, val_loss: 0.000019, val_NMSE: -43.18, lr: 1.9073486328125e-08
# Epoch 0099 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -47.70, lr: 1.9073486328125e-08
# Epoch 0100 — train_loss: 0.000028, val_loss: 0.000021, val_NMSE: -42.70, lr: 1.9073486328125e-08
# Epoch 0101 — train_loss: 0.000009, val_loss: 0.000008, val_NMSE: -47.11, lr: 1.9073486328125e-08
# Epoch 0102 — train_loss: 0.000010, val_loss: 0.000009, val_NMSE: -46.56, lr: 1.9073486328125e-08
# Epoch 0103 — train_loss: 0.000008, val_loss: 0.000006, val_NMSE: -48.37, lr: 1.9073486328125e-08
# Epoch 0104 — train_loss: 0.000340, val_loss: 0.000210, val_NMSE: -32.69, lr: 1.9073486328125e-08
# Epoch 0105 — train_loss: 0.000008, val_loss: 0.000006, val_NMSE: -48.41, lr: 1.9073486328125e-08
# Epoch 0106 — train_loss: 0.000008, val_loss: 0.000007, val_NMSE: -47.63, lr: 1.9073486328125e-08
# Epoch 0107 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.15, lr: 1.9073486328125e-08
# Epoch 0108 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.37, lr: 1.9073486328125e-08
# Epoch 0109 — train_loss: 0.000206, val_loss: 0.000227, val_NMSE: -32.35, lr: 1.9073486328125e-08
# Epoch 0110 — train_loss: 0.000009, val_loss: 0.000008, val_NMSE: -47.04, lr: 1.9073486328125e-08
# Epoch 0111 — train_loss: 0.000011, val_loss: 0.000014, val_NMSE: -44.41, lr: 1.9073486328125e-08
# Epoch 0112 — train_loss: 0.000010, val_loss: 0.000009, val_NMSE: -46.15, lr: 1.9073486328125e-08
# Epoch 0113 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.13, lr: 1.9073486328125e-08
# Epoch 0114 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -47.60, lr: 1.9073486328125e-08
# Epoch 0115 — train_loss: 0.000011, val_loss: 0.000011, val_NMSE: -45.58, lr: 1.9073486328125e-08
# Epoch 0116 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -47.84, lr: 1.9073486328125e-08
# Epoch 0117 — train_loss: 0.000009, val_loss: 0.000008, val_NMSE: -47.13, lr: 1.9073486328125e-08
# Epoch 0118 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.42, lr: 1.9073486328125e-08
# Epoch 0119 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.29, lr: 1.9073486328125e-08
# Epoch 0120 — train_loss: 0.000069, val_loss: 0.000024, val_NMSE: -42.09, lr: 1.9073486328125e-08
# Epoch 0121 — train_loss: 0.000011, val_loss: 0.000010, val_NMSE: -45.95, lr: 1.9073486328125e-08
# Epoch 0122 — train_loss: 0.000014, val_loss: 0.000014, val_NMSE: -44.54, lr: 1.9073486328125e-08
# Epoch 0123 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -47.81, lr: 1.9073486328125e-08
# Epoch 0124 — train_loss: 0.000008, val_loss: 0.000006, val_NMSE: -47.81, lr: 1.9073486328125e-08
# Epoch 0125 — train_loss: 0.000015, val_loss: 0.000014, val_NMSE: -44.33, lr: 1.9073486328125e-08
# Epoch 0126 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -47.46, lr: 1.9073486328125e-08
# Epoch 0127 — train_loss: 0.000008, val_loss: 0.000007, val_NMSE: -47.65, lr: 1.9073486328125e-08
# Epoch 0128 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -47.98, lr: 1.9073486328125e-08
# Epoch 0129 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.40, lr: 1.9073486328125e-08
# Epoch 0130 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.06, lr: 1.9073486328125e-08
# Epoch 0131 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.25, lr: 1.9073486328125e-08
# Epoch 0132 — train_loss: 0.000009, val_loss: 0.000006, val_NMSE: -47.89, lr: 1.9073486328125e-08
# Epoch 0133 — train_loss: 0.000301, val_loss: 0.000364, val_NMSE: -30.30, lr: 1.9073486328125e-08
# Epoch 0134 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.32, lr: 1.9073486328125e-08
# Epoch 0135 — train_loss: 0.000009, val_loss: 0.000007, val_NMSE: -47.74, lr: 1.9073486328125e-08
# Epoch 0136 — train_loss: 0.000014, val_loss: 0.000009, val_NMSE: -46.18, lr: 1.9073486328125e-08
# Epoch 0137 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.30, lr: 1.9073486328125e-08
# Epoch 0138 — train_loss: 0.000008, val_loss: 0.000006, val_NMSE: -47.79, lr: 1.9073486328125e-08
# Epoch 0139 — train_loss: 0.000010, val_loss: 0.000010, val_NMSE: -45.88, lr: 1.9073486328125e-08
# Epoch 0140 — train_loss: 0.000009, val_loss: 0.000006, val_NMSE: -47.89, lr: 1.9073486328125e-08
# Epoch 0141 — train_loss: 0.000015, val_loss: 0.000018, val_NMSE: -43.42, lr: 1.9073486328125e-08
# Epoch 0142 — train_loss: 0.000020, val_loss: 0.000012, val_NMSE: -45.26, lr: 1.9073486328125e-08
# Epoch 0143 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.27, lr: 1.9073486328125e-08
# Epoch 0144 — train_loss: 0.000008, val_loss: 0.000007, val_NMSE: -47.38, lr: 1.9073486328125e-08
# Epoch 0145 — train_loss: 0.000314, val_loss: 0.000372, val_NMSE: -30.21, lr: 1.9073486328125e-08
# Epoch 0146 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.30, lr: 1.9073486328125e-08
# Epoch 0147 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.22, lr: 1.9073486328125e-08
# Epoch 0148 — train_loss: 0.000028, val_loss: 0.000032, val_NMSE: -40.86, lr: 1.9073486328125e-08
# Epoch 0149 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.25, lr: 1.9073486328125e-08
# Epoch 0150 — train_loss: 0.000009, val_loss: 0.000007, val_NMSE: -47.65, lr: 1.9073486328125e-08
# Epoch 0151 — train_loss: 0.000028, val_loss: 0.000026, val_NMSE: -41.77, lr: 1.9073486328125e-08
# Epoch 0152 — train_loss: 0.000008, val_loss: 0.000008, val_NMSE: -47.07, lr: 1.9073486328125e-08
# Epoch 0153 — train_loss: 0.000008, val_loss: 0.000008, val_NMSE: -46.72, lr: 1.9073486328125e-08
# Epoch 0154 — train_loss: 0.000015, val_loss: 0.000017, val_NMSE: -43.61, lr: 1.9073486328125e-08
# Epoch 0155 — train_loss: 0.000008, val_loss: 0.000007, val_NMSE: -47.68, lr: 1.9073486328125e-08
# Epoch 0156 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.26, lr: 1.9073486328125e-08
# Epoch 0157 — train_loss: 0.000017, val_loss: 0.000018, val_NMSE: -43.39, lr: 1.9073486328125e-08
# Epoch 0158 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.36, lr: 1.9073486328125e-08
# Epoch 0159 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.38, lr: 1.9073486328125e-08
# Epoch 0160 — train_loss: 0.000030, val_loss: 0.000030, val_NMSE: -41.10, lr: 1.9073486328125e-08
# Epoch 0161 — train_loss: 0.000063, val_loss: 0.000042, val_NMSE: -39.67, lr: 1.9073486328125e-08
# Epoch 0162 — train_loss: 0.000008, val_loss: 0.000006, val_NMSE: -48.36, lr: 1.9073486328125e-08
# Epoch 0163 — train_loss: 0.000008, val_loss: 0.000006, val_NMSE: -48.28, lr: 1.9073486328125e-08
# Epoch 0164 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.37, lr: 1.9073486328125e-08
# Epoch 0165 — train_loss: 0.000016, val_loss: 0.000021, val_NMSE: -42.64, lr: 1.9073486328125e-08
# Epoch 0166 — train_loss: 0.000008, val_loss: 0.000007, val_NMSE: -47.37, lr: 1.9073486328125e-08
# Epoch 0167 — train_loss: 0.000584, val_loss: 0.000476, val_NMSE: -29.13, lr: 1.9073486328125e-08
# Epoch 0168 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.38, lr: 1.9073486328125e-08
# Epoch 0169 — train_loss: 0.000008, val_loss: 0.000007, val_NMSE: -47.37, lr: 1.9073486328125e-08
# Epoch 0170 — train_loss: 0.000046, val_loss: 0.000032, val_NMSE: -40.86, lr: 1.9073486328125e-08
# Epoch 0171 — train_loss: 0.000008, val_loss: 0.000006, val_NMSE: -47.87, lr: 1.9073486328125e-08
# Epoch 0172 — train_loss: 0.000017, val_loss: 0.000014, val_NMSE: -44.47, lr: 1.9073486328125e-08
# Epoch 0173 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.42, lr: 1.9073486328125e-08
# Epoch 0174 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.37, lr: 1.9073486328125e-08
# Epoch 0175 — train_loss: 0.000006, val_loss: 0.000006, val_NMSE: -47.96, lr: 1.9073486328125e-08
# Epoch 0176 — train_loss: 0.000058, val_loss: 0.000129, val_NMSE: -34.81, lr: 1.9073486328125e-08
# Epoch 0177 — train_loss: 0.000008, val_loss: 0.000008, val_NMSE: -47.10, lr: 1.9073486328125e-08
# Epoch 0178 — train_loss: 0.000021, val_loss: 0.000011, val_NMSE: -45.33, lr: 1.9073486328125e-08
# Epoch 0179 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -47.72, lr: 1.9073486328125e-08
# Epoch 0180 — train_loss: 0.000044, val_loss: 0.000063, val_NMSE: -37.91, lr: 1.9073486328125e-08
# Epoch 0181 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.28, lr: 1.9073486328125e-08
# Epoch 0182 — train_loss: 0.000008, val_loss: 0.000007, val_NMSE: -47.37, lr: 1.9073486328125e-08
# Epoch 0183 — train_loss: 0.000015, val_loss: 0.000009, val_NMSE: -46.48, lr: 1.9073486328125e-08
# Epoch 0184 — train_loss: 0.000008, val_loss: 0.000006, val_NMSE: -47.94, lr: 1.9073486328125e-08
# Epoch 0185 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -47.98, lr: 1.9073486328125e-08
# Epoch 0186 — train_loss: 0.000009, val_loss: 0.000008, val_NMSE: -46.81, lr: 1.9073486328125e-08
# Epoch 0187 — train_loss: 0.000116, val_loss: 0.000008, val_NMSE: -46.95, lr: 1.9073486328125e-08
# Epoch 0188 — train_loss: 0.000008, val_loss: 0.000006, val_NMSE: -47.94, lr: 1.9073486328125e-08
# Epoch 0189 — train_loss: 0.000008, val_loss: 0.000006, val_NMSE: -48.23, lr: 1.9073486328125e-08
# Epoch 0190 — train_loss: 0.000100, val_loss: 0.000065, val_NMSE: -37.75, lr: 1.9073486328125e-08
# Epoch 0191 — train_loss: 0.000010, val_loss: 0.000008, val_NMSE: -46.69, lr: 1.9073486328125e-08
# Epoch 0192 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.02, lr: 1.9073486328125e-08
# Epoch 0193 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.31, lr: 1.9073486328125e-08
# Epoch 0194 — train_loss: 0.000008, val_loss: 0.000006, val_NMSE: -48.34, lr: 1.9073486328125e-08
# Epoch 0195 — train_loss: 0.000021, val_loss: 0.000015, val_NMSE: -44.24, lr: 1.9073486328125e-08
# Epoch 0196 — train_loss: 0.000014, val_loss: 0.000014, val_NMSE: -44.51, lr: 1.9073486328125e-08
# Epoch 0197 — train_loss: 0.000077, val_loss: 0.000084, val_NMSE: -36.65, lr: 1.9073486328125e-08
# Epoch 0198 — train_loss: 0.000011, val_loss: 0.000010, val_NMSE: -45.73, lr: 1.9073486328125e-08
# Epoch 0199 — train_loss: 0.000007, val_loss: 0.000009, val_NMSE: -46.31, lr: 1.9073486328125e-08
# Epoch 0200 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -47.88, lr: 1.9073486328125e-08
# Epoch 0201 — train_loss: 0.000008, val_loss: 0.000007, val_NMSE: -47.62, lr: 1.9073486328125e-08
# Epoch 0202 — train_loss: 0.000008, val_loss: 0.000008, val_NMSE: -47.10, lr: 1.9073486328125e-08
# Epoch 0203 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -47.98, lr: 1.9073486328125e-08
# Epoch 0204 — train_loss: 0.000009, val_loss: 0.000008, val_NMSE: -46.89, lr: 1.9073486328125e-08
# Epoch 0205 — train_loss: 0.000018, val_loss: 0.000006, val_NMSE: -47.91, lr: 1.9073486328125e-08
# Epoch 0206 — train_loss: 0.000008, val_loss: 0.000007, val_NMSE: -47.60, lr: 1.9073486328125e-08
# Epoch 0207 — train_loss: 0.000008, val_loss: 0.000006, val_NMSE: -47.92, lr: 1.9073486328125e-08
# Epoch 0208 — train_loss: 0.000009, val_loss: 0.000008, val_NMSE: -46.76, lr: 1.9073486328125e-08
# Epoch 0209 — train_loss: 0.000008, val_loss: 0.000007, val_NMSE: -47.71, lr: 1.9073486328125e-08
# Epoch 0210 — train_loss: 0.000013, val_loss: 0.000012, val_NMSE: -45.16, lr: 1.9073486328125e-08
# Epoch 0211 — train_loss: 0.000019, val_loss: 0.000017, val_NMSE: -43.72, lr: 1.9073486328125e-08
# Epoch 0212 — train_loss: 0.000009, val_loss: 0.000007, val_NMSE: -47.21, lr: 1.9073486328125e-08
# Epoch 0213 — train_loss: 0.000099, val_loss: 0.000079, val_NMSE: -36.92, lr: 1.9073486328125e-08
# Epoch 0214 — train_loss: 0.000012, val_loss: 0.000012, val_NMSE: -45.19, lr: 1.9073486328125e-08
# Epoch 0215 — train_loss: 0.000050, val_loss: 0.000013, val_NMSE: -44.74, lr: 1.9073486328125e-08
# Epoch 0216 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.23, lr: 1.9073486328125e-08
# Epoch 0217 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.22, lr: 1.9073486328125e-08
# Epoch 0218 — train_loss: 0.000010, val_loss: 0.000008, val_NMSE: -47.03, lr: 1.9073486328125e-08
# Epoch 0219 — train_loss: 0.000008, val_loss: 0.000006, val_NMSE: -47.87, lr: 1.9073486328125e-08
# Epoch 0220 — train_loss: 0.000008, val_loss: 0.000006, val_NMSE: -48.10, lr: 1.9073486328125e-08
# Epoch 0221 — train_loss: 0.000079, val_loss: 0.000055, val_NMSE: -38.53, lr: 1.9073486328125e-08
# Epoch 0222 — train_loss: 0.000008, val_loss: 0.000006, val_NMSE: -48.32, lr: 1.9073486328125e-08
# Epoch 0223 — train_loss: 0.000176, val_loss: 0.000123, val_NMSE: -35.00, lr: 1.9073486328125e-08
# Epoch 0224 — train_loss: 0.000008, val_loss: 0.000006, val_NMSE: -47.96, lr: 1.9073486328125e-08
# Epoch 0225 — train_loss: 0.000013, val_loss: 0.000015, val_NMSE: -44.19, lr: 1.9073486328125e-08
# Epoch 0226 — train_loss: 0.000473, val_loss: 0.000582, val_NMSE: -28.26, lr: 1.9073486328125e-08
# Epoch 0227 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.38, lr: 1.9073486328125e-08
# Epoch 0228 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.17, lr: 1.9073486328125e-08
# Epoch 0229 — train_loss: 0.000106, val_loss: 0.000088, val_NMSE: -36.46, lr: 1.9073486328125e-08
# Epoch 0230 — train_loss: 0.000087, val_loss: 0.000106, val_NMSE: -35.65, lr: 1.9073486328125e-08
# Epoch 0231 — train_loss: 0.000009, val_loss: 0.000007, val_NMSE: -47.78, lr: 1.9073486328125e-08
# Epoch 0232 — train_loss: 0.000009, val_loss: 0.000008, val_NMSE: -47.04, lr: 1.9073486328125e-08
# Epoch 0233 — train_loss: 0.000008, val_loss: 0.000020, val_NMSE: -42.90, lr: 1.9073486328125e-08
# Epoch 0234 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.37, lr: 1.9073486328125e-08
# Epoch 0235 — train_loss: 0.000112, val_loss: 0.000046, val_NMSE: -39.30, lr: 1.9073486328125e-08
# Epoch 0236 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -47.79, lr: 1.9073486328125e-08
# Epoch 0237 — train_loss: 0.000020, val_loss: 0.000015, val_NMSE: -44.28, lr: 1.9073486328125e-08
# Epoch 0238 — train_loss: 0.000029, val_loss: 0.000020, val_NMSE: -42.83, lr: 1.9073486328125e-08
# Epoch 0239 — train_loss: 0.000008, val_loss: 0.000007, val_NMSE: -47.17, lr: 1.9073486328125e-08
# Epoch 0240 — train_loss: 0.000071, val_loss: 0.000057, val_NMSE: -38.37, lr: 1.9073486328125e-08
# Epoch 0241 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -47.19, lr: 1.9073486328125e-08
# Epoch 0242 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.34, lr: 1.9073486328125e-08
# Epoch 0243 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -47.48, lr: 1.9073486328125e-08
# Epoch 0244 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -47.95, lr: 1.9073486328125e-08
# Epoch 0245 — train_loss: 0.000008, val_loss: 0.000006, val_NMSE: -47.79, lr: 1.9073486328125e-08
# Epoch 0246 — train_loss: 0.000009, val_loss: 0.000008, val_NMSE: -46.64, lr: 1.9073486328125e-08
# Epoch 0247 — train_loss: 0.000012, val_loss: 0.000012, val_NMSE: -45.04, lr: 1.9073486328125e-08
# Epoch 0248 — train_loss: 0.000010, val_loss: 0.000007, val_NMSE: -47.33, lr: 1.9073486328125e-08
# Epoch 0249 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.06, lr: 1.9073486328125e-08
# Epoch 0250 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -47.84, lr: 1.9073486328125e-08
# Epoch 0251 — train_loss: 0.000011, val_loss: 0.000015, val_NMSE: -44.22, lr: 1.9073486328125e-08
# Epoch 0252 — train_loss: 0.000008, val_loss: 0.000007, val_NMSE: -47.76, lr: 1.9073486328125e-08
# Epoch 0253 — train_loss: 0.000008, val_loss: 0.000016, val_NMSE: -43.89, lr: 1.9073486328125e-08
# Epoch 0254 — train_loss: 0.000008, val_loss: 0.000007, val_NMSE: -47.62, lr: 1.9073486328125e-08
# Epoch 0255 — train_loss: 0.000124, val_loss: 0.000054, val_NMSE: -38.57, lr: 1.9073486328125e-08
# Epoch 0256 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.10, lr: 1.9073486328125e-08
# Epoch 0257 — train_loss: 0.000018, val_loss: 0.000026, val_NMSE: -41.73, lr: 1.9073486328125e-08
# Epoch 0258 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.03, lr: 1.9073486328125e-08
# Epoch 0259 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -47.90, lr: 1.9073486328125e-08
# Epoch 0260 — train_loss: 0.000010, val_loss: 0.000011, val_NMSE: -45.64, lr: 1.9073486328125e-08
# Epoch 0261 — train_loss: 0.000009, val_loss: 0.000009, val_NMSE: -46.23, lr: 1.9073486328125e-08
# Epoch 0262 — train_loss: 0.000016, val_loss: 0.000015, val_NMSE: -44.19, lr: 1.9073486328125e-08
# Epoch 0263 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -47.91, lr: 1.9073486328125e-08
# Epoch 0264 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.38, lr: 1.9073486328125e-08
# Epoch 0265 — train_loss: 0.000009, val_loss: 0.000017, val_NMSE: -43.56, lr: 1.9073486328125e-08
# Epoch 0266 — train_loss: 0.000008, val_loss: 0.000006, val_NMSE: -47.83, lr: 1.9073486328125e-08
# Epoch 0267 — train_loss: 0.000010, val_loss: 0.000013, val_NMSE: -44.84, lr: 1.9073486328125e-08
# Epoch 0268 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.31, lr: 1.9073486328125e-08
# Epoch 0269 — train_loss: 0.000009, val_loss: 0.000009, val_NMSE: -46.21, lr: 1.9073486328125e-08
# Epoch 0270 — train_loss: 0.000012, val_loss: 0.000013, val_NMSE: -44.69, lr: 1.9073486328125e-08
# Epoch 0271 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.42, lr: 1.9073486328125e-08
# Epoch 0272 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -47.98, lr: 1.9073486328125e-08
# Epoch 0273 — train_loss: 0.000011, val_loss: 0.000008, val_NMSE: -46.84, lr: 1.9073486328125e-08
# Epoch 0274 — train_loss: 0.000009, val_loss: 0.000008, val_NMSE: -46.85, lr: 1.9073486328125e-08
# Epoch 0275 — train_loss: 0.000008, val_loss: 0.000018, val_NMSE: -43.30, lr: 1.9073486328125e-08
# Epoch 0276 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -47.74, lr: 1.9073486328125e-08
# Epoch 0277 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.40, lr: 1.9073486328125e-08
# Epoch 0278 — train_loss: 0.000029, val_loss: 0.000037, val_NMSE: -40.23, lr: 1.9073486328125e-08
# Epoch 0279 — train_loss: 0.000008, val_loss: 0.000009, val_NMSE: -46.52, lr: 1.9073486328125e-08
# Epoch 0280 — train_loss: 0.000013, val_loss: 0.000016, val_NMSE: -43.80, lr: 1.9073486328125e-08
# Epoch 0281 — train_loss: 0.000044, val_loss: 0.000028, val_NMSE: -41.46, lr: 1.9073486328125e-08
# Epoch 0282 — train_loss: 0.000026, val_loss: 0.000021, val_NMSE: -42.69, lr: 1.9073486328125e-08
# Epoch 0283 — train_loss: 0.000225, val_loss: 0.000340, val_NMSE: -30.60, lr: 1.9073486328125e-08
# Epoch 0284 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.17, lr: 1.9073486328125e-08
# Epoch 0285 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -47.64, lr: 1.9073486328125e-08
# Epoch 0286 — train_loss: 0.000009, val_loss: 0.000009, val_NMSE: -46.34, lr: 1.9073486328125e-08
# Epoch 0287 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.19, lr: 1.9073486328125e-08
# Epoch 0288 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.14, lr: 1.9073486328125e-08
# Epoch 0289 — train_loss: 0.000058, val_loss: 0.000062, val_NMSE: -37.97, lr: 1.9073486328125e-08
# Epoch 0290 — train_loss: 0.000042, val_loss: 0.000040, val_NMSE: -39.87, lr: 1.9073486328125e-08
# Epoch 0291 — train_loss: 0.000011, val_loss: 0.000006, val_NMSE: -47.81, lr: 1.9073486328125e-08
# Epoch 0292 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.38, lr: 1.9073486328125e-08
# Epoch 0293 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.28, lr: 1.9073486328125e-08
# Epoch 0294 — train_loss: 0.000040, val_loss: 0.000019, val_NMSE: -43.16, lr: 1.9073486328125e-08
# Epoch 0295 — train_loss: 0.000009, val_loss: 0.000009, val_NMSE: -46.42, lr: 1.9073486328125e-08
# Epoch 0296 — train_loss: 0.000011, val_loss: 0.000006, val_NMSE: -47.88, lr: 1.9073486328125e-08
# Epoch 0297 — train_loss: 0.000010, val_loss: 0.000010, val_NMSE: -46.08, lr: 1.9073486328125e-08
# Epoch 0298 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -47.51, lr: 1.9073486328125e-08
# Epoch 0299 — train_loss: 0.000007, val_loss: 0.000006, val_NMSE: -48.24, lr: 1.9073486328125e-08
# ===Training complete===
# Выполнение заняло: 0:13:01
# Coefficients saved to model_params/dla_BatchGMP_Ka2_La2_Kb2_Lb2_Mb2_Kc2_Lc2_Mc2.pt
# Model NMSE: -48.14

# %% [markdown]
# ILA DPD grad

# %%
# ila_train_loader = [(x_train, x_train)]
# ila_val_loader = [(x_val, x_val)]

epochs = 300
lr = 0.01

ila_degree = 2
ila_config = params.make_gmp_params(
    Ka=ila_degree,
    La=ila_degree,
    Kb=ila_degree,
    Lb=ila_degree,
    Mb=ila_degree,
    Kc=ila_degree,
    Lc=ila_degree,
    Mc=ila_degree,
)
dpd_model_ila = BatchGMP(**ila_config, model_name="ila")

is_load = dpd_model_ila.load_weights()
casc_ila_train = utils.CascadeModel(model_2=dpd_model_ila, model_1=pa_model, gain=gain, cascade_type="ila")
casc_ila_eval = utils.CascadeModel(model_1=dpd_model_ila, model_2=pa_model)

optimizer = torch.optim.AdamW(casc_ila_train.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=10)

if not is_load:
    learning.train(net=casc_ila_train, 
                   criterion=criterion, 
                   optimizer=optimizer, 
                   train_loader=ila_train_loader, 
                   val_loader=ila_val_loader, 
                   grad_clip_val=0, 
                   n_epochs=epochs, 
                   metric_criterion=metric_criterion,
                   scheduler=scheduler)
    dpd_model_ila.save_weights()

y_val_ila = learning.net_inference(net=casc_ila_eval, x=x_val)
nmse_ila = metrics.compute_nmse(y_val_ila, y_val_target)
print(f"Model NMSE: {nmse_ila:.2f}")
# Out:
# No saved coefficients found at model_params/ila_BatchGMP_Ka2_La2_Kb2_Lb2_Mb2_Kc2_Lc2_Mc2.pt, initializing new parameters.
# ===Start training===
# Epoch 0000 — train_loss: 0.000066, val_loss: 0.000066, val_NMSE: -29.66, lr: 0.01
# Epoch 0001 — train_loss: 0.000021, val_loss: 0.000020, val_NMSE: -34.87, lr: 0.01
# Epoch 0002 — train_loss: 0.000011, val_loss: 0.000010, val_NMSE: -37.85, lr: 0.01
# Epoch 0003 — train_loss: 0.000006, val_loss: 0.000006, val_NMSE: -40.25, lr: 0.01
# Epoch 0004 — train_loss: 0.000005, val_loss: 0.000004, val_NMSE: -42.06, lr: 0.01
# Epoch 0005 — train_loss: 0.000003, val_loss: 0.000003, val_NMSE: -43.42, lr: 0.01
# Epoch 0006 — train_loss: 0.000003, val_loss: 0.000002, val_NMSE: -44.34, lr: 0.01
# Epoch 0007 — train_loss: 0.000002, val_loss: 0.000002, val_NMSE: -44.87, lr: 0.01
# Epoch 0008 — train_loss: 0.000002, val_loss: 0.000002, val_NMSE: -45.22, lr: 0.01
# Epoch 0009 — train_loss: 0.000002, val_loss: 0.000002, val_NMSE: -45.36, lr: 0.01
# Epoch 0010 — train_loss: 0.000002, val_loss: 0.000002, val_NMSE: -45.41, lr: 0.01
# Epoch 0011 — train_loss: 0.000002, val_loss: 0.000002, val_NMSE: -45.55, lr: 0.01
# Epoch 0012 — train_loss: 0.000002, val_loss: 0.000002, val_NMSE: -45.63, lr: 0.01
# Epoch 0013 — train_loss: 0.000002, val_loss: 0.000002, val_NMSE: -45.70, lr: 0.01
# Epoch 0014 — train_loss: 0.000002, val_loss: 0.000002, val_NMSE: -45.70, lr: 0.01
# Epoch 0015 — train_loss: 0.000002, val_loss: 0.000002, val_NMSE: -45.75, lr: 0.01
# Epoch 0016 — train_loss: 0.000002, val_loss: 0.000002, val_NMSE: -45.48, lr: 0.01
# Epoch 0017 — train_loss: 0.000002, val_loss: 0.000002, val_NMSE: -45.69, lr: 0.01
# Epoch 0018 — train_loss: 0.000002, val_loss: 0.000002, val_NMSE: -45.78, lr: 0.01
# Epoch 0019 — train_loss: 0.000003, val_loss: 0.000002, val_NMSE: -44.10, lr: 0.01
# Epoch 0020 — train_loss: 0.000006, val_loss: 0.000005, val_NMSE: -41.18, lr: 0.01
# Epoch 0021 — train_loss: 0.000002, val_loss: 0.000002, val_NMSE: -45.28, lr: 0.01
# Epoch 0022 — train_loss: 0.000002, val_loss: 0.000002, val_NMSE: -45.92, lr: 0.01
# Epoch 0023 — train_loss: 0.000002, val_loss: 0.000002, val_NMSE: -46.00, lr: 0.01
# Epoch 0024 — train_loss: 0.000002, val_loss: 0.000002, val_NMSE: -45.13, lr: 0.01
# Epoch 0025 — train_loss: 0.000005, val_loss: 0.000003, val_NMSE: -43.05, lr: 0.01
# Epoch 0026 — train_loss: 0.000003, val_loss: 0.000003, val_NMSE: -42.67, lr: 0.01
# Epoch 0027 — train_loss: 0.000002, val_loss: 0.000002, val_NMSE: -45.46, lr: 0.01
# Epoch 0028 — train_loss: 0.000010, val_loss: 0.000010, val_NMSE: -37.98, lr: 0.01
# Epoch 0029 — train_loss: 0.000003, val_loss: 0.000004, val_NMSE: -41.63, lr: 0.01
# Epoch 0030 — train_loss: 0.000002, val_loss: 0.000002, val_NMSE: -45.25, lr: 0.01
# Epoch 0031 — train_loss: 0.000005, val_loss: 0.000005, val_NMSE: -40.96, lr: 0.01
# Epoch 0032 — train_loss: 0.000002, val_loss: 0.000002, val_NMSE: -44.95, lr: 0.01
# Epoch 0033 — train_loss: 0.000002, val_loss: 0.000002, val_NMSE: -45.20, lr: 0.01
# Epoch 0034 — train_loss: 0.000002, val_loss: 0.000002, val_NMSE: -46.08, lr: 0.01
# Epoch 0035 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.30, lr: 0.01
# Epoch 0036 — train_loss: 0.000004, val_loss: 0.000005, val_NMSE: -41.16, lr: 0.01
# Epoch 0037 — train_loss: 0.000002, val_loss: 0.000002, val_NMSE: -46.11, lr: 0.01
# Epoch 0038 — train_loss: 0.000001, val_loss: 0.000002, val_NMSE: -46.08, lr: 0.01
# Epoch 0039 — train_loss: 0.000003, val_loss: 0.000003, val_NMSE: -42.91, lr: 0.01
# Epoch 0040 — train_loss: 0.000006, val_loss: 0.000009, val_NMSE: -38.36, lr: 0.01
# Epoch 0041 — train_loss: 0.000001, val_loss: 0.000002, val_NMSE: -45.89, lr: 0.01
# Epoch 0042 — train_loss: 0.000003, val_loss: 0.000005, val_NMSE: -41.33, lr: 0.01
# Epoch 0043 — train_loss: 0.000003, val_loss: 0.000002, val_NMSE: -44.11, lr: 0.01
# Epoch 0044 — train_loss: 0.000002, val_loss: 0.000002, val_NMSE: -46.10, lr: 0.01
# Epoch 0045 — train_loss: 0.000007, val_loss: 0.000008, val_NMSE: -38.97, lr: 0.01
# Epoch 0046 — train_loss: 0.000001, val_loss: 0.000002, val_NMSE: -45.87, lr: 0.005
# Epoch 0047 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.45, lr: 0.005
# Epoch 0048 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.45, lr: 0.005
# Epoch 0049 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.49, lr: 0.005
# Epoch 0050 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.48, lr: 0.005
# Epoch 0051 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.39, lr: 0.005
# Epoch 0052 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.49, lr: 0.005
# Epoch 0053 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.51, lr: 0.005
# Epoch 0054 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.49, lr: 0.005
# Epoch 0055 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.47, lr: 0.005
# Epoch 0056 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.51, lr: 0.005
# Epoch 0057 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.35, lr: 0.005
# Epoch 0058 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.52, lr: 0.005
# Epoch 0059 — train_loss: 0.000002, val_loss: 0.000002, val_NMSE: -46.07, lr: 0.005
# Epoch 0060 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.48, lr: 0.005
# Epoch 0061 — train_loss: 0.000002, val_loss: 0.000002, val_NMSE: -45.87, lr: 0.005
# Epoch 0062 — train_loss: 0.000002, val_loss: 0.000002, val_NMSE: -45.02, lr: 0.005
# Epoch 0063 — train_loss: 0.000003, val_loss: 0.000003, val_NMSE: -43.61, lr: 0.005
# Epoch 0064 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.38, lr: 0.005
# Epoch 0065 — train_loss: 0.000002, val_loss: 0.000002, val_NMSE: -45.59, lr: 0.005
# Epoch 0066 — train_loss: 0.000004, val_loss: 0.000003, val_NMSE: -43.05, lr: 0.005
# Epoch 0067 — train_loss: 0.000002, val_loss: 0.000002, val_NMSE: -45.68, lr: 0.005
# Epoch 0068 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.50, lr: 0.005
# Epoch 0069 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.46, lr: 0.0025
# Epoch 0070 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.54, lr: 0.0025
# Epoch 0071 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.52, lr: 0.0025
# Epoch 0072 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.51, lr: 0.0025
# Epoch 0073 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.38, lr: 0.0025
# Epoch 0074 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.50, lr: 0.0025
# Epoch 0075 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.48, lr: 0.0025
# Epoch 0076 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.49, lr: 0.0025
# Epoch 0077 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.45, lr: 0.0025
# Epoch 0078 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.47, lr: 0.0025
# Epoch 0079 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.50, lr: 0.0025
# Epoch 0080 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.44, lr: 0.0025
# Epoch 0081 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.46, lr: 0.00125
# Epoch 0082 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.54, lr: 0.00125
# Epoch 0083 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 0.00125
# Epoch 0084 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.52, lr: 0.00125
# Epoch 0085 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 0.00125
# Epoch 0086 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.52, lr: 0.00125
# Epoch 0087 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.43, lr: 0.00125
# Epoch 0088 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.50, lr: 0.00125
# Epoch 0089 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.51, lr: 0.00125
# Epoch 0090 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.52, lr: 0.00125
# Epoch 0091 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.47, lr: 0.00125
# Epoch 0092 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.45, lr: 0.000625
# Epoch 0093 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.48, lr: 0.000625
# Epoch 0094 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.54, lr: 0.000625
# Epoch 0095 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.52, lr: 0.000625
# Epoch 0096 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.45, lr: 0.000625
# Epoch 0097 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.52, lr: 0.000625
# Epoch 0098 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.46, lr: 0.000625
# Epoch 0099 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 0.000625
# Epoch 0100 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 0.000625
# Epoch 0101 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.49, lr: 0.000625
# Epoch 0102 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.47, lr: 0.000625
# Epoch 0103 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.54, lr: 0.0003125
# Epoch 0104 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.52, lr: 0.0003125
# Epoch 0105 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.52, lr: 0.0003125
# Epoch 0106 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.51, lr: 0.0003125
# Epoch 0107 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.52, lr: 0.0003125
# Epoch 0108 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 0.0003125
# Epoch 0109 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.52, lr: 0.0003125
# Epoch 0110 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.34, lr: 0.0003125
# Epoch 0111 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.38, lr: 0.0003125
# Epoch 0112 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.49, lr: 0.0003125
# Epoch 0113 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.47, lr: 0.0003125
# Epoch 0114 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.51, lr: 0.00015625
# Epoch 0115 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.52, lr: 0.00015625
# Epoch 0116 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 0.00015625
# Epoch 0117 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.52, lr: 0.00015625
# Epoch 0118 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 0.00015625
# Epoch 0119 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.51, lr: 0.00015625
# Epoch 0120 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.52, lr: 0.00015625
# Epoch 0121 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.52, lr: 0.00015625
# Epoch 0122 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.50, lr: 0.00015625
# Epoch 0123 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 0.00015625
# Epoch 0124 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 0.00015625
# Epoch 0125 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.52, lr: 7.8125e-05
# Epoch 0126 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 7.8125e-05
# Epoch 0127 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 7.8125e-05
# Epoch 0128 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 7.8125e-05
# Epoch 0129 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 7.8125e-05
# Epoch 0130 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 7.8125e-05
# Epoch 0131 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.52, lr: 7.8125e-05
# Epoch 0132 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.50, lr: 7.8125e-05
# Epoch 0133 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 7.8125e-05
# Epoch 0134 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.52, lr: 7.8125e-05
# Epoch 0135 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 7.8125e-05
# Epoch 0136 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 3.90625e-05
# Epoch 0137 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.52, lr: 3.90625e-05
# Epoch 0138 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 3.90625e-05
# Epoch 0139 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.54, lr: 3.90625e-05
# Epoch 0140 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.52, lr: 3.90625e-05
# Epoch 0141 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.52, lr: 3.90625e-05
# Epoch 0142 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 3.90625e-05
# Epoch 0143 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 3.90625e-05
# Epoch 0144 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.51, lr: 3.90625e-05
# Epoch 0145 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 3.90625e-05
# Epoch 0146 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.51, lr: 3.90625e-05
# Epoch 0147 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.51, lr: 1.953125e-05
# Epoch 0148 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.953125e-05
# Epoch 0149 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.953125e-05
# Epoch 0150 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.953125e-05
# Epoch 0151 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.953125e-05
# Epoch 0152 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.52, lr: 1.953125e-05
# Epoch 0153 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.51, lr: 1.953125e-05
# Epoch 0154 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.953125e-05
# Epoch 0155 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.953125e-05
# Epoch 0156 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.52, lr: 1.953125e-05
# Epoch 0157 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.953125e-05
# Epoch 0158 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.54, lr: 9.765625e-06
# Epoch 0159 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 9.765625e-06
# Epoch 0160 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.52, lr: 9.765625e-06
# Epoch 0161 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.52, lr: 9.765625e-06
# Epoch 0162 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 9.765625e-06
# Epoch 0163 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.52, lr: 9.765625e-06
# Epoch 0164 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 9.765625e-06
# Epoch 0165 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.52, lr: 9.765625e-06
# Epoch 0166 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 9.765625e-06
# Epoch 0167 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 9.765625e-06
# Epoch 0168 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 9.765625e-06
# Epoch 0169 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 4.8828125e-06
# Epoch 0170 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 4.8828125e-06
# Epoch 0171 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 4.8828125e-06
# Epoch 0172 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.52, lr: 4.8828125e-06
# Epoch 0173 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 4.8828125e-06
# Epoch 0174 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 4.8828125e-06
# Epoch 0175 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 4.8828125e-06
# Epoch 0176 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 4.8828125e-06
# Epoch 0177 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 4.8828125e-06
# Epoch 0178 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 4.8828125e-06
# Epoch 0179 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.52, lr: 4.8828125e-06
# Epoch 0180 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 2.44140625e-06
# Epoch 0181 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 2.44140625e-06
# Epoch 0182 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 2.44140625e-06
# Epoch 0183 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 2.44140625e-06
# Epoch 0184 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 2.44140625e-06
# Epoch 0185 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 2.44140625e-06
# Epoch 0186 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 2.44140625e-06
# Epoch 0187 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 2.44140625e-06
# Epoch 0188 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 2.44140625e-06
# Epoch 0189 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 2.44140625e-06
# Epoch 0190 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 2.44140625e-06
# Epoch 0191 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.220703125e-06
# Epoch 0192 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.220703125e-06
# Epoch 0193 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.220703125e-06
# Epoch 0194 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.220703125e-06
# Epoch 0195 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.220703125e-06
# Epoch 0196 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.220703125e-06
# Epoch 0197 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.220703125e-06
# Epoch 0198 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.52, lr: 1.220703125e-06
# Epoch 0199 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.220703125e-06
# Epoch 0200 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.220703125e-06
# Epoch 0201 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.220703125e-06
# Epoch 0202 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 6.103515625e-07
# Epoch 0203 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 6.103515625e-07
# Epoch 0204 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 6.103515625e-07
# Epoch 0205 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 6.103515625e-07
# Epoch 0206 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 6.103515625e-07
# Epoch 0207 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 6.103515625e-07
# Epoch 0208 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 6.103515625e-07
# Epoch 0209 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 6.103515625e-07
# Epoch 0210 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.52, lr: 6.103515625e-07
# Epoch 0211 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 6.103515625e-07
# Epoch 0212 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 6.103515625e-07
# Epoch 0213 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 3.0517578125e-07
# Epoch 0214 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 3.0517578125e-07
# Epoch 0215 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 3.0517578125e-07
# Epoch 0216 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 3.0517578125e-07
# Epoch 0217 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 3.0517578125e-07
# Epoch 0218 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 3.0517578125e-07
# Epoch 0219 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 3.0517578125e-07
# Epoch 0220 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 3.0517578125e-07
# Epoch 0221 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 3.0517578125e-07
# Epoch 0222 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 3.0517578125e-07
# Epoch 0223 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 3.0517578125e-07
# Epoch 0224 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.52587890625e-07
# Epoch 0225 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.52587890625e-07
# Epoch 0226 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.52587890625e-07
# Epoch 0227 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.52587890625e-07
# Epoch 0228 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.52587890625e-07
# Epoch 0229 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.52587890625e-07
# Epoch 0230 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.52587890625e-07
# Epoch 0231 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.52587890625e-07
# Epoch 0232 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.52587890625e-07
# Epoch 0233 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.52587890625e-07
# Epoch 0234 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.52587890625e-07
# Epoch 0235 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 7.62939453125e-08
# Epoch 0236 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 7.62939453125e-08
# Epoch 0237 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 7.62939453125e-08
# Epoch 0238 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 7.62939453125e-08
# Epoch 0239 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 7.62939453125e-08
# Epoch 0240 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 7.62939453125e-08
# Epoch 0241 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 7.62939453125e-08
# Epoch 0242 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 7.62939453125e-08
# Epoch 0243 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 7.62939453125e-08
# Epoch 0244 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 7.62939453125e-08
# Epoch 0245 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 7.62939453125e-08
# Epoch 0246 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 3.814697265625e-08
# Epoch 0247 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 3.814697265625e-08
# Epoch 0248 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 3.814697265625e-08
# Epoch 0249 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 3.814697265625e-08
# Epoch 0250 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 3.814697265625e-08
# Epoch 0251 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 3.814697265625e-08
# Epoch 0252 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 3.814697265625e-08
# Epoch 0253 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 3.814697265625e-08
# Epoch 0254 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 3.814697265625e-08
# Epoch 0255 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 3.814697265625e-08
# Epoch 0256 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 3.814697265625e-08
# Epoch 0257 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.9073486328125e-08
# Epoch 0258 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.9073486328125e-08
# Epoch 0259 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.9073486328125e-08
# Epoch 0260 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.9073486328125e-08
# Epoch 0261 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.9073486328125e-08
# Epoch 0262 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.9073486328125e-08
# Epoch 0263 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.9073486328125e-08
# Epoch 0264 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.9073486328125e-08
# Epoch 0265 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.9073486328125e-08
# Epoch 0266 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.9073486328125e-08
# Epoch 0267 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.9073486328125e-08
# Epoch 0268 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.9073486328125e-08
# Epoch 0269 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.9073486328125e-08
# Epoch 0270 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.9073486328125e-08
# Epoch 0271 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.9073486328125e-08
# Epoch 0272 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.9073486328125e-08
# Epoch 0273 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.9073486328125e-08
# Epoch 0274 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.9073486328125e-08
# Epoch 0275 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.9073486328125e-08
# Epoch 0276 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.9073486328125e-08
# Epoch 0277 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.9073486328125e-08
# Epoch 0278 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.9073486328125e-08
# Epoch 0279 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.9073486328125e-08
# Epoch 0280 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.9073486328125e-08
# Epoch 0281 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.9073486328125e-08
# Epoch 0282 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.9073486328125e-08
# Epoch 0283 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.9073486328125e-08
# Epoch 0284 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.9073486328125e-08
# Epoch 0285 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.9073486328125e-08
# Epoch 0286 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.9073486328125e-08
# Epoch 0287 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.9073486328125e-08
# Epoch 0288 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.9073486328125e-08
# Epoch 0289 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.9073486328125e-08
# Epoch 0290 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.9073486328125e-08
# Epoch 0291 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.9073486328125e-08
# Epoch 0292 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.9073486328125e-08
# Epoch 0293 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.9073486328125e-08
# Epoch 0294 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.9073486328125e-08
# Epoch 0295 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.9073486328125e-08
# Epoch 0296 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.9073486328125e-08
# Epoch 0297 — train_loss: 0.000002, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.9073486328125e-08
# Epoch 0298 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.9073486328125e-08
# Epoch 0299 — train_loss: 0.000001, val_loss: 0.000001, val_NMSE: -46.53, lr: 1.9073486328125e-08
# ===Training complete===
# Выполнение заняло: 0:07:06
# Coefficients saved to model_params/ila_BatchGMP_Ka2_La2_Kb2_Lb2_Mb2_Kc2_Lc2_Mc2.pt
# Model NMSE: -46.54

# %% [markdown]
# ILC DPD grad

# %%
u_k_train = learning.ilc_signal(x_train, y_train_target, pa_model, epochs=500, learning_rate=0.001)
u_k_val = learning.ilc_signal(x_val, y_val_target, pa_model, epochs=500, learning_rate=0.001)
u_k_pa = pa_model.forward(u_k_train).detach()

nmse_uk_pa = metrics.compute_nmse(u_k_pa, y_train_target)
print(f"NMSE на выходе усилителя (ILC): {nmse_uk_pa:.2f} db")

data["ilc_train_output"] = u_k_train
data["ilc_val_output"] = u_k_val

ilc_train_loader, ilc_val_loader = data_loader.build_dataloaders(data_dict=data, 
                                                                 frame_length=frame_length, 
                                                                 batch_size=batch_size, 
                                                                 batch_size_eval=batch_size_eval, 
                                                                 arch="ilc")
# Out:
# Epoch [0/500], Loss: 0.029589394107460976
# Epoch [100/500], Loss: 0.0009480466251261532
# Epoch [200/500], Loss: 2.3879050786490552e-05
# Epoch [300/500], Loss: 5.011692110201693e-07
# Epoch [400/500], Loss: 8.303884690974428e-09
# Epoch [499/500], Loss: 1.1732961824328925e-10
# Выполнение заняло: 0:00:12
# Epoch [0/500], Loss: 0.02922748774290085
# Epoch [100/500], Loss: 0.0009296299540437758
# Epoch [200/500], Loss: 2.4677301553310826e-05
# Epoch [300/500], Loss: 5.404369289863098e-07
# Epoch [400/500], Loss: 9.253311894497074e-09
# Epoch [499/500], Loss: 1.3148733490897513e-10
# Выполнение заняло: 0:00:09
# NMSE на выходе усилителя (ILC): -95.31 db

# %%
epochs = 300
lr = 0.01

ilc_degree = 2
ilc_config = params.make_gmp_params(
    Ka=ilc_degree,
    La=ilc_degree,
    Kb=ilc_degree,
    Lb=ilc_degree,
    Mb=ilc_degree,
    Kc=ilc_degree,
    Lc=ilc_degree,
    Mc=ilc_degree,
)

dpd_model_ilc = BatchGMP(**ilc_config, model_name="ilc")
is_load = dpd_model_ilc.load_weights()
optimizer = torch.optim.AdamW(dpd_model_ilc.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=10)

if not is_load:
    learning.train(net=dpd_model_ilc, 
                   criterion=criterion, 
                   optimizer=optimizer, 
                   train_loader=ilc_train_loader, 
                   val_loader=ilc_val_loader, 
                   grad_clip_val=0, 
                   n_epochs=epochs, 
                   metric_criterion=metric_criterion,
                   scheduler=scheduler)
    dpd_model_ilc.save_weights()

casc_ilc_eval = utils.CascadeModel(model_1=dpd_model_ilc, model_2=pa_model)
y_val_ilc = learning.net_inference(net=casc_ilc_eval, x=x_val)
nmse_ilc = metrics.compute_nmse(y_val_ilc, y_val_target)
print(f"Model NMSE: {nmse_ilc:.2f}")
# Out:
# No saved coefficients found at model_params/ilc_BatchGMP_Ka2_La2_Kb2_Lb2_Mb2_Kc2_Lc2_Mc2.pt, initializing new parameters.
# ===Start training===
# Epoch 0000 — train_loss: 0.000054, val_loss: 0.000045, val_NMSE: -29.30, lr: 0.01
# Epoch 0001 — train_loss: 0.000024, val_loss: 0.000014, val_NMSE: -34.38, lr: 0.01
# Epoch 0002 — train_loss: 0.000013, val_loss: 0.000007, val_NMSE: -37.74, lr: 0.01
# Epoch 0003 — train_loss: 0.000011, val_loss: 0.000004, val_NMSE: -40.38, lr: 0.01
# Epoch 0004 — train_loss: 0.000009, val_loss: 0.000002, val_NMSE: -42.10, lr: 0.01
# Epoch 0005 — train_loss: 0.000009, val_loss: 0.000002, val_NMSE: -43.31, lr: 0.01
# Epoch 0006 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -44.34, lr: 0.01
# Epoch 0007 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -44.98, lr: 0.01
# Epoch 0008 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -44.85, lr: 0.01
# Epoch 0009 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.30, lr: 0.01
# Epoch 0010 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.05, lr: 0.01
# Epoch 0011 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.56, lr: 0.01
# Epoch 0012 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -44.99, lr: 0.01
# Epoch 0013 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -44.57, lr: 0.01
# Epoch 0014 — train_loss: 0.000020, val_loss: 0.000009, val_NMSE: -36.31, lr: 0.01
# Epoch 0015 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.14, lr: 0.01
# Epoch 0016 — train_loss: 0.000009, val_loss: 0.000002, val_NMSE: -43.72, lr: 0.01
# Epoch 0017 — train_loss: 0.000008, val_loss: 0.000002, val_NMSE: -42.36, lr: 0.01
# Epoch 0018 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.68, lr: 0.01
# Epoch 0019 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.67, lr: 0.01
# Epoch 0020 — train_loss: 0.000008, val_loss: 0.000002, val_NMSE: -44.04, lr: 0.01
# Epoch 0021 — train_loss: 0.000008, val_loss: 0.000003, val_NMSE: -40.46, lr: 0.01
# Epoch 0022 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.58, lr: 0.01
# Epoch 0023 — train_loss: 0.000008, val_loss: 0.000002, val_NMSE: -42.44, lr: 0.01
# Epoch 0024 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -44.96, lr: 0.01
# Epoch 0025 — train_loss: 0.000009, val_loss: 0.000003, val_NMSE: -40.78, lr: 0.01
# Epoch 0026 — train_loss: 0.000009, val_loss: 0.000005, val_NMSE: -39.29, lr: 0.01
# Epoch 0027 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.74, lr: 0.01
# Epoch 0028 — train_loss: 0.000008, val_loss: 0.000002, val_NMSE: -42.67, lr: 0.01
# Epoch 0029 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -44.72, lr: 0.01
# Epoch 0030 — train_loss: 0.000006, val_loss: 0.000001, val_NMSE: -45.74, lr: 0.01
# Epoch 0031 — train_loss: 0.000009, val_loss: 0.000001, val_NMSE: -44.59, lr: 0.01
# Epoch 0032 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.64, lr: 0.01
# Epoch 0033 — train_loss: 0.000009, val_loss: 0.000002, val_NMSE: -42.52, lr: 0.01
# Epoch 0034 — train_loss: 0.000007, val_loss: 0.000002, val_NMSE: -43.26, lr: 0.01
# Epoch 0035 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.49, lr: 0.01
# Epoch 0036 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.02, lr: 0.01
# Epoch 0037 — train_loss: 0.000010, val_loss: 0.000003, val_NMSE: -40.86, lr: 0.01
# Epoch 0038 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.09, lr: 0.01
# Epoch 0039 — train_loss: 0.000010, val_loss: 0.000002, val_NMSE: -43.50, lr: 0.01
# Epoch 0040 — train_loss: 0.000008, val_loss: 0.000002, val_NMSE: -42.73, lr: 0.01
# Epoch 0041 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.11, lr: 0.005
# Epoch 0042 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.79, lr: 0.005
# Epoch 0043 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.67, lr: 0.005
# Epoch 0044 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.29, lr: 0.005
# Epoch 0045 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.90, lr: 0.005
# Epoch 0046 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.25, lr: 0.005
# Epoch 0047 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.79, lr: 0.005
# Epoch 0048 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.23, lr: 0.005
# Epoch 0049 — train_loss: 0.000006, val_loss: 0.000001, val_NMSE: -45.86, lr: 0.005
# Epoch 0050 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.93, lr: 0.005
# Epoch 0051 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.92, lr: 0.005
# Epoch 0052 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.87, lr: 0.005
# Epoch 0053 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.82, lr: 0.005
# Epoch 0054 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.91, lr: 0.005
# Epoch 0055 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.50, lr: 0.005
# Epoch 0056 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.97, lr: 0.005
# Epoch 0057 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.67, lr: 0.005
# Epoch 0058 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.56, lr: 0.005
# Epoch 0059 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -44.70, lr: 0.005
# Epoch 0060 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.93, lr: 0.005
# Epoch 0061 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -44.27, lr: 0.005
# Epoch 0062 — train_loss: 0.000007, val_loss: 0.000002, val_NMSE: -42.65, lr: 0.005
# Epoch 0063 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -44.96, lr: 0.005
# Epoch 0064 — train_loss: 0.000008, val_loss: 0.000002, val_NMSE: -43.23, lr: 0.005
# Epoch 0065 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.90, lr: 0.005
# Epoch 0066 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.94, lr: 0.005
# Epoch 0067 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.88, lr: 0.0025
# Epoch 0068 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.60, lr: 0.0025
# Epoch 0069 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.96, lr: 0.0025
# Epoch 0070 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.95, lr: 0.0025
# Epoch 0071 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.95, lr: 0.0025
# Epoch 0072 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.52, lr: 0.0025
# Epoch 0073 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.91, lr: 0.0025
# Epoch 0074 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.53, lr: 0.0025
# Epoch 0075 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.83, lr: 0.0025
# Epoch 0076 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.87, lr: 0.0025
# Epoch 0077 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.83, lr: 0.0025
# Epoch 0078 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.94, lr: 0.00125
# Epoch 0079 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.82, lr: 0.00125
# Epoch 0080 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.92, lr: 0.00125
# Epoch 0081 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.81, lr: 0.00125
# Epoch 0082 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.94, lr: 0.00125
# Epoch 0083 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.76, lr: 0.00125
# Epoch 0084 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.84, lr: 0.00125
# Epoch 0085 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.57, lr: 0.00125
# Epoch 0086 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.84, lr: 0.00125
# Epoch 0087 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.59, lr: 0.00125
# Epoch 0088 — train_loss: 0.000006, val_loss: 0.000001, val_NMSE: -45.88, lr: 0.00125
# Epoch 0089 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.93, lr: 0.000625
# Epoch 0090 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.93, lr: 0.000625
# Epoch 0091 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.87, lr: 0.000625
# Epoch 0092 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.97, lr: 0.000625
# Epoch 0093 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 0.000625
# Epoch 0094 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.73, lr: 0.000625
# Epoch 0095 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.36, lr: 0.000625
# Epoch 0096 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.81, lr: 0.000625
# Epoch 0097 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.84, lr: 0.000625
# Epoch 0098 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.60, lr: 0.000625
# Epoch 0099 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.78, lr: 0.000625
# Epoch 0100 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.84, lr: 0.000625
# Epoch 0101 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.90, lr: 0.000625
# Epoch 0102 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.84, lr: 0.000625
# Epoch 0103 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.49, lr: 0.0003125
# Epoch 0104 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.80, lr: 0.0003125
# Epoch 0105 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 0.0003125
# Epoch 0106 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.89, lr: 0.0003125
# Epoch 0107 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.78, lr: 0.0003125
# Epoch 0108 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.55, lr: 0.0003125
# Epoch 0109 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.86, lr: 0.0003125
# Epoch 0110 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.86, lr: 0.0003125
# Epoch 0111 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.69, lr: 0.0003125
# Epoch 0112 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.75, lr: 0.0003125
# Epoch 0113 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.88, lr: 0.0003125
# Epoch 0114 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.76, lr: 0.00015625
# Epoch 0115 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.87, lr: 0.00015625
# Epoch 0116 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.73, lr: 0.00015625
# Epoch 0117 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.91, lr: 0.00015625
# Epoch 0118 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.79, lr: 0.00015625
# Epoch 0119 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.78, lr: 0.00015625
# Epoch 0120 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.90, lr: 0.00015625
# Epoch 0121 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.78, lr: 0.00015625
# Epoch 0122 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.83, lr: 0.00015625
# Epoch 0123 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.93, lr: 0.00015625
# Epoch 0124 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.93, lr: 0.00015625
# Epoch 0125 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.89, lr: 7.8125e-05
# Epoch 0126 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.91, lr: 7.8125e-05
# Epoch 0127 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.81, lr: 7.8125e-05
# Epoch 0128 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.82, lr: 7.8125e-05
# Epoch 0129 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.84, lr: 7.8125e-05
# Epoch 0130 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.78, lr: 7.8125e-05
# Epoch 0131 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.90, lr: 7.8125e-05
# Epoch 0132 — train_loss: 0.000006, val_loss: 0.000001, val_NMSE: -45.84, lr: 7.8125e-05
# Epoch 0133 — train_loss: 0.000006, val_loss: 0.000001, val_NMSE: -45.88, lr: 7.8125e-05
# Epoch 0134 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.62, lr: 7.8125e-05
# Epoch 0135 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.83, lr: 7.8125e-05
# Epoch 0136 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.81, lr: 3.90625e-05
# Epoch 0137 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.79, lr: 3.90625e-05
# Epoch 0138 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.74, lr: 3.90625e-05
# Epoch 0139 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.77, lr: 3.90625e-05
# Epoch 0140 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.86, lr: 3.90625e-05
# Epoch 0141 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.86, lr: 3.90625e-05
# Epoch 0142 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.84, lr: 3.90625e-05
# Epoch 0143 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.92, lr: 3.90625e-05
# Epoch 0144 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.79, lr: 3.90625e-05
# Epoch 0145 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.77, lr: 3.90625e-05
# Epoch 0146 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.84, lr: 3.90625e-05
# Epoch 0147 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.91, lr: 1.953125e-05
# Epoch 0148 — train_loss: 0.000006, val_loss: 0.000001, val_NMSE: -45.77, lr: 1.953125e-05
# Epoch 0149 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.953125e-05
# Epoch 0150 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.78, lr: 1.953125e-05
# Epoch 0151 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.86, lr: 1.953125e-05
# Epoch 0152 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.86, lr: 1.953125e-05
# Epoch 0153 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.89, lr: 1.953125e-05
# Epoch 0154 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.953125e-05
# Epoch 0155 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.86, lr: 1.953125e-05
# Epoch 0156 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.86, lr: 1.953125e-05
# Epoch 0157 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.87, lr: 1.953125e-05
# Epoch 0158 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.89, lr: 9.765625e-06
# Epoch 0159 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.86, lr: 9.765625e-06
# Epoch 0160 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.83, lr: 9.765625e-06
# Epoch 0161 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.83, lr: 9.765625e-06
# Epoch 0162 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 9.765625e-06
# Epoch 0163 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 9.765625e-06
# Epoch 0164 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.83, lr: 9.765625e-06
# Epoch 0165 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.84, lr: 9.765625e-06
# Epoch 0166 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.84, lr: 9.765625e-06
# Epoch 0167 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 9.765625e-06
# Epoch 0168 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.80, lr: 9.765625e-06
# Epoch 0169 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.86, lr: 4.8828125e-06
# Epoch 0170 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.84, lr: 4.8828125e-06
# Epoch 0171 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.85, lr: 4.8828125e-06
# Epoch 0172 — train_loss: 0.000006, val_loss: 0.000001, val_NMSE: -45.87, lr: 4.8828125e-06
# Epoch 0173 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.87, lr: 4.8828125e-06
# Epoch 0174 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.86, lr: 4.8828125e-06
# Epoch 0175 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.85, lr: 4.8828125e-06
# Epoch 0176 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.84, lr: 4.8828125e-06
# Epoch 0177 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.84, lr: 4.8828125e-06
# Epoch 0178 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.81, lr: 4.8828125e-06
# Epoch 0179 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 4.8828125e-06
# Epoch 0180 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.86, lr: 2.44140625e-06
# Epoch 0181 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 2.44140625e-06
# Epoch 0182 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 2.44140625e-06
# Epoch 0183 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.83, lr: 2.44140625e-06
# Epoch 0184 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 2.44140625e-06
# Epoch 0185 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.82, lr: 2.44140625e-06
# Epoch 0186 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 2.44140625e-06
# Epoch 0187 — train_loss: 0.000006, val_loss: 0.000001, val_NMSE: -45.84, lr: 2.44140625e-06
# Epoch 0188 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 2.44140625e-06
# Epoch 0189 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.88, lr: 2.44140625e-06
# Epoch 0190 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.87, lr: 2.44140625e-06
# Epoch 0191 — train_loss: 0.000006, val_loss: 0.000001, val_NMSE: -45.86, lr: 1.220703125e-06
# Epoch 0192 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.220703125e-06
# Epoch 0193 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.84, lr: 1.220703125e-06
# Epoch 0194 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.220703125e-06
# Epoch 0195 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.84, lr: 1.220703125e-06
# Epoch 0196 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.84, lr: 1.220703125e-06
# Epoch 0197 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.220703125e-06
# Epoch 0198 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.84, lr: 1.220703125e-06
# Epoch 0199 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.220703125e-06
# Epoch 0200 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.220703125e-06
# Epoch 0201 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.84, lr: 1.220703125e-06
# Epoch 0202 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.84, lr: 6.103515625e-07
# Epoch 0203 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 6.103515625e-07
# Epoch 0204 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.84, lr: 6.103515625e-07
# Epoch 0205 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 6.103515625e-07
# Epoch 0206 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 6.103515625e-07
# Epoch 0207 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.84, lr: 6.103515625e-07
# Epoch 0208 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.84, lr: 6.103515625e-07
# Epoch 0209 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 6.103515625e-07
# Epoch 0210 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 6.103515625e-07
# Epoch 0211 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 6.103515625e-07
# Epoch 0212 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 6.103515625e-07
# Epoch 0213 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.84, lr: 3.0517578125e-07
# Epoch 0214 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 3.0517578125e-07
# Epoch 0215 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 3.0517578125e-07
# Epoch 0216 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.85, lr: 3.0517578125e-07
# Epoch 0217 — train_loss: 0.000006, val_loss: 0.000001, val_NMSE: -45.85, lr: 3.0517578125e-07
# Epoch 0218 — train_loss: 0.000006, val_loss: 0.000001, val_NMSE: -45.85, lr: 3.0517578125e-07
# Epoch 0219 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 3.0517578125e-07
# Epoch 0220 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.86, lr: 3.0517578125e-07
# Epoch 0221 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.84, lr: 3.0517578125e-07
# Epoch 0222 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 3.0517578125e-07
# Epoch 0223 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 3.0517578125e-07
# Epoch 0224 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.52587890625e-07
# Epoch 0225 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.52587890625e-07
# Epoch 0226 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.52587890625e-07
# Epoch 0227 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.52587890625e-07
# Epoch 0228 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.52587890625e-07
# Epoch 0229 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.52587890625e-07
# Epoch 0230 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.52587890625e-07
# Epoch 0231 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.52587890625e-07
# Epoch 0232 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.52587890625e-07
# Epoch 0233 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.52587890625e-07
# Epoch 0234 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.52587890625e-07
# Epoch 0235 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 7.62939453125e-08
# Epoch 0236 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 7.62939453125e-08
# Epoch 0237 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 7.62939453125e-08
# Epoch 0238 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 7.62939453125e-08
# Epoch 0239 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 7.62939453125e-08
# Epoch 0240 — train_loss: 0.000006, val_loss: 0.000001, val_NMSE: -45.85, lr: 7.62939453125e-08
# Epoch 0241 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 7.62939453125e-08
# Epoch 0242 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 7.62939453125e-08
# Epoch 0243 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 7.62939453125e-08
# Epoch 0244 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.85, lr: 7.62939453125e-08
# Epoch 0245 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 7.62939453125e-08
# Epoch 0246 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.85, lr: 3.814697265625e-08
# Epoch 0247 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 3.814697265625e-08
# Epoch 0248 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 3.814697265625e-08
# Epoch 0249 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 3.814697265625e-08
# Epoch 0250 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.85, lr: 3.814697265625e-08
# Epoch 0251 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 3.814697265625e-08
# Epoch 0252 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.85, lr: 3.814697265625e-08
# Epoch 0253 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 3.814697265625e-08
# Epoch 0254 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.85, lr: 3.814697265625e-08
# Epoch 0255 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 3.814697265625e-08
# Epoch 0256 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 3.814697265625e-08
# Epoch 0257 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.9073486328125e-08
# Epoch 0258 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.9073486328125e-08
# Epoch 0259 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.9073486328125e-08
# Epoch 0260 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.9073486328125e-08
# Epoch 0261 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.9073486328125e-08
# Epoch 0262 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.9073486328125e-08
# Epoch 0263 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.9073486328125e-08
# Epoch 0264 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.9073486328125e-08
# Epoch 0265 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.9073486328125e-08
# Epoch 0266 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.9073486328125e-08
# Epoch 0267 — train_loss: 0.000006, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.9073486328125e-08
# Epoch 0268 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.9073486328125e-08
# Epoch 0269 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.9073486328125e-08
# Epoch 0270 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.9073486328125e-08
# Epoch 0271 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.9073486328125e-08
# Epoch 0272 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.9073486328125e-08
# Epoch 0273 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.9073486328125e-08
# Epoch 0274 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.9073486328125e-08
# Epoch 0275 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.9073486328125e-08
# Epoch 0276 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.9073486328125e-08
# Epoch 0277 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.9073486328125e-08
# Epoch 0278 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.9073486328125e-08
# Epoch 0279 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.9073486328125e-08
# Epoch 0280 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.9073486328125e-08
# Epoch 0281 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.9073486328125e-08
# Epoch 0282 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.9073486328125e-08
# Epoch 0283 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.9073486328125e-08
# Epoch 0284 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.9073486328125e-08
# Epoch 0285 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.9073486328125e-08
# Epoch 0286 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.9073486328125e-08
# Epoch 0287 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.9073486328125e-08
# Epoch 0288 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.9073486328125e-08
# Epoch 0289 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.9073486328125e-08
# Epoch 0290 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.9073486328125e-08
# Epoch 0291 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.9073486328125e-08
# Epoch 0292 — train_loss: 0.000006, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.9073486328125e-08
# Epoch 0293 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.9073486328125e-08
# Epoch 0294 — train_loss: 0.000008, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.9073486328125e-08
# Epoch 0295 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.9073486328125e-08
# Epoch 0296 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.9073486328125e-08
# Epoch 0297 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.9073486328125e-08
# Epoch 0298 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.9073486328125e-08
# Epoch 0299 — train_loss: 0.000007, val_loss: 0.000001, val_NMSE: -45.85, lr: 1.9073486328125e-08
# ===Training complete===
# Выполнение заняло: 0:04:39
# Coefficients saved to model_params/ilc_BatchGMP_Ka2_La2_Kb2_Lb2_Mb2_Kc2_Lc2_Mc2.pt
# Model NMSE: -46.89

# %% [markdown]
# Metrics

# %%
nmse_after_pa = metrics.compute_nmse(y_val_pa, y_val_target)

print(f"NMSE на выходе усилителя (без DPD): {nmse_after_pa:.2f} db")

print(f"NMSE на выходе усилителя (DLA DPD): {nmse_dla:.2f} db")

print(f"NMSE на выходе усилителя (ILA DPD): {nmse_ila:.2f} db")

print(f"NMSE на выходе усилителя (ILC DPD): {nmse_ilc:.2f} db")
# Out:
# NMSE на выходе усилителя (без DPD): -11.25 db
# NMSE на выходе усилителя (DLA DPD): -48.14 db
# NMSE на выходе усилителя (ILA DPD): -46.54 db
# NMSE на выходе усилителя (ILC DPD): -46.89 db

# %%
x_val_acpr = metrics.calculate_acpr(x_val, acpr_meter)
y_val_acpr = metrics.calculate_acpr(y_val, acpr_meter)
y_val_pa_acpr = metrics.calculate_acpr(y_val_pa, acpr_meter)
y_val_target_acpr = metrics.calculate_acpr(y_val_target, acpr_meter)

y_lin_dla_acpr = metrics.calculate_acpr(y_val_dla, acpr_meter)
y_lin_ila_acpr = metrics.calculate_acpr(y_val_ila, acpr_meter)
y_lin_ilc_acpr = metrics.calculate_acpr(y_val_ilc, acpr_meter)

print(f"x_val_acpr: {x_val_acpr}")
print(f"y_val_acpr: {y_val_acpr}")
print(f"y_val_pa_acpr: {y_val_pa_acpr}")
print(f"y_val_target_acpr: {y_val_target_acpr}")

print(f"lin_dla_acpr: {y_lin_dla_acpr}")
print(f"lin_ila_acpr: {y_lin_ila_acpr}")
print(f"lin_ilc_acpr: {y_lin_ilc_acpr}")
# Out:
# x_val_acpr: [-48.08083195 -48.40122574]
# y_val_acpr: [-40.60778184 -38.20237847]
# y_val_pa_acpr: [-43.80641043 -42.69900341]
# y_val_target_acpr: [-48.08083304 -48.40122404]
# lin_dla_acpr: [-48.41785281 -48.65080363]
# lin_ila_acpr: [-48.3324866  -48.45624519]
# lin_ilc_acpr: [-48.26860169 -48.75293983]

# %%
nmse_uk_pa = metrics.compute_nmse(u_k_pa, y_train_target)
print(f"NMSE на выходе усилителя (ILC): {nmse_uk_pa:.2f} db")

u_k_acpr = metrics.calculate_acpr(u_k_val, acpr_meter)
u_k_pa_acpr = metrics.calculate_acpr(u_k_pa, acpr_meter)

print(f"u_k_acpr: {u_k_acpr}")
print(f"u_k_pa_acpr: {u_k_pa_acpr}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 nmse_uk_pa = metrics.compute_nmse(u_k_pa, y_train_target)
#       2 print(f"NMSE на выходе усилителя (ILC): {nmse_uk_pa:.2f} db")
#       4 u_k_acpr = metrics.calculate_acpr(u_k_val, acpr_meter)
#
# NameError: name 'metrics' is not defined

# %% [markdown]
# Spectrum

# %%
window_size = 100

freqs, spectrum_y_in = metrics.power_spectrum(x_val, fs, nperseg, window_size)
_, spectrum_y_out = metrics.power_spectrum(y_val, fs, nperseg, window_size)
_, spectrum_y_val_pa = metrics.power_spectrum(y_val_pa, fs, nperseg, window_size)
_, spectrum_y_val_target = metrics.power_spectrum(y_val_target, fs, nperseg, window_size)

# _, spectrum_y_dpd_dla = metrics.power_spectrum(y_dpd_dla, fs, nperseg, window_size)
# _, spectrum_y_dpd_ila = metrics.power_spectrum(y_dpd_ila, fs, nperseg, window_size)
# _, spectrum_y_dpd_ilc = metrics.power_spectrum(y_dpd_ilc, fs, nperseg, window_size)

_, spectrum_y_val_dla = metrics.power_spectrum(y_val_dla, fs, nperseg, window_size)
_, spectrum_y_val_ila = metrics.power_spectrum(y_val_ila, fs, nperseg, window_size)
_, spectrum_y_val_ilc = metrics.power_spectrum(y_val_ilc, fs, nperseg, window_size)


_, spectrum_u_k = metrics.power_spectrum(u_k_val, fs, nperseg, window_size)
_, spectrum_u_k_pa = metrics.power_spectrum(u_k_pa, fs, nperseg, window_size)

# %%
# построение спектра

xlabel="Частота (МГц)"
ylabel= "Спектральная плотность мощности (дБ)"
fontsize = 12
figsize=(12, 6)

plt.figure(figsize=figsize)

plt.plot(freqs / 1e6, spectrum_y_in, color='grey', label='Входной сигнал')
plt.plot(freqs / 1e6, spectrum_y_val_pa, color='gold', label='Выходной сигнал')
plt.plot(freqs / 1e6, spectrum_u_k_pa, color='red', label='Оптимальный сигнал ILC')
plt.plot(freqs / 1e6, spectrum_y_val_dla, color='darkorange', label='Сигнал с предыскажением DLA')
plt.plot(freqs / 1e6, spectrum_y_val_ila, color='limegreen', label='Сигнал с предыскажением ILA')
plt.plot(freqs / 1e6, spectrum_y_val_ilc, color='lightcoral', label='Сигнал с предыскажением ILC')


plt.xlabel(xlabel, fontsize=fontsize)
plt.ylabel(ylabel, fontsize=fontsize)
plt.legend()
plt.grid()
plt.show()

# %%
# moving_average
window_size = 100

freqs_s, spectrum_y_in_s = utils.moving_average(spectrum_y_in, freqs, fs, window_size)
_, spectrum_y_out_s = utils.moving_average(spectrum_y_out, freqs, fs, window_size)
_, spectrum_y_val_pa_s = utils.moving_average(spectrum_y_val_pa, freqs, fs, window_size)
_, spectrum_y_val_target_s = utils.moving_average(spectrum_y_val_target, freqs, fs, window_size)

# _, spectrum_y_val_dla_s = utils.moving_average(spectrum_y_val_dla, freqs, fs, window_size)
# _, spectrum_y_val_ila_s = utils.moving_average(spectrum_y_val_ila, freqs, fs, window_size)
# _, spectrum_y_dpd_ilc_grad_s = utils.moving_average(spectrum_y_dpd_ilc_grad, freqs, fs, window_size)

_, spectrum_y_val_dla_s = utils.moving_average(spectrum_y_val_dla, freqs, fs, window_size)
_, spectrum_y_val_ila_s = utils.moving_average(spectrum_y_val_ila, freqs, fs, window_size)
_, spectrum_y_val_ilc_s = utils.moving_average(spectrum_y_val_ilc, freqs, fs, window_size)

# _, spectrum_u_k_s = utils.moving_average(spectrum_u_k, freqs, fs, window_size)
# _, spectrum_u_k_pa_s = utils.moving_average(spectrum_u_k_pa, freqs, fs, window_size)

# %%
# (сглаженный) построение спектра

xlabel="Частота, МГц"
ylabel= "Спектральная плотность мощности, дБВт/Гц"
fontsize = 12
figsize=(12, 8)
markersize=8

plt.figure(figsize=figsize)

plt.plot(freqs_s / 1e6, 10 * np.log10(np.abs(spectrum_y_in_s)), 
         color='grey', label='Входной сигнал',marker = '*', markevery=90, markersize=markersize)
plt.plot(freqs_s / 1e6, 10 * np.log10(np.abs(spectrum_y_val_target_s)), 
         color='black', label='Выходной сигнал\n(линейный усилитель)',marker = '*', markevery=90, markersize=markersize)
plt.plot(freqs_s / 1e6, 10 * np.log10(np.abs(spectrum_y_val_pa_s)), 
         color='gold', label='Выходной сигнал\n(реальный усилитель)', marker='o', markevery=90, markersize=markersize)
# plt.plot(freqs_s / 1e6, 10 * np.log10(np.abs(spectrum_u_k_pa_s)), 
#          color='red', label='Оптимальный сигнал ILC', marker='v', markevery=95, markersize=markersize)
plt.plot(freqs_s / 1e6, 10 * np.log10(np.abs(spectrum_y_val_dla_s)), 
         color='darkorange', label='Сигнал с предыскажением DLA', marker='D', markevery=90, markersize=markersize)
plt.plot(freqs_s / 1e6, 10 * np.log10(np.abs(spectrum_y_val_ila_s)), 
         color='limegreen', label='Сигнал с предыскажением ILA', marker='X', markevery=110, markersize=markersize)
plt.plot(freqs_s / 1e6, 10 * np.log10(np.abs(spectrum_y_val_ilc_s)), 
         color='lightcoral', label='Сигнал с предыскажением ILC', marker='s', markevery=120, markersize=markersize)

plt.xlabel(xlabel, fontsize=fontsize)
plt.ylabel(ylabel, fontsize=fontsize)
plt.legend()
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 11
#       7 markersize=8
#       9 plt.figure(figsize=figsize)
# ---> 11 plt.plot(freqs_s / 1e6, 10 * np.log10(np.abs(spectrum_y_in_s)),
#      12          color='grey', label='Входной сигнал',marker = '*', markevery=90, markersize=markersize)
#      13 plt.plot(freqs_s / 1e6, 10 * np.log10(np.abs(spectrum_y_val_target_s)),
#      14          color='black', label='Выходной сигнал\n(линейный усилитель)',marker = '*', markevery=90, markersize=markersize)
#      15 plt.plot(freqs_s / 1e6, 10 * np.log10(np.abs(spectrum_y_val_pa_s)),
#      16          color='gold', label='Выходной сигнал\n(реальный усилитель)', marker='o', markevery=90, markersize=markersize)
#
# NameError: name 'freqs_s' is not defined

# %% [markdown]
# AM/AM & AM/PM

# %%
y_in_am_am, y_out_am_am = metrics.calculate_am_am(x_val, y_val)
y_in_am_pm, y_in_phase_am_pm = metrics.calculate_am_pm(x_val, y_val)

_, y_pa_am_am = metrics.calculate_am_am(x_val, y_val_pa)
_, y_pa_phase_am_pm = metrics.calculate_am_pm(x_val, y_val_pa)

_, y_val_target_am_am = metrics.calculate_am_am(x_val, y_val_target)
_, y_val_target_phase_am_pm = metrics.calculate_am_pm(x_val, y_val_target)

# x_in_am_am, u_k_am_am = metrics.calculate_am_am(x_train, u_k)
# x_in_am_pm, u_k_phase_am_pm = metrics.calculate_am_pm(x_train, u_k)

# _, u_k_pa_am_am = metrics.calculate_am_am(x_train, u_k_pa)
# _, u_k_pa_phase_am_pm = metrics.calculate_am_pm(x_train, u_k_pa)

#linearized
_, y_val_dla_am_am = metrics.calculate_am_am(x_val, y_val_dla)
_, y_val_dla_phase_am_pm = metrics.calculate_am_pm(x_val, y_val_dla)

_, y_val_ila_am_am = metrics.calculate_am_am(x_val, y_val_ila)
_, y_val_ila_phase_am_pm = metrics.calculate_am_pm(x_val, y_val_ila)

_, y_val_ilc_am_am = metrics.calculate_am_am(x_val, y_val_ilc)
_, y_val_ilc_phase_am_pm = metrics.calculate_am_pm(x_val, y_val_ilc)

# %%
#DLA

am_am_data = [
    (y_in_am_am, y_pa_am_am, 'gold', 'Выходной сигнал'),
    # (y_in_am_am, y_val_dla_am_am, 'magenta', 'Сигнал на выходе DPD'),
    (y_in_am_am, y_val_dla_am_am, 'darkorange', 'Сигнал с предыскажением'),
]

am_pm_data = [
    (y_in_am_pm, y_pa_phase_am_pm, 'gold', 'Выходной сигнал'),
    (y_in_am_pm, y_val_dla_phase_am_pm, 'darkorange', 'Сигнал с предыскажением'),
]

plotting.plot_am_am_pm(
    am_am_data=am_am_data,
    am_pm_data=am_pm_data,
    figsize=(12, 6),
    titles=("AM/AM DLA", "AM/PM DLA"),
    xlabels=("Амплитуда на входе", "Амплитуда на входе"),
    ylabels=("Амплитуда на выходе", "Фазовый сдвиг на выходе (градусы)")
)

# %%
#ILA

am_am_data = [
    (y_in_am_am, y_pa_am_am, 'gold', 'Выходной сигнал'),
    # (y_in_am_am, y_val_ila_am_am, 'magenta', 'Сигнал на выходе DPD'),
    (y_in_am_am, y_val_ila_am_am, 'darkorange', 'Сигнал с предыскажением'),
]

am_pm_data = [
    (y_in_am_pm, y_pa_phase_am_pm, 'gold', 'Выходной сигнал'),
    (y_in_am_pm, y_val_ila_phase_am_pm, 'darkorange', 'Сигнал с предыскажением'),
]

plotting.plot_am_am_pm(
    am_am_data=am_am_data,
    am_pm_data=am_pm_data,
    figsize=(12, 6),
    titles=("AM/AM ILA", "AM/PM ILA"),
    xlabels=("Амплитуда на входе", "Амплитуда на входе"),
    ylabels=("Амплитуда на выходе", "Фазовый сдвиг на выходе (градусы)")
)

# %%
#ILC

am_am_data = [
    (y_in_am_am, y_pa_am_am, 'gold', 'Выходной сигнал'),
    # (y_in_am_am, y_dpd_ilc_grad_am_am, 'magenta', 'Сигнал на выходе корректора'),
    (y_in_am_am, y_val_ilc_am_am, 'darkorange', 'Сигнал с предыскажением'),
]

am_pm_data = [
    (y_in_am_pm, y_pa_phase_am_pm, 'gold', 'Выходной сигнал'),
    (y_in_am_pm, y_val_ilc_phase_am_pm, 'darkorange', 'Сигнал с предыскажением'),
]

plotting.plot_am_am_pm(
    am_am_data=am_am_data,
    am_pm_data=am_pm_data,
    figsize=(12, 6),
    titles=("AM/AM ILC", "AM/PM ILC"),
    xlabels=("Амплитуда на входе", "Амплитуда на входе"),
    ylabels=("Амплитуда на выходе", "Фазовый сдвиг на выходе (градусы)")
)

# %% [markdown]
# Add noise

# %%
snr_range = list(range(20, 61, 10))

epochs = 10
lr = 0.01
num_realizations = 500

snr_params = params.make_snr_params(
    snr_range=snr_range,
    num_realizations=num_realizations,
    fs=fs,
    bw_main_ch=bw_main_ch,
    epochs=epochs,
    learning_rate=lr,
    acpr_meter=acpr_meter,
    pa_model=pa_model,
    gain=gain
)

gmp_degree = 5
gmp_params = {"gmp_degree": gmp_degree}

snr_metrics_runner = pipelines.SnrPipeline(base_model=BatchGMP, 
                                           input_model_params=gmp_params, 
                                           data_dict=data, 
                                           snr_params=snr_params)

# %%
snr_metrics_runner.run_dla_noise()
# Out:
# SNR: 20
# ===Start training===
# Epoch 0000 — train_loss: 0.218147, val_loss: 0.022959, val_NMSE: -15.31
# Epoch 0001 — train_loss: 0.018544, val_loss: 0.015924, val_NMSE: -16.90
# Epoch 0002 — train_loss: 0.015232, val_loss: 0.014882, val_NMSE: -17.19
# Epoch 0003 — train_loss: 0.014828, val_loss: 0.015034, val_NMSE: -17.15
# Epoch 0004 — train_loss: 0.014858, val_loss: 0.015014, val_NMSE: -17.16
# Epoch 0005 — train_loss: 0.014799, val_loss: 0.014886, val_NMSE: -17.19
# Epoch 0006 — train_loss: 0.014820, val_loss: 0.014992, val_NMSE: -17.16
# Epoch 0007 — train_loss: 0.014843, val_loss: 0.014892, val_NMSE: -17.19
# Epoch 0008 — train_loss: 0.014847, val_loss: 0.015162, val_NMSE: -17.11
# Epoch 0009 — train_loss: 0.014832, val_loss: 0.014588, val_NMSE: -17.28
# ===Training complete===
# Выполнение заняло: 0:02:54
# SNR: 30
# ===Start training===
# Epoch 0000 — train_loss: 0.472684, val_loss: 0.010352, val_NMSE: -18.77
# Epoch 0001 — train_loss: 0.005322, val_loss: 0.002467, val_NMSE: -25.00
# Epoch 0002 — train_loss: 0.001997, val_loss: 0.001717, val_NMSE: -26.57
# Epoch 0003 — train_loss: 0.001623, val_loss: 0.001596, val_NMSE: -26.89
# Epoch 0004 — train_loss: 0.001571, val_loss: 0.001541, val_NMSE: -27.04
# Epoch 0005 — train_loss: 0.001554, val_loss: 0.001582, val_NMSE: -26.93
# Epoch 0006 — train_loss: 0.001552, val_loss: 0.001552, val_NMSE: -27.01
# Epoch 0007 — train_loss: 0.001551, val_loss: 0.001596, val_NMSE: -26.89
# Epoch 0008 — train_loss: 0.001548, val_loss: 0.001579, val_NMSE: -26.94
# Epoch 0009 — train_loss: 0.001545, val_loss: 0.001557, val_NMSE: -27.00
# ===Training complete===
# Выполнение заняло: 0:02:52
# SNR: 40
# ===Start training===
# Epoch 0000 — train_loss: 0.287177, val_loss: 0.010029, val_NMSE: -18.91
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 snr_metrics_runner.run_dla_noise()
#
# File d:\Учёба\проект\python\DPD_Research\modules\pipelines.py:422, in SnrPipeline.run_dla_noise(self)
#     418 casc_dla = utils.CascadeModel(model_1=dpd_model,
#     419                                 model_2=casc_pa_noise)
#     420 optimizer = torch.optim.Adam(casc_dla.parameters(), lr=self.lr)
# --> 422 learning.train(net=casc_dla,
#     423             criterion=self.criterion,
#     424             optimizer=optimizer,
#     425             train_loader=self.dla_train_loader,
#     426             val_loader=self.dla_val_loader,
#     427             grad_clip_val=self.grad_clip_val,
#     428             n_epochs=self.epochs,
#     429             metric_criterion=self.metric_criterion)
#     431 nmse, acpr_left, acpr_right = metrics.noise_realizations(self.num_realizations,
#     432                                                 model=casc_dla,
#     433                                                 x=self.x_val,
#     434                                                 y_target=self.y_val_target,
#     435                                                 acpr_meter=self.acpr_meter)
#     436 self.results["dla"]["nmse"].append(nmse.item())
#
# File d:\Учёба\проект\python\DPD_Research\modules\utils.py:119, in timer_decorator.<locals>.wrapper(*args, **kwargs)
#     116 @functools.wraps(func)
#     117 def wrapper(*args, **kwargs):
#     118     start = time.time()
# --> 119     result = func(*args, **kwargs)
#     120     elapsed = time.time() - start
#     121     print(f"Выполнение заняло: {timedelta(seconds=round(elapsed))}")
#
# File d:\Учёба\проект\python\DPD_Research\modules\learning.py:75, in train(net, criterion, optimizer, train_loader, val_loader, n_epochs, metric_criterion, grad_clip_val)
#      73 print("===Start training===")
#      74 for epoch in range(n_epochs):
# ---> 75     net, train_loss = net_train(net=net,
#      76                     optimizer=optimizer,
#      77                     criterion=criterion,
#      78                     dataloader=train_loader,
#      79                     grad_clip_val=grad_clip_val)
#      81     val_loss, val_metric_loss = net_eval(net=net,
#      82                                          criterion=criterion,
#      83                                          dataloader=val_loader,
#      84                                          metric_criterion=metric_criterion)
#      86     if epoch % 1 == 0 or epoch == n_epochs - 1:
#
# File d:\Учёба\проект\python\DPD_Research\modules\learning.py:36, in net_train(net, dataloader, optimizer, criterion, grad_clip_val)
#      34 for features, targets in dataloader:
#      35     optimizer.zero_grad()
# ---> 36     out = net(features)
#      37     loss = criterion(out, targets)
#      38     loss.backward()
#
# File c:\Users\maximp\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File c:\Users\maximp\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File d:\Учёба\проект\python\DPD_Research\modules\utils.py:154, in CascadeModel.forward(self, x)
#     152 if self.cascade_type == "ila" and self.gain:
#     153     x = x / self.gain
# --> 154 x = self.model_2(x)
#     155 return x
#
# File c:\Users\maximp\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File c:\Users\maximp\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File d:\Учёба\проект\python\DPD_Research\modules\utils.py:151, in CascadeModel.forward(self, x)
#     150 def forward(self, x):
# --> 151     x = self.model_1(x)
#     152     if self.cascade_type == "ila" and self.gain:
#     153         x = x / self.gain
#
# File c:\Users\maximp\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File c:\Users\maximp\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File d:\Учёба\проект\python\DPD_Research\modules\utils.py:51, in complex_handler.<locals>.wrapper(self, inputs, *args, **kwargs)
#      48 else:
#      49     inputs = inputs
# ---> 51 result = forward_func(self, inputs, *args, **kwargs)
#      53 if result is None:
#      54     return
#
# File d:\Учёба\проект\python\DPD_Research\modules\gmp_model.py:268, in BatchGMP.forward(self, x)
#     265 y_re = term_a_re + term_b_re + term_c_re
#     266 y_im = term_a_im + term_b_im + term_c_im
# --> 268 y = torch.stack([y_re, y_im], dim=-1)
#     269 return y
#
# File c:\Users\maximp\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\functional.py:407, in einsum(*args)
#     402     return einsum(equation, *_operands)
#     404 if len(operands) <= 2 or not opt_einsum.enabled:
#     405     # the path for contracting 0 or 1 time(s) is already optimized
#     406     # or the user has disabled using opt_einsum
# --> 407     return _VF.einsum(equation, operands)  # type: ignore[attr-defined]
#     409 path = None
#     410 if opt_einsum.is_available():
#
# KeyboardInterrupt:

# %%
snr_metrics_runner.run_ila_noise()
# Out:
# SNR: 20
# ===Start training===
# Epoch 0000 — train_loss: 0.059848, val_loss: 0.081936, val_NMSE: -1.76
# Epoch 0100 — train_loss: 0.001612, val_loss: 0.001666, val_NMSE: -18.67
# Epoch 0200 — train_loss: 0.001570, val_loss: 0.001626, val_NMSE: -18.78
# Epoch 0300 — train_loss: 0.001572, val_loss: 0.001608, val_NMSE: -18.83
# Epoch 0400 — train_loss: 0.001557, val_loss: 0.001562, val_NMSE: -18.95
# Epoch 0499 — train_loss: 0.001543, val_loss: 0.001567, val_NMSE: -18.94
# Время обучения: 0:01:14
# ===Training complete===
# SNR: 25
# ===Start training===
# Epoch 0000 — train_loss: 0.059314, val_loss: 0.097127, val_NMSE: -1.02
# Epoch 0100 — train_loss: 0.000611, val_loss: 0.000626, val_NMSE: -22.92
# Epoch 0200 — train_loss: 0.000581, val_loss: 0.000595, val_NMSE: -23.14
# Epoch 0300 — train_loss: 0.000569, val_loss: 0.000595, val_NMSE: -23.15
# Epoch 0400 — train_loss: 0.000564, val_loss: 0.000592, val_NMSE: -23.17
# Epoch 0499 — train_loss: 0.000557, val_loss: 0.000590, val_NMSE: -23.18
# Время обучения: 0:01:14
# ===Training complete===
# SNR: 30
# ===Start training===
# Epoch 0000 — train_loss: 0.059866, val_loss: 0.075397, val_NMSE: -2.12
# Epoch 0100 — train_loss: 0.000239, val_loss: 0.000245, val_NMSE: -26.99
# Epoch 0200 — train_loss: 0.000213, val_loss: 0.000215, val_NMSE: -27.57
# Epoch 0300 — train_loss: 0.000206, val_loss: 0.000214, val_NMSE: -27.58
# Epoch 0400 — train_loss: 0.000205, val_loss: 0.000209, val_NMSE: -27.70
# Epoch 0499 — train_loss: 0.000197, val_loss: 0.000203, val_NMSE: -27.82
# Время обучения: 0:01:15
# ===Training complete===
# SNR: 35
# ===Start training===
# Epoch 0000 — train_loss: 0.060001, val_loss: 0.075433, val_NMSE: -2.11
# Epoch 0100 — train_loss: 0.000111, val_loss: 0.000108, val_NMSE: -30.54
# Epoch 0200 — train_loss: 0.000084, val_loss: 0.000084, val_NMSE: -31.64
# Epoch 0300 — train_loss: 0.000078, val_loss: 0.000078, val_NMSE: -31.99
# Epoch 0400 — train_loss: 0.000076, val_loss: 0.000076, val_NMSE: -32.08
# Epoch 0499 — train_loss: 0.000074, val_loss: 0.000076, val_NMSE: -32.09
# Время обучения: 0:01:15
# ===Training complete===
# SNR: 40
# ===Start training===
# Epoch 0000 — train_loss: 0.059537, val_loss: 0.098361, val_NMSE: -0.96
# Epoch 0100 — train_loss: 0.000068, val_loss: 0.000068, val_NMSE: -32.59
# Epoch 0200 — train_loss: 0.000042, val_loss: 0.000041, val_NMSE: -34.75
# Epoch 0300 — train_loss: 0.000035, val_loss: 0.000035, val_NMSE: -35.48
# Epoch 0400 — train_loss: 0.000032, val_loss: 0.000032, val_NMSE: -35.80
# Epoch 0499 — train_loss: 0.000029, val_loss: 0.000030, val_NMSE: -36.11
# Время обучения: 0:01:14
# ===Training complete===
# SNR: 45
# ===Start training===
# Epoch 0000 — train_loss: 0.060041, val_loss: 0.075214, val_NMSE: -2.13
# Epoch 0100 — train_loss: 0.000055, val_loss: 0.000053, val_NMSE: -33.64
# Epoch 0200 — train_loss: 0.000028, val_loss: 0.000027, val_NMSE: -36.59
# Epoch 0300 — train_loss: 0.000019, val_loss: 0.000020, val_NMSE: -37.90
# Epoch 0400 — train_loss: 0.000016, val_loss: 0.000016, val_NMSE: -38.81
# Epoch 0499 — train_loss: 0.000014, val_loss: 0.000015, val_NMSE: -39.21
# Время обучения: 0:01:14
# ===Training complete===
# SNR: 50
# ===Start training===
# Epoch 0000 — train_loss: 0.060424, val_loss: 0.074536, val_NMSE: -2.17
# Epoch 0100 — train_loss: 0.000051, val_loss: 0.000050, val_NMSE: -33.94
# Epoch 0200 — train_loss: 0.000023, val_loss: 0.000023, val_NMSE: -37.33
# Epoch 0300 — train_loss: 0.000015, val_loss: 0.000015, val_NMSE: -39.09
# Epoch 0400 — train_loss: 0.000011, val_loss: 0.000011, val_NMSE: -40.29
# Epoch 0499 — train_loss: 0.000009, val_loss: 0.000010, val_NMSE: -40.92
# Время обучения: 0:01:15
# ===Training complete===
# SNR: 55
# ===Start training===
# Epoch 0000 — train_loss: 0.059847, val_loss: 0.098678, val_NMSE: -0.95
# Epoch 0100 — train_loss: 0.000049, val_loss: 0.000047, val_NMSE: -34.14
# Epoch 0200 — train_loss: 0.000022, val_loss: 0.000021, val_NMSE: -37.64
# Epoch 0300 — train_loss: 0.000014, val_loss: 0.000014, val_NMSE: -39.42
# Epoch 0400 — train_loss: 0.000010, val_loss: 0.000010, val_NMSE: -40.68
# Epoch 0499 — train_loss: 0.000008, val_loss: 0.000009, val_NMSE: -41.54
# Время обучения: 0:01:15
# ===Training complete===
# SNR: 60
# ===Start training===
# Epoch 0000 — train_loss: 0.061038, val_loss: 0.076367, val_NMSE: -2.06
# Epoch 0100 — train_loss: 0.000050, val_loss: 0.000048, val_NMSE: -34.03
# Epoch 0200 — train_loss: 0.000022, val_loss: 0.000021, val_NMSE: -37.65
# Epoch 0300 — train_loss: 0.000013, val_loss: 0.000013, val_NMSE: -39.61
# Epoch 0400 — train_loss: 0.000009, val_loss: 0.000010, val_NMSE: -40.99
# Epoch 0499 — train_loss: 0.000007, val_loss: 0.000008, val_NMSE: -41.89
# Время обучения: 0:01:15
# ===Training complete===

# %%
snr_metrics_runner.run_ilc_noise()
# Out:
# SNR: 20
# Epoch [0/500], Loss: 0.05481655150651932
# Epoch [100/500], Loss: 0.018765931949019432
# Epoch [200/500], Loss: 0.014988327398896217
# Epoch [300/500], Loss: 0.014843262732028961
# Epoch [400/500], Loss: 0.014706596732139587
# Epoch [499/500], Loss: 0.014754110015928745
# Время расчёта ilc_signal: 0:01:14
# ===Start training===
# Epoch 0000 — train_loss: 0.035044, val_loss: 0.028912, val_NMSE: -3.81
# Epoch 0100 — train_loss: 0.000031, val_loss: 0.000031, val_NMSE: -33.49
# Epoch 0200 — train_loss: 0.000021, val_loss: 0.000020, val_NMSE: -35.31
# Epoch 0300 — train_loss: 0.000018, val_loss: 0.000018, val_NMSE: -35.93
# Epoch 0400 — train_loss: 0.000017, val_loss: 0.000017, val_NMSE: -36.21
# Epoch 0499 — train_loss: 0.000016, val_loss: 0.000016, val_NMSE: -36.35
# Время обучения: 0:00:58
# ===Training complete===
# SNR: 25
# Epoch [0/500], Loss: 0.03817254304885864
# Epoch [100/500], Loss: 0.006577697116881609
# Epoch [200/500], Loss: 0.004973146133124828
# Epoch [300/500], Loss: 0.004793424159288406
# Epoch [400/500], Loss: 0.004835061263293028
# Epoch [499/500], Loss: 0.004866930190473795
# Время расчёта ilc_signal: 0:01:14
# ===Start training===
# Epoch 0000 — train_loss: 0.036354, val_loss: 0.029019, val_NMSE: -4.04
# Epoch 0100 — train_loss: 0.000026, val_loss: 0.000027, val_NMSE: -34.40
# Epoch 0200 — train_loss: 0.000015, val_loss: 0.000015, val_NMSE: -36.94
# Epoch 0300 — train_loss: 0.000012, val_loss: 0.000012, val_NMSE: -37.90
# Epoch 0400 — train_loss: 0.000011, val_loss: 0.000011, val_NMSE: -38.37
# Epoch 0499 — train_loss: 0.000010, val_loss: 0.000010, val_NMSE: -38.62
# Время обучения: 0:00:58
# ===Training complete===
# SNR: 30
# Epoch [0/500], Loss: 0.03279691934585571
# Epoch [100/500], Loss: 0.0028426661156117916
# Epoch [200/500], Loss: 0.0016168872825801373
# Epoch [300/500], Loss: 0.0015573921846225858
# Epoch [400/500], Loss: 0.0015769460005685687
# Epoch [499/500], Loss: 0.0015687770210206509
# Время расчёта ilc_signal: 0:01:14
# ===Start training===
# Epoch 0000 — train_loss: 0.037541, val_loss: 0.029196, val_NMSE: -4.09
# Epoch 0100 — train_loss: 0.000023, val_loss: 0.000023, val_NMSE: -35.04
# Epoch 0200 — train_loss: 0.000011, val_loss: 0.000011, val_NMSE: -38.19
# Epoch 0300 — train_loss: 0.000008, val_loss: 0.000008, val_NMSE: -39.57
# Epoch 0400 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -40.31
# Epoch 0499 — train_loss: 0.000006, val_loss: 0.000006, val_NMSE: -40.70
# Время обучения: 0:00:58
# ===Training complete===
# SNR: 35
# Epoch [0/500], Loss: 0.031205661594867706
# Epoch [100/500], Loss: 0.0016312811058014631
# Epoch [200/500], Loss: 0.0005373336607590318
# Epoch [300/500], Loss: 0.0005056122899986804
# Epoch [400/500], Loss: 0.0005162161542102695
# Epoch [499/500], Loss: 0.0005061766132712364
# Время расчёта ilc_signal: 0:01:14
# ===Start training===
# Epoch 0000 — train_loss: 0.038151, val_loss: 0.029826, val_NMSE: -4.02
# Epoch 0100 — train_loss: 0.000021, val_loss: 0.000022, val_NMSE: -35.42
# Epoch 0200 — train_loss: 0.000009, val_loss: 0.000009, val_NMSE: -39.08
# Epoch 0300 — train_loss: 0.000006, val_loss: 0.000006, val_NMSE: -40.89
# Epoch 0400 — train_loss: 0.000005, val_loss: 0.000005, val_NMSE: -41.94
# Epoch 0499 — train_loss: 0.000004, val_loss: 0.000004, val_NMSE: -42.54
# Время обучения: 0:00:58
# ===Training complete===
# SNR: 40
# Epoch [0/500], Loss: 0.030763790011405945
# Epoch [100/500], Loss: 0.0012514161644503474
# Epoch [200/500], Loss: 0.00019459206669125706
# Epoch [300/500], Loss: 0.000164226716151461
# Epoch [400/500], Loss: 0.00016362925816792995
# Epoch [499/500], Loss: 0.00016435881843790412
# Время расчёта ilc_signal: 0:01:14
# ===Start training===
# Epoch 0000 — train_loss: 0.038475, val_loss: 0.029715, val_NMSE: -4.04
# Epoch 0100 — train_loss: 0.000020, val_loss: 0.000020, val_NMSE: -35.68
# Epoch 0200 — train_loss: 0.000008, val_loss: 0.000008, val_NMSE: -39.61
# Epoch 0300 — train_loss: 0.000005, val_loss: 0.000005, val_NMSE: -41.71
# Epoch 0400 — train_loss: 0.000004, val_loss: 0.000004, val_NMSE: -43.02
# Epoch 0499 — train_loss: 0.000003, val_loss: 0.000003, val_NMSE: -43.81
# Время обучения: 0:00:58
# ===Training complete===
# SNR: 45
# Epoch [0/500], Loss: 0.030568702146410942
# Epoch [100/500], Loss: 0.0011276033474132419
# Epoch [200/500], Loss: 8.217983122449368e-05
# Epoch [300/500], Loss: 5.3550458687823266e-05
# Epoch [400/500], Loss: 5.33772908966057e-05
# Epoch [499/500], Loss: 5.405112824519165e-05
# Время расчёта ilc_signal: 0:01:14
# ===Start training===
# Epoch 0000 — train_loss: 0.037436, val_loss: 0.029644, val_NMSE: -4.05
# Epoch 0100 — train_loss: 0.000020, val_loss: 0.000020, val_NMSE: -35.82
# Epoch 0200 — train_loss: 0.000008, val_loss: 0.000008, val_NMSE: -39.92
# Epoch 0300 — train_loss: 0.000005, val_loss: 0.000005, val_NMSE: -42.22
# Epoch 0400 — train_loss: 0.000003, val_loss: 0.000003, val_NMSE: -43.70
# Epoch 0499 — train_loss: 0.000003, val_loss: 0.000003, val_NMSE: -44.64
# Время обучения: 0:00:58
# ===Training complete===
# SNR: 50
# Epoch [0/500], Loss: 0.030510419979691505
# Epoch [100/500], Loss: 0.0010877472814172506
# Epoch [200/500], Loss: 4.665843152906746e-05
# Epoch [300/500], Loss: 1.77346846612636e-05
# Epoch [400/500], Loss: 1.750207957229577e-05
# Epoch [499/500], Loss: 1.768688343872782e-05
# Время расчёта ilc_signal: 0:01:13
# ===Start training===
# Epoch 0000 — train_loss: 0.037823, val_loss: 0.028641, val_NMSE: -4.20
# Epoch 0100 — train_loss: 0.000020, val_loss: 0.000019, val_NMSE: -35.91
# Epoch 0200 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -40.14
# Epoch 0300 — train_loss: 0.000004, val_loss: 0.000004, val_NMSE: -42.56
# Epoch 0400 — train_loss: 0.000003, val_loss: 0.000003, val_NMSE: -44.14
# Epoch 0499 — train_loss: 0.000002, val_loss: 0.000002, val_NMSE: -45.17
# Время обучения: 0:00:59
# ===Training complete===
# SNR: 55
# Epoch [0/500], Loss: 0.030490567907691002
# Epoch [100/500], Loss: 0.0010749859502539039
# Epoch [200/500], Loss: 3.513009141897783e-05
# Epoch [300/500], Loss: 6.256213509914232e-06
# Epoch [400/500], Loss: 5.638692528009415e-06
# Epoch [499/500], Loss: 5.718673037335975e-06
# Время расчёта ilc_signal: 0:01:13
# ===Start training===
# Epoch 0000 — train_loss: 0.037942, val_loss: 0.029391, val_NMSE: -4.09
# Epoch 0100 — train_loss: 0.000019, val_loss: 0.000019, val_NMSE: -35.88
# Epoch 0200 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -40.18
# Epoch 0300 — train_loss: 0.000004, val_loss: 0.000004, val_NMSE: -42.62
# Epoch 0400 — train_loss: 0.000003, val_loss: 0.000003, val_NMSE: -44.25
# Epoch 0499 — train_loss: 0.000002, val_loss: 0.000002, val_NMSE: -45.32
# Время обучения: 0:00:58
# ===Training complete===
# SNR: 60
# Epoch [0/500], Loss: 0.030479632318019867
# Epoch [100/500], Loss: 0.0010703527368605137
# Epoch [200/500], Loss: 3.141530032735318e-05
# Epoch [300/500], Loss: 2.5014817310875515e-06
# Epoch [400/500], Loss: 1.905332851492858e-06
# Epoch [499/500], Loss: 1.909884304041043e-06
# Время расчёта ilc_signal: 0:01:13
# ===Start training===
# Epoch 0000 — train_loss: 0.037370, val_loss: 0.028831, val_NMSE: -4.18
# Epoch 0100 — train_loss: 0.000020, val_loss: 0.000019, val_NMSE: -35.89
# Epoch 0200 — train_loss: 0.000007, val_loss: 0.000007, val_NMSE: -40.18
# Epoch 0300 — train_loss: 0.000004, val_loss: 0.000004, val_NMSE: -42.66
# Epoch 0400 — train_loss: 0.000003, val_loss: 0.000003, val_NMSE: -44.32
# Epoch 0499 — train_loss: 0.000002, val_loss: 0.000002, val_NMSE: -45.41
# Время обучения: 0:00:58
# ===Training complete===

# %%
results = snr_metrics_runner.get_results()

snr_range = results["snr_range"]

nmse_dla_list = results["dla"]["nmse"]
acpr_left_dla_list = results["dla"]["acpr_left"]
acpr_right_dla_list = results["dla"]["acpr_right"]

nmse_ila_list = results["ila"]["nmse"]
acpr_left_ila_list = results["ila"]["acpr_left"]
acpr_right_ila_list = results["ila"]["acpr_right"]

nmse_ilc_list = results["ilc"]["nmse"]
acpr_left_ilc_list = results["ilc"]["acpr_left"]
acpr_right_ilc_list = results["ilc"]["acpr_right"]

nmse_uk_list = results["uk"]["nmse"]
acpr_left_uk_list = results["uk"]["acpr_left"]
acpr_right_uk_list = results["uk"]["acpr_right"]

# %%
print(f"snr_range = {snr_range}")
print()

print(f"nmse_dla_list = {(nmse_dla_list)}")
print(f"acpr_left_dla_list = {acpr_left_dla_list}")
print(f"acpr_right_dla_list = {acpr_right_dla_list}")
print()

print(f"nmse_ila_list = {nmse_ila_list}")
print(f"acpr_left_ila_list = {acpr_left_ila_list}")
print(f"acpr_right_ila_list = {acpr_right_ila_list}")
print()

print(f"nmse_ilc_list = {nmse_ilc_list}")
print(f"acpr_left_ilc_list = {acpr_left_ilc_list}")
print(f"acpr_right_ilc_list = {acpr_right_ilc_list}")
print()

print(f"nmse_uk_list = {nmse_uk_list}")
print(f"acpr_left_uk_list = {acpr_left_uk_list}")
print(f"acpr_right_uk_list = {acpr_right_uk_list}")
# Out:
# snr_range = [20, 25, 30, 35, 40, 45, 50, 55, 60]
#
# nmse_dla_list = [-17.148632049560547, -22.024913787841797, -26.938125610351562, -31.83021354675293, -36.51686096191406, -40.62764358520508, -43.64088821411133, -45.28367233276367, -45.97032928466797]
# acpr_left_dla_list = [np.float64(-20.02928768602456), np.float64(-24.982584759640396), np.float64(-29.94026217788973), np.float64(-34.790795872739075), np.float64(-39.38424284115534), np.float64(-43.27951405106335), np.float64(-45.91862097413965), np.float64(-47.333822464193716), np.float64(-47.83152138893719)]
# acpr_right_dla_list = [np.float64(-20.042172905027773), np.float64(-25.000703280641286), np.float64(-29.94555560855832), np.float64(-34.80382540388212), np.float64(-39.38523604062279), np.float64(-43.28755626930241), np.float64(-45.98511389366253), np.float64(-47.36026912001858), np.float64(-47.90736568475759)]
#
# nmse_ila_list = [-16.83725929260254, -21.696548461914062, -26.669509887695312, -31.488346099853516, -36.02500915527344, -39.879154205322266, -42.40645217895508, -43.42716979980469, -43.93549346923828]
# acpr_left_ila_list = [np.float64(-20.00222177006019), np.float64(-24.971782017744154), np.float64(-29.923676246124597), np.float64(-34.80161732949249), np.float64(-39.42496900898496), np.float64(-43.28975773398101), np.float64(-45.873289415878496), np.float64(-47.202136411878605), np.float64(-47.756956490565976)]
# acpr_right_ila_list = [np.float64(-19.993474395769827), np.float64(-24.971225060341276), np.float64(-29.892187352223697), np.float64(-34.74605686633869), np.float64(-39.33391505070409), np.float64(-43.2264451233586), np.float64(-45.85228436821109), np.float64(-47.18489131799368), np.float64(-47.6152281122493)]
#
# nmse_ilc_list = [-17.158906936645508, -22.031850814819336, -26.965087890625, -31.861326217651367, -36.56019592285156, -40.75254440307617, -43.91820526123047, -45.680294036865234, -46.44440460205078]
# acpr_left_ilc_list = [np.float64(-20.044396458130798), np.float64(-24.993578868965155), np.float64(-29.9372842180529), np.float64(-34.772924693359265), np.float64(-39.31178774909315), np.float64(-43.099510420284886), np.float64(-45.61383020944608), np.float64(-46.92524581800085), np.float64(-47.35796834667576)]
# acpr_right_ilc_list = [np.float64(-20.040459827433555), np.float64(-24.992806883037694), np.float64(-29.944472317953025), np.float64(-34.81252600026537), np.float64(-39.403898012451755), np.float64(-43.3101146452194), np.float64(-46.009645430692416), np.float64(-47.33800239352745), np.float64(-47.92661068555603)]
#
# nmse_uk_list = [-17.104299545288086, -21.947444915771484, -26.852418899536133, -31.760339736938477, -36.646244049072266, -41.51726150512695, -46.37682342529297, -51.21725082397461, -56.03969192504883]
# acpr_left_uk_list = [np.float64(-19.998647945394534), np.float64(-24.925774868876385), np.float64(-29.859171441485117), np.float64(-34.72613479202458), np.float64(-39.43138138529091), np.float64(-43.75281378471498), np.float64(-47.17010201888079), np.float64(-49.318533219410455), np.float64(-50.34103656182335)]
# acpr_right_uk_list = [np.float64(-19.95078639388352), np.float64(-24.84866152192613), np.float64(-29.723849726576287), np.float64(-34.526383917218666), np.float64(-39.1178723599403), np.float64(-43.31461094685448), np.float64(-46.65804885579808), np.float64(-48.72905610711496), np.float64(-49.792518163401525)]

# %%
# # значения в виде списков чтобы не рассчитывать снова все значения

# snr_range = [20, 22, 24, 26, 28, 30, 32, 34, 36, 38, 40, 42, 44, 46, 48, 50, 52, 54, 56, 58, 60]

# nmse_dla_list = [-17.154949188232422, -19.09251594543457, -21.044750213623047, -23.021923065185547, -25.002155303955078, -26.98126983642578, -28.954303741455078, -30.937488555908203, -32.90107345581055, -34.845218658447266, -36.755924224853516, -38.61607360839844, -40.426910400390625, -42.124752044677734, -43.687843322753906, -45.075897216796875, -46.248626708984375, -47.228172302246094, -47.92564010620117, -48.49229431152344, -48.84376907348633]
# acpr_left_dla_list = [np.float64(-20.032896621274734), np.float64(-22.002898276331), np.float64(-23.980167111262954), np.float64(-25.985284041461938), np.float64(-27.943916970011372), np.float64(-29.91541877521779), np.float64(-31.871352771576074), np.float64(-33.797012660383636), np.float64(-35.67219414298505), np.float64(-37.49542101433636), np.float64(-39.210372332336746), np.float64(-40.8129737284458), np.float64(-42.2611022976035), np.float64(-43.489963007240796), np.float64(-44.48969779871533), np.float64(-45.26628275458397), np.float64(-45.82507862711507), np.float64(-46.26964161953022), np.float64(-46.544344312319446), np.float64(-46.7247453176207), np.float64(-46.8625007497271)]
# acpr_right_dla_list = [np.float64(-20.03067217721715), np.float64(-22.023901072994782), np.float64(-23.999487986191852), np.float64(-25.990288997195552), np.float64(-27.97879723510448), np.float64(-29.93405882623138), np.float64(-31.885189566353002), np.float64(-33.83402270942291), np.float64(-35.73882672394366), np.float64(-37.591940638042516), np.float64(-39.35400356485398), np.float64(-41.02262823000135), np.float64(-42.529186070031216), np.float64(-43.87146478243156), np.float64(-44.98060385142986), np.float64(-45.87641689390573), np.float64(-46.57500010862354), np.float64(-47.01434234515064), np.float64(-47.360535320706695), np.float64(-47.54855205738099), np.float64(-47.716042344669965)]

# nmse_ila_list = [-17.14900016784668, -19.082727432250977, -21.0418701171875, -23.009443283081055, -24.970191955566406, -26.952104568481445, -28.929380416870117, -30.873485565185547, -32.79220199584961, -34.68447494506836, -36.50259017944336, -38.23097229003906, -39.86079025268555, -41.318084716796875, -42.59962463378906, -43.62651062011719, -44.414581298828125, -45.008975982666016, -45.430274963378906, -45.73917007446289, -45.99494552612305]
# acpr_left_ila_list = [np.float64(-20.023492672712504), np.float64(-22.00194266264846), np.float64(-23.982589695597863), np.float64(-25.971010353814368), np.float64(-27.954582475654398), np.float64(-29.883061513651946), np.float64(-31.84119207223084), np.float64(-33.741020731136594), np.float64(-35.59542076282507), np.float64(-37.389910008838555), np.float64(-39.05389357257544), np.float64(-40.57882064420808), np.float64(-41.87301807298115), np.float64(-43.028623797072676), np.float64(-43.97164913381233), np.float64(-44.47478498942156), np.float64(-45.094347042181134), np.float64(-45.44431979439592), np.float64(-45.6689972060291), np.float64(-45.81347702948893), np.float64(-45.919890365450364)]
# acpr_right_ila_list = [np.float64(-20.037619673095683), np.float64(-22.02154157779769), np.float64(-24.00141855357515), np.float64(-25.97407114783849), np.float64(-27.954493059455036), np.float64(-29.931848642514495), np.float64(-31.87500171448285), np.float64(-33.78634424089804), np.float64(-35.682854215253045), np.float64(-37.49031966564913), np.float64(-39.21893888309752), np.float64(-40.82172035769772), np.float64(-42.24376419843244), np.float64(-43.494933171804725), np.float64(-44.48705283113159), np.float64(-45.28125077526404), np.float64(-45.82150567692158), np.float64(-46.23586524416965), np.float64(-46.483727735029944), np.float64(-46.80989034343764), np.float64(-46.76467487891643)]

# nmse_ilc_list = [-17.161582946777344, -19.08861541748047, -21.052515029907227, -23.02472496032715, -25.0006103515625, -26.98052978515625, -28.957475662231445, -30.93657875061035, -32.8939208984375, -34.8338737487793, -36.754276275634766, -38.548091888427734, -40.303565979003906, -41.94981002807617, -43.43807601928711, -44.752685546875, -45.811702728271484, -46.68809509277344, -47.2928581237793, -47.732051849365234, -48.105037689208984]
# acpr_left_ilc_list = [np.float64(-20.04499601993586), np.float64(-22.000575773262312), np.float64(-24.005173164637622), np.float64(-25.975381528613166), np.float64(-27.948773007731976), np.float64(-29.904547380654257), np.float64(-31.83497348292303), np.float64(-33.76508347209344), np.float64(-35.63135714041884), np.float64(-37.43372467772184), np.float64(-39.14673797702895), np.float64(-40.682020346354115), np.float64(-42.074796748562314), np.float64(-43.25955583198558), np.float64(-44.172655984033355), np.float64(-44.92677486420471), np.float64(-45.42858744174152), np.float64(-45.81765459787905), np.float64(-46.0679249887625), np.float64(-46.22621768342928), np.float64(-46.348104813507604)]
# acpr_right_ilc_list = [np.float64(-20.055033821205793), np.float64(-22.02296109860739), np.float64(-24.011375645858735), np.float64(-25.989965909004713), np.float64(-27.974052697082097), np.float64(-29.94138650953073), np.float64(-31.89681741205028), np.float64(-33.840142017577605), np.float64(-35.730656379008416), np.float64(-37.598354712999864), np.float64(-39.381993008609946), np.float64(-41.00939897421255), np.float64(-42.49628648885533), np.float64(-43.81904566125652), np.float64(-44.926036747000865), np.float64(-45.77697004484083), np.float64(-46.456832260637114), np.float64(-46.9203740307759), np.float64(-47.219135964704975), np.float64(-47.42920449390439), np.float64(-47.62513932513492)]

# nmse_uk_list = [-17.094663619995117, -19.016490936279297, -20.960582733154297, -22.905410766601562, -24.86489486694336, -26.823619842529297, -28.778156280517578, -30.729806900024414, -32.679481506347656, -34.633670806884766, -36.5738410949707, -38.51299285888672, -40.44480514526367, -42.37684631347656, -44.29717254638672, -46.236045837402344, -48.150821685791016, -50.04896926879883, -51.969764709472656, -53.85963439941406, -55.72507858276367]
# acpr_left_uk_list = [np.float64(-19.99438441289194), np.float64(-21.9658512665871), np.float64(-23.945869167743208), np.float64(-25.92128162743692), np.float64(-27.9018250793472), np.float64(-29.857668613519994), np.float64(-31.830175197925897), np.float64(-33.76021792312188), np.float64(-35.677025441911994), np.float64(-37.586095603435375), np.float64(-39.42729918519659), np.float64(-41.22707557884934), np.float64(-42.936348574753275), np.float64(-44.508877373457345), np.float64(-45.93217114866118), np.float64(-47.16637553054871), np.float64(-48.16740369704331), np.float64(-48.992740555776834), np.float64(-49.56517529961033), np.float64(-50.01273812436431), np.float64(-50.31230743627908)]
# acpr_right_uk_list = [np.float64(-19.908159326520842), np.float64(-21.85695263610488), np.float64(-23.818630432812846), np.float64(-25.74280605561588), np.float64(-27.685123164021324), np.float64(-29.597578780431057), np.float64(-31.50956145186845), np.float64(-33.408043631235536), np.float64(-35.2641539488935), np.float64(-37.11290256809776), np.float64(-38.87993901305795), np.float64(-40.61697803065708), np.float64(-42.25138725427255), np.float64(-43.7730148204967), np.float64(-45.139205723386205), np.float64(-46.40286494928455), np.float64(-47.41226707888618), np.float64(-48.2239296586826), np.float64(-48.8718445889375), np.float64(-49.305717773680755), np.float64(-49.67857146555004)]

# %%
markersize = 8
plt.figure(figsize=(9, 5))
plt.plot(snr_range, nmse_dla_list,color='blue', linestyle='-', label="Сигнал с предыскажением DLA",
         marker='o', markersize=markersize)
plt.plot(snr_range, nmse_ila_list, color='orange', linestyle='--', label="Сигнал с предыскажением ILA",
         marker='s', markersize=markersize)
plt.plot(snr_range, nmse_ilc_list, color='green', linestyle='-.', label="Сигнал с предыскажением ILC",
         marker='d', markersize=markersize)
plt.plot(snr_range, nmse_uk_list, color='red', linestyle='-.', label="Оптимальный сигнал ILC",
         marker='*', markersize=markersize)

plt.xlabel("ОСШ, дБ", fontsize=12)
plt.ylabel("NMSE, дБ", fontsize=12)
# plt.title("Зависимость NMSE от ОСШ")
plt.xticks(range(20, 61, 5))
plt.yticks(range(-55, -9, 5))
plt.legend()
plt.grid(True)

plt.show()

# %%
markersize=8
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(snr_range, acpr_left_dla_list, color='blue', linestyle='-', label="Сигнал с предыскажением DLA", 
         marker='o', markersize=markersize)
plt.plot(snr_range, acpr_left_ila_list, color='orange', linestyle='--', label="Сигнал с предыскажением ILA", 
         marker='s', markersize=markersize)
plt.plot(snr_range, acpr_left_ilc_list, color='green', linestyle='-.', label="Сигнал с предыскажением ILC", 
         marker='d', markersize=markersize)
plt.plot(snr_range, acpr_left_uk_list, color='red', linestyle='-.', label="Оптимальный сигнал ILC", 
         marker='*', markersize=markersize)
plt.title('Левый канал', fontsize=12)
plt.xlabel('ОСШ, дБ', fontsize=12)
plt.ylabel('ACPR, дБ', fontsize=12)
plt.xticks(range(20, 61, 5))
plt.yticks(range(-55, -14, 5))
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(snr_range, acpr_right_dla_list, color='blue', linestyle='-', label="Сигнал с предыскажением DLA", 
         marker='o', markersize=markersize)
plt.plot(snr_range, acpr_right_ila_list, color='orange', linestyle='--', label="Сигнал с предыскажением ILA", 
         marker='s', markersize=markersize)
plt.plot(snr_range, acpr_right_ilc_list, color='green', linestyle='-.', label="Сигнал с предыскажением ILC", 
         marker='d', markersize=markersize)
plt.plot(snr_range, acpr_right_uk_list, color='red', linestyle='-.', label="Оптимальный сигнал ILC", 
         marker='*', markersize=markersize)
plt.title('Правый канал', fontsize=12)
plt.xlabel('ОСШ, дБ', fontsize=12)
plt.ylabel('ACPR, дБ', fontsize=12)
plt.xticks(range(20, 61, 5))
plt.yticks(range(-55, -14, 5))
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
