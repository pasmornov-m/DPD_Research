# %%
# %load_ext autoreload
# %autoreload 2

# %%
from modules import data_loader, metrics, learning, plotting, utils, params, pipelines, prunning
import matplotlib.pyplot as plt
import numpy as np
import torch
from modules.gmp_model import BatchGMP
from modules.nn_model import GRU, LSTM


import torch.nn.utils.prune as prune
import matplotlib as mpl
import seaborn as sns
import time
from datetime import timedelta

# %% [markdown]
# Load data from files and init acpr meter

# %%
container = data_loader.DataContainer()
container.load_data(file_path="datasets/Custom_dataset")
container.get_gained_signals()


acpr_meter = metrics.ACPR(
        sample_rate=container.input_signal_fs,
        main_measurement_bandwidth=container.bw_main_ch,
        adjacent_channel_offset=[-container.bw_main_ch, container.bw_main_ch],
        segment_length=container.nperseg,
        overlap_percentage=60,
        window='blackmanharris',
        fft_length=container.nperseg,
        power_units='dBW',
        return_main_power=True,
        return_adjacent_powers=True
    )

# %%
frame_length = 64
batch_size = 128
batch_size_eval = 2048

pa_train_loader, pa_val_loader = data_loader.build_dataloaders(data_dict=container.to_dict(), frame_length=frame_length, batch_size=batch_size, batch_size_eval=batch_size_eval)
dla_train_loader, dla_val_loader = data_loader.build_dataloaders(data_dict=container.to_dict(), frame_length=frame_length, batch_size=batch_size, batch_size_eval=batch_size_eval, arch="dla")
ila_train_loader, ila_val_loader = data_loader.build_dataloaders(data_dict=container.to_dict(), frame_length=frame_length, batch_size=batch_size, batch_size_eval=batch_size_eval, arch="ila")

criterion = metrics.compute_mse
metric_criterion = metrics.compute_nmse

# %% [markdown]
# PA

# %%
pa_degree = 10
pa_config = params.make_gmp_params(
    Ka=pa_degree,
    La=pa_degree,
    Kb=pa_degree,
    Lb=pa_degree,
    Mb=pa_degree,
    Kc=pa_degree,
    Lc=pa_degree,
    Mc=pa_degree,
)

pa_model = BatchGMP(**pa_config, model_name="pa")


print(f"total_params: {pa_model.count_params()}")

epochs = 100
lr = 0.01

optimizer = torch.optim.AdamW(pa_model.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=10)

if not pa_model.load_weights():
      learning.train(net=pa_model, 
            criterion=criterion, 
            optimizer=optimizer, 
            train_loader=pa_train_loader, 
            val_loader=pa_val_loader, 
            n_epochs=epochs, 
            metric_criterion=metric_criterion,
            scheduler=scheduler)
      pa_model.save_weights()
utils.freeze_pa_model(pa_model)

y_val_pa = learning.net_inference(net=pa_model, x=container.val_input)
pa_nmse = metrics.compute_nmse(y_val_pa, container.val_output)
print(f"Model NMSE: {pa_nmse:.2f}")
# Out:
# total_params: 4200
# Coefficients loaded from model_params/pa_BatchGMP_Ka10_La10_Kb10_Lb10_Mb10_Kc10_Lc10_Mc10.pt
# Model NMSE: -41.06

# %%
epochs = 50
lr = 0.01
pa_model = LSTM(hidden_size=32, num_layers=1, model_name="pa")


print(f"total_params: {pa_model.count_params()}")

optimizer = torch.optim.AdamW(pa_model.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=10)

      
learning.train(net=pa_model, 
            criterion=criterion, 
            optimizer=optimizer, 
            train_loader=pa_train_loader, 
            val_loader=pa_val_loader, 
            n_epochs=epochs, 
            metric_criterion=metric_criterion,
            scheduler=scheduler)

# utils.freeze_pa_model(pa_model)

y_val_pa = learning.net_inference(net=pa_model, x=container.val_input)
pa_nmse = metrics.compute_nmse(y_val_pa, container.val_output)
print(f"Model NMSE: {pa_nmse:.2f}")
# Out:
# total_params: 4416
# ===Start training===
# Epoch 0000 — train_loss: 0.00655528, val_loss: 0.00022366, val_NMSE: -24.11, lr: 0.01
# Epoch 0001 — train_loss: 0.00040686, val_loss: 0.00009701, val_NMSE: -27.74, lr: 0.01
# Epoch 0002 — train_loss: 0.00020704, val_loss: 0.00003972, val_NMSE: -31.62, lr: 0.01
# Epoch 0003 — train_loss: 0.00013839, val_loss: 0.00002409, val_NMSE: -33.79, lr: 0.01
# Epoch 0004 — train_loss: 0.00011198, val_loss: 0.00001848, val_NMSE: -34.94, lr: 0.01
# Epoch 0005 — train_loss: 0.00009967, val_loss: 0.00001574, val_NMSE: -35.64, lr: 0.01
# Epoch 0006 — train_loss: 0.00009118, val_loss: 0.00001442, val_NMSE: -36.02, lr: 0.01
# Epoch 0007 — train_loss: 0.00007859, val_loss: 0.00000956, val_NMSE: -37.80, lr: 0.01
# Epoch 0008 — train_loss: 0.00360636, val_loss: 0.00020180, val_NMSE: -24.56, lr: 0.01
# Epoch 0009 — train_loss: 0.00017170, val_loss: 0.00004848, val_NMSE: -30.75, lr: 0.01
# Epoch 0010 — train_loss: 0.00012077, val_loss: 0.00003047, val_NMSE: -32.77, lr: 0.01
# Epoch 0011 — train_loss: 0.00011115, val_loss: 0.00002388, val_NMSE: -33.83, lr: 0.01
# Epoch 0012 — train_loss: 0.00010736, val_loss: 0.00002090, val_NMSE: -34.41, lr: 0.01
# Epoch 0013 — train_loss: 0.00010527, val_loss: 0.00001916, val_NMSE: -34.78, lr: 0.01
# Epoch 0014 — train_loss: 0.00010372, val_loss: 0.00001818, val_NMSE: -35.01, lr: 0.01
# Epoch 0015 — train_loss: 0.00010218, val_loss: 0.00001738, val_NMSE: -35.21, lr: 0.01
# Epoch 0016 — train_loss: 0.00010043, val_loss: 0.00001693, val_NMSE: -35.32, lr: 0.01
# Epoch 0017 — train_loss: 0.00009835, val_loss: 0.00001648, val_NMSE: -35.44, lr: 0.01
# Epoch 0018 — train_loss: 0.00009571, val_loss: 0.00001597, val_NMSE: -35.57, lr: 0.005
# Epoch 0019 — train_loss: 0.00009316, val_loss: 0.00001550, val_NMSE: -35.70, lr: 0.005
# Epoch 0020 — train_loss: 0.00009075, val_loss: 0.00001470, val_NMSE: -35.94, lr: 0.005
# Epoch 0021 — train_loss: 0.00008774, val_loss: 0.00001349, val_NMSE: -36.31, lr: 0.005
# Epoch 0022 — train_loss: 0.00008462, val_loss: 0.00001206, val_NMSE: -36.79, lr: 0.005
# Epoch 0023 — train_loss: 0.00008181, val_loss: 0.00001080, val_NMSE: -37.27, lr: 0.005
# Epoch 0024 — train_loss: 0.00007916, val_loss: 0.00000970, val_NMSE: -37.74, lr: 0.005
# Epoch 0025 — train_loss: 0.00007669, val_loss: 0.00000872, val_NMSE: -38.20, lr: 0.005
# Epoch 0026 — train_loss: 0.00007435, val_loss: 0.00000786, val_NMSE: -38.66, lr: 0.005
# Epoch 0027 — train_loss: 0.00007219, val_loss: 0.00000704, val_NMSE: -39.13, lr: 0.005
# Epoch 0028 — train_loss: 0.00007013, val_loss: 0.00000670, val_NMSE: -39.35, lr: 0.005
# Epoch 0029 — train_loss: 0.00006821, val_loss: 0.00000591, val_NMSE: -39.90, lr: 0.005
# Epoch 0030 — train_loss: 0.00006645, val_loss: 0.00000540, val_NMSE: -40.28, lr: 0.005
# Epoch 0031 — train_loss: 0.00080412, val_loss: 0.00003454, val_NMSE: -32.23, lr: 0.005
# Epoch 0032 — train_loss: 0.00009631, val_loss: 0.00002035, val_NMSE: -34.52, lr: 0.005
# Epoch 0033 — train_loss: 0.00009017, val_loss: 0.00001585, val_NMSE: -35.61, lr: 0.005
# Epoch 0034 — train_loss: 0.00008828, val_loss: 0.00001382, val_NMSE: -36.20, lr: 0.005
# Epoch 0035 — train_loss: 0.00008744, val_loss: 0.00001286, val_NMSE: -36.51, lr: 0.005
# Epoch 0036 — train_loss: 0.00008682, val_loss: 0.00001234, val_NMSE: -36.70, lr: 0.005
# Epoch 0037 — train_loss: 0.00008625, val_loss: 0.00001226, val_NMSE: -36.72, lr: 0.005
# Epoch 0038 — train_loss: 0.00008559, val_loss: 0.00001209, val_NMSE: -36.78, lr: 0.005
# Epoch 0039 — train_loss: 0.00008479, val_loss: 0.00001214, val_NMSE: -36.77, lr: 0.005
# Epoch 0040 — train_loss: 0.00008381, val_loss: 0.00001206, val_NMSE: -36.79, lr: 0.005
# Epoch 0041 — train_loss: 0.00008258, val_loss: 0.00001196, val_NMSE: -36.83, lr: 0.0025
# Epoch 0042 — train_loss: 0.00008145, val_loss: 0.00001189, val_NMSE: -36.86, lr: 0.0025
# Epoch 0043 — train_loss: 0.00008047, val_loss: 0.00001171, val_NMSE: -36.92, lr: 0.0025
# Epoch 0044 — train_loss: 0.00007926, val_loss: 0.00001147, val_NMSE: -37.01, lr: 0.0025
# Epoch 0045 — train_loss: 0.00007779, val_loss: 0.00001103, val_NMSE: -37.18, lr: 0.0025
# Epoch 0046 — train_loss: 0.00007605, val_loss: 0.00001048, val_NMSE: -37.40, lr: 0.0025
# Epoch 0047 — train_loss: 0.00007410, val_loss: 0.00000963, val_NMSE: -37.77, lr: 0.0025
# Epoch 0048 — train_loss: 0.00007201, val_loss: 0.00000866, val_NMSE: -38.24, lr: 0.0025
# Epoch 0049 — train_loss: 0.00007000, val_loss: 0.00000770, val_NMSE: -38.75, lr: 0.0025
# ===Training complete===
# Выполнение заняло: 0:02:34
# Model NMSE: -39.10

# %%
plotting.plot_weight_heatmaps(pa_model, vmin=-4, vmax=4)

# %%
amount_to_prune = 0.6

parameters_to_prune = prunning.get_parameters_to_prune(pa_model)

prune.global_unstructured(parameters_to_prune,
                          pruning_method=prune.L1Unstructured,
                          amount=amount_to_prune)

optimizer = torch.optim.AdamW(pa_model.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=10)

learning.train(net=pa_model, 
            criterion=criterion, 
            optimizer=optimizer, 
            train_loader=pa_train_loader, 
            val_loader=pa_val_loader, 
            n_epochs=epochs, 
            metric_criterion=metric_criterion,
            scheduler=scheduler)

prunning.remove_prunned_parameters(parameters_to_prune)

prunning.log_layerwise_sparsity(pa_model)


y_val_pa = learning.net_inference(net=pa_model, x=container.val_input)
pa_nmse = metrics.compute_nmse(y_val_pa, container.val_output)
print(f"Model NMSE: {pa_nmse:.2f}")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 6
#       1 amount_to_prune = 0.6
#       4 parameters_to_prune = get_parameters_to_prune(pa_model)
# ----> 6 prune.global_unstructured(parameters_to_prune,
#       7                           pruning_method=prune.L1Unstructured,
#       8                           amount=amount_to_prune)
#      10 optimizer = torch.optim.AdamW(pa_model.parameters(), lr=lr)
#      11 scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=10)
#
# File c:\Users\maximp\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\utils\prune.py:1093, in global_unstructured(parameters, pruning_method, importance_scores, **kwargs)
#    1090     raise TypeError("global_unstructured(): importance_scores must be of type dict")
#    1092 # flatten importance scores to consider them all at once in global pruning
# -> 1093 relevant_importance_scores = torch.nn.utils.parameters_to_vector(
#    1094     [
#    1095         importance_scores.get((module, name), getattr(module, name))
#    1096         for (module, name) in parameters
#    1097     ]
#    1098 )
#    1099 # similarly, flatten the masks (if they exist), or use a flattened vector
#    1100 # of 1s of the same dimensions as t
#    1101 default_mask = torch.nn.utils.parameters_to_vector(
#    1102     [
#    1103         getattr(module, name + "_mask", torch.ones_like(getattr(module, name)))
#    1104         for (module, name) in parameters
#    1105     ]
#    1106 )
#
# File c:\Users\maximp\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\utils\convert_parameters.py:25, in parameters_to_vector(parameters)
#      22     param_device = _check_param_device(param, param_device)
#      24     vec.append(param.view(-1))
# ---> 25 return torch.cat(vec)
#
# RuntimeError: torch.cat(): expected a non-empty list of Tensors

# %%
plotting.plot_weight_heatmaps(pa_model, vmin=-4, vmax=4)

# %%
window_size = 50

freqs, spectrum_x_val = metrics.power_spectrum(container.val_input, container.input_signal_fs, container.nperseg, window_size)
_, spectrum_y_val = metrics.power_spectrum(container.val_output, container.input_signal_fs, container.nperseg, window_size)
_, spectrum_pa = metrics.power_spectrum(y_val_pa, container.input_signal_fs, container.nperseg, window_size)

xlabel="Частота (МГц)"
ylabel= "Спектральная плотность мощности (дБ)"
fontsize = 12
figsize=(12, 6)

plt.figure(figsize=figsize)

plt.plot(freqs / 1e6, spectrum_x_val, color='grey', label='Входной сигнал')
plt.plot(freqs / 1e6, spectrum_y_val, color='black', label='Выходной сигнал')
plt.plot(freqs / 1e6, spectrum_pa, color='gold', label='Выходной сигнал PA (GRU)')


plt.xlabel(xlabel, fontsize=fontsize)
plt.ylabel(ylabel, fontsize=fontsize)
plt.legend()
plt.ylim(bottom=-170)
plt.xticks(np.arange(-500, 600, 100))
plt.grid()
plt.show()
# Out:
# c:\Users\maximp\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\signal\_spectral_py.py:652: UserWarning: Input data is complex, switching to return_onesided=False
#   freqs, Pxx = csd(x, x, fs=fs, window=window, nperseg=nperseg,

# %% [markdown]
# DLA DPD

# %%
epochs = 100
lr = 0.001
gru_dla = GRU(hidden_size=64, num_layers=1, model_name="dla")
print(f"total_params: {gru_dla.count_params()}")

is_load = gru_dla.load_weights()
casc_gru_dla = utils.CascadeModel(model_1=gru_dla, model_2=pa_model)

optimizer = torch.optim.Adam(casc_gru_dla.parameters(), lr=lr)

if not is_load:
    learning.train(net=casc_gru_dla, 
                   criterion=criterion, 
                   optimizer=optimizer, 
                   train_loader=dla_train_loader, 
                   val_loader=dla_val_loader, 
                   grad_clip_val=1.0, 
                   n_epochs=epochs, 
                   metric_criterion=metric_criterion)
    gru_dla.save_weights()

y_val_gru_dla = learning.net_inference(net=casc_gru_dla, x=x_val)
gru_dla_nmse = metrics.compute_nmse(y_val_gru_dla, y_val_target)
print(f"Model NMSE: {gru_dla_nmse:.2f}")
# Out:
# total_params: 13186
# No saved weights found at model_params/dla_GRU_hs64_nl1_in2_out2.pt, initializing new parameters.
# ===Start training===
# Epoch 0000 — train_loss: 0.166782, val_loss: 0.008736, val_NMSE: -19.51
# Epoch 0001 — train_loss: 0.004453, val_loss: 0.000492, val_NMSE: -32.00
# Epoch 0002 — train_loss: 0.002231, val_loss: 0.000300, val_NMSE: -34.16
# Epoch 0003 — train_loss: 0.001720, val_loss: 0.000257, val_NMSE: -34.81
# Epoch 0004 — train_loss: 0.001410, val_loss: 0.000246, val_NMSE: -35.02
# Epoch 0005 — train_loss: 0.001182, val_loss: 0.000234, val_NMSE: -35.22
# Epoch 0006 — train_loss: 0.001004, val_loss: 0.000223, val_NMSE: -35.43
# Epoch 0007 — train_loss: 0.000859, val_loss: 0.000217, val_NMSE: -35.56
# Epoch 0008 — train_loss: 0.000739, val_loss: 0.000214, val_NMSE: -35.62
# Epoch 0009 — train_loss: 0.000639, val_loss: 0.000208, val_NMSE: -35.75
# Epoch 0010 — train_loss: 0.000556, val_loss: 0.000205, val_NMSE: -35.80
# Epoch 0011 — train_loss: 0.000488, val_loss: 0.000205, val_NMSE: -35.81
# Epoch 0012 — train_loss: 0.000432, val_loss: 0.000201, val_NMSE: -35.88
# Epoch 0013 — train_loss: 0.000385, val_loss: 0.000201, val_NMSE: -35.89
# Epoch 0014 — train_loss: 0.000347, val_loss: 0.000202, val_NMSE: -35.87
# Epoch 0015 — train_loss: 0.000317, val_loss: 0.000201, val_NMSE: -35.88
# Epoch 0016 — train_loss: 0.000292, val_loss: 0.000205, val_NMSE: -35.80
# Epoch 0017 — train_loss: 0.000275, val_loss: 0.000216, val_NMSE: -35.57
# Epoch 0018 — train_loss: 0.000255, val_loss: 0.000201, val_NMSE: -35.89
# Epoch 0019 — train_loss: 0.000242, val_loss: 0.000209, val_NMSE: -35.73
# Epoch 0020 — train_loss: 0.000233, val_loss: 0.000199, val_NMSE: -35.94
# Epoch 0021 — train_loss: 0.000224, val_loss: 0.000224, val_NMSE: -35.42
# Epoch 0022 — train_loss: 0.000218, val_loss: 0.000197, val_NMSE: -35.98
# Epoch 0023 — train_loss: 0.000213, val_loss: 0.000200, val_NMSE: -35.90
# Epoch 0024 — train_loss: 0.000203, val_loss: 0.000190, val_NMSE: -36.13
# Epoch 0025 — train_loss: 0.000204, val_loss: 0.000190, val_NMSE: -36.13
# Epoch 0026 — train_loss: 0.000191, val_loss: 0.000184, val_NMSE: -36.27
# Epoch 0027 — train_loss: 0.000189, val_loss: 0.000183, val_NMSE: -36.31
# Epoch 0028 — train_loss: 0.000178, val_loss: 0.000170, val_NMSE: -36.62
# Epoch 0029 — train_loss: 0.000176, val_loss: 0.000168, val_NMSE: -36.68
# Epoch 0030 — train_loss: 0.000167, val_loss: 0.000153, val_NMSE: -37.06
# Epoch 0031 — train_loss: 0.000163, val_loss: 0.000162, val_NMSE: -36.83
# Epoch 0032 — train_loss: 0.000159, val_loss: 0.000144, val_NMSE: -37.33
# Epoch 0033 — train_loss: 0.000152, val_loss: 0.000139, val_NMSE: -37.49
# Epoch 0034 — train_loss: 0.000149, val_loss: 0.000160, val_NMSE: -36.87
# Epoch 0035 — train_loss: 0.000145, val_loss: 0.000138, val_NMSE: -37.53
# Epoch 0036 — train_loss: 0.000140, val_loss: 0.000139, val_NMSE: -37.50
# Epoch 0037 — train_loss: 0.000136, val_loss: 0.000129, val_NMSE: -37.81
# Epoch 0038 — train_loss: 0.000130, val_loss: 0.000116, val_NMSE: -38.27
# Epoch 0039 — train_loss: 0.000129, val_loss: 0.000139, val_NMSE: -37.50
# Epoch 0040 — train_loss: 0.000118, val_loss: 0.000112, val_NMSE: -38.43
# Epoch 0041 — train_loss: 0.000116, val_loss: 0.000100, val_NMSE: -38.92
# Epoch 0042 — train_loss: 0.000112, val_loss: 0.000095, val_NMSE: -39.16
# Epoch 0043 — train_loss: 0.000103, val_loss: 0.000092, val_NMSE: -39.29
# Epoch 0044 — train_loss: 0.000102, val_loss: 0.000101, val_NMSE: -38.86
# Epoch 0045 — train_loss: 0.000100, val_loss: 0.000084, val_NMSE: -39.67
# Epoch 0046 — train_loss: 0.000093, val_loss: 0.000085, val_NMSE: -39.60
# Epoch 0047 — train_loss: 0.000092, val_loss: 0.000091, val_NMSE: -39.32
# Epoch 0048 — train_loss: 0.000091, val_loss: 0.000078, val_NMSE: -39.99
# Epoch 0049 — train_loss: 0.000085, val_loss: 0.000076, val_NMSE: -40.11
# Epoch 0050 — train_loss: 0.000084, val_loss: 0.000080, val_NMSE: -39.91
# Epoch 0051 — train_loss: 0.000083, val_loss: 0.000073, val_NMSE: -40.28
# Epoch 0052 — train_loss: 0.000081, val_loss: 0.000066, val_NMSE: -40.70
# Epoch 0053 — train_loss: 0.000076, val_loss: 0.000068, val_NMSE: -40.62
# Epoch 0054 — train_loss: 0.000076, val_loss: 0.000085, val_NMSE: -39.64
# Epoch 0055 — train_loss: 0.000077, val_loss: 0.000062, val_NMSE: -41.00
# Epoch 0056 — train_loss: 0.000071, val_loss: 0.000063, val_NMSE: -40.89
# Epoch 0057 — train_loss: 0.000071, val_loss: 0.000072, val_NMSE: -40.35
# Epoch 0058 — train_loss: 0.000069, val_loss: 0.000058, val_NMSE: -41.26
# Epoch 0059 — train_loss: 0.000070, val_loss: 0.000062, val_NMSE: -41.01
# Epoch 0060 — train_loss: 0.000065, val_loss: 0.000056, val_NMSE: -41.42
# Epoch 0061 — train_loss: 0.000067, val_loss: 0.000060, val_NMSE: -41.16
# Epoch 0062 — train_loss: 0.000068, val_loss: 0.000056, val_NMSE: -41.43
# Epoch 0063 — train_loss: 0.000063, val_loss: 0.000063, val_NMSE: -40.95
# Epoch 0064 — train_loss: 0.000062, val_loss: 0.000086, val_NMSE: -39.59
# Epoch 0065 — train_loss: 0.000066, val_loss: 0.000056, val_NMSE: -41.44
# Epoch 0066 — train_loss: 0.000062, val_loss: 0.000059, val_NMSE: -41.18
# Epoch 0067 — train_loss: 0.000061, val_loss: 0.000055, val_NMSE: -41.56
# Epoch 0068 — train_loss: 0.000061, val_loss: 0.000062, val_NMSE: -41.00
# Epoch 0069 — train_loss: 0.000062, val_loss: 0.000057, val_NMSE: -41.37
# Epoch 0070 — train_loss: 0.000061, val_loss: 0.000065, val_NMSE: -40.77
# Epoch 0071 — train_loss: 0.000057, val_loss: 0.000055, val_NMSE: -41.50
# Epoch 0072 — train_loss: 0.000061, val_loss: 0.000052, val_NMSE: -41.79
# Epoch 0073 — train_loss: 0.000060, val_loss: 0.000062, val_NMSE: -40.98
# Epoch 0074 — train_loss: 0.000056, val_loss: 0.000094, val_NMSE: -39.21
# Epoch 0075 — train_loss: 0.000060, val_loss: 0.000052, val_NMSE: -41.79
# Epoch 0076 — train_loss: 0.000058, val_loss: 0.000051, val_NMSE: -41.85
# Epoch 0077 — train_loss: 0.000059, val_loss: 0.000050, val_NMSE: -41.96
# Epoch 0078 — train_loss: 0.000054, val_loss: 0.000057, val_NMSE: -41.33
# Epoch 0079 — train_loss: 0.000058, val_loss: 0.000051, val_NMSE: -41.88
# Epoch 0080 — train_loss: 0.000054, val_loss: 0.000097, val_NMSE: -39.03
# Epoch 0081 — train_loss: 0.000056, val_loss: 0.000051, val_NMSE: -41.81
# Epoch 0082 — train_loss: 0.000055, val_loss: 0.000051, val_NMSE: -41.85
# Epoch 0083 — train_loss: 0.000059, val_loss: 0.000064, val_NMSE: -40.84
# Epoch 0084 — train_loss: 0.000053, val_loss: 0.000054, val_NMSE: -41.59
# Epoch 0085 — train_loss: 0.000053, val_loss: 0.000051, val_NMSE: -41.89
# Epoch 0086 — train_loss: 0.000054, val_loss: 0.000049, val_NMSE: -42.05
# Epoch 0087 — train_loss: 0.000056, val_loss: 0.000053, val_NMSE: -41.70
# Epoch 0088 — train_loss: 0.000051, val_loss: 0.000048, val_NMSE: -42.14
# Epoch 0089 — train_loss: 0.000052, val_loss: 0.000048, val_NMSE: -42.07
# Epoch 0090 — train_loss: 0.000055, val_loss: 0.000063, val_NMSE: -40.91
# Epoch 0091 — train_loss: 0.000052, val_loss: 0.000051, val_NMSE: -41.88
# Epoch 0092 — train_loss: 0.000052, val_loss: 0.000050, val_NMSE: -41.90
# Epoch 0093 — train_loss: 0.000052, val_loss: 0.000048, val_NMSE: -42.10
# Epoch 0094 — train_loss: 0.000052, val_loss: 0.000047, val_NMSE: -42.17
# Epoch 0095 — train_loss: 0.000050, val_loss: 0.000049, val_NMSE: -42.03
# Epoch 0096 — train_loss: 0.000054, val_loss: 0.000050, val_NMSE: -41.96
# Epoch 0097 — train_loss: 0.000050, val_loss: 0.000050, val_NMSE: -41.97
# Epoch 0098 — train_loss: 0.000049, val_loss: 0.000053, val_NMSE: -41.65
# Epoch 0099 — train_loss: 0.000052, val_loss: 0.000055, val_NMSE: -41.53
# ===Training complete===
# Выполнение заняло: 0:17:40
# Model weights saved to model_params/dla_GRU_hs64_nl1_in2_out2.pt
# Model NMSE: -41.53

# %%
freqs, spectrum_x_val = metrics.power_spectrum(x_val, fs, nperseg)
_, spectrum_y_val = metrics.power_spectrum(y_val, fs, nperseg)
_, spectrum_y_val_gru_pa = metrics.power_spectrum(y_val_pa, fs, nperseg)
_, spectrum_lin_dla_nn = metrics.power_spectrum(y_val_gru_dla, fs, nperseg)

xlabel="Частота (МГц)"
ylabel= "Спектральная плотность мощности (дБ)"
fontsize = 12
figsize=(12, 6)

plt.figure(figsize=figsize)

plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_x_val)), color='grey', label='Входной сигнал')
plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_y_val_gru_pa)), color='gold', label='Выходной сигнал PA')
plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_y_val)), color='black', label='Выходной сигнал')
plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_lin_dla_nn)), color='green', label='spectrum_lin_dla_nn')


plt.xlabel(xlabel, fontsize=fontsize)
plt.ylabel(ylabel, fontsize=fontsize)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ILA DPD grad

# %%
epochs = 100
lr = 0.001
gru_ila = GRU(hidden_size=64, num_layers=1, model_name="ila")
is_load = gru_ila.load_weights()
casc_gru_ila_train = utils.CascadeModel(model_1=pa_model, model_2=gru_ila, gain=gain, cascade_type="ila")

optimizer = torch.optim.Adam(casc_gru_ila_train.parameters(), lr=lr)

if not is_load:
    learning.train(net=casc_gru_ila_train, 
                   criterion=criterion, 
                   optimizer=optimizer, 
                   train_loader=ila_train_loader, 
                   val_loader=ila_val_loader, 
                   grad_clip_val=1.0, 
                   n_epochs=epochs, 
                   metric_criterion=metric_criterion)
    gru_ila.save_weights()
    
casc_gru_ila_eval = utils.CascadeModel(model_1=gru_ila, model_2=pa_model)
y_val_gru_ila = learning.net_inference(net=casc_gru_ila_eval, x=x_val)
gru_ila_nmse = metrics.compute_nmse(y_val_gru_ila, y_val_target)
print(f"Model NMSE: {gru_ila_nmse:.2f}")
# Out:
# No saved weights found at model_params/ila_GRU_hs64_nl1_in2_out2.pt, initializing new parameters.
# ===Start training===
# Epoch 0000 — train_loss: 0.022608, val_loss: 0.000612, val_NMSE: -23.02
# Epoch 0001 — train_loss: 0.000822, val_loss: 0.000195, val_NMSE: -27.98
# Epoch 0002 — train_loss: 0.000542, val_loss: 0.000159, val_NMSE: -28.89
# Epoch 0003 — train_loss: 0.000434, val_loss: 0.000144, val_NMSE: -29.31
# Epoch 0004 — train_loss: 0.000365, val_loss: 0.000135, val_NMSE: -29.59
# Epoch 0005 — train_loss: 0.000313, val_loss: 0.000130, val_NMSE: -29.74
# Epoch 0006 — train_loss: 0.000274, val_loss: 0.000150, val_NMSE: -29.12
# Epoch 0007 — train_loss: 0.000243, val_loss: 0.000125, val_NMSE: -29.91
# Epoch 0008 — train_loss: 0.000219, val_loss: 0.000136, val_NMSE: -29.55
# Epoch 0009 — train_loss: 0.000199, val_loss: 0.000125, val_NMSE: -29.91
# Epoch 0010 — train_loss: 0.000182, val_loss: 0.000123, val_NMSE: -30.00
# Epoch 0011 — train_loss: 0.000171, val_loss: 0.000117, val_NMSE: -30.20
# Epoch 0012 — train_loss: 0.000156, val_loss: 0.000121, val_NMSE: -30.05
# Epoch 0013 — train_loss: 0.000148, val_loss: 0.000117, val_NMSE: -30.23
# Epoch 0014 — train_loss: 0.000139, val_loss: 0.000122, val_NMSE: -30.02
# Epoch 0015 — train_loss: 0.000134, val_loss: 0.000115, val_NMSE: -30.28
# Epoch 0016 — train_loss: 0.000130, val_loss: 0.000115, val_NMSE: -30.30
# Epoch 0017 — train_loss: 0.000124, val_loss: 0.000115, val_NMSE: -30.29
# Epoch 0018 — train_loss: 0.000125, val_loss: 0.000121, val_NMSE: -30.06
# Epoch 0019 — train_loss: 0.000119, val_loss: 0.000110, val_NMSE: -30.47
# Epoch 0020 — train_loss: 0.000115, val_loss: 0.000133, val_NMSE: -29.64
# Epoch 0021 — train_loss: 0.000113, val_loss: 0.000112, val_NMSE: -30.39
# Epoch 0022 — train_loss: 0.000113, val_loss: 0.000109, val_NMSE: -30.53
# Epoch 0023 — train_loss: 0.000110, val_loss: 0.000111, val_NMSE: -30.42
# Epoch 0024 — train_loss: 0.000110, val_loss: 0.000108, val_NMSE: -30.54
# Epoch 0025 — train_loss: 0.000105, val_loss: 0.000110, val_NMSE: -30.46
# Epoch 0026 — train_loss: 0.000108, val_loss: 0.000116, val_NMSE: -30.25
# Epoch 0027 — train_loss: 0.000104, val_loss: 0.000128, val_NMSE: -29.82
# Epoch 0028 — train_loss: 0.000102, val_loss: 0.000101, val_NMSE: -30.84
# Epoch 0029 — train_loss: 0.000097, val_loss: 0.000098, val_NMSE: -31.00
# Epoch 0030 — train_loss: 0.000098, val_loss: 0.000094, val_NMSE: -31.15
# Epoch 0031 — train_loss: 0.000092, val_loss: 0.000099, val_NMSE: -30.96
# Epoch 0032 — train_loss: 0.000088, val_loss: 0.000098, val_NMSE: -30.96
# Epoch 0033 — train_loss: 0.000080, val_loss: 0.000077, val_NMSE: -32.00
# Epoch 0034 — train_loss: 0.000072, val_loss: 0.000064, val_NMSE: -32.80
# Epoch 0035 — train_loss: 0.000065, val_loss: 0.000062, val_NMSE: -32.99
# Epoch 0036 — train_loss: 0.000061, val_loss: 0.000056, val_NMSE: -33.38
# Epoch 0037 — train_loss: 0.000058, val_loss: 0.000053, val_NMSE: -33.68
# Epoch 0038 — train_loss: 0.000054, val_loss: 0.000058, val_NMSE: -33.23
# Epoch 0039 — train_loss: 0.000054, val_loss: 0.000049, val_NMSE: -33.95
# Epoch 0040 — train_loss: 0.000049, val_loss: 0.000046, val_NMSE: -34.27
# Epoch 0041 — train_loss: 0.000050, val_loss: 0.000044, val_NMSE: -34.47
# Epoch 0042 — train_loss: 0.000045, val_loss: 0.000041, val_NMSE: -34.79
# Epoch 0043 — train_loss: 0.000045, val_loss: 0.000052, val_NMSE: -33.76
# Epoch 0044 — train_loss: 0.000045, val_loss: 0.000042, val_NMSE: -34.63
# Epoch 0045 — train_loss: 0.000043, val_loss: 0.000040, val_NMSE: -34.86
# Epoch 0046 — train_loss: 0.000041, val_loss: 0.000044, val_NMSE: -34.41
# Epoch 0047 — train_loss: 0.000043, val_loss: 0.000056, val_NMSE: -33.42
# Epoch 0048 — train_loss: 0.000039, val_loss: 0.000039, val_NMSE: -35.03
# Epoch 0049 — train_loss: 0.000039, val_loss: 0.000040, val_NMSE: -34.84
# Epoch 0050 — train_loss: 0.000039, val_loss: 0.000036, val_NMSE: -35.37
# Epoch 0051 — train_loss: 0.000039, val_loss: 0.000035, val_NMSE: -35.50
# Epoch 0052 — train_loss: 0.000038, val_loss: 0.000041, val_NMSE: -34.74
# Epoch 0053 — train_loss: 0.000036, val_loss: 0.000038, val_NMSE: -35.15
# Epoch 0054 — train_loss: 0.000037, val_loss: 0.000036, val_NMSE: -35.39
# Epoch 0055 — train_loss: 0.000035, val_loss: 0.000043, val_NMSE: -34.59
# Epoch 0056 — train_loss: 0.000036, val_loss: 0.000032, val_NMSE: -35.91
# Epoch 0057 — train_loss: 0.000034, val_loss: 0.000036, val_NMSE: -35.39
# Epoch 0058 — train_loss: 0.000034, val_loss: 0.000031, val_NMSE: -36.02
# Epoch 0059 — train_loss: 0.000035, val_loss: 0.000030, val_NMSE: -36.16
# Epoch 0060 — train_loss: 0.000032, val_loss: 0.000030, val_NMSE: -36.17
# Epoch 0061 — train_loss: 0.000034, val_loss: 0.000036, val_NMSE: -35.32
# Epoch 0062 — train_loss: 0.000034, val_loss: 0.000030, val_NMSE: -36.07
# Epoch 0063 — train_loss: 0.000031, val_loss: 0.000030, val_NMSE: -36.10
# Epoch 0064 — train_loss: 0.000032, val_loss: 0.000029, val_NMSE: -36.32
# Epoch 0065 — train_loss: 0.000031, val_loss: 0.000031, val_NMSE: -36.04
# Epoch 0066 — train_loss: 0.000031, val_loss: 0.000031, val_NMSE: -35.98
# Epoch 0067 — train_loss: 0.000031, val_loss: 0.000034, val_NMSE: -35.53
# Epoch 0068 — train_loss: 0.000029, val_loss: 0.000029, val_NMSE: -36.21
# Epoch 0069 — train_loss: 0.000030, val_loss: 0.000027, val_NMSE: -36.53
# Epoch 0070 — train_loss: 0.000030, val_loss: 0.000034, val_NMSE: -35.55
# Epoch 0071 — train_loss: 0.000028, val_loss: 0.000026, val_NMSE: -36.76
# Epoch 0072 — train_loss: 0.000029, val_loss: 0.000029, val_NMSE: -36.22
# Epoch 0073 — train_loss: 0.000029, val_loss: 0.000026, val_NMSE: -36.75
# Epoch 0074 — train_loss: 0.000028, val_loss: 0.000028, val_NMSE: -36.44
# Epoch 0075 — train_loss: 0.000028, val_loss: 0.000026, val_NMSE: -36.77
# Epoch 0076 — train_loss: 0.000027, val_loss: 0.000028, val_NMSE: -36.36
# Epoch 0077 — train_loss: 0.000027, val_loss: 0.000033, val_NMSE: -35.73
# Epoch 0078 — train_loss: 0.000028, val_loss: 0.000033, val_NMSE: -35.64
# Epoch 0079 — train_loss: 0.000027, val_loss: 0.000024, val_NMSE: -37.03
# Epoch 0080 — train_loss: 0.000026, val_loss: 0.000025, val_NMSE: -36.98
# Epoch 0081 — train_loss: 0.000027, val_loss: 0.000023, val_NMSE: -37.26
# Epoch 0082 — train_loss: 0.000026, val_loss: 0.000028, val_NMSE: -36.39
# Epoch 0083 — train_loss: 0.000024, val_loss: 0.000026, val_NMSE: -36.67
# Epoch 0084 — train_loss: 0.000025, val_loss: 0.000036, val_NMSE: -35.27
# Epoch 0085 — train_loss: 0.000023, val_loss: 0.000023, val_NMSE: -37.30
# Epoch 0086 — train_loss: 0.000026, val_loss: 0.000022, val_NMSE: -37.52
# Epoch 0087 — train_loss: 0.000024, val_loss: 0.000035, val_NMSE: -35.50
# Epoch 0088 — train_loss: 0.000024, val_loss: 0.000022, val_NMSE: -37.49
# Epoch 0089 — train_loss: 0.000024, val_loss: 0.000027, val_NMSE: -36.56
# Epoch 0090 — train_loss: 0.000023, val_loss: 0.000021, val_NMSE: -37.69
# Epoch 0091 — train_loss: 0.000023, val_loss: 0.000021, val_NMSE: -37.58
# Epoch 0092 — train_loss: 0.000023, val_loss: 0.000024, val_NMSE: -37.09
# Epoch 0093 — train_loss: 0.000023, val_loss: 0.000021, val_NMSE: -37.68
# Epoch 0094 — train_loss: 0.000021, val_loss: 0.000021, val_NMSE: -37.72
# Epoch 0095 — train_loss: 0.000022, val_loss: 0.000020, val_NMSE: -37.84
# Epoch 0096 — train_loss: 0.000021, val_loss: 0.000019, val_NMSE: -38.02
# Epoch 0097 — train_loss: 0.000022, val_loss: 0.000023, val_NMSE: -37.36
# Epoch 0098 — train_loss: 0.000020, val_loss: 0.000019, val_NMSE: -38.06
# Epoch 0099 — train_loss: 0.000021, val_loss: 0.000020, val_NMSE: -37.83
# ===Training complete===
# Выполнение заняло: 0:12:20
# Model weights saved to model_params/ila_GRU_hs64_nl1_in2_out2.pt
# Model NMSE: -40.11

# %%
freqs, spectrum_x_val = metrics.power_spectrum(x_val, fs, nperseg)
_, spectrum_y_val = metrics.power_spectrum(y_val, fs, nperseg)
_, spectrum_y_val_gru_pa = metrics.power_spectrum(y_val_pa, fs, nperseg)
_, spectrum_y_val_gru_ila = metrics.power_spectrum(y_val_gru_ila, fs, nperseg)
_, spectrum_y_val_target = metrics.power_spectrum(y_val_target, fs, nperseg)

xlabel="Частота (МГц)"
ylabel= "Спектральная плотность мощности (дБ)"
fontsize = 12
figsize=(12, 6)

plt.figure(figsize=figsize)

plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_x_val)), color='grey', label='Входной сигнал')
plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_y_val_gru_pa)), color='gold', label='Выходной сигнал PA')
plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_y_val)), color='black', label='Выходной сигнал')
plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_lin_dla_nn)), color='green', label='spectrum_y_val_gru_ila')
# plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_y_val_target)), color='magenta', label='spectrum_y_val_target')


plt.xlabel(xlabel, fontsize=fontsize)
plt.ylabel(ylabel, fontsize=fontsize)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ILC DPD

# %%
u_k_train = learning.ilc_signal(container.train_input, container.train_output_target, pa_model, epochs=200, learning_rate=0.01)
u_k_val = learning.ilc_signal(container.val_input, container.val_output_target, pa_model, epochs=200, learning_rate=0.01)
u_k_pa = pa_model.forward(u_k_train).detach()

nmse_uk_pa = metrics.compute_nmse(u_k_pa, container.train_output_target)
print(f"NMSE на выходе усилителя (ILC): {nmse_uk_pa:.2f} db")

container.ilc_train_output = u_k_train
container.ilc_val_output = u_k_val

ilc_train_loader, ilc_val_loader = data_loader.build_dataloaders(data_dict=container.to_dict(), 
                                                                 frame_length=frame_length, 
                                                                 batch_size=batch_size, 
                                                                 batch_size_eval=batch_size_eval, 
                                                                 arch="ilc")
# Out:
# Epoch [0/200], Loss: 0.004440282005816698
# Epoch [100/200], Loss: 8.267591056210222e-08
# Epoch [199/200], Loss: 2.463312609446433e-10
# Выполнение заняло: 0:13:03
# Epoch [0/200], Loss: 0.0044114054180681705
# Epoch [100/200], Loss: 8.303114640284548e-08
# Epoch [199/200], Loss: 6.3758376356304325e-09
# Выполнение заняло: 0:01:33
# NMSE на выходе усилителя (ILC): -79.35 db

# %%
epochs = 100
lr = 0.01

model_ilc = LSTM(hidden_size=32, num_layers=1, model_name="ilc")
print(f"total params: {model_ilc.count_params()}")

optimizer = torch.optim.AdamW(model_ilc.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=10)


learning.train(net=model_ilc, 
                criterion=criterion, 
                optimizer=optimizer, 
                train_loader=ilc_train_loader, 
                val_loader=ilc_val_loader, 
                n_epochs=epochs, 
                metric_criterion=metric_criterion,
                scheduler=scheduler)


casc_ilc_eval = utils.CascadeModel(model_1=model_ilc, model_2=pa_model)
y_val_ilc_base = learning.net_inference(net=casc_ilc_eval, x=container.val_input)
ilc_base_nmse = metrics.compute_nmse(y_val_ilc_base, container.val_output_target)
print(f"Model NMSE (base): {ilc_base_nmse:.2f}")


plotting.plot_weight_heatmaps(model_ilc, vmin=-4, vmax=4)
# Out:
# total params: 4416
# ===Start training===
# Epoch 0000 — train_loss: 0.00001545, val_loss: 0.00000128, val_NMSE: -24.20, lr: 0.01
# Epoch 0001 — train_loss: 0.00000217, val_loss: 0.00000126, val_NMSE: -24.27, lr: 0.01
# Epoch 0002 — train_loss: 0.00000212, val_loss: 0.00000125, val_NMSE: -24.32, lr: 0.01
# Epoch 0003 — train_loss: 0.00000211, val_loss: 0.00000123, val_NMSE: -24.36, lr: 0.01
# Epoch 0004 — train_loss: 0.00000210, val_loss: 0.00000123, val_NMSE: -24.38, lr: 0.01
# Epoch 0005 — train_loss: 0.00000210, val_loss: 0.00000123, val_NMSE: -24.37, lr: 0.01
# Epoch 0006 — train_loss: 0.00000210, val_loss: 0.00000124, val_NMSE: -24.34, lr: 0.01
# Epoch 0007 — train_loss: 0.00000210, val_loss: 0.00000124, val_NMSE: -24.35, lr: 0.01
# Epoch 0008 — train_loss: 0.00000210, val_loss: 0.00000127, val_NMSE: -24.24, lr: 0.01
# Epoch 0009 — train_loss: 0.00000209, val_loss: 0.00000121, val_NMSE: -24.46, lr: 0.01
# Epoch 0010 — train_loss: 0.00000207, val_loss: 0.00000120, val_NMSE: -24.50, lr: 0.01
# Epoch 0011 — train_loss: 0.00000196, val_loss: 0.00000109, val_NMSE: -24.90, lr: 0.01
# Epoch 0012 — train_loss: 0.00000169, val_loss: 0.00000085, val_NMSE: -25.97, lr: 0.01
# Epoch 0013 — train_loss: 0.00000124, val_loss: 0.00000040, val_NMSE: -29.26, lr: 0.01
# Epoch 0014 — train_loss: 0.00000090, val_loss: 0.00000032, val_NMSE: -30.24, lr: 0.01
# Epoch 0015 — train_loss: 0.00000077, val_loss: 0.00000027, val_NMSE: -30.96, lr: 0.01
# Epoch 0016 — train_loss: 0.00000070, val_loss: 0.00000021, val_NMSE: -32.09, lr: 0.01
# Epoch 0017 — train_loss: 0.00000064, val_loss: 0.00000020, val_NMSE: -32.37, lr: 0.01
# Epoch 0018 — train_loss: 0.00000061, val_loss: 0.00000013, val_NMSE: -34.24, lr: 0.01
# Epoch 0019 — train_loss: 0.00000059, val_loss: 0.00000011, val_NMSE: -34.81, lr: 0.01
# Epoch 0020 — train_loss: 0.00000057, val_loss: 0.00000013, val_NMSE: -34.14, lr: 0.01
# Epoch 0021 — train_loss: 0.00000055, val_loss: 0.00000016, val_NMSE: -33.19, lr: 0.01
# Epoch 0022 — train_loss: 0.00000054, val_loss: 0.00000017, val_NMSE: -32.97, lr: 0.01
# Epoch 0023 — train_loss: 0.00000053, val_loss: 0.00000009, val_NMSE: -35.61, lr: 0.01
# Epoch 0024 — train_loss: 0.00000052, val_loss: 0.00000010, val_NMSE: -35.35, lr: 0.01
# Epoch 0025 — train_loss: 0.00000051, val_loss: 0.00000014, val_NMSE: -33.77, lr: 0.01
# Epoch 0026 — train_loss: 0.00000276, val_loss: 0.00000043, val_NMSE: -28.95, lr: 0.01
# Epoch 0027 — train_loss: 0.00000091, val_loss: 0.00000031, val_NMSE: -30.43, lr: 0.01
# Epoch 0028 — train_loss: 0.00000076, val_loss: 0.00000022, val_NMSE: -31.77, lr: 0.01
# Epoch 0029 — train_loss: 0.00000068, val_loss: 0.00000021, val_NMSE: -32.13, lr: 0.01
# Epoch 0030 — train_loss: 0.00000064, val_loss: 0.00000015, val_NMSE: -33.40, lr: 0.01
# Epoch 0031 — train_loss: 0.00000061, val_loss: 0.00000015, val_NMSE: -33.57, lr: 0.01
# Epoch 0032 — train_loss: 0.00000060, val_loss: 0.00000018, val_NMSE: -32.62, lr: 0.01
# Epoch 0033 — train_loss: 0.00000058, val_loss: 0.00000014, val_NMSE: -33.91, lr: 0.01
# Epoch 0034 — train_loss: 0.00000057, val_loss: 0.00000013, val_NMSE: -34.28, lr: 0.005
# Epoch 0035 — train_loss: 0.00000055, val_loss: 0.00000011, val_NMSE: -34.93, lr: 0.005
# Epoch 0036 — train_loss: 0.00000054, val_loss: 0.00000011, val_NMSE: -34.71, lr: 0.005
# Epoch 0037 — train_loss: 0.00000054, val_loss: 0.00000011, val_NMSE: -34.96, lr: 0.005
# Epoch 0038 — train_loss: 0.00000054, val_loss: 0.00000013, val_NMSE: -34.08, lr: 0.005
# Epoch 0039 — train_loss: 0.00000054, val_loss: 0.00000010, val_NMSE: -35.18, lr: 0.005
# Epoch 0040 — train_loss: 0.00000053, val_loss: 0.00000012, val_NMSE: -34.30, lr: 0.005
# Epoch 0041 — train_loss: 0.00000053, val_loss: 0.00000011, val_NMSE: -34.77, lr: 0.005
# Epoch 0042 — train_loss: 0.00000052, val_loss: 0.00000015, val_NMSE: -33.65, lr: 0.005
# Epoch 0043 — train_loss: 0.00000052, val_loss: 0.00000011, val_NMSE: -34.92, lr: 0.005
# Epoch 0044 — train_loss: 0.00000051, val_loss: 0.00000010, val_NMSE: -35.39, lr: 0.005
# Epoch 0045 — train_loss: 0.00000051, val_loss: 0.00000010, val_NMSE: -35.24, lr: 0.0025
# Epoch 0046 — train_loss: 0.00000049, val_loss: 0.00000008, val_NMSE: -36.24, lr: 0.0025
# Epoch 0047 — train_loss: 0.00000049, val_loss: 0.00000009, val_NMSE: -35.96, lr: 0.0025
# Epoch 0048 — train_loss: 0.00000048, val_loss: 0.00000008, val_NMSE: -36.30, lr: 0.0025
# Epoch 0049 — train_loss: 0.00000048, val_loss: 0.00000008, val_NMSE: -36.38, lr: 0.0025
# Epoch 0050 — train_loss: 0.00000048, val_loss: 0.00000008, val_NMSE: -36.33, lr: 0.0025
# Epoch 0051 — train_loss: 0.00000048, val_loss: 0.00000008, val_NMSE: -36.20, lr: 0.0025
# Epoch 0052 — train_loss: 0.00000047, val_loss: 0.00000008, val_NMSE: -36.29, lr: 0.0025
# Epoch 0053 — train_loss: 0.00000047, val_loss: 0.00000007, val_NMSE: -36.59, lr: 0.0025
# Epoch 0054 — train_loss: 0.00000047, val_loss: 0.00000007, val_NMSE: -36.56, lr: 0.0025
# Epoch 0055 — train_loss: 0.00000046, val_loss: 0.00000007, val_NMSE: -36.64, lr: 0.0025
# Epoch 0056 — train_loss: 0.00000046, val_loss: 0.00000006, val_NMSE: -37.19, lr: 0.0025
# Epoch 0057 — train_loss: 0.00000170, val_loss: 0.00000024, val_NMSE: -31.47, lr: 0.0025
# Epoch 0058 — train_loss: 0.00000069, val_loss: 0.00000019, val_NMSE: -32.60, lr: 0.0025
# Epoch 0059 — train_loss: 0.00000061, val_loss: 0.00000015, val_NMSE: -33.45, lr: 0.0025
# Epoch 0060 — train_loss: 0.00000055, val_loss: 0.00000012, val_NMSE: -34.54, lr: 0.0025
# Epoch 0061 — train_loss: 0.00000052, val_loss: 0.00000010, val_NMSE: -35.24, lr: 0.0025
# Epoch 0062 — train_loss: 0.00000050, val_loss: 0.00000009, val_NMSE: -35.66, lr: 0.0025
# Epoch 0063 — train_loss: 0.00000049, val_loss: 0.00000008, val_NMSE: -35.98, lr: 0.0025
# Epoch 0064 — train_loss: 0.00000048, val_loss: 0.00000008, val_NMSE: -36.09, lr: 0.0025
# Epoch 0065 — train_loss: 0.00000048, val_loss: 0.00000009, val_NMSE: -35.86, lr: 0.0025
# Epoch 0066 — train_loss: 0.00000048, val_loss: 0.00000008, val_NMSE: -36.32, lr: 0.0025
# Epoch 0067 — train_loss: 0.00000047, val_loss: 0.00000007, val_NMSE: -36.55, lr: 0.00125
# Epoch 0068 — train_loss: 0.00000047, val_loss: 0.00000007, val_NMSE: -36.65, lr: 0.00125
# Epoch 0069 — train_loss: 0.00000046, val_loss: 0.00000007, val_NMSE: -36.82, lr: 0.00125
# Epoch 0070 — train_loss: 0.00000046, val_loss: 0.00000007, val_NMSE: -36.88, lr: 0.00125
# Epoch 0071 — train_loss: 0.00000046, val_loss: 0.00000007, val_NMSE: -36.87, lr: 0.00125
# Epoch 0072 — train_loss: 0.00000046, val_loss: 0.00000007, val_NMSE: -37.00, lr: 0.00125
# Epoch 0073 — train_loss: 0.00000046, val_loss: 0.00000007, val_NMSE: -36.86, lr: 0.00125
# Epoch 0074 — train_loss: 0.00000046, val_loss: 0.00000007, val_NMSE: -37.09, lr: 0.00125
# Epoch 0075 — train_loss: 0.00000046, val_loss: 0.00000006, val_NMSE: -37.17, lr: 0.00125
# Epoch 0076 — train_loss: 0.00000045, val_loss: 0.00000007, val_NMSE: -36.66, lr: 0.00125
# Epoch 0077 — train_loss: 0.00000045, val_loss: 0.00000007, val_NMSE: -37.00, lr: 0.00125
# Epoch 0078 — train_loss: 0.00000045, val_loss: 0.00000006, val_NMSE: -37.18, lr: 0.000625
# Epoch 0079 — train_loss: 0.00000045, val_loss: 0.00000006, val_NMSE: -37.26, lr: 0.000625
# Epoch 0080 — train_loss: 0.00000045, val_loss: 0.00000006, val_NMSE: -37.37, lr: 0.000625
# Epoch 0081 — train_loss: 0.00000044, val_loss: 0.00000006, val_NMSE: -37.48, lr: 0.000625
# Epoch 0082 — train_loss: 0.00000044, val_loss: 0.00000006, val_NMSE: -37.22, lr: 0.000625
# Epoch 0083 — train_loss: 0.00000044, val_loss: 0.00000006, val_NMSE: -37.30, lr: 0.000625
# Epoch 0084 — train_loss: 0.00000044, val_loss: 0.00000006, val_NMSE: -37.44, lr: 0.000625
# Epoch 0085 — train_loss: 0.00000044, val_loss: 0.00000006, val_NMSE: -37.62, lr: 0.000625
# Epoch 0086 — train_loss: 0.00000044, val_loss: 0.00000006, val_NMSE: -37.61, lr: 0.000625
# Epoch 0087 — train_loss: 0.00000044, val_loss: 0.00000006, val_NMSE: -37.65, lr: 0.000625
# Epoch 0088 — train_loss: 0.00000044, val_loss: 0.00000006, val_NMSE: -37.63, lr: 0.000625
# Epoch 0089 — train_loss: 0.00000043, val_loss: 0.00000006, val_NMSE: -37.73, lr: 0.000625
# Epoch 0090 — train_loss: 0.00000043, val_loss: 0.00000006, val_NMSE: -37.58, lr: 0.000625
# Epoch 0091 — train_loss: 0.00000043, val_loss: 0.00000006, val_NMSE: -37.79, lr: 0.000625
# Epoch 0092 — train_loss: 0.00000043, val_loss: 0.00000006, val_NMSE: -37.51, lr: 0.000625
# Epoch 0093 — train_loss: 0.00000043, val_loss: 0.00000006, val_NMSE: -37.83, lr: 0.000625
# Epoch 0094 — train_loss: 0.00000043, val_loss: 0.00000005, val_NMSE: -37.90, lr: 0.000625
# Epoch 0095 — train_loss: 0.00000043, val_loss: 0.00000006, val_NMSE: -37.82, lr: 0.000625
# Epoch 0096 — train_loss: 0.00000042, val_loss: 0.00000005, val_NMSE: -37.94, lr: 0.000625
# Epoch 0097 — train_loss: 0.00000042, val_loss: 0.00000005, val_NMSE: -37.97, lr: 0.000625
# Epoch 0098 — train_loss: 0.00000042, val_loss: 0.00000006, val_NMSE: -37.79, lr: 0.000625
# Epoch 0099 — train_loss: 0.00000042, val_loss: 0.00000005, val_NMSE: -38.03, lr: 0.000625
# ===Training complete===
# Выполнение заняло: 0:05:08
# Model NMSE (base): -40.05

# %%
amount_to_prune = 0.5

parameters_to_prune = prunning.get_parameters_to_prune(model_ilc)

prune.global_unstructured(parameters_to_prune,
                          pruning_method=prune.L1Unstructured,
                          amount=amount_to_prune)

casc_ilc_eval = utils.CascadeModel(model_1=model_ilc, model_2=pa_model)
y_val_ilc_prune = learning.net_inference(net=casc_ilc_eval, x=container.val_input)
ilc_prune_nmse = metrics.compute_nmse(y_val_ilc_prune, container.val_output_target)
print(f"Model NMSE (prune): {ilc_prune_nmse:.2f}")


optimizer = torch.optim.AdamW(model_ilc.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=10)

learning.train(net=model_ilc, 
            criterion=criterion, 
            optimizer=optimizer, 
            train_loader=ilc_train_loader, 
            val_loader=ilc_val_loader, 
            n_epochs=epochs, 
            metric_criterion=metric_criterion,
            scheduler=scheduler)

prunning.remove_prunned_parameters(parameters_to_prune)

prunning.log_layerwise_sparsity(model_ilc)


casc_ilc_eval = utils.CascadeModel(model_1=model_ilc, model_2=pa_model)
y_val_ilc_finetune = learning.net_inference(net=casc_ilc_eval, x=container.val_input)
ilc_finetune_nmse = metrics.compute_nmse(y_val_ilc_finetune, container.val_output_target)
print(f"Model NMSE (finetune): {ilc_finetune_nmse:.2f}")


plotting.plot_weight_heatmaps(model_ilc, vmin=-4, vmax=4)
# Out:
# Model NMSE (prune): -12.91
# ===Start training===
# Epoch 0000 — train_loss: 0.00000142, val_loss: 0.00000012, val_NMSE: -34.34, lr: 0.01
# Epoch 0001 — train_loss: 0.00000050, val_loss: 0.00000010, val_NMSE: -35.24, lr: 0.01
# Epoch 0002 — train_loss: 0.00000049, val_loss: 0.00000010, val_NMSE: -35.44, lr: 0.01
# Epoch 0003 — train_loss: 0.00000049, val_loss: 0.00000009, val_NMSE: -35.65, lr: 0.01
# Epoch 0004 — train_loss: 0.00000049, val_loss: 0.00000009, val_NMSE: -35.70, lr: 0.01
# Epoch 0005 — train_loss: 0.00000049, val_loss: 0.00000012, val_NMSE: -34.31, lr: 0.01
# Epoch 0006 — train_loss: 0.00000049, val_loss: 0.00000010, val_NMSE: -35.09, lr: 0.01
# Epoch 0007 — train_loss: 0.00000048, val_loss: 0.00000008, val_NMSE: -36.10, lr: 0.01
# Epoch 0008 — train_loss: 0.00000049, val_loss: 0.00000008, val_NMSE: -36.45, lr: 0.01
# Epoch 0009 — train_loss: 0.00000049, val_loss: 0.00000011, val_NMSE: -35.00, lr: 0.01
# Epoch 0010 — train_loss: 0.00000048, val_loss: 0.00000008, val_NMSE: -36.43, lr: 0.01
# Epoch 0011 — train_loss: 0.00000048, val_loss: 0.00000008, val_NMSE: -36.51, lr: 0.01
# Epoch 0012 — train_loss: 0.00000048, val_loss: 0.00000007, val_NMSE: -36.76, lr: 0.01
# Epoch 0013 — train_loss: 0.00000048, val_loss: 0.00000008, val_NMSE: -36.01, lr: 0.01
# Epoch 0014 — train_loss: 0.00000047, val_loss: 0.00000012, val_NMSE: -34.56, lr: 0.01
# Epoch 0015 — train_loss: 0.00000047, val_loss: 0.00000007, val_NMSE: -36.85, lr: 0.01
# Epoch 0016 — train_loss: 0.00000047, val_loss: 0.00000009, val_NMSE: -35.61, lr: 0.01
# Epoch 0017 — train_loss: 0.00000047, val_loss: 0.00000009, val_NMSE: -35.78, lr: 0.01
# Epoch 0018 — train_loss: 0.00000046, val_loss: 0.00000008, val_NMSE: -36.17, lr: 0.01
# Epoch 0019 — train_loss: 0.00000046, val_loss: 0.00000014, val_NMSE: -33.96, lr: 0.01
# Epoch 0020 — train_loss: 0.00000046, val_loss: 0.00000006, val_NMSE: -37.23, lr: 0.01
# Epoch 0021 — train_loss: 0.00000046, val_loss: 0.00000006, val_NMSE: -37.30, lr: 0.01
# Epoch 0022 — train_loss: 0.00000045, val_loss: 0.00000010, val_NMSE: -35.47, lr: 0.01
# Epoch 0023 — train_loss: 0.00000045, val_loss: 0.00000013, val_NMSE: -34.22, lr: 0.01
# Epoch 0024 — train_loss: 0.00000045, val_loss: 0.00000019, val_NMSE: -32.47, lr: 0.01
# Epoch 0025 — train_loss: 0.00000044, val_loss: 0.00000012, val_NMSE: -34.66, lr: 0.01
# Epoch 0026 — train_loss: 0.00000044, val_loss: 0.00000012, val_NMSE: -34.43, lr: 0.01
# Epoch 0027 — train_loss: 0.00000044, val_loss: 0.00000007, val_NMSE: -36.65, lr: 0.01
# Epoch 0028 — train_loss: 0.00000044, val_loss: 0.00000006, val_NMSE: -37.19, lr: 0.01
# Epoch 0029 — train_loss: 0.00000044, val_loss: 0.00000010, val_NMSE: -35.41, lr: 0.01
# Epoch 0030 — train_loss: 0.00000448, val_loss: 0.00000052, val_NMSE: -28.11, lr: 0.01
# Epoch 0031 — train_loss: 0.00000096, val_loss: 0.00000030, val_NMSE: -30.49, lr: 0.01
# Epoch 0032 — train_loss: 0.00000082, val_loss: 0.00000027, val_NMSE: -30.98, lr: 0.005
# Epoch 0033 — train_loss: 0.00000078, val_loss: 0.00000026, val_NMSE: -31.18, lr: 0.005
# Epoch 0034 — train_loss: 0.00000076, val_loss: 0.00000025, val_NMSE: -31.24, lr: 0.005
# Epoch 0035 — train_loss: 0.00000074, val_loss: 0.00000025, val_NMSE: -31.32, lr: 0.005
# Epoch 0036 — train_loss: 0.00000072, val_loss: 0.00000024, val_NMSE: -31.45, lr: 0.005
# Epoch 0037 — train_loss: 0.00000071, val_loss: 0.00000024, val_NMSE: -31.52, lr: 0.005
# Epoch 0038 — train_loss: 0.00000069, val_loss: 0.00000023, val_NMSE: -31.62, lr: 0.005
# Epoch 0039 — train_loss: 0.00000067, val_loss: 0.00000022, val_NMSE: -31.85, lr: 0.005
# Epoch 0040 — train_loss: 0.00000065, val_loss: 0.00000020, val_NMSE: -32.21, lr: 0.005
# Epoch 0041 — train_loss: 0.00000062, val_loss: 0.00000018, val_NMSE: -32.65, lr: 0.005
# Epoch 0042 — train_loss: 0.00000059, val_loss: 0.00000015, val_NMSE: -33.47, lr: 0.005
# Epoch 0043 — train_loss: 0.00000057, val_loss: 0.00000013, val_NMSE: -34.20, lr: 0.0025
# Epoch 0044 — train_loss: 0.00000055, val_loss: 0.00000012, val_NMSE: -34.43, lr: 0.0025
# Epoch 0045 — train_loss: 0.00000054, val_loss: 0.00000011, val_NMSE: -34.78, lr: 0.0025
# Epoch 0046 — train_loss: 0.00000053, val_loss: 0.00000010, val_NMSE: -35.08, lr: 0.0025
# Epoch 0047 — train_loss: 0.00000053, val_loss: 0.00000010, val_NMSE: -35.28, lr: 0.0025
# Epoch 0048 — train_loss: 0.00000052, val_loss: 0.00000010, val_NMSE: -35.48, lr: 0.0025
# Epoch 0049 — train_loss: 0.00000051, val_loss: 0.00000009, val_NMSE: -35.69, lr: 0.0025
# Epoch 0050 — train_loss: 0.00000050, val_loss: 0.00000008, val_NMSE: -36.13, lr: 0.0025
# Epoch 0051 — train_loss: 0.00000050, val_loss: 0.00000008, val_NMSE: -36.02, lr: 0.0025
# Epoch 0052 — train_loss: 0.00000049, val_loss: 0.00000008, val_NMSE: -36.47, lr: 0.0025
# Epoch 0053 — train_loss: 0.00000049, val_loss: 0.00000008, val_NMSE: -36.41, lr: 0.0025
# Epoch 0054 — train_loss: 0.00000048, val_loss: 0.00000008, val_NMSE: -36.34, lr: 0.00125
# Epoch 0055 — train_loss: 0.00000047, val_loss: 0.00000007, val_NMSE: -36.89, lr: 0.00125
# Epoch 0056 — train_loss: 0.00000047, val_loss: 0.00000007, val_NMSE: -37.01, lr: 0.00125
# Epoch 0057 — train_loss: 0.00000046, val_loss: 0.00000007, val_NMSE: -36.70, lr: 0.00125
# Epoch 0058 — train_loss: 0.00000046, val_loss: 0.00000007, val_NMSE: -37.08, lr: 0.00125
# Epoch 0059 — train_loss: 0.00000046, val_loss: 0.00000006, val_NMSE: -37.28, lr: 0.00125
# Epoch 0060 — train_loss: 0.00000046, val_loss: 0.00000006, val_NMSE: -37.42, lr: 0.00125
# Epoch 0061 — train_loss: 0.00000045, val_loss: 0.00000007, val_NMSE: -36.95, lr: 0.00125
# Epoch 0062 — train_loss: 0.00000045, val_loss: 0.00000006, val_NMSE: -37.44, lr: 0.00125
# Epoch 0063 — train_loss: 0.00000045, val_loss: 0.00000006, val_NMSE: -37.28, lr: 0.00125
# Epoch 0064 — train_loss: 0.00000045, val_loss: 0.00000006, val_NMSE: -37.32, lr: 0.00125
# Epoch 0065 — train_loss: 0.00000044, val_loss: 0.00000006, val_NMSE: -37.72, lr: 0.00125
# Epoch 0066 — train_loss: 0.00000044, val_loss: 0.00000006, val_NMSE: -37.58, lr: 0.00125
# Epoch 0067 — train_loss: 0.00000044, val_loss: 0.00000006, val_NMSE: -37.77, lr: 0.00125
# Epoch 0068 — train_loss: 0.00000044, val_loss: 0.00000006, val_NMSE: -37.79, lr: 0.00125
# Epoch 0069 — train_loss: 0.00000043, val_loss: 0.00000006, val_NMSE: -37.83, lr: 0.00125
# Epoch 0070 — train_loss: 0.00000043, val_loss: 0.00000005, val_NMSE: -37.96, lr: 0.00125
# Epoch 0071 — train_loss: 0.00000043, val_loss: 0.00000006, val_NMSE: -37.77, lr: 0.00125
# Epoch 0072 — train_loss: 0.00000043, val_loss: 0.00000006, val_NMSE: -37.82, lr: 0.00125
# Epoch 0073 — train_loss: 0.00000043, val_loss: 0.00000005, val_NMSE: -38.03, lr: 0.00125
# Epoch 0074 — train_loss: 0.00000042, val_loss: 0.00000006, val_NMSE: -37.56, lr: 0.00125
# Epoch 0075 — train_loss: 0.00000042, val_loss: 0.00000005, val_NMSE: -37.96, lr: 0.00125
# Epoch 0076 — train_loss: 0.00000042, val_loss: 0.00000005, val_NMSE: -38.14, lr: 0.00125
# Epoch 0077 — train_loss: 0.00000042, val_loss: 0.00000005, val_NMSE: -38.13, lr: 0.00125
# Epoch 0078 — train_loss: 0.00000042, val_loss: 0.00000005, val_NMSE: -38.24, lr: 0.00125
# Epoch 0079 — train_loss: 0.00000042, val_loss: 0.00000006, val_NMSE: -37.67, lr: 0.00125
# Epoch 0080 — train_loss: 0.00000041, val_loss: 0.00000005, val_NMSE: -38.29, lr: 0.00125
# Epoch 0081 — train_loss: 0.00000041, val_loss: 0.00000005, val_NMSE: -38.28, lr: 0.00125
# Epoch 0082 — train_loss: 0.00000041, val_loss: 0.00000005, val_NMSE: -38.33, lr: 0.00125
# Epoch 0083 — train_loss: 0.00000041, val_loss: 0.00000005, val_NMSE: -38.09, lr: 0.00125
# Epoch 0084 — train_loss: 0.00000041, val_loss: 0.00000006, val_NMSE: -37.76, lr: 0.00125
# Epoch 0085 — train_loss: 0.00000041, val_loss: 0.00000005, val_NMSE: -37.96, lr: 0.00125
# Epoch 0086 — train_loss: 0.00000041, val_loss: 0.00000005, val_NMSE: -38.19, lr: 0.00125
# Epoch 0087 — train_loss: 0.00000041, val_loss: 0.00000005, val_NMSE: -38.47, lr: 0.00125
# Epoch 0088 — train_loss: 0.00000040, val_loss: 0.00000005, val_NMSE: -38.51, lr: 0.00125
# Epoch 0089 — train_loss: 0.00000040, val_loss: 0.00000005, val_NMSE: -38.51, lr: 0.00125
# Epoch 0090 — train_loss: 0.00000040, val_loss: 0.00000005, val_NMSE: -38.61, lr: 0.00125
# Epoch 0091 — train_loss: 0.00000040, val_loss: 0.00000005, val_NMSE: -38.39, lr: 0.00125
# Epoch 0092 — train_loss: 0.00000040, val_loss: 0.00000005, val_NMSE: -38.34, lr: 0.00125
# Epoch 0093 — train_loss: 0.00000040, val_loss: 0.00000005, val_NMSE: -38.55, lr: 0.00125
# Epoch 0094 — train_loss: 0.00000040, val_loss: 0.00000005, val_NMSE: -38.05, lr: 0.00125
# Epoch 0095 — train_loss: 0.00000040, val_loss: 0.00000005, val_NMSE: -38.57, lr: 0.00125
# Epoch 0096 — train_loss: 0.00000040, val_loss: 0.00000005, val_NMSE: -38.21, lr: 0.00125
# Epoch 0097 — train_loss: 0.00000040, val_loss: 0.00000005, val_NMSE: -38.43, lr: 0.00125
# Epoch 0098 — train_loss: 0.00000079, val_loss: 0.00000010, val_NMSE: -35.42, lr: 0.00125
# Epoch 0099 — train_loss: 0.00000045, val_loss: 0.00000007, val_NMSE: -36.67, lr: 0.00125
# ===Training complete===
# Выполнение заняло: 0:05:08
# ========================================================================
# Layer-wise sparsity report
# ========================================================================
# lstm.weight_ih_l0         | nonzero:      195 /      256 (76.17%)
# lstm.weight_hh_l0         | nonzero:     1969 /     4096 (48.07%)
# lstm                     | LAYER TOTAL:     2164 /     4352 (49.72%)
# ------------------------------------------------------------------------
# fc_out.weight               | nonzero:       44 /       64 (68.75%)
# fc_out                   | LAYER TOTAL:       44 /       64 (68.75%)
# ------------------------------------------------------------------------
# ========================================================================
# MODEL TOTAL: nonzero 2208 / 4416 (50.00%)
# ========================================================================
# Model NMSE (finetune): -38.40

# %%
window_size = 30

freqs, spectrum_x_val = metrics.power_spectrum(container.val_input, container.input_signal_fs, container.nperseg, window_size)
_, spectrum_y_val = metrics.power_spectrum(container.val_output, container.input_signal_fs, container.nperseg, window_size)

_, spectrum_y_val_pa = metrics.power_spectrum(y_val_pa, container.input_signal_fs, container.nperseg, window_size)
_, spectrum_y_val_ilc_base = metrics.power_spectrum(y_val_ilc_base, container.input_signal_fs, container.nperseg, window_size)
_, spectrum_y_val_ilc_prune = metrics.power_spectrum(y_val_ilc_prune, container.input_signal_fs, container.nperseg, window_size)
_, spectrum_y_val_ilc_finetune = metrics.power_spectrum(y_val_ilc_finetune, container.input_signal_fs, container.nperseg, window_size)
_, spectrum_y_val_target = metrics.power_spectrum(container.val_output_target, container.input_signal_fs, container.nperseg, window_size)
_, spectrum_u_k_pa = metrics.power_spectrum(u_k_pa, container.input_signal_fs, container.nperseg, window_size)
# _, spectrum_u_k = metrics.power_spectrum(u_k_train, container.input_signal_fs, container.nperseg, window_size)


xlabel="Частота (МГц)"
ylabel= "Спектральная плотность мощности (дБ)"
fontsize = 12
figsize=(12, 6)

plt.figure(figsize=figsize)

plt.plot(freqs / 1e6, spectrum_x_val, color='grey', label='Входной сигнал')
# plt.plot(freqs / 1e6, spectrum_y_val, color='black', label='Выходной сигнал')
plt.plot(freqs / 1e6, spectrum_y_val_pa, color='gold', label='Выходной сигнал PA')
plt.plot(freqs / 1e6, spectrum_y_val_ilc_base, color='springgreen', label='(LSTM base) Сигнал с \nпредыскажением ILC')
plt.plot(freqs / 1e6, spectrum_y_val_ilc_prune, color='lightcoral', label='(LSTM prune) Сигнал с \nпредыскажением ILC')
plt.plot(freqs / 1e6, spectrum_y_val_ilc_finetune, color='violet', label='(LSTM finetune) Сигнал с \nпредыскажением ILC')

# plt.plot(freqs / 1e6, spectrum_u_k, color='magenta', label='spectrum_u_k')
plt.plot(freqs / 1e6, spectrum_u_k_pa, color='red', label='Оптимальный сигнал ILC')


plt.xlabel(xlabel, fontsize=fontsize)
plt.ylabel(ylabel, fontsize=fontsize)
plt.legend()
plt.ylim(bottom=-170)
plt.xticks(np.arange(-500, 600, 100))
plt.grid()
plt.show()

# %%
import torch.nn.utils.prune as prune



epochs = 30
lr = 0.01

model_ilc = LSTM(hidden_size=32, num_layers=1, model_name="ilc")
print(f"total params: {model_ilc.count_params()}")

optimizer = torch.optim.AdamW(model_ilc.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=10)


learning.train(net=model_ilc, 
                criterion=criterion, 
                optimizer=optimizer, 
                train_loader=ilc_train_loader, 
                val_loader=ilc_val_loader, 
                n_epochs=epochs, 
                metric_criterion=metric_criterion,
                scheduler=scheduler)


casc_ilc_eval = utils.CascadeModel(model_1=model_ilc, model_2=pa_model)
y_val_ilc_base = learning.net_inference(net=casc_ilc_eval, x=container.val_input)
ilc_base_nmse = metrics.compute_nmse(y_val_ilc_base, container.val_output_target)
print(f"Model NMSE (base): {ilc_base_nmse:.2f}")


# plotting.plot_weight_heatmaps(model_ilc, vmin=-4, vmax=4)

parameters_to_prune = prunning.get_parameters_to_prune(model_ilc)

prune.global_unstructured(
    parameters_to_prune,
    pruning_method=prunning.GlobalL1ThresholdUnstructured,
    threshold=0.1,
)

learning.train(net=model_ilc, 
            criterion=criterion, 
            optimizer=optimizer, 
            train_loader=ilc_train_loader, 
            val_loader=ilc_val_loader, 
            n_epochs=epochs, 
            metric_criterion=metric_criterion,
            scheduler=scheduler)

prunning.remove_prunned_parameters(parameters_to_prune)

prunning.log_layerwise_sparsity(model_ilc)

casc_ilc_eval = utils.CascadeModel(model_1=model_ilc, model_2=pa_model)
y_val_ilc_finetune = learning.net_inference(net=casc_ilc_eval, x=container.val_input)
ilc_finetune_nmse = metrics.compute_nmse(y_val_ilc_finetune, container.val_output_target)
print(f"Model NMSE (threshold): {ilc_finetune_nmse:.2f}")

plotting.plot_weight_heatmaps(model_ilc, vmin=-4, vmax=4)
# Out:
# total params: 4416
# ===Start training===
# Epoch 0000 — train_loss: 0.00001406, val_loss: 0.00000129, val_NMSE: -24.18, lr: 0.01
# Epoch 0001 — train_loss: 0.00000215, val_loss: 0.00000124, val_NMSE: -24.35, lr: 0.01
# Epoch 0002 — train_loss: 0.00000211, val_loss: 0.00000125, val_NMSE: -24.32, lr: 0.01
# Epoch 0003 — train_loss: 0.00000210, val_loss: 0.00000127, val_NMSE: -24.23, lr: 0.01
# Epoch 0004 — train_loss: 0.00000210, val_loss: 0.00000124, val_NMSE: -24.33, lr: 0.01
# Epoch 0005 — train_loss: 0.00000210, val_loss: 0.00000126, val_NMSE: -24.28, lr: 0.01
# Epoch 0006 — train_loss: 0.00000209, val_loss: 0.00000123, val_NMSE: -24.38, lr: 0.01
# Epoch 0007 — train_loss: 0.00000210, val_loss: 0.00000124, val_NMSE: -24.35, lr: 0.01
# Epoch 0008 — train_loss: 0.00000210, val_loss: 0.00000123, val_NMSE: -24.38, lr: 0.01
# Epoch 0009 — train_loss: 0.00000210, val_loss: 0.00000123, val_NMSE: -24.38, lr: 0.01
# Epoch 0010 — train_loss: 0.00000208, val_loss: 0.00000122, val_NMSE: -24.42, lr: 0.01
# Epoch 0011 — train_loss: 0.00000199, val_loss: 0.00000109, val_NMSE: -24.88, lr: 0.01
# Epoch 0012 — train_loss: 0.00000175, val_loss: 0.00000086, val_NMSE: -25.91, lr: 0.01
# Epoch 0013 — train_loss: 0.00000137, val_loss: 0.00000060, val_NMSE: -27.52, lr: 0.01
# Epoch 0014 — train_loss: 0.00000104, val_loss: 0.00000040, val_NMSE: -29.20, lr: 0.01
# Epoch 0015 — train_loss: 0.00000083, val_loss: 0.00000023, val_NMSE: -31.64, lr: 0.01
# Epoch 0016 — train_loss: 0.00000072, val_loss: 0.00000043, val_NMSE: -28.92, lr: 0.01
# Epoch 0017 — train_loss: 0.00000066, val_loss: 0.00000016, val_NMSE: -33.25, lr: 0.01
# Epoch 0018 — train_loss: 0.00000062, val_loss: 0.00000014, val_NMSE: -33.67, lr: 0.01
# Epoch 0019 — train_loss: 0.00000059, val_loss: 0.00000011, val_NMSE: -34.77, lr: 0.01
# Epoch 0020 — train_loss: 0.00000057, val_loss: 0.00000017, val_NMSE: -33.01, lr: 0.01
# Epoch 0021 — train_loss: 0.00000055, val_loss: 0.00000011, val_NMSE: -34.98, lr: 0.01
# Epoch 0022 — train_loss: 0.00000055, val_loss: 0.00000013, val_NMSE: -34.00, lr: 0.01
# Epoch 0023 — train_loss: 0.00000053, val_loss: 0.00000010, val_NMSE: -35.30, lr: 0.01
# Epoch 0024 — train_loss: 0.00000052, val_loss: 0.00000009, val_NMSE: -35.61, lr: 0.01
# Epoch 0025 — train_loss: 0.00000051, val_loss: 0.00000011, val_NMSE: -34.71, lr: 0.01
# Epoch 0026 — train_loss: 0.00000050, val_loss: 0.00000010, val_NMSE: -35.31, lr: 0.01
# Epoch 0027 — train_loss: 0.00000050, val_loss: 0.00000011, val_NMSE: -34.70, lr: 0.01
# Epoch 0028 — train_loss: 0.00000049, val_loss: 0.00000009, val_NMSE: -35.89, lr: 0.01
# Epoch 0029 — train_loss: 0.00000048, val_loss: 0.00000009, val_NMSE: -35.76, lr: 0.01
# ===Training complete===
# Выполнение заняло: 0:01:40
# Model NMSE (base): -37.45
# ===Start training===
# Epoch 0000 — train_loss: 0.00000056, val_loss: 0.00000009, val_NMSE: -35.68, lr: 0.01
# Epoch 0001 — train_loss: 0.00000045, val_loss: 0.00000010, val_NMSE: -35.32, lr: 0.01
# Epoch 0002 — train_loss: 0.00000046, val_loss: 0.00000008, val_NMSE: -36.33, lr: 0.01
# Epoch 0003 — train_loss: 0.00000046, val_loss: 0.00000009, val_NMSE: -35.78, lr: 0.01
# Epoch 0004 — train_loss: 0.00000045, val_loss: 0.00000006, val_NMSE: -37.17, lr: 0.01
# Epoch 0005 — train_loss: 0.00000045, val_loss: 0.00000009, val_NMSE: -35.78, lr: 0.01
# Epoch 0006 — train_loss: 0.00000045, val_loss: 0.00000009, val_NMSE: -35.97, lr: 0.01
# Epoch 0007 — train_loss: 0.00000044, val_loss: 0.00000011, val_NMSE: -34.70, lr: 0.01
# Epoch 0008 — train_loss: 0.00000828, val_loss: 0.00000035, val_NMSE: -29.84, lr: 0.01
# Epoch 0009 — train_loss: 0.00000072, val_loss: 0.00000024, val_NMSE: -31.41, lr: 0.01
# Epoch 0010 — train_loss: 0.00000065, val_loss: 0.00000022, val_NMSE: -31.89, lr: 0.01
# Epoch 0011 — train_loss: 0.00000063, val_loss: 0.00000020, val_NMSE: -32.16, lr: 0.01
# Epoch 0012 — train_loss: 0.00000062, val_loss: 0.00000019, val_NMSE: -32.44, lr: 0.01
# Epoch 0013 — train_loss: 0.00000061, val_loss: 0.00000019, val_NMSE: -32.51, lr: 0.01
# Epoch 0014 — train_loss: 0.00000061, val_loss: 0.00000018, val_NMSE: -32.84, lr: 0.01
# Epoch 0015 — train_loss: 0.00000061, val_loss: 0.00000019, val_NMSE: -32.57, lr: 0.005
# Epoch 0016 — train_loss: 0.00000060, val_loss: 0.00000016, val_NMSE: -33.12, lr: 0.005
# Epoch 0017 — train_loss: 0.00000060, val_loss: 0.00000016, val_NMSE: -33.22, lr: 0.005
# Epoch 0018 — train_loss: 0.00000060, val_loss: 0.00000017, val_NMSE: -33.06, lr: 0.005
# Epoch 0019 — train_loss: 0.00000060, val_loss: 0.00000015, val_NMSE: -33.52, lr: 0.005
# Epoch 0020 — train_loss: 0.00000059, val_loss: 0.00000014, val_NMSE: -33.67, lr: 0.005
# Epoch 0021 — train_loss: 0.00000059, val_loss: 0.00000014, val_NMSE: -33.79, lr: 0.005
# Epoch 0022 — train_loss: 0.00000058, val_loss: 0.00000014, val_NMSE: -33.82, lr: 0.005
# Epoch 0023 — train_loss: 0.00000058, val_loss: 0.00000014, val_NMSE: -33.79, lr: 0.005
# Epoch 0024 — train_loss: 0.00000057, val_loss: 0.00000012, val_NMSE: -34.38, lr: 0.005
# Epoch 0025 — train_loss: 0.00000056, val_loss: 0.00000013, val_NMSE: -34.13, lr: 0.005
# Epoch 0026 — train_loss: 0.00000056, val_loss: 0.00000013, val_NMSE: -34.06, lr: 0.0025
# Epoch 0027 — train_loss: 0.00000054, val_loss: 0.00000011, val_NMSE: -34.71, lr: 0.0025
# Epoch 0028 — train_loss: 0.00000054, val_loss: 0.00000011, val_NMSE: -35.01, lr: 0.0025
# Epoch 0029 — train_loss: 0.00000054, val_loss: 0.00000011, val_NMSE: -34.94, lr: 0.0025
# ===Training complete===
# Выполнение заняло: 0:01:38
# Model NMSE (threshold): -36.84

# %%
weights = []

for name, param in model_ilc.named_parameters():
    if "weight" in name:
        weights.append(param.detach().flatten())

all_weights = torch.cat(weights)
print(f"all_weights.shape: {all_weights.shape}")

abs_w = all_weights.abs()


plt.figure()
plt.hist(abs_w.cpu().numpy(), bins=100)
# sns.kdeplot(data=abs_w, fill=True, alpha=0.9, bw_adjust=0.2)
# plt.hist(all_weights, bins=300)

plt.xlabel("|weight|")
plt.ylabel("count")
plt.title("LSTM weight magnitude distribution")
plt.grid()
plt.show()
# Out:
# all_weights.shape: torch.Size([4416])

# %%
rnn_train_props = {
    "hidden_size": 32, 
    "num_layers": 1,
    "bidirectional": False,
    "lr": 0.01,
    "epochs": 30,
    "acpr_meter": acpr_meter
}

lstm_pipeline = prunning.SparsityPipeline(container=container, 
                              train_props=rnn_train_props, 
                              base_model=LSTM,
                              pa_model=pa_model)

# %%
amount_range = np.arange(0, 1, 0.1)

lstm_pipeline.ilc_prune_amount(amount_range, n_runs=3)
# Out:
# [UK] NMSE: -79.35, ACPR: [-38.55972492 -38.6515661 ]
# [Amount 0.00] Run 1/3
# ===Start training===
# Epoch 0000 — train_loss: 0.00001760, val_loss: 0.00000147, val_NMSE: -23.60, lr: 0.01
# Epoch 0001 — train_loss: 0.00000273, val_loss: 0.00000143, val_NMSE: -23.72, lr: 0.01
# Epoch 0002 — train_loss: 0.00000268, val_loss: 0.00000140, val_NMSE: -23.81, lr: 0.01
# Epoch 0003 — train_loss: 0.00000268, val_loss: 0.00000139, val_NMSE: -23.85, lr: 0.01
# Epoch 0004 — train_loss: 0.00000268, val_loss: 0.00000146, val_NMSE: -23.63, lr: 0.01
# Epoch 0005 — train_loss: 0.00000268, val_loss: 0.00000140, val_NMSE: -23.80, lr: 0.01
# Epoch 0006 — train_loss: 0.00000268, val_loss: 0.00000136, val_NMSE: -23.95, lr: 0.01
# Epoch 0007 — train_loss: 0.00000269, val_loss: 0.00000148, val_NMSE: -23.56, lr: 0.01
# Epoch 0008 — train_loss: 0.00000268, val_loss: 0.00000137, val_NMSE: -23.92, lr: 0.01
# Epoch 0009 — train_loss: 0.00000268, val_loss: 0.00000148, val_NMSE: -23.56, lr: 0.01
# Epoch 0010 — train_loss: 0.00000267, val_loss: 0.00000137, val_NMSE: -23.91, lr: 0.01
# Epoch 0011 — train_loss: 0.00000266, val_loss: 0.00000138, val_NMSE: -23.87, lr: 0.01
# Epoch 0012 — train_loss: 0.00000253, val_loss: 0.00000118, val_NMSE: -24.57, lr: 0.01
# Epoch 0013 — train_loss: 0.00000229, val_loss: 0.00000102, val_NMSE: -25.17, lr: 0.01
# Epoch 0014 — train_loss: 0.00000196, val_loss: 0.00000074, val_NMSE: -26.60, lr: 0.01
# Epoch 0015 — train_loss: 0.00000159, val_loss: 0.00000047, val_NMSE: -28.57, lr: 0.01
# Epoch 0016 — train_loss: 0.00000124, val_loss: 0.00000027, val_NMSE: -31.02, lr: 0.01
# Epoch 0017 — train_loss: 0.00000110, val_loss: 0.00000026, val_NMSE: -31.07, lr: 0.01
# Epoch 0018 — train_loss: 0.00000103, val_loss: 0.00000019, val_NMSE: -32.59, lr: 0.01
# Epoch 0019 — train_loss: 0.00000099, val_loss: 0.00000015, val_NMSE: -33.40, lr: 0.01
# Epoch 0020 — train_loss: 0.00000096, val_loss: 0.00000016, val_NMSE: -33.31, lr: 0.01
# Epoch 0021 — train_loss: 0.00000093, val_loss: 0.00000013, val_NMSE: -34.06, lr: 0.01
# Epoch 0022 — train_loss: 0.00000091, val_loss: 0.00000013, val_NMSE: -34.25, lr: 0.01
# Epoch 0023 — train_loss: 0.00000089, val_loss: 0.00000013, val_NMSE: -34.17, lr: 0.01
# Epoch 0024 — train_loss: 0.00000088, val_loss: 0.00000018, val_NMSE: -32.83, lr: 0.01
# Epoch 0025 — train_loss: 0.00000087, val_loss: 0.00000013, val_NMSE: -34.28, lr: 0.01
# Epoch 0026 — train_loss: 0.00000085, val_loss: 0.00000012, val_NMSE: -34.44, lr: 0.01
# Epoch 0027 — train_loss: 0.00000083, val_loss: 0.00000014, val_NMSE: -33.70, lr: 0.01
# Epoch 0028 — train_loss: 0.00000083, val_loss: 0.00000015, val_NMSE: -33.50, lr: 0.01
# Epoch 0029 — train_loss: 0.00000081, val_loss: 0.00000012, val_NMSE: -34.40, lr: 0.01
# Epoch 0030 — train_loss: 0.00000081, val_loss: 0.00000010, val_NMSE: -35.38, lr: 0.01
# Epoch 0031 — train_loss: 0.00000080, val_loss: 0.00000021, val_NMSE: -32.12, lr: 0.01
# Epoch 0032 — train_loss: 0.00000079, val_loss: 0.00000030, val_NMSE: -30.52, lr: 0.01
# Epoch 0033 — train_loss: 0.00000078, val_loss: 0.00000025, val_NMSE: -31.35, lr: 0.01
# Epoch 0034 — train_loss: 0.00000077, val_loss: 0.00000016, val_NMSE: -33.25, lr: 0.01
# Epoch 0035 — train_loss: 0.00000077, val_loss: 0.00000010, val_NMSE: -35.46, lr: 0.01
# Epoch 0036 — train_loss: 0.00000076, val_loss: 0.00000016, val_NMSE: -33.32, lr: 0.01
# Epoch 0037 — train_loss: 0.00000075, val_loss: 0.00000017, val_NMSE: -32.90, lr: 0.01
# Epoch 0038 — train_loss: 0.00000074, val_loss: 0.00000012, val_NMSE: -34.52, lr: 0.01
# Epoch 0039 — train_loss: 0.00000075, val_loss: 0.00000014, val_NMSE: -33.81, lr: 0.01
# Epoch 0040 — train_loss: 0.00000073, val_loss: 0.00000011, val_NMSE: -34.95, lr: 0.01
# Epoch 0041 — train_loss: 0.00000074, val_loss: 0.00000014, val_NMSE: -33.88, lr: 0.01
# Epoch 0042 — train_loss: 0.00000073, val_loss: 0.00000011, val_NMSE: -34.84, lr: 0.01
# Epoch 0043 — train_loss: 0.00000072, val_loss: 0.00000011, val_NMSE: -34.85, lr: 0.01
# Epoch 0044 — train_loss: 0.00000072, val_loss: 0.00000015, val_NMSE: -33.60, lr: 0.01
# Epoch 0045 — train_loss: 0.00000072, val_loss: 0.00000010, val_NMSE: -35.41, lr: 0.01
# Epoch 0046 — train_loss: 0.00000072, val_loss: 0.00000012, val_NMSE: -34.66, lr: 0.005
# Epoch 0047 — train_loss: 0.00000067, val_loss: 0.00000006, val_NMSE: -37.28, lr: 0.005
# Epoch 0048 — train_loss: 0.00000067, val_loss: 0.00000007, val_NMSE: -36.75, lr: 0.005
# Epoch 0049 — train_loss: 0.00000067, val_loss: 0.00000009, val_NMSE: -35.91, lr: 0.005
# ===Training complete===
# Выполнение заняло: 0:01:51
# [ILC] [Base] NMSE: -37.24, ACPR: [-38.47459841 -36.68793578], nonzero_params: 4416
# ========================================================================
# Layer-wise sparsity report
# ========================================================================
# lstm.weight_ih_l0_orig    | nonzero:      256 /      256 (100.00%)
# lstm.weight_hh_l0_orig    | nonzero:     4096 /     4096 (100.00%)
# lstm                     | LAYER TOTAL:     4352 /     4352 (100.00%)
# ------------------------------------------------------------------------
# fc_out.weight_orig          | nonzero:       64 /       64 (100.00%)
# fc_out                   | LAYER TOTAL:       64 /       64 (100.00%)
# ------------------------------------------------------------------------
# ========================================================================
# MODEL TOTAL: nonzero 4416 / 4416 (100.00%)
# ========================================================================
# [ILC] [Prune] NMSE: -37.24, ACPR: [-38.47459841 -36.68793578], nonzero_params: 4416
# ===Start training===
# Epoch 0000 — train_loss: 0.00000066, val_loss: 0.00000008, val_NMSE: -36.13, lr: 0.005
# Epoch 0001 — train_loss: 0.00000066, val_loss: 0.00000008, val_NMSE: -36.23, lr: 0.005
# Epoch 0002 — train_loss: 0.00000066, val_loss: 0.00000007, val_NMSE: -36.85, lr: 0.005
# Epoch 0003 — train_loss: 0.00000066, val_loss: 0.00000009, val_NMSE: -35.52, lr: 0.005
# Epoch 0004 — train_loss: 0.00000066, val_loss: 0.00000007, val_NMSE: -36.64, lr: 0.005
# Epoch 0005 — train_loss: 0.00000066, val_loss: 0.00000007, val_NMSE: -37.07, lr: 0.005
# Epoch 0006 — train_loss: 0.00000065, val_loss: 0.00000006, val_NMSE: -37.56, lr: 0.005
# Epoch 0007 — train_loss: 0.00000065, val_loss: 0.00000006, val_NMSE: -37.59, lr: 0.005
# Epoch 0008 — train_loss: 0.00000065, val_loss: 0.00000008, val_NMSE: -36.25, lr: 0.005
# Epoch 0009 — train_loss: 0.00000064, val_loss: 0.00000008, val_NMSE: -36.40, lr: 0.005
# Epoch 0010 — train_loss: 0.00000064, val_loss: 0.00000007, val_NMSE: -36.56, lr: 0.005
# Epoch 0011 — train_loss: 0.00000064, val_loss: 0.00000008, val_NMSE: -36.26, lr: 0.005
# Epoch 0012 — train_loss: 0.00000064, val_loss: 0.00000012, val_NMSE: -34.31, lr: 0.005
# Epoch 0013 — train_loss: 0.00000064, val_loss: 0.00000012, val_NMSE: -34.46, lr: 0.005
# Epoch 0014 — train_loss: 0.00000064, val_loss: 0.00000008, val_NMSE: -36.24, lr: 0.005
# Epoch 0015 — train_loss: 0.00000064, val_loss: 0.00000009, val_NMSE: -35.67, lr: 0.005
# Epoch 0016 — train_loss: 0.00000064, val_loss: 0.00000009, val_NMSE: -35.55, lr: 0.005
# Epoch 0017 — train_loss: 0.00000063, val_loss: 0.00000008, val_NMSE: -36.40, lr: 0.005
# Epoch 0018 — train_loss: 0.00000063, val_loss: 0.00000008, val_NMSE: -36.23, lr: 0.0025
# Epoch 0019 — train_loss: 0.00000061, val_loss: 0.00000005, val_NMSE: -37.94, lr: 0.0025
# Epoch 0020 — train_loss: 0.00000061, val_loss: 0.00000006, val_NMSE: -37.76, lr: 0.0025
# Epoch 0021 — train_loss: 0.00000061, val_loss: 0.00000006, val_NMSE: -37.27, lr: 0.0025
# Epoch 0022 — train_loss: 0.00000061, val_loss: 0.00000005, val_NMSE: -37.87, lr: 0.0025
# Epoch 0023 — train_loss: 0.00000061, val_loss: 0.00000006, val_NMSE: -37.61, lr: 0.0025
# Epoch 0024 — train_loss: 0.00000061, val_loss: 0.00000006, val_NMSE: -37.80, lr: 0.0025
# Epoch 0025 — train_loss: 0.00000061, val_loss: 0.00000010, val_NMSE: -35.45, lr: 0.0025
# Epoch 0026 — train_loss: 0.00000061, val_loss: 0.00000005, val_NMSE: -37.88, lr: 0.0025
# Epoch 0027 — train_loss: 0.00000061, val_loss: 0.00000005, val_NMSE: -38.06, lr: 0.0025
# Epoch 0028 — train_loss: 0.00000060, val_loss: 0.00000006, val_NMSE: -37.64, lr: 0.0025
# Epoch 0029 — train_loss: 0.00000060, val_loss: 0.00000006, val_NMSE: -37.79, lr: 0.0025
# Epoch 0030 — train_loss: 0.00000060, val_loss: 0.00000006, val_NMSE: -37.77, lr: 0.0025
# Epoch 0031 — train_loss: 0.00000060, val_loss: 0.00000006, val_NMSE: -37.17, lr: 0.0025
# Epoch 0032 — train_loss: 0.00000060, val_loss: 0.00000005, val_NMSE: -37.90, lr: 0.0025
# Epoch 0033 — train_loss: 0.00000060, val_loss: 0.00000005, val_NMSE: -38.10, lr: 0.0025
# Epoch 0034 — train_loss: 0.00000060, val_loss: 0.00000006, val_NMSE: -37.38, lr: 0.0025
# Epoch 0035 — train_loss: 0.00000060, val_loss: 0.00000006, val_NMSE: -37.47, lr: 0.0025
# Epoch 0036 — train_loss: 0.00000059, val_loss: 0.00000007, val_NMSE: -36.92, lr: 0.0025
# Epoch 0037 — train_loss: 0.00000059, val_loss: 0.00000006, val_NMSE: -37.84, lr: 0.0025
# Epoch 0038 — train_loss: 0.00000059, val_loss: 0.00000006, val_NMSE: -37.54, lr: 0.0025
# Epoch 0039 — train_loss: 0.00000059, val_loss: 0.00000007, val_NMSE: -37.12, lr: 0.0025
# Epoch 0040 — train_loss: 0.00000059, val_loss: 0.00000007, val_NMSE: -36.77, lr: 0.0025
# Epoch 0041 — train_loss: 0.00000059, val_loss: 0.00000005, val_NMSE: -37.92, lr: 0.0025
# Epoch 0042 — train_loss: 0.00000059, val_loss: 0.00000005, val_NMSE: -38.35, lr: 0.0025
# Epoch 0043 — train_loss: 0.00000059, val_loss: 0.00000006, val_NMSE: -37.30, lr: 0.0025
# Epoch 0044 — train_loss: 0.00000059, val_loss: 0.00000005, val_NMSE: -38.31, lr: 0.0025
# Epoch 0045 — train_loss: 0.00000059, val_loss: 0.00000005, val_NMSE: -38.44, lr: 0.0025
# Epoch 0046 — train_loss: 0.00000059, val_loss: 0.00000006, val_NMSE: -37.73, lr: 0.0025
# Epoch 0047 — train_loss: 0.00000059, val_loss: 0.00000006, val_NMSE: -37.25, lr: 0.0025
# Epoch 0048 — train_loss: 0.00000058, val_loss: 0.00000005, val_NMSE: -38.53, lr: 0.0025
# Epoch 0049 — train_loss: 0.00000058, val_loss: 0.00000006, val_NMSE: -37.37, lr: 0.0025
# ===Training complete===
# Выполнение заняло: 0:01:50
# ========================================================================
# Layer-wise sparsity report
# ========================================================================
# lstm.weight_ih_l0         | nonzero:      256 /      256 (100.00%)
# lstm.weight_hh_l0         | nonzero:     4096 /     4096 (100.00%)
# lstm                     | LAYER TOTAL:     4352 /     4352 (100.00%)
# ------------------------------------------------------------------------
# fc_out.weight               | nonzero:       64 /       64 (100.00%)
# fc_out                   | LAYER TOTAL:       64 /       64 (100.00%)
# ------------------------------------------------------------------------
# ========================================================================
# MODEL TOTAL: nonzero 4416 / 4416 (100.00%)
# ========================================================================
# [ILC] [Finetune] NMSE: -38.88, ACPR: [-38.66246258 -36.68462845], nonzero_params: 4416
# [Amount 0.00] Run 2/3
# ===Start training===
# Epoch 0000 — train_loss: 0.00001705, val_loss: 0.00000146, val_NMSE: -23.62, lr: 0.01
# Epoch 0001 — train_loss: 0.00000273, val_loss: 0.00000143, val_NMSE: -23.71, lr: 0.01
# Epoch 0002 — train_loss: 0.00000270, val_loss: 0.00000138, val_NMSE: -23.89, lr: 0.01
# Epoch 0003 — train_loss: 0.00000267, val_loss: 0.00000150, val_NMSE: -23.51, lr: 0.01
# Epoch 0004 — train_loss: 0.00000268, val_loss: 0.00000138, val_NMSE: -23.88, lr: 0.01
# Epoch 0005 — train_loss: 0.00000268, val_loss: 0.00000141, val_NMSE: -23.79, lr: 0.01
# Epoch 0006 — train_loss: 0.00000268, val_loss: 0.00000139, val_NMSE: -23.86, lr: 0.01
# Epoch 0007 — train_loss: 0.00000268, val_loss: 0.00000140, val_NMSE: -23.81, lr: 0.01
# Epoch 0008 — train_loss: 0.00000267, val_loss: 0.00000138, val_NMSE: -23.88, lr: 0.01
# Epoch 0009 — train_loss: 0.00000266, val_loss: 0.00000139, val_NMSE: -23.83, lr: 0.01
# Epoch 0010 — train_loss: 0.00000266, val_loss: 0.00000139, val_NMSE: -23.85, lr: 0.01
# Epoch 0011 — train_loss: 0.00000260, val_loss: 0.00000147, val_NMSE: -23.61, lr: 0.01
# Epoch 0012 — train_loss: 0.00000240, val_loss: 0.00000108, val_NMSE: -24.92, lr: 0.01
# Epoch 0013 — train_loss: 0.00000210, val_loss: 0.00000083, val_NMSE: -26.06, lr: 0.01
# Epoch 0014 — train_loss: 0.00000177, val_loss: 0.00000066, val_NMSE: -27.11, lr: 0.01
# Epoch 0015 — train_loss: 0.00000147, val_loss: 0.00000063, val_NMSE: -27.27, lr: 0.01
# Epoch 0016 — train_loss: 0.00000123, val_loss: 0.00000027, val_NMSE: -30.91, lr: 0.01
# Epoch 0017 — train_loss: 0.00000110, val_loss: 0.00000020, val_NMSE: -32.33, lr: 0.01
# Epoch 0018 — train_loss: 0.00000102, val_loss: 0.00000017, val_NMSE: -33.03, lr: 0.01
# Epoch 0019 — train_loss: 0.00000099, val_loss: 0.00000016, val_NMSE: -33.33, lr: 0.01
# Epoch 0020 — train_loss: 0.00000095, val_loss: 0.00000017, val_NMSE: -32.95, lr: 0.01
# Epoch 0021 — train_loss: 0.00000092, val_loss: 0.00000017, val_NMSE: -32.88, lr: 0.01
# Epoch 0022 — train_loss: 0.00000091, val_loss: 0.00000022, val_NMSE: -31.88, lr: 0.01
# Epoch 0023 — train_loss: 0.00000088, val_loss: 0.00000019, val_NMSE: -32.40, lr: 0.01
# Epoch 0024 — train_loss: 0.00000086, val_loss: 0.00000012, val_NMSE: -34.66, lr: 0.01
# Epoch 0025 — train_loss: 0.00000085, val_loss: 0.00000017, val_NMSE: -32.88, lr: 0.01
# Epoch 0026 — train_loss: 0.00000085, val_loss: 0.00000014, val_NMSE: -33.97, lr: 0.01
# Epoch 0027 — train_loss: 0.00000083, val_loss: 0.00000013, val_NMSE: -34.11, lr: 0.01
# Epoch 0028 — train_loss: 0.00000082, val_loss: 0.00000009, val_NMSE: -35.69, lr: 0.01
# Epoch 0029 — train_loss: 0.00000081, val_loss: 0.00000014, val_NMSE: -33.73, lr: 0.01
# Epoch 0030 — train_loss: 0.00000079, val_loss: 0.00000012, val_NMSE: -34.40, lr: 0.01
# Epoch 0031 — train_loss: 0.00000079, val_loss: 0.00000011, val_NMSE: -34.92, lr: 0.01
# Epoch 0032 — train_loss: 0.00000078, val_loss: 0.00000013, val_NMSE: -34.04, lr: 0.01
# Epoch 0033 — train_loss: 0.00000077, val_loss: 0.00000021, val_NMSE: -32.11, lr: 0.01
# Epoch 0034 — train_loss: 0.00000077, val_loss: 0.00000009, val_NMSE: -35.76, lr: 0.01
# Epoch 0035 — train_loss: 0.00000076, val_loss: 0.00000009, val_NMSE: -35.57, lr: 0.01
# Epoch 0036 — train_loss: 0.00000075, val_loss: 0.00000015, val_NMSE: -33.51, lr: 0.01
# Epoch 0037 — train_loss: 0.00000075, val_loss: 0.00000010, val_NMSE: -35.10, lr: 0.01
# Epoch 0038 — train_loss: 0.00000074, val_loss: 0.00000016, val_NMSE: -33.29, lr: 0.01
# Epoch 0039 — train_loss: 0.00000074, val_loss: 0.00000010, val_NMSE: -35.40, lr: 0.01
# Epoch 0040 — train_loss: 0.00000073, val_loss: 0.00000011, val_NMSE: -34.87, lr: 0.01
# Epoch 0041 — train_loss: 0.00000073, val_loss: 0.00000009, val_NMSE: -35.96, lr: 0.01
# Epoch 0042 — train_loss: 0.00000073, val_loss: 0.00000019, val_NMSE: -32.57, lr: 0.01
# Epoch 0043 — train_loss: 0.00000072, val_loss: 0.00000014, val_NMSE: -33.73, lr: 0.01
# Epoch 0044 — train_loss: 0.00000071, val_loss: 0.00000010, val_NMSE: -35.46, lr: 0.01
# Epoch 0045 — train_loss: 0.00000070, val_loss: 0.00000011, val_NMSE: -35.03, lr: 0.01
# Epoch 0046 — train_loss: 0.00000070, val_loss: 0.00000008, val_NMSE: -36.08, lr: 0.01
# Epoch 0047 — train_loss: 0.00000071, val_loss: 0.00000012, val_NMSE: -34.46, lr: 0.01
# Epoch 0048 — train_loss: 0.00000069, val_loss: 0.00000013, val_NMSE: -34.02, lr: 0.01
# Epoch 0049 — train_loss: 0.00000069, val_loss: 0.00000009, val_NMSE: -35.63, lr: 0.01
# ===Training complete===
# Выполнение заняло: 0:01:52
# [ILC] [Base] NMSE: -37.04, ACPR: [-38.48446594 -36.68724014], nonzero_params: 4416
# ========================================================================
# Layer-wise sparsity report
# ========================================================================
# lstm.weight_ih_l0_orig    | nonzero:      256 /      256 (100.00%)
# lstm.weight_hh_l0_orig    | nonzero:     4096 /     4096 (100.00%)
# lstm                     | LAYER TOTAL:     4352 /     4352 (100.00%)
# ------------------------------------------------------------------------
# fc_out.weight_orig          | nonzero:       64 /       64 (100.00%)
# fc_out                   | LAYER TOTAL:       64 /       64 (100.00%)
# ------------------------------------------------------------------------
# ========================================================================
# MODEL TOTAL: nonzero 4416 / 4416 (100.00%)
# ========================================================================
# [ILC] [Prune] NMSE: -37.04, ACPR: [-38.48446594 -36.68724014], nonzero_params: 4416
# ===Start training===
# Epoch 0000 — train_loss: 0.00000069, val_loss: 0.00000009, val_NMSE: -35.63, lr: 0.01
# Epoch 0001 — train_loss: 0.00000069, val_loss: 0.00000009, val_NMSE: -35.90, lr: 0.01
# Epoch 0002 — train_loss: 0.00000069, val_loss: 0.00000010, val_NMSE: -35.49, lr: 0.01
# Epoch 0003 — train_loss: 0.00000068, val_loss: 0.00000015, val_NMSE: -33.59, lr: 0.01
# Epoch 0004 — train_loss: 0.00000068, val_loss: 0.00000014, val_NMSE: -33.74, lr: 0.01
# Epoch 0005 — train_loss: 0.00000068, val_loss: 0.00000014, val_NMSE: -33.72, lr: 0.01
# Epoch 0006 — train_loss: 0.00000067, val_loss: 0.00000014, val_NMSE: -33.81, lr: 0.01
# Epoch 0007 — train_loss: 0.00000067, val_loss: 0.00000009, val_NMSE: -35.85, lr: 0.005
# Epoch 0008 — train_loss: 0.00000063, val_loss: 0.00000007, val_NMSE: -37.11, lr: 0.005
# Epoch 0009 — train_loss: 0.00000063, val_loss: 0.00000009, val_NMSE: -35.83, lr: 0.005
# Epoch 0010 — train_loss: 0.00000063, val_loss: 0.00000007, val_NMSE: -36.79, lr: 0.005
# Epoch 0011 — train_loss: 0.00000063, val_loss: 0.00000010, val_NMSE: -35.10, lr: 0.005
# Epoch 0012 — train_loss: 0.00000063, val_loss: 0.00000008, val_NMSE: -36.03, lr: 0.005
# Epoch 0013 — train_loss: 0.00000063, val_loss: 0.00000006, val_NMSE: -37.63, lr: 0.005
# Epoch 0014 — train_loss: 0.00000062, val_loss: 0.00000006, val_NMSE: -37.68, lr: 0.005
# Epoch 0015 — train_loss: 0.00000062, val_loss: 0.00000007, val_NMSE: -36.57, lr: 0.005
# Epoch 0016 — train_loss: 0.00000062, val_loss: 0.00000005, val_NMSE: -38.12, lr: 0.005
# Epoch 0017 — train_loss: 0.00000062, val_loss: 0.00000006, val_NMSE: -37.26, lr: 0.005
# Epoch 0018 — train_loss: 0.00000061, val_loss: 0.00000006, val_NMSE: -37.62, lr: 0.005
# Epoch 0019 — train_loss: 0.00000061, val_loss: 0.00000008, val_NMSE: -36.49, lr: 0.005
# Epoch 0020 — train_loss: 0.00000061, val_loss: 0.00000008, val_NMSE: -36.51, lr: 0.005
# Epoch 0021 — train_loss: 0.00000061, val_loss: 0.00000008, val_NMSE: -36.42, lr: 0.005
# Epoch 0022 — train_loss: 0.00000061, val_loss: 0.00000006, val_NMSE: -37.62, lr: 0.005
# Epoch 0023 — train_loss: 0.00000061, val_loss: 0.00000005, val_NMSE: -38.19, lr: 0.005
# Epoch 0024 — train_loss: 0.00000061, val_loss: 0.00000006, val_NMSE: -37.44, lr: 0.005
# Epoch 0025 — train_loss: 0.00000060, val_loss: 0.00000006, val_NMSE: -37.24, lr: 0.005
# Epoch 0026 — train_loss: 0.00000060, val_loss: 0.00000008, val_NMSE: -36.24, lr: 0.005
# Epoch 0027 — train_loss: 0.00000060, val_loss: 0.00000005, val_NMSE: -37.90, lr: 0.005
# Epoch 0028 — train_loss: 0.00000060, val_loss: 0.00000006, val_NMSE: -37.86, lr: 0.005
# Epoch 0029 — train_loss: 0.00000060, val_loss: 0.00000005, val_NMSE: -38.29, lr: 0.005
# Epoch 0030 — train_loss: 0.00000060, val_loss: 0.00000005, val_NMSE: -38.55, lr: 0.005
# Epoch 0031 — train_loss: 0.00000060, val_loss: 0.00000005, val_NMSE: -37.87, lr: 0.005
# Epoch 0032 — train_loss: 0.00000060, val_loss: 0.00000007, val_NMSE: -37.13, lr: 0.005
# Epoch 0033 — train_loss: 0.00000060, val_loss: 0.00000006, val_NMSE: -37.85, lr: 0.005
# Epoch 0034 — train_loss: 0.00000059, val_loss: 0.00000005, val_NMSE: -38.47, lr: 0.005
# Epoch 0035 — train_loss: 0.00000059, val_loss: 0.00000005, val_NMSE: -37.96, lr: 0.005
# Epoch 0036 — train_loss: 0.00000059, val_loss: 0.00000006, val_NMSE: -37.25, lr: 0.005
# Epoch 0037 — train_loss: 0.00000059, val_loss: 0.00000009, val_NMSE: -35.73, lr: 0.005
# Epoch 0038 — train_loss: 0.00000059, val_loss: 0.00000006, val_NMSE: -37.33, lr: 0.005
# Epoch 0039 — train_loss: 0.00000059, val_loss: 0.00000007, val_NMSE: -37.03, lr: 0.005
# Epoch 0040 — train_loss: 0.00000059, val_loss: 0.00000007, val_NMSE: -36.75, lr: 0.005
# Epoch 0041 — train_loss: 0.00000058, val_loss: 0.00000005, val_NMSE: -38.70, lr: 0.005
# Epoch 0042 — train_loss: 0.00000059, val_loss: 0.00000006, val_NMSE: -37.46, lr: 0.005
# Epoch 0043 — train_loss: 0.00000059, val_loss: 0.00000005, val_NMSE: -37.88, lr: 0.005
# Epoch 0044 — train_loss: 0.00000059, val_loss: 0.00000006, val_NMSE: -37.43, lr: 0.005
# Epoch 0045 — train_loss: 0.00000058, val_loss: 0.00000005, val_NMSE: -38.52, lr: 0.005
# Epoch 0046 — train_loss: 0.00000059, val_loss: 0.00000005, val_NMSE: -37.99, lr: 0.005
# Epoch 0047 — train_loss: 0.00000058, val_loss: 0.00000007, val_NMSE: -36.54, lr: 0.005
# Epoch 0048 — train_loss: 0.00000059, val_loss: 0.00000012, val_NMSE: -34.53, lr: 0.005
# Epoch 0049 — train_loss: 0.00000058, val_loss: 0.00000006, val_NMSE: -37.76, lr: 0.005
# ===Training complete===
# Выполнение заняло: 0:01:56
# ========================================================================
# Layer-wise sparsity report
# ========================================================================
# lstm.weight_ih_l0         | nonzero:      256 /      256 (100.00%)
# lstm.weight_hh_l0         | nonzero:     4096 /     4096 (100.00%)
# lstm                     | LAYER TOTAL:     4352 /     4352 (100.00%)
# ------------------------------------------------------------------------
# fc_out.weight               | nonzero:       64 /       64 (100.00%)
# fc_out                   | LAYER TOTAL:       64 /       64 (100.00%)
# ------------------------------------------------------------------------
# ========================================================================
# MODEL TOTAL: nonzero 4416 / 4416 (100.00%)
# ========================================================================
# [ILC] [Finetune] NMSE: -39.19, ACPR: [-38.70119922 -36.83897269], nonzero_params: 4416
# [Amount 0.00] Run 3/3
# ===Start training===
# Epoch 0000 — train_loss: 0.00001514, val_loss: 0.00000145, val_NMSE: -23.66, lr: 0.01
# Epoch 0001 — train_loss: 0.00000272, val_loss: 0.00000143, val_NMSE: -23.73, lr: 0.01
# Epoch 0002 — train_loss: 0.00000269, val_loss: 0.00000142, val_NMSE: -23.76, lr: 0.01
# Epoch 0003 — train_loss: 0.00000267, val_loss: 0.00000139, val_NMSE: -23.84, lr: 0.01
# Epoch 0004 — train_loss: 0.00000268, val_loss: 0.00000141, val_NMSE: -23.77, lr: 0.01
# Epoch 0005 — train_loss: 0.00000269, val_loss: 0.00000141, val_NMSE: -23.77, lr: 0.01
# Epoch 0006 — train_loss: 0.00000268, val_loss: 0.00000137, val_NMSE: -23.90, lr: 0.01
# Epoch 0007 — train_loss: 0.00000268, val_loss: 0.00000141, val_NMSE: -23.78, lr: 0.01
# Epoch 0008 — train_loss: 0.00000267, val_loss: 0.00000136, val_NMSE: -23.95, lr: 0.01
# Epoch 0009 — train_loss: 0.00000267, val_loss: 0.00000139, val_NMSE: -23.84, lr: 0.01
# Epoch 0010 — train_loss: 0.00000264, val_loss: 0.00000142, val_NMSE: -23.76, lr: 0.01
# Epoch 0011 — train_loss: 0.00000245, val_loss: 0.00000114, val_NMSE: -24.70, lr: 0.01
# Epoch 0012 — train_loss: 0.00000207, val_loss: 0.00000086, val_NMSE: -25.92, lr: 0.01
# Epoch 0013 — train_loss: 0.00000169, val_loss: 0.00000061, val_NMSE: -27.45, lr: 0.01
# Epoch 0014 — train_loss: 0.00000138, val_loss: 0.00000041, val_NMSE: -29.16, lr: 0.01
# Epoch 0015 — train_loss: 0.00000118, val_loss: 0.00000029, val_NMSE: -30.67, lr: 0.01
# Epoch 0016 — train_loss: 0.00000107, val_loss: 0.00000024, val_NMSE: -31.44, lr: 0.01
# Epoch 0017 — train_loss: 0.00000100, val_loss: 0.00000021, val_NMSE: -32.11, lr: 0.01
# Epoch 0018 — train_loss: 0.00000096, val_loss: 0.00000021, val_NMSE: -32.01, lr: 0.01
# Epoch 0019 — train_loss: 0.00000093, val_loss: 0.00000019, val_NMSE: -32.44, lr: 0.01
# Epoch 0020 — train_loss: 0.00000091, val_loss: 0.00000014, val_NMSE: -33.69, lr: 0.01
# Epoch 0021 — train_loss: 0.00000089, val_loss: 0.00000014, val_NMSE: -33.86, lr: 0.01
# Epoch 0022 — train_loss: 0.00000087, val_loss: 0.00000013, val_NMSE: -34.01, lr: 0.01
# Epoch 0023 — train_loss: 0.00000087, val_loss: 0.00000015, val_NMSE: -33.43, lr: 0.01
# Epoch 0024 — train_loss: 0.00000084, val_loss: 0.00000018, val_NMSE: -32.80, lr: 0.01
# Epoch 0025 — train_loss: 0.00000083, val_loss: 0.00000016, val_NMSE: -33.14, lr: 0.01
# Epoch 0026 — train_loss: 0.00000083, val_loss: 0.00000013, val_NMSE: -33.98, lr: 0.01
# Epoch 0027 — train_loss: 0.00000082, val_loss: 0.00000012, val_NMSE: -34.35, lr: 0.01
# Epoch 0028 — train_loss: 0.00000081, val_loss: 0.00000010, val_NMSE: -35.42, lr: 0.01
# Epoch 0029 — train_loss: 0.00000080, val_loss: 0.00000022, val_NMSE: -31.93, lr: 0.01
# Epoch 0030 — train_loss: 0.00000079, val_loss: 0.00000018, val_NMSE: -32.77, lr: 0.01
# Epoch 0031 — train_loss: 0.00000079, val_loss: 0.00000011, val_NMSE: -34.92, lr: 0.01
# Epoch 0032 — train_loss: 0.00000078, val_loss: 0.00000027, val_NMSE: -31.03, lr: 0.01
# Epoch 0033 — train_loss: 0.00000077, val_loss: 0.00000010, val_NMSE: -35.16, lr: 0.01
# Epoch 0034 — train_loss: 0.00000076, val_loss: 0.00000012, val_NMSE: -34.57, lr: 0.01
# Epoch 0035 — train_loss: 0.00000076, val_loss: 0.00000021, val_NMSE: -32.10, lr: 0.01
# Epoch 0036 — train_loss: 0.00000075, val_loss: 0.00000016, val_NMSE: -33.29, lr: 0.01
# Epoch 0037 — train_loss: 0.00000074, val_loss: 0.00000015, val_NMSE: -33.62, lr: 0.01
# Epoch 0038 — train_loss: 0.00000074, val_loss: 0.00000018, val_NMSE: -32.60, lr: 0.01
# Epoch 0039 — train_loss: 0.00000075, val_loss: 0.00000013, val_NMSE: -34.20, lr: 0.005
# Epoch 0040 — train_loss: 0.00000070, val_loss: 0.00000009, val_NMSE: -35.82, lr: 0.005
# Epoch 0041 — train_loss: 0.00000070, val_loss: 0.00000009, val_NMSE: -35.66, lr: 0.005
# Epoch 0042 — train_loss: 0.00000069, val_loss: 0.00000009, val_NMSE: -35.83, lr: 0.005
# Epoch 0043 — train_loss: 0.00000069, val_loss: 0.00000010, val_NMSE: -35.23, lr: 0.005
# Epoch 0044 — train_loss: 0.00000069, val_loss: 0.00000011, val_NMSE: -34.69, lr: 0.005
# Epoch 0045 — train_loss: 0.00000069, val_loss: 0.00000011, val_NMSE: -34.81, lr: 0.005
# Epoch 0046 — train_loss: 0.00000068, val_loss: 0.00000010, val_NMSE: -35.28, lr: 0.005
# Epoch 0047 — train_loss: 0.00000068, val_loss: 0.00000008, val_NMSE: -36.10, lr: 0.005
# Epoch 0048 — train_loss: 0.00000068, val_loss: 0.00000007, val_NMSE: -36.57, lr: 0.005
# Epoch 0049 — train_loss: 0.00000067, val_loss: 0.00000007, val_NMSE: -36.55, lr: 0.005
# ===Training complete===
# Выполнение заняло: 0:01:51
# [ILC] [Base] NMSE: -38.13, ACPR: [-38.48567547 -36.697148  ], nonzero_params: 4416
# ========================================================================
# Layer-wise sparsity report
# ========================================================================
# lstm.weight_ih_l0_orig    | nonzero:      256 /      256 (100.00%)
# lstm.weight_hh_l0_orig    | nonzero:     4096 /     4096 (100.00%)
# lstm                     | LAYER TOTAL:     4352 /     4352 (100.00%)
# ------------------------------------------------------------------------
# fc_out.weight_orig          | nonzero:       64 /       64 (100.00%)
# fc_out                   | LAYER TOTAL:       64 /       64 (100.00%)
# ------------------------------------------------------------------------
# ========================================================================
# MODEL TOTAL: nonzero 4416 / 4416 (100.00%)
# ========================================================================
# [ILC] [Prune] NMSE: -38.13, ACPR: [-38.48567547 -36.697148  ], nonzero_params: 4416
# ===Start training===
# Epoch 0000 — train_loss: 0.00000068, val_loss: 0.00000010, val_NMSE: -35.25, lr: 0.005
# Epoch 0001 — train_loss: 0.00000067, val_loss: 0.00000009, val_NMSE: -35.83, lr: 0.005
# Epoch 0002 — train_loss: 0.00000066, val_loss: 0.00000013, val_NMSE: -34.30, lr: 0.005
# Epoch 0003 — train_loss: 0.00000067, val_loss: 0.00000007, val_NMSE: -36.59, lr: 0.005
# Epoch 0004 — train_loss: 0.00000066, val_loss: 0.00000010, val_NMSE: -35.28, lr: 0.005
# Epoch 0005 — train_loss: 0.00000066, val_loss: 0.00000008, val_NMSE: -36.28, lr: 0.005
# Epoch 0006 — train_loss: 0.00000066, val_loss: 0.00000007, val_NMSE: -36.93, lr: 0.005
# Epoch 0007 — train_loss: 0.00000065, val_loss: 0.00000008, val_NMSE: -36.36, lr: 0.005
# Epoch 0008 — train_loss: 0.00000065, val_loss: 0.00000008, val_NMSE: -36.27, lr: 0.005
# Epoch 0009 — train_loss: 0.00000065, val_loss: 0.00000008, val_NMSE: -36.16, lr: 0.005
# Epoch 0010 — train_loss: 0.00000065, val_loss: 0.00000008, val_NMSE: -36.42, lr: 0.005
# Epoch 0011 — train_loss: 0.00000065, val_loss: 0.00000008, val_NMSE: -36.47, lr: 0.005
# Epoch 0012 — train_loss: 0.00000065, val_loss: 0.00000006, val_NMSE: -37.16, lr: 0.005
# Epoch 0013 — train_loss: 0.00000064, val_loss: 0.00000007, val_NMSE: -36.63, lr: 0.005
# Epoch 0014 — train_loss: 0.00000064, val_loss: 0.00000008, val_NMSE: -36.40, lr: 0.005
# Epoch 0015 — train_loss: 0.00000065, val_loss: 0.00000009, val_NMSE: -35.68, lr: 0.005
# Epoch 0016 — train_loss: 0.00000064, val_loss: 0.00000007, val_NMSE: -36.90, lr: 0.005
# Epoch 0017 — train_loss: 0.00000064, val_loss: 0.00000008, val_NMSE: -36.15, lr: 0.005
# Epoch 0018 — train_loss: 0.00000064, val_loss: 0.00000007, val_NMSE: -36.81, lr: 0.005
# Epoch 0019 — train_loss: 0.00000064, val_loss: 0.00000015, val_NMSE: -33.48, lr: 0.005
# Epoch 0020 — train_loss: 0.00000064, val_loss: 0.00000008, val_NMSE: -36.02, lr: 0.005
# Epoch 0021 — train_loss: 0.00000063, val_loss: 0.00000008, val_NMSE: -36.17, lr: 0.005
# Epoch 0022 — train_loss: 0.00000063, val_loss: 0.00000011, val_NMSE: -35.04, lr: 0.005
# Epoch 0023 — train_loss: 0.00000064, val_loss: 0.00000007, val_NMSE: -37.12, lr: 0.0025
# Epoch 0024 — train_loss: 0.00000061, val_loss: 0.00000006, val_NMSE: -37.39, lr: 0.0025
# Epoch 0025 — train_loss: 0.00000061, val_loss: 0.00000007, val_NMSE: -37.07, lr: 0.0025
# Epoch 0026 — train_loss: 0.00000061, val_loss: 0.00000006, val_NMSE: -37.72, lr: 0.0025
# Epoch 0027 — train_loss: 0.00000061, val_loss: 0.00000006, val_NMSE: -37.86, lr: 0.0025
# Epoch 0028 — train_loss: 0.00000061, val_loss: 0.00000006, val_NMSE: -37.62, lr: 0.0025
# Epoch 0029 — train_loss: 0.00000061, val_loss: 0.00000006, val_NMSE: -37.59, lr: 0.0025
# Epoch 0030 — train_loss: 0.00000061, val_loss: 0.00000006, val_NMSE: -37.71, lr: 0.0025
# Epoch 0031 — train_loss: 0.00000061, val_loss: 0.00000006, val_NMSE: -37.42, lr: 0.0025
# Epoch 0032 — train_loss: 0.00000061, val_loss: 0.00000006, val_NMSE: -37.64, lr: 0.0025
# Epoch 0033 — train_loss: 0.00000061, val_loss: 0.00000005, val_NMSE: -37.87, lr: 0.0025
# Epoch 0034 — train_loss: 0.00000060, val_loss: 0.00000005, val_NMSE: -38.15, lr: 0.0025
# Epoch 0035 — train_loss: 0.00000060, val_loss: 0.00000006, val_NMSE: -37.78, lr: 0.0025
# Epoch 0036 — train_loss: 0.00000060, val_loss: 0.00000006, val_NMSE: -37.63, lr: 0.0025
# Epoch 0037 — train_loss: 0.00000060, val_loss: 0.00000006, val_NMSE: -37.55, lr: 0.0025
# Epoch 0038 — train_loss: 0.00000060, val_loss: 0.00000006, val_NMSE: -37.59, lr: 0.0025
# Epoch 0039 — train_loss: 0.00000060, val_loss: 0.00000007, val_NMSE: -36.72, lr: 0.0025
# Epoch 0040 — train_loss: 0.00000060, val_loss: 0.00000007, val_NMSE: -37.06, lr: 0.0025
# Epoch 0041 — train_loss: 0.00000060, val_loss: 0.00000006, val_NMSE: -37.29, lr: 0.0025
# Epoch 0042 — train_loss: 0.00000060, val_loss: 0.00000008, val_NMSE: -36.31, lr: 0.0025
# Epoch 0043 — train_loss: 0.00000059, val_loss: 0.00000007, val_NMSE: -36.59, lr: 0.0025
# Epoch 0044 — train_loss: 0.00000059, val_loss: 0.00000006, val_NMSE: -37.31, lr: 0.0025
# Epoch 0045 — train_loss: 0.00000059, val_loss: 0.00000005, val_NMSE: -37.96, lr: 0.00125
# Epoch 0046 — train_loss: 0.00000058, val_loss: 0.00000005, val_NMSE: -38.61, lr: 0.00125
# Epoch 0047 — train_loss: 0.00000058, val_loss: 0.00000005, val_NMSE: -38.09, lr: 0.00125
# Epoch 0048 — train_loss: 0.00000058, val_loss: 0.00000006, val_NMSE: -37.55, lr: 0.00125
# Epoch 0049 — train_loss: 0.00000058, val_loss: 0.00000006, val_NMSE: -37.61, lr: 0.00125
# ===Training complete===
# Выполнение заняло: 0:01:52
# ========================================================================
# Layer-wise sparsity report
# ========================================================================
# lstm.weight_ih_l0         | nonzero:      256 /      256 (100.00%)
# lstm.weight_hh_l0         | nonzero:     4096 /     4096 (100.00%)
# lstm                     | LAYER TOTAL:     4352 /     4352 (100.00%)
# ------------------------------------------------------------------------
# fc_out.weight               | nonzero:       64 /       64 (100.00%)
# fc_out                   | LAYER TOTAL:       64 /       64 (100.00%)
# ------------------------------------------------------------------------
# ========================================================================
# MODEL TOTAL: nonzero 4416 / 4416 (100.00%)
# ========================================================================
# [ILC] [Finetune] NMSE: -39.10, ACPR: [-38.71420208 -36.78714275], nonzero_params: 4416
# [Amount 0.10] Run 1/3
# ===Start training===
# Epoch 0000 — train_loss: 0.00001584, val_loss: 0.00000146, val_NMSE: -23.62, lr: 0.01
# Epoch 0001 — train_loss: 0.00000272, val_loss: 0.00000142, val_NMSE: -23.76, lr: 0.01
# Epoch 0002 — train_loss: 0.00000268, val_loss: 0.00000142, val_NMSE: -23.75, lr: 0.01
# Epoch 0003 — train_loss: 0.00000269, val_loss: 0.00000139, val_NMSE: -23.85, lr: 0.01
# Epoch 0004 — train_loss: 0.00000267, val_loss: 0.00000152, val_NMSE: -23.45, lr: 0.01
# Epoch 0005 — train_loss: 0.00000269, val_loss: 0.00000139, val_NMSE: -23.84, lr: 0.01
# Epoch 0006 — train_loss: 0.00000267, val_loss: 0.00000143, val_NMSE: -23.73, lr: 0.01
# Epoch 0007 — train_loss: 0.00000267, val_loss: 0.00000136, val_NMSE: -23.93, lr: 0.01
# Epoch 0008 — train_loss: 0.00000265, val_loss: 0.00000134, val_NMSE: -23.99, lr: 0.01
# Epoch 0009 — train_loss: 0.00000261, val_loss: 0.00000130, val_NMSE: -24.12, lr: 0.01
# Epoch 0010 — train_loss: 0.00000234, val_loss: 0.00000120, val_NMSE: -24.49, lr: 0.01
# Epoch 0011 — train_loss: 0.00000196, val_loss: 0.00000083, val_NMSE: -26.09, lr: 0.01
# Epoch 0012 — train_loss: 0.00000158, val_loss: 0.00000047, val_NMSE: -28.51, lr: 0.01
# Epoch 0013 — train_loss: 0.00000131, val_loss: 0.00000041, val_NMSE: -29.20, lr: 0.01
# Epoch 0014 — train_loss: 0.00000114, val_loss: 0.00000040, val_NMSE: -29.30, lr: 0.01
# Epoch 0015 — train_loss: 0.00000105, val_loss: 0.00000024, val_NMSE: -31.41, lr: 0.01
# Epoch 0016 — train_loss: 0.00000100, val_loss: 0.00000016, val_NMSE: -33.19, lr: 0.01
# Epoch 0017 — train_loss: 0.00000096, val_loss: 0.00000020, val_NMSE: -32.28, lr: 0.01
# Epoch 0018 — train_loss: 0.00000093, val_loss: 0.00000016, val_NMSE: -33.24, lr: 0.01
# Epoch 0019 — train_loss: 0.00000090, val_loss: 0.00000029, val_NMSE: -30.61, lr: 0.01
# Epoch 0020 — train_loss: 0.00000090, val_loss: 0.00000018, val_NMSE: -32.66, lr: 0.01
# Epoch 0021 — train_loss: 0.00000087, val_loss: 0.00000015, val_NMSE: -33.38, lr: 0.01
# Epoch 0022 — train_loss: 0.00000086, val_loss: 0.00000012, val_NMSE: -34.31, lr: 0.01
# Epoch 0023 — train_loss: 0.00000084, val_loss: 0.00000018, val_NMSE: -32.69, lr: 0.01
# Epoch 0024 — train_loss: 0.00000083, val_loss: 0.00000018, val_NMSE: -32.70, lr: 0.01
# Epoch 0025 — train_loss: 0.00000081, val_loss: 0.00000017, val_NMSE: -32.86, lr: 0.01
# Epoch 0026 — train_loss: 0.00000081, val_loss: 0.00000018, val_NMSE: -32.66, lr: 0.01
# Epoch 0027 — train_loss: 0.00000080, val_loss: 0.00000016, val_NMSE: -33.14, lr: 0.01
# Epoch 0028 — train_loss: 0.00000079, val_loss: 0.00000013, val_NMSE: -33.97, lr: 0.01
# Epoch 0029 — train_loss: 0.00000077, val_loss: 0.00000011, val_NMSE: -34.70, lr: 0.01
# Epoch 0030 — train_loss: 0.00000077, val_loss: 0.00000022, val_NMSE: -31.88, lr: 0.01
# Epoch 0031 — train_loss: 0.00000077, val_loss: 0.00000012, val_NMSE: -34.48, lr: 0.01
# Epoch 0032 — train_loss: 0.00000076, val_loss: 0.00000009, val_NMSE: -35.62, lr: 0.01
# Epoch 0033 — train_loss: 0.00000075, val_loss: 0.00000014, val_NMSE: -33.82, lr: 0.01
# Epoch 0034 — train_loss: 0.00000075, val_loss: 0.00000011, val_NMSE: -35.02, lr: 0.01
# Epoch 0035 — train_loss: 0.00000075, val_loss: 0.00000009, val_NMSE: -35.85, lr: 0.01
# Epoch 0036 — train_loss: 0.00000074, val_loss: 0.00000017, val_NMSE: -32.85, lr: 0.01
# Epoch 0037 — train_loss: 0.00000074, val_loss: 0.00000008, val_NMSE: -36.05, lr: 0.01
# Epoch 0038 — train_loss: 0.00000073, val_loss: 0.00000012, val_NMSE: -34.63, lr: 0.01
# Epoch 0039 — train_loss: 0.00000073, val_loss: 0.00000011, val_NMSE: -34.88, lr: 0.01
# Epoch 0040 — train_loss: 0.00000073, val_loss: 0.00000015, val_NMSE: -33.43, lr: 0.01
# Epoch 0041 — train_loss: 0.00000072, val_loss: 0.00000012, val_NMSE: -34.52, lr: 0.01
# Epoch 0042 — train_loss: 0.00000072, val_loss: 0.00000010, val_NMSE: -35.20, lr: 0.01
# Epoch 0043 — train_loss: 0.00000072, val_loss: 0.00000017, val_NMSE: -32.97, lr: 0.01
# Epoch 0044 — train_loss: 0.00000072, val_loss: 0.00000010, val_NMSE: -35.48, lr: 0.01
# Epoch 0045 — train_loss: 0.00000071, val_loss: 0.00000017, val_NMSE: -32.98, lr: 0.01
# Epoch 0046 — train_loss: 0.00000071, val_loss: 0.00000013, val_NMSE: -34.20, lr: 0.01
# Epoch 0047 — train_loss: 0.00000070, val_loss: 0.00000008, val_NMSE: -36.23, lr: 0.01
# Epoch 0048 — train_loss: 0.00000070, val_loss: 0.00000011, val_NMSE: -34.74, lr: 0.01
# Epoch 0049 — train_loss: 0.00000071, val_loss: 0.00000009, val_NMSE: -35.91, lr: 0.01
# ===Training complete===
# Выполнение заняло: 0:01:55
# [ILC] [Base] NMSE: -37.16, ACPR: [-38.44543881 -36.63067064], nonzero_params: 4416
# ========================================================================
# Layer-wise sparsity report
# ========================================================================
# lstm.weight_ih_l0_orig    | nonzero:      256 /      256 (100.00%)
# lstm.weight_hh_l0_orig    | nonzero:     4096 /     4096 (100.00%)
# lstm                     | LAYER TOTAL:     4352 /     4352 (100.00%)
# ------------------------------------------------------------------------
# fc_out.weight_orig          | nonzero:       64 /       64 (100.00%)
# fc_out                   | LAYER TOTAL:       64 /       64 (100.00%)
# ------------------------------------------------------------------------
# ========================================================================
# MODEL TOTAL: nonzero 4416 / 4416 (100.00%)
# ========================================================================
# [ILC] [Prune] NMSE: -35.93, ACPR: [-38.46869913 -36.63854408], nonzero_params: 4416
# ===Start training===
# Epoch 0000 — train_loss: 0.00000069, val_loss: 0.00000009, val_NMSE: -35.86, lr: 0.01
# Epoch 0001 — train_loss: 0.00000070, val_loss: 0.00000013, val_NMSE: -34.28, lr: 0.01
# Epoch 0002 — train_loss: 0.00000069, val_loss: 0.00000022, val_NMSE: -31.85, lr: 0.01
# Epoch 0003 — train_loss: 0.00000069, val_loss: 0.00000007, val_NMSE: -36.77, lr: 0.01
# Epoch 0004 — train_loss: 0.00000069, val_loss: 0.00000012, val_NMSE: -34.54, lr: 0.01
# Epoch 0005 — train_loss: 0.00000068, val_loss: 0.00000009, val_NMSE: -35.69, lr: 0.01
# Epoch 0006 — train_loss: 0.00000068, val_loss: 0.00000008, val_NMSE: -36.17, lr: 0.01
# Epoch 0007 — train_loss: 0.00000068, val_loss: 0.00000008, val_NMSE: -36.29, lr: 0.01
# Epoch 0008 — train_loss: 0.00000068, val_loss: 0.00000012, val_NMSE: -34.61, lr: 0.01
# Epoch 0009 — train_loss: 0.00000068, val_loss: 0.00000010, val_NMSE: -35.33, lr: 0.01
# Epoch 0010 — train_loss: 0.00000067, val_loss: 0.00000007, val_NMSE: -36.60, lr: 0.01
# Epoch 0011 — train_loss: 0.00000067, val_loss: 0.00000016, val_NMSE: -33.18, lr: 0.01
# Epoch 0012 — train_loss: 0.00000067, val_loss: 0.00000013, val_NMSE: -34.05, lr: 0.01
# Epoch 0013 — train_loss: 0.00000067, val_loss: 0.00000008, val_NMSE: -36.11, lr: 0.01
# Epoch 0014 — train_loss: 0.00000067, val_loss: 0.00000008, val_NMSE: -36.31, lr: 0.005
# Epoch 0015 — train_loss: 0.00000063, val_loss: 0.00000007, val_NMSE: -36.76, lr: 0.005
# Epoch 0016 — train_loss: 0.00000063, val_loss: 0.00000007, val_NMSE: -36.96, lr: 0.005
# Epoch 0017 — train_loss: 0.00000063, val_loss: 0.00000006, val_NMSE: -37.26, lr: 0.005
# Epoch 0018 — train_loss: 0.00000062, val_loss: 0.00000009, val_NMSE: -35.78, lr: 0.005
# Epoch 0019 — train_loss: 0.00000062, val_loss: 0.00000008, val_NMSE: -36.37, lr: 0.005
# Epoch 0020 — train_loss: 0.00000062, val_loss: 0.00000006, val_NMSE: -37.59, lr: 0.005
# Epoch 0021 — train_loss: 0.00000062, val_loss: 0.00000007, val_NMSE: -37.04, lr: 0.005
# Epoch 0022 — train_loss: 0.00000062, val_loss: 0.00000011, val_NMSE: -34.73, lr: 0.005
# Epoch 0023 — train_loss: 0.00000062, val_loss: 0.00000008, val_NMSE: -36.35, lr: 0.005
# Epoch 0024 — train_loss: 0.00000062, val_loss: 0.00000009, val_NMSE: -35.66, lr: 0.005
# Epoch 0025 — train_loss: 0.00000061, val_loss: 0.00000008, val_NMSE: -36.16, lr: 0.005
# Epoch 0026 — train_loss: 0.00000061, val_loss: 0.00000007, val_NMSE: -36.82, lr: 0.005
# Epoch 0027 — train_loss: 0.00000061, val_loss: 0.00000009, val_NMSE: -35.60, lr: 0.005
# Epoch 0028 — train_loss: 0.00000061, val_loss: 0.00000007, val_NMSE: -36.89, lr: 0.005
# Epoch 0029 — train_loss: 0.00000061, val_loss: 0.00000008, val_NMSE: -36.45, lr: 0.005
# Epoch 0030 — train_loss: 0.00000060, val_loss: 0.00000011, val_NMSE: -35.01, lr: 0.005
# Epoch 0031 — train_loss: 0.00000060, val_loss: 0.00000006, val_NMSE: -37.78, lr: 0.005
# Epoch 0032 — train_loss: 0.00000060, val_loss: 0.00000007, val_NMSE: -36.54, lr: 0.005
# Epoch 0033 — train_loss: 0.00000060, val_loss: 0.00000006, val_NMSE: -37.26, lr: 0.005
# Epoch 0034 — train_loss: 0.00000060, val_loss: 0.00000017, val_NMSE: -33.02, lr: 0.005
# Epoch 0035 — train_loss: 0.00000060, val_loss: 0.00000007, val_NMSE: -37.04, lr: 0.005
# Epoch 0036 — train_loss: 0.00000060, val_loss: 0.00000007, val_NMSE: -36.64, lr: 0.005
# Epoch 0037 — train_loss: 0.00000060, val_loss: 0.00000005, val_NMSE: -38.17, lr: 0.005
# Epoch 0038 — train_loss: 0.00000059, val_loss: 0.00000005, val_NMSE: -38.04, lr: 0.005
# Epoch 0039 — train_loss: 0.00000059, val_loss: 0.00000006, val_NMSE: -37.41, lr: 0.005
# Epoch 0040 — train_loss: 0.00000059, val_loss: 0.00000009, val_NMSE: -35.57, lr: 0.005
# Epoch 0041 — train_loss: 0.00000059, val_loss: 0.00000007, val_NMSE: -36.81, lr: 0.005
# Epoch 0042 — train_loss: 0.00000059, val_loss: 0.00000006, val_NMSE: -37.55, lr: 0.005
# Epoch 0043 — train_loss: 0.00000059, val_loss: 0.00000005, val_NMSE: -38.02, lr: 0.005
# Epoch 0044 — train_loss: 0.00000059, val_loss: 0.00000009, val_NMSE: -35.69, lr: 0.005
# Epoch 0045 — train_loss: 0.00000059, val_loss: 0.00000007, val_NMSE: -36.56, lr: 0.005
# Epoch 0046 — train_loss: 0.00000059, val_loss: 0.00000006, val_NMSE: -37.78, lr: 0.005
# Epoch 0047 — train_loss: 0.00000059, val_loss: 0.00000007, val_NMSE: -36.98, lr: 0.005
# Epoch 0048 — train_loss: 0.00000059, val_loss: 0.00000006, val_NMSE: -37.86, lr: 0.0025
# Epoch 0049 — train_loss: 0.00000057, val_loss: 0.00000004, val_NMSE: -39.16, lr: 0.0025
# ===Training complete===
# Выполнение заняло: 0:01:56
# ========================================================================
# Layer-wise sparsity report
# ========================================================================
# lstm.weight_ih_l0         | nonzero:      250 /      256 (97.66%)
# lstm.weight_hh_l0         | nonzero:     3661 /     4096 (89.38%)
# lstm                     | LAYER TOTAL:     3911 /     4352 (89.87%)
# ------------------------------------------------------------------------
# fc_out.weight               | nonzero:       63 /       64 (98.44%)
# fc_out                   | LAYER TOTAL:       63 /       64 (98.44%)
# ------------------------------------------------------------------------
# ========================================================================
# MODEL TOTAL: nonzero 3974 / 4416 (89.99%)
# ========================================================================
# [ILC] [Finetune] NMSE: -40.71, ACPR: [-38.75087483 -36.81554234], nonzero_params: 3974
# [Amount 0.10] Run 2/3
# ===Start training===
# Epoch 0000 — train_loss: 0.00001642, val_loss: 0.00000147, val_NMSE: -23.61, lr: 0.01
# Epoch 0001 — train_loss: 0.00000272, val_loss: 0.00000143, val_NMSE: -23.72, lr: 0.01
# Epoch 0002 — train_loss: 0.00000269, val_loss: 0.00000143, val_NMSE: -23.71, lr: 0.01
# Epoch 0003 — train_loss: 0.00000267, val_loss: 0.00000137, val_NMSE: -23.89, lr: 0.01
# Epoch 0004 — train_loss: 0.00000268, val_loss: 0.00000143, val_NMSE: -23.71, lr: 0.01
# Epoch 0005 — train_loss: 0.00000268, val_loss: 0.00000139, val_NMSE: -23.84, lr: 0.01
# Epoch 0006 — train_loss: 0.00000268, val_loss: 0.00000135, val_NMSE: -23.98, lr: 0.01
# Epoch 0007 — train_loss: 0.00000267, val_loss: 0.00000139, val_NMSE: -23.84, lr: 0.01
# Epoch 0008 — train_loss: 0.00000266, val_loss: 0.00000135, val_NMSE: -23.96, lr: 0.01
# Epoch 0009 — train_loss: 0.00000263, val_loss: 0.00000135, val_NMSE: -23.96, lr: 0.01
# Epoch 0010 — train_loss: 0.00000247, val_loss: 0.00000117, val_NMSE: -24.58, lr: 0.01
# Epoch 0011 — train_loss: 0.00000215, val_loss: 0.00000084, val_NMSE: -26.01, lr: 0.01
# Epoch 0012 — train_loss: 0.00000178, val_loss: 0.00000066, val_NMSE: -27.10, lr: 0.01
# Epoch 0013 — train_loss: 0.00000146, val_loss: 0.00000038, val_NMSE: -29.48, lr: 0.01
# Epoch 0014 — train_loss: 0.00000123, val_loss: 0.00000032, val_NMSE: -30.20, lr: 0.01
# Epoch 0015 — train_loss: 0.00000111, val_loss: 0.00000030, val_NMSE: -30.55, lr: 0.01
# Epoch 0016 — train_loss: 0.00000103, val_loss: 0.00000017, val_NMSE: -32.92, lr: 0.01
# Epoch 0017 — train_loss: 0.00000099, val_loss: 0.00000017, val_NMSE: -33.04, lr: 0.01
# Epoch 0018 — train_loss: 0.00000095, val_loss: 0.00000019, val_NMSE: -32.38, lr: 0.01
# Epoch 0019 — train_loss: 0.00000092, val_loss: 0.00000012, val_NMSE: -34.34, lr: 0.01
# Epoch 0020 — train_loss: 0.00000090, val_loss: 0.00000014, val_NMSE: -33.87, lr: 0.01
# Epoch 0021 — train_loss: 0.00000088, val_loss: 0.00000010, val_NMSE: -35.18, lr: 0.01
# Epoch 0022 — train_loss: 0.00000086, val_loss: 0.00000014, val_NMSE: -33.90, lr: 0.01
# Epoch 0023 — train_loss: 0.00000085, val_loss: 0.00000011, val_NMSE: -34.71, lr: 0.01
# Epoch 0024 — train_loss: 0.00000084, val_loss: 0.00000026, val_NMSE: -31.05, lr: 0.01
# Epoch 0025 — train_loss: 0.00000082, val_loss: 0.00000010, val_NMSE: -35.15, lr: 0.01
# Epoch 0026 — train_loss: 0.00000080, val_loss: 0.00000027, val_NMSE: -31.03, lr: 0.01
# Epoch 0027 — train_loss: 0.00000080, val_loss: 0.00000013, val_NMSE: -34.05, lr: 0.01
# Epoch 0028 — train_loss: 0.00000079, val_loss: 0.00000046, val_NMSE: -28.62, lr: 0.01
# Epoch 0029 — train_loss: 0.00000078, val_loss: 0.00000010, val_NMSE: -35.39, lr: 0.01
# Epoch 0030 — train_loss: 0.00000077, val_loss: 0.00000010, val_NMSE: -35.12, lr: 0.01
# Epoch 0031 — train_loss: 0.00000076, val_loss: 0.00000010, val_NMSE: -35.47, lr: 0.01
# Epoch 0032 — train_loss: 0.00000075, val_loss: 0.00000012, val_NMSE: -34.52, lr: 0.01
# Epoch 0033 — train_loss: 0.00000074, val_loss: 0.00000011, val_NMSE: -34.78, lr: 0.01
# Epoch 0034 — train_loss: 0.00000074, val_loss: 0.00000027, val_NMSE: -30.91, lr: 0.01
# Epoch 0035 — train_loss: 0.00000074, val_loss: 0.00000023, val_NMSE: -31.60, lr: 0.01
# Epoch 0036 — train_loss: 0.00000072, val_loss: 0.00000010, val_NMSE: -35.22, lr: 0.01
# Epoch 0037 — train_loss: 0.00000071, val_loss: 0.00000011, val_NMSE: -34.78, lr: 0.01
# Epoch 0038 — train_loss: 0.00000071, val_loss: 0.00000016, val_NMSE: -33.34, lr: 0.01
# Epoch 0039 — train_loss: 0.00000071, val_loss: 0.00000008, val_NMSE: -36.43, lr: 0.01
# Epoch 0040 — train_loss: 0.00000070, val_loss: 0.00000008, val_NMSE: -36.06, lr: 0.01
# Epoch 0041 — train_loss: 0.00000070, val_loss: 0.00000015, val_NMSE: -33.44, lr: 0.01
# Epoch 0042 — train_loss: 0.00000069, val_loss: 0.00000013, val_NMSE: -34.12, lr: 0.01
# Epoch 0043 — train_loss: 0.00000069, val_loss: 0.00000009, val_NMSE: -35.62, lr: 0.01
# Epoch 0044 — train_loss: 0.00000068, val_loss: 0.00000007, val_NMSE: -36.69, lr: 0.01
# Epoch 0045 — train_loss: 0.00000069, val_loss: 0.00000013, val_NMSE: -34.02, lr: 0.01
# Epoch 0046 — train_loss: 0.00000067, val_loss: 0.00000015, val_NMSE: -33.61, lr: 0.01
# Epoch 0047 — train_loss: 0.00000067, val_loss: 0.00000009, val_NMSE: -35.64, lr: 0.01
# Epoch 0048 — train_loss: 0.00000067, val_loss: 0.00000013, val_NMSE: -34.05, lr: 0.01
# Epoch 0049 — train_loss: 0.00000066, val_loss: 0.00000008, val_NMSE: -36.23, lr: 0.01
# ===Training complete===
# Выполнение заняло: 0:01:54
# [ILC] [Base] NMSE: -37.47, ACPR: [-38.67077348 -36.74427686], nonzero_params: 4416
# ========================================================================
# Layer-wise sparsity report
# ========================================================================
# lstm.weight_ih_l0_orig    | nonzero:      256 /      256 (100.00%)
# lstm.weight_hh_l0_orig    | nonzero:     4096 /     4096 (100.00%)
# ...
# Epoch 0000 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.01
# Epoch 0001 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.01
# Epoch 0002 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.01
# Epoch 0003 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.005
# Epoch 0004 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.005
# Epoch 0005 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.005
# Epoch 0006 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.005
# Epoch 0007 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.005
# Epoch 0008 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.005
# Epoch 0009 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.005
# Epoch 0010 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.005
# Epoch 0011 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.005
# Epoch 0012 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.005
# Epoch 0013 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.005
# Epoch 0014 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.0025
# Epoch 0015 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.0025
# Epoch 0016 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.0025
# Epoch 0017 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.0025
# Epoch 0018 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.0025
# Epoch 0019 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.0025
# Epoch 0020 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.0025
# Epoch 0021 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.0025
# Epoch 0022 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.0025
# Epoch 0023 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.0025
# Epoch 0024 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.0025
# Epoch 0025 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.00125
# Epoch 0026 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.00125
# Epoch 0027 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.00125
# Epoch 0028 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.00125
# Epoch 0029 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.00125
# Epoch 0030 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.00125
# Epoch 0031 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.00125
# Epoch 0032 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.00125
# Epoch 0033 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.00125
# Epoch 0034 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.00125
# Epoch 0035 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.00125
# Epoch 0036 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.000625
# Epoch 0037 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.000625
# Epoch 0038 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.000625
# Epoch 0039 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.000625
# Epoch 0040 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.000625
# Epoch 0041 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.000625
# Epoch 0042 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.000625
# Epoch 0043 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.000625
# Epoch 0044 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.000625
# Epoch 0045 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.000625
# Epoch 0046 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.000625
# Epoch 0047 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.0003125
# Epoch 0048 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.0003125
# Epoch 0049 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.0003125
# ===Training complete===
# Выполнение заняло: 0:01:42
# ========================================================================
# Layer-wise sparsity report
# ========================================================================
# lstm.weight_ih_l0         | nonzero:       88 /      256 (34.38%)
# lstm.weight_hh_l0         | nonzero:      354 /     4096 ( 8.64%)
# lstm                     | LAYER TOTAL:      442 /     4352 (10.16%)
# ------------------------------------------------------------------------
# fc_out.weight               | nonzero:        0 /       64 ( 0.00%)
# fc_out                   | LAYER TOTAL:        0 /       64 ( 0.00%)
# ------------------------------------------------------------------------
# ========================================================================
# MODEL TOTAL: nonzero 442 / 4416 (10.01%)
# ========================================================================
# [ILC] [Finetune] NMSE: 0.00, ACPR: [nan nan], nonzero_params: 442
# [Amount 0.90] Run 3/3
# ===Start training===
# Epoch 0000 — train_loss: 0.00001649, val_loss: 0.00000145, val_NMSE: -23.67, lr: 0.01
# Epoch 0001 — train_loss: 0.00000273, val_loss: 0.00000148, val_NMSE: -23.58, lr: 0.01
# Epoch 0002 — train_loss: 0.00000270, val_loss: 0.00000155, val_NMSE: -23.38, lr: 0.01
# Epoch 0003 — train_loss: 0.00000268, val_loss: 0.00000138, val_NMSE: -23.87, lr: 0.01
# Epoch 0004 — train_loss: 0.00000268, val_loss: 0.00000140, val_NMSE: -23.81, lr: 0.01
# Epoch 0005 — train_loss: 0.00000268, val_loss: 0.00000142, val_NMSE: -23.76, lr: 0.01
# Epoch 0006 — train_loss: 0.00000267, val_loss: 0.00000135, val_NMSE: -23.97, lr: 0.01
# Epoch 0007 — train_loss: 0.00000268, val_loss: 0.00000136, val_NMSE: -23.95, lr: 0.01
# Epoch 0008 — train_loss: 0.00000268, val_loss: 0.00000140, val_NMSE: -23.83, lr: 0.01
# Epoch 0009 — train_loss: 0.00000267, val_loss: 0.00000146, val_NMSE: -23.64, lr: 0.01
# Epoch 0010 — train_loss: 0.00000266, val_loss: 0.00000137, val_NMSE: -23.89, lr: 0.01
# Epoch 0011 — train_loss: 0.00000265, val_loss: 0.00000138, val_NMSE: -23.89, lr: 0.01
# Epoch 0012 — train_loss: 0.00000246, val_loss: 0.00000124, val_NMSE: -24.33, lr: 0.01
# Epoch 0013 — train_loss: 0.00000214, val_loss: 0.00000095, val_NMSE: -25.49, lr: 0.01
# Epoch 0014 — train_loss: 0.00000176, val_loss: 0.00000065, val_NMSE: -27.12, lr: 0.01
# Epoch 0015 — train_loss: 0.00000143, val_loss: 0.00000059, val_NMSE: -27.54, lr: 0.01
# Epoch 0016 — train_loss: 0.00000122, val_loss: 0.00000042, val_NMSE: -29.06, lr: 0.01
# Epoch 0017 — train_loss: 0.00000109, val_loss: 0.00000021, val_NMSE: -32.08, lr: 0.01
# Epoch 0018 — train_loss: 0.00000102, val_loss: 0.00000026, val_NMSE: -31.09, lr: 0.01
# Epoch 0019 — train_loss: 0.00000098, val_loss: 0.00000018, val_NMSE: -32.72, lr: 0.01
# Epoch 0020 — train_loss: 0.00000095, val_loss: 0.00000017, val_NMSE: -32.99, lr: 0.01
# Epoch 0021 — train_loss: 0.00000092, val_loss: 0.00000018, val_NMSE: -32.68, lr: 0.01
# Epoch 0022 — train_loss: 0.00000090, val_loss: 0.00000015, val_NMSE: -33.56, lr: 0.01
# Epoch 0023 — train_loss: 0.00000089, val_loss: 0.00000015, val_NMSE: -33.62, lr: 0.01
# Epoch 0024 — train_loss: 0.00000087, val_loss: 0.00000017, val_NMSE: -33.03, lr: 0.01
# Epoch 0025 — train_loss: 0.00000086, val_loss: 0.00000014, val_NMSE: -33.85, lr: 0.01
# Epoch 0026 — train_loss: 0.00000084, val_loss: 0.00000018, val_NMSE: -32.64, lr: 0.01
# Epoch 0027 — train_loss: 0.00000084, val_loss: 0.00000012, val_NMSE: -34.43, lr: 0.01
# Epoch 0028 — train_loss: 0.00000082, val_loss: 0.00000011, val_NMSE: -34.73, lr: 0.01
# Epoch 0029 — train_loss: 0.00000081, val_loss: 0.00000015, val_NMSE: -33.62, lr: 0.01
# Epoch 0030 — train_loss: 0.00000080, val_loss: 0.00000027, val_NMSE: -30.99, lr: 0.01
# Epoch 0031 — train_loss: 0.00000079, val_loss: 0.00000020, val_NMSE: -32.24, lr: 0.01
# Epoch 0032 — train_loss: 0.00000079, val_loss: 0.00000014, val_NMSE: -33.81, lr: 0.01
# Epoch 0033 — train_loss: 0.00000078, val_loss: 0.00000012, val_NMSE: -34.31, lr: 0.01
# Epoch 0034 — train_loss: 0.00000077, val_loss: 0.00000011, val_NMSE: -34.92, lr: 0.01
# Epoch 0035 — train_loss: 0.00000077, val_loss: 0.00000015, val_NMSE: -33.37, lr: 0.01
# Epoch 0036 — train_loss: 0.00000075, val_loss: 0.00000013, val_NMSE: -34.01, lr: 0.01
# Epoch 0037 — train_loss: 0.00000075, val_loss: 0.00000012, val_NMSE: -34.48, lr: 0.01
# Epoch 0038 — train_loss: 0.00000074, val_loss: 0.00000018, val_NMSE: -32.73, lr: 0.01
# Epoch 0039 — train_loss: 0.00000074, val_loss: 0.00000009, val_NMSE: -35.66, lr: 0.01
# Epoch 0040 — train_loss: 0.00000075, val_loss: 0.00000020, val_NMSE: -32.36, lr: 0.01
# Epoch 0041 — train_loss: 0.00000072, val_loss: 0.00000018, val_NMSE: -32.76, lr: 0.01
# Epoch 0042 — train_loss: 0.00000073, val_loss: 0.00000009, val_NMSE: -35.92, lr: 0.01
# Epoch 0043 — train_loss: 0.00000072, val_loss: 0.00000010, val_NMSE: -35.19, lr: 0.01
# Epoch 0044 — train_loss: 0.00000072, val_loss: 0.00000010, val_NMSE: -35.21, lr: 0.01
# Epoch 0045 — train_loss: 0.00000072, val_loss: 0.00000012, val_NMSE: -34.34, lr: 0.01
# Epoch 0046 — train_loss: 0.00000072, val_loss: 0.00000013, val_NMSE: -34.01, lr: 0.01
# Epoch 0047 — train_loss: 0.00000071, val_loss: 0.00000015, val_NMSE: -33.54, lr: 0.01
# Epoch 0048 — train_loss: 0.00000070, val_loss: 0.00000011, val_NMSE: -35.02, lr: 0.01
# Epoch 0049 — train_loss: 0.00000071, val_loss: 0.00000009, val_NMSE: -35.68, lr: 0.01
# ===Training complete===
# Выполнение заняло: 0:01:39
# [ILC] [Base] NMSE: -37.00, ACPR: [-38.40821686 -36.67783302], nonzero_params: 4416
# ========================================================================
# Layer-wise sparsity report
# ========================================================================
# lstm.weight_ih_l0_orig    | nonzero:      256 /      256 (100.00%)
# lstm.weight_hh_l0_orig    | nonzero:     4096 /     4096 (100.00%)
# lstm                     | LAYER TOTAL:     4352 /     4352 (100.00%)
# ------------------------------------------------------------------------
# fc_out.weight_orig          | nonzero:       64 /       64 (100.00%)
# fc_out                   | LAYER TOTAL:       64 /       64 (100.00%)
# ------------------------------------------------------------------------
# ========================================================================
# MODEL TOTAL: nonzero 4416 / 4416 (100.00%)
# ========================================================================
# [ILC] [Prune] NMSE: 0.00, ACPR: [nan nan], nonzero_params: 4416
# ===Start training===
# Epoch 0000 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.01
# Epoch 0001 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.01
# Epoch 0002 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.01
# Epoch 0003 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.005
# Epoch 0004 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.005
# Epoch 0005 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.005
# Epoch 0006 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.005
# Epoch 0007 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.005
# Epoch 0008 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.005
# Epoch 0009 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.005
# Epoch 0010 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.005
# Epoch 0011 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.005
# Epoch 0012 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.005
# Epoch 0013 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.005
# Epoch 0014 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.0025
# Epoch 0015 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.0025
# Epoch 0016 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.0025
# Epoch 0017 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.0025
# Epoch 0018 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.0025
# Epoch 0019 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.0025
# Epoch 0020 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.0025
# Epoch 0021 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.0025
# Epoch 0022 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.0025
# Epoch 0023 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.0025
# Epoch 0024 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.0025
# Epoch 0025 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.00125
# Epoch 0026 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.00125
# Epoch 0027 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.00125
# Epoch 0028 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.00125
# Epoch 0029 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.00125
# Epoch 0030 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.00125
# Epoch 0031 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.00125
# Epoch 0032 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.00125
# Epoch 0033 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.00125
# Epoch 0034 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.00125
# Epoch 0035 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.00125
# Epoch 0036 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.000625
# Epoch 0037 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.000625
# Epoch 0038 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.000625
# Epoch 0039 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.000625
# Epoch 0040 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.000625
# Epoch 0041 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.000625
# Epoch 0042 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.000625
# Epoch 0043 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.000625
# Epoch 0044 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.000625
# Epoch 0045 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.000625
# Epoch 0046 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.000625
# Epoch 0047 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.0003125
# Epoch 0048 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.0003125
# Epoch 0049 — train_loss: 0.00036889, val_loss: 0.00033681, val_NMSE: 0.00, lr: 0.0003125
# ===Training complete===
# Выполнение заняло: 0:01:41
# ========================================================================
# Layer-wise sparsity report
# ========================================================================
# lstm.weight_ih_l0         | nonzero:       99 /      256 (38.67%)
# lstm.weight_hh_l0         | nonzero:      343 /     4096 ( 8.37%)
# lstm                     | LAYER TOTAL:      442 /     4352 (10.16%)
# ------------------------------------------------------------------------
# fc_out.weight               | nonzero:        0 /       64 ( 0.00%)
# fc_out                   | LAYER TOTAL:        0 /       64 ( 0.00%)
# ------------------------------------------------------------------------
# ========================================================================
# MODEL TOTAL: nonzero 442 / 4416 (10.01%)
# ========================================================================
# [ILC] [Finetune] NMSE: 0.00, ACPR: [nan nan], nonzero_params: 442

# %%
signals_list = []
nmse_list = []
acpr_list = []
count_params_list = []

res = lstm_pipeline.get_results()
ilc_res = res['ilc']

for i in amount_range:
    current = ilc_res[i]
    
    signals_list.append(current['y_val_ilc_finetune'])
    nmse_list.append(current['nmse_finetune'])
    acpr_list.append(current['acpr_finetune'].mean())
    count_params_list.append(current['nonzero_params_finetune'])


# figsize=(12, 6)
plt.figure()
plt.plot(amount_range, nmse_list, label='amount vs nmse')
plt.xlabel('amount')
plt.ylabel('nmse')
plt.xticks(amount_range)
plt.legend()
plt.grid()
plt.show()

plt.figure()
plt.plot(amount_range, acpr_list, label='amount vs acpr')
plt.xlabel('amount')
plt.ylabel('mean acpr')
plt.xticks(amount_range)
plt.legend()
plt.grid()
plt.show()

# %%
window_size = 30

freqs, spectrum_x_val = metrics.power_spectrum(container.val_input, container.input_signal_fs, container.nperseg, window_size)
_, spectrum_y_val = metrics.power_spectrum(container.val_output, container.input_signal_fs, container.nperseg, window_size)

_, spectrum_y_val_pa = metrics.power_spectrum(y_val_pa, container.input_signal_fs, container.nperseg, window_size)
_, spectrum_y_val_ilc_base = metrics.power_spectrum(y_val_ilc_base, container.input_signal_fs, container.nperseg, window_size)
_, spectrum_y_val_ilc_prune = metrics.power_spectrum(y_val_ilc_prune, container.input_signal_fs, container.nperseg, window_size)
_, spectrum_y_val_ilc_finetune = metrics.power_spectrum(y_val_ilc_finetune, container.input_signal_fs, container.nperseg, window_size)
_, spectrum_y_val_target = metrics.power_spectrum(container.val_output_target, container.input_signal_fs, container.nperseg, window_size)
_, spectrum_u_k_pa = metrics.power_spectrum(u_k_pa, container.input_signal_fs, container.nperseg, window_size)
# _, spectrum_u_k = metrics.power_spectrum(u_k_train, container.input_signal_fs, container.nperseg, window_size)


xlabel="Частота (МГц)"
ylabel= "Спектральная плотность мощности (дБ)"
fontsize = 12
figsize=(12, 6)

plt.figure(figsize=figsize)

plt.plot(freqs / 1e6, spectrum_x_val, color='grey', label='Входной сигнал')
# plt.plot(freqs / 1e6, spectrum_y_val, color='black', label='Выходной сигнал')
plt.plot(freqs / 1e6, spectrum_y_val_pa, color='gold', label='Выходной сигнал PA')
plt.plot(freqs / 1e6, spectrum_y_val_ilc_base, color='springgreen', label='(LSTM base) Сигнал с \nпредыскажением ILC')
plt.plot(freqs / 1e6, spectrum_y_val_ilc_prune, color='lightcoral', label='(LSTM prune) Сигнал с \nпредыскажением ILC')
plt.plot(freqs / 1e6, spectrum_y_val_ilc_finetune, color='violet', label='(LSTM finetune) Сигнал с \nпредыскажением ILC')

# plt.plot(freqs / 1e6, spectrum_u_k, color='magenta', label='spectrum_u_k')
plt.plot(freqs / 1e6, spectrum_u_k_pa, color='red', label='Оптимальный сигнал ILC')


plt.xlabel(xlabel, fontsize=fontsize)
plt.ylabel(ylabel, fontsize=fontsize)
plt.legend()
plt.ylim(bottom=-170)
plt.xticks(np.arange(-500, 600, 100))
plt.grid()
plt.show()

# %% [markdown]
# Metrics

# %%
nmse_after_pa = metrics.compute_nmse(y_val_pa, y_val_target)

print(f"NMSE на выходе усилителя (без DPD): {nmse_after_pa:.2f} db")
print(f"NMSE на выходе усилителя (DLA DPD): {gru_dla_nmse:.2f} db")
print(f"NMSE на выходе усилителя (ILA DPD): {gru_ila_nmse:.2f} db")
print(f"NMSE на выходе усилителя (ILC DPD): {gru_ilc_nmse:.2f} db")
# Out:
# NMSE на выходе усилителя (без DPD): -14.19 db
# NMSE на выходе усилителя (DLA DPD): -41.53 db
# NMSE на выходе усилителя (ILA DPD): -40.11 db
# NMSE на выходе усилителя (ILC DPD): -42.04 db

# %%
x_val_acpr = metrics.calculate_acpr(x_val, acpr_meter)
y_val_acpr = metrics.calculate_acpr(y_val, acpr_meter)
y_val_pa_acpr = metrics.calculate_acpr(y_val_pa, acpr_meter)
y_val_target_acpr = metrics.calculate_acpr(y_val_target, acpr_meter)

y_lin_dla_acpr = metrics.calculate_acpr(y_val_gru_dla, acpr_meter)
y_lin_ila_acpr = metrics.calculate_acpr(y_val_gru_ila, acpr_meter)
y_lin_ilc_acpr = metrics.calculate_acpr(y_val_gru_ilc, acpr_meter)

print(f"x_val_acpr: {x_val_acpr}")
print(f"y_val_acpr: {y_val_acpr}")
print(f"y_val_pa_acpr: {y_val_pa_acpr}")
print(f"y_val_target_acpr: {y_val_target_acpr}")

print(f"lin_dla_acpr: {y_lin_dla_acpr}")
print(f"lin_ila_acpr: {y_lin_ila_acpr}")
print(f"lin_ilc_acpr: {y_lin_ilc_acpr}")
# Out:
# x_val_acpr: [-48.08083195 -48.40122574]
# y_val_acpr: [-40.60778184 -38.20237847]
# y_val_pa_acpr: [-43.00702386 -41.82281169]
# y_val_target_acpr: [-48.08083304 -48.40122404]
# lin_dla_acpr: [-46.11408473 -46.21505539]
# lin_ila_acpr: [-46.34155705 -46.7854869 ]
# lin_ilc_acpr: [-45.85540157 -46.60117848]

# %%
nmse_uk_pa = metrics.compute_nmse(u_k_pa, y_train_target)
print(f"NMSE на выходе усилителя (ILC): {nmse_uk_pa:.2f} db")

u_k_acpr = metrics.calculate_acpr(u_k_train, acpr_meter)
u_k_pa_acpr = metrics.calculate_acpr(u_k_pa, acpr_meter)

print(f"u_k_acpr: {u_k_acpr}")
print(f"u_k_pa_acpr: {u_k_pa_acpr}")
# Out:
# NMSE на выходе усилителя (ILC): -108.53 db
# u_k_acpr: [-43.85630619 -43.42479372]
# u_k_pa_acpr: [-50.93607041 -50.36966328]

# %% [markdown]
# Spectrum

# %%
window_size = 60

freqs, spectrum_x_val = metrics.power_spectrum(x_val, fs, nperseg, window_size)
_, spectrum_y_val = metrics.power_spectrum(y_val, fs, nperseg, window_size)
_, spectrum_y_val_gru_pa = metrics.power_spectrum(y_val_pa, fs, nperseg, window_size)
_, spectrum_y_val_target = metrics.power_spectrum(y_val_target, fs, nperseg, window_size)

_, spectrum_y_val_gru_dla = metrics.power_spectrum(y_val_gru_dla, fs, nperseg, window_size)
_, spectrum_y_val_gru_ila = metrics.power_spectrum(y_val_gru_ila, fs, nperseg, window_size)
_, spectrum_y_val_gru_ilc = metrics.power_spectrum(y_val_gru_ilc, fs, nperseg, window_size)

_, spectrum_u_k = metrics.power_spectrum(u_k_train, fs, nperseg, window_size)
_, spectrum_u_k_pa = metrics.power_spectrum(u_k_pa, fs, nperseg, window_size)

# %%
# построение спектра

xlabel="Частота (МГц)"
ylabel= "Спектральная плотность мощности (дБ)"
fontsize = 12
figsize=(12, 6)

plt.figure(figsize=figsize)

plt.plot(freqs / 1e6, spectrum_x_val, color='grey', label='Входной сигнал')
plt.plot(freqs / 1e6, spectrum_y_val_gru_pa, color='gold', label='Выходной сигнал модели PA')
plt.plot(freqs / 1e6, spectrum_u_k_pa, color='red', label='Оптимальный сигнал ILC')
plt.plot(freqs / 1e6, spectrum_y_val_gru_dla, color='darkorange', label='Сигнал с предыскажением DLA')
plt.plot(freqs / 1e6, spectrum_y_val_gru_ila, color='limegreen', label='Сигнал с предыскажением ILA')
plt.plot(freqs / 1e6, spectrum_y_val_gru_ilc, color='lightcoral', label='Сигнал с предыскажением ILC')


plt.xlabel(xlabel, fontsize=fontsize)
plt.ylabel(ylabel, fontsize=fontsize)
plt.legend()
plt.grid()
plt.show()

# %%
# moving_average
window_size = 100

freqs_s, spectrum_x_val_s = utils.moving_average(spectrum_x_val, freqs, fs, window_size)
_, spectrum_y_val_s = utils.moving_average(spectrum_y_val, freqs, fs, window_size)
_, spectrum_y_val_gru_pa_s = utils.moving_average(spectrum_y_val_gru_pa, freqs, fs, window_size)
_, spectrum_y_val_target_s = utils.moving_average(spectrum_y_val_target, freqs, fs, window_size)

# _, spectrum_y_val_gru_dla_s = utils.moving_average(spectrum_y_val_gru_dla, freqs, fs, window_size)
# _, spectrum_y_val_gru_ila_s = utils.moving_average(spectrum_y_val_gru_ila, freqs, fs, window_size)
# _, spectrum_y_val_gru_ilc_s = utils.moving_average(spectrum_y_val_gru_ilc, freqs, fs, window_size)

_, spectrum_y_val_gru_dla_s = utils.moving_average(spectrum_y_val_gru_dla, freqs, fs, window_size)
_, spectrum_y_val_gru_ila_s = utils.moving_average(spectrum_y_val_gru_ila, freqs, fs, window_size)
_, spectrum_y_val_gru_ilc_s = utils.moving_average(spectrum_y_val_gru_ilc, freqs, fs, window_size)

_, spectrum_u_k_s = utils.moving_average(spectrum_u_k, freqs, fs, window_size)
_, spectrum_u_k_pa_s = utils.moving_average(spectrum_u_k_pa, freqs, fs, window_size)

# %%
# (сглаженный) построение спектра

xlabel="Частота, МГц"
ylabel= "Спектральная плотность мощности, дБВт/Гц"
fontsize = 12
figsize=(12, 8)
markersize=8

plt.figure(figsize=figsize)

# plt.plot(freqs_s / 1e6, 10 * np.log10(np.abs(spectrum_x_val_s)), 
#          color='grey', label='Входной сигнал',marker = '*', markevery=90, markersize=markersize)
plt.plot(freqs_s / 1e6, 10 * np.log10(np.abs(spectrum_y_val_target_s)), 
         color='black', label='Выходной сигнал\n(линейный усилитель)',marker = '*', markevery=90, markersize=markersize)
plt.plot(freqs_s / 1e6, 10 * np.log10(np.abs(spectrum_y_val_gru_pa_s)), 
         color='gold', label='Выходной сигнал\n(реальный усилитель)', marker='o', markevery=90, markersize=markersize)
plt.plot(freqs_s / 1e6, 10 * np.log10(np.abs(spectrum_u_k_pa_s)), 
         color='red', label='Оптимальный сигнал ILC', marker='v', markevery=95, markersize=markersize)
plt.plot(freqs_s / 1e6, 10 * np.log10(np.abs(spectrum_y_val_gru_dla_s)), 
         color='darkorange', label='Сигнал с предыскажением DLA', marker='D', markevery=90, markersize=markersize)
plt.plot(freqs_s / 1e6, 10 * np.log10(np.abs(spectrum_y_val_gru_ila_s)), 
         color='limegreen', label='Сигнал с предыскажением ILA', marker='X', markevery=110, markersize=markersize)
plt.plot(freqs_s / 1e6, 10 * np.log10(np.abs(spectrum_y_val_gru_ilc_s)), 
         color='lightcoral', label='Сигнал с предыскажением ILC', marker='s', markevery=120, markersize=markersize)

plt.xlabel(xlabel, fontsize=fontsize)
plt.ylabel(ylabel, fontsize=fontsize)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# AM/AM & AM/PM

# %%
y_in_am_am, y_out_am_am = metrics.calculate_am_am(x_val, y_val)
y_in_am_pm, y_in_phase_am_pm = metrics.calculate_am_pm(x_val, y_val)

_, y_pa_am_am = metrics.calculate_am_am(x_val, y_val_gru_pa)
_, y_pa_phase_am_pm = metrics.calculate_am_pm(x_val, y_val_gru_pa)

_, y_val_target_am_am = metrics.calculate_am_am(x_val, y_val_target)
_, y_val_target_phase_am_pm = metrics.calculate_am_pm(x_val, y_val_target)

# x_in_am_am, u_k_am_am = metrics.calculate_am_am(x_in_tensor, u_k)
# x_in_am_pm, u_k_phase_am_pm = metrics.calculate_am_pm(x_in_tensor, u_k)

# _, u_k_pa_am_am = metrics.calculate_am_am(x_in_tensor, u_k_pa)
# _, u_k_pa_phase_am_pm = metrics.calculate_am_pm(x_in_tensor, u_k_pa)

# dpd
# _, y_val_gru_dla_am_am = metrics.calculate_am_am(x_val, y_val_gru_dla)
# _, y_val_gru_dla_phase_am_pm = metrics.calculate_am_pm(x_val, y_val_gru_dla)

# _, y_val_gru_ila_am_am = metrics.calculate_am_am(x_val, y_val_gru_ila)
# _, y_val_gru_ila_phase_am_pm = metrics.calculate_am_pm(x_val, y_val_gru_ila)

# _, y_val_gru_ilc_am_am = metrics.calculate_am_am(x_val, y_val_gru_ilc)
# _, y_val_gru_ilc_phase_am_pm = metrics.calculate_am_pm(x_val, y_val_gru_ilc)

#linearized
_, y_val_gru_dla_am_am = metrics.calculate_am_am(x_val, y_val_gru_dla)
_, y_val_gru_dla_phase_am_pm = metrics.calculate_am_pm(x_val, y_val_gru_dla)

_, y_val_gru_ila_am_am = metrics.calculate_am_am(x_val, y_val_gru_ila)
_, y_val_gru_ila_phase_am_pm = metrics.calculate_am_pm(x_val, y_val_gru_ila)

_, y_val_gru_ilc_am_am = metrics.calculate_am_am(x_val, y_val_gru_ilc)
_, y_val_gru_ilc_phase_am_pm = metrics.calculate_am_pm(x_val, y_val_gru_ilc)

# %%
#DLA

am_am_data = [
    (y_in_am_am, y_pa_am_am, 'gold', 'Выходной сигнал'),
    # (y_in_am_am, y_val_gru_dla_am_am, 'magenta', 'Сигнал на выходе DPD'),
    (y_in_am_am, y_val_gru_dla_am_am, 'darkorange', 'Сигнал с предыскажением'),
]

am_pm_data = [
    (y_in_am_pm, y_pa_phase_am_pm, 'gold', 'Выходной сигнал'),
    (y_in_am_pm, y_val_gru_dla_phase_am_pm, 'darkorange', 'Сигнал с предыскажением'),
]

plotting.plot_am_am_pm(
    am_am_data=am_am_data,
    am_pm_data=am_pm_data,
    figsize=(12, 6),
    titles=("AM/AM DLA", "AM/PM DLA"),
    xlabels=("Амплитуда на входе", "Амплитуда на входе"),
    ylabels=("Амплитуда на выходе", "Фазовый сдвиг на выходе (градусы)")
)

# %%
#ILA

am_am_data = [
    (y_in_am_am, y_pa_am_am, 'gold', 'Выходной сигнал'),
    # (y_in_am_am, y_val_gru_ila_am_am, 'magenta', 'Сигнал на выходе DPD'),
    (y_in_am_am, y_val_gru_ila_am_am, 'darkorange', 'Сигнал с предыскажением'),
]

am_pm_data = [
    (y_in_am_pm, y_pa_phase_am_pm, 'gold', 'Выходной сигнал'),
    (y_in_am_pm, y_val_gru_ila_phase_am_pm, 'darkorange', 'Сигнал с предыскажением'),
]

plotting.plot_am_am_pm(
    am_am_data=am_am_data,
    am_pm_data=am_pm_data,
    figsize=(12, 6),
    titles=("AM/AM ILA", "AM/PM ILA"),
    xlabels=("Амплитуда на входе", "Амплитуда на входе"),
    ylabels=("Амплитуда на выходе", "Фазовый сдвиг на выходе (градусы)")
)

# %%
#ILC

am_am_data = [
    (y_in_am_am, y_pa_am_am, 'gold', 'Выходной сигнал'),
    # (y_in_am_am, y_val_gru_ilc_am_am, 'magenta', 'Сигнал на выходе корректора'),
    (y_in_am_am, y_val_gru_ilc_am_am, 'darkorange', 'Сигнал с предыскажением'),
]

am_pm_data = [
    (y_in_am_pm, y_pa_phase_am_pm, 'gold', 'Выходной сигнал'),
    (y_in_am_pm, y_val_gru_ilc_phase_am_pm, 'darkorange', 'Сигнал с предыскажением'),
]

plotting.plot_am_am_pm(
    am_am_data=am_am_data,
    am_pm_data=am_pm_data,
    figsize=(12, 6),
    titles=("AM/AM ILC", "AM/PM ILC"),
    xlabels=("Амплитуда на входе", "Амплитуда на входе"),
    ylabels=("Амплитуда на выходе", "Фазовый сдвиг на выходе (градусы)")
)

# %% [markdown]
# Add noise

# %%
snr_range = list(range(20, 61, 5))

epochs = 100
lr = 0.001
num_realizations = 200

hidden_size=8
num_layers=1


snr_params = params.make_snr_params(
    snr_range=snr_range,
    num_realizations=num_realizations,
    fs=fs,
    bw_main_ch=bw_main_ch,
    epochs=epochs,
    learning_rate=lr,
    acpr_meter=acpr_meter,
    pa_model=gru_pa,
    gain=gain
)

nn_params = {
    "hidden_size": hidden_size,
    "num_layers": num_layers
}

snr_metrics_runner = pipelines.SnrPipeline(base_model=GRU, 
                                           input_model_params=nn_params, 
                                           data_dict=data, 
                                           snr_params=snr_params)

# %%
snr_metrics_runner.run_dla_noise()
# Out:
# SNR: 20
# ===Start training===
# Epoch 0000 — train_loss: 0.079289, val_loss: 0.016323, val_NMSE: -16.79
# Epoch 0049 — train_loss: 0.014882, val_loss: 0.014754, val_NMSE: -17.23
# Время обучения: 0:01:28
# ===Training complete===
# SNR: 25
# ===Start training===
# Epoch 0000 — train_loss: 0.098993, val_loss: 0.005751, val_NMSE: -21.32
# Epoch 0049 — train_loss: 0.004938, val_loss: 0.005057, val_NMSE: -21.88
# Время обучения: 0:01:29
# ===Training complete===
# SNR: 30
# ===Start training===
# Epoch 0000 — train_loss: 0.070503, val_loss: 0.002585, val_NMSE: -24.80
# Epoch 0049 — train_loss: 0.001667, val_loss: 0.001624, val_NMSE: -26.82
# Время обучения: 0:01:28
# ===Training complete===
# SNR: 35
# ===Start training===
# Epoch 0000 — train_loss: 0.103375, val_loss: 0.002465, val_NMSE: -25.00
# Epoch 0049 — train_loss: 0.000583, val_loss: 0.000549, val_NMSE: -31.53
# Время обучения: 0:01:27
# ===Training complete===
# SNR: 40
# ===Start training===
# Epoch 0000 — train_loss: 0.074668, val_loss: 0.001108, val_NMSE: -28.47
# Epoch 0049 — train_loss: 0.000233, val_loss: 0.000216, val_NMSE: -35.58
# Время обучения: 0:01:26
# ===Training complete===
# SNR: 45
# ===Start training===
# Epoch 0000 — train_loss: 0.099892, val_loss: 0.001489, val_NMSE: -27.19
# Epoch 0049 — train_loss: 0.000140, val_loss: 0.000107, val_NMSE: -38.65
# Время обучения: 0:01:26
# ===Training complete===
# SNR: 50
# ===Start training===
# Epoch 0000 — train_loss: 0.088426, val_loss: 0.001357, val_NMSE: -27.60
# Epoch 0049 — train_loss: 0.000150, val_loss: 0.000096, val_NMSE: -39.10
# Время обучения: 0:01:27
# ===Training complete===
# SNR: 55
# ===Start training===
# Epoch 0000 — train_loss: 0.109540, val_loss: 0.001204, val_NMSE: -28.12
# Epoch 0049 — train_loss: 0.000113, val_loss: 0.000106, val_NMSE: -38.65
# Время обучения: 0:01:26
# ===Training complete===
# SNR: 60
# ===Start training===
# Epoch 0000 — train_loss: 0.064650, val_loss: 0.000958, val_NMSE: -29.11
# Epoch 0049 — train_loss: 0.000095, val_loss: 0.000062, val_NMSE: -41.01
# Время обучения: 0:01:28
# ===Training complete===

# %%
snr_metrics_runner.run_ila_noise()
# Out:
# SNR: 20
# ===Start training===
# Epoch 0000 — train_loss: 0.016766, val_loss: 0.002250, val_NMSE: -17.37
# Epoch 0049 — train_loss: 0.001898, val_loss: 0.001839, val_NMSE: -18.24
# Время обучения: 0:01:08
# ===Training complete===
# SNR: 25
# ===Start training===
# Epoch 0000 — train_loss: 0.014179, val_loss: 0.000916, val_NMSE: -21.27
# Epoch 0049 — train_loss: 0.000684, val_loss: 0.000642, val_NMSE: -22.81
# Время обучения: 0:01:08
# ===Training complete===
# SNR: 30
# ===Start training===
# Epoch 0000 — train_loss: 0.016422, val_loss: 0.000622, val_NMSE: -22.96
# Epoch 0049 — train_loss: 0.000252, val_loss: 0.000237, val_NMSE: -27.15
# Время обучения: 0:01:08
# ===Training complete===
# SNR: 35
# ===Start training===
# Epoch 0000 — train_loss: 0.020940, val_loss: 0.000851, val_NMSE: -21.59
# Epoch 0049 — train_loss: 0.000104, val_loss: 0.000087, val_NMSE: -31.50
# Время обучения: 0:01:08
# ===Training complete===
# SNR: 40
# ===Start training===
# Epoch 0000 — train_loss: 0.026843, val_loss: 0.000824, val_NMSE: -21.73
# Epoch 0049 — train_loss: 0.000046, val_loss: 0.000037, val_NMSE: -35.25
# Время обучения: 0:01:08
# ===Training complete===
# SNR: 45
# ===Start training===
# Epoch 0000 — train_loss: 0.034027, val_loss: 0.000642, val_NMSE: -22.82
# Epoch 0049 — train_loss: 0.000039, val_loss: 0.000045, val_NMSE: -34.36
# Время обучения: 0:01:08
# ===Training complete===
# SNR: 50
# ===Start training===
# Epoch 0000 — train_loss: 0.014051, val_loss: 0.000291, val_NMSE: -26.26
# Epoch 0049 — train_loss: 0.000022, val_loss: 0.000019, val_NMSE: -38.07
# Время обучения: 0:01:08
# ===Training complete===
# SNR: 55
# ===Start training===
# Epoch 0000 — train_loss: 0.005039, val_loss: 0.000200, val_NMSE: -27.89
# Epoch 0049 — train_loss: 0.000019, val_loss: 0.000010, val_NMSE: -40.73
# Время обучения: 0:01:11
# ===Training complete===
# SNR: 60
# ===Start training===
# Epoch 0000 — train_loss: 0.013979, val_loss: 0.000293, val_NMSE: -26.22
# Epoch 0049 — train_loss: 0.000016, val_loss: 0.000013, val_NMSE: -39.90
# Время обучения: 0:01:09
# ===Training complete===

# %%
snr_metrics_runner.run_ilc_noise()
# Out:
# SNR: 20
# Epoch [0/200], Loss: 0.05504428967833519
# Epoch [100/200], Loss: 0.0163440965116024
# Epoch [199/200], Loss: 0.01662500575184822
# Время расчёта ilc_signal: 0:12:49
# ===Start training===
# Epoch 0000 — train_loss: 0.008179, val_loss: 0.072946, val_NMSE: 0.15
# Epoch 0049 — train_loss: 0.000178, val_loss: 0.072638, val_NMSE: 0.13
# Время обучения: 0:00:49
# ===Training complete===
# SNR: 25
# Epoch [0/200], Loss: 0.038476452231407166
# Epoch [100/200], Loss: 0.005731415934860706
# Epoch [199/200], Loss: 0.005766578484326601
# Время расчёта ilc_signal: 0:12:47
# ===Start training===
# Epoch 0000 — train_loss: 0.014055, val_loss: 0.075401, val_NMSE: 0.06
# Epoch 0049 — train_loss: 0.000118, val_loss: 0.076817, val_NMSE: 0.14
# Время обучения: 0:00:50
# ===Training complete===
# SNR: 30
# Epoch [0/200], Loss: 0.03320373594760895
# Epoch [100/200], Loss: 0.0020090616308152676
# Epoch [199/200], Loss: 0.002058345125988126
# Время расчёта ilc_signal: 0:12:51
# ===Start training===
# Epoch 0000 — train_loss: 0.011876, val_loss: 0.077647, val_NMSE: 0.11
# Epoch 0049 — train_loss: 0.000077, val_loss: 0.078057, val_NMSE: 0.13
# Время обучения: 0:00:49
# ===Training complete===
# SNR: 35
# Epoch [0/200], Loss: 0.0314423143863678
# Epoch [100/200], Loss: 0.0007028212421573699
# Epoch [199/200], Loss: 0.0007392372353933752
# Время расчёта ilc_signal: 0:12:51
# ===Start training===
# Epoch 0000 — train_loss: 0.009034, val_loss: 0.078302, val_NMSE: 0.13
# Epoch 0049 — train_loss: 0.000058, val_loss: 0.078815, val_NMSE: 0.16
# Время обучения: 0:00:49
# ===Training complete===
# SNR: 40
# Epoch [0/200], Loss: 0.031012840569019318
# Epoch [100/200], Loss: 0.00025029503740370274
# Epoch [199/200], Loss: 0.0002647075743880123
# Время расчёта ilc_signal: 0:12:52
# ===Start training===
# Epoch 0000 — train_loss: 0.007629, val_loss: 0.079108, val_NMSE: 0.17
# Epoch 0049 — train_loss: 0.000042, val_loss: 0.078628, val_NMSE: 0.14
# Время обучения: 0:00:50
# ===Training complete===
# SNR: 45
# Epoch [0/200], Loss: 0.030800344422459602
# Epoch [100/200], Loss: 8.90527298906818e-05
# Epoch [199/200], Loss: 9.801665146369487e-05
# Время расчёта ilc_signal: 0:12:52
# ===Start training===
# Epoch 0000 — train_loss: 0.012746, val_loss: 0.078164, val_NMSE: 0.11
# Epoch 0049 — train_loss: 0.000035, val_loss: 0.078732, val_NMSE: 0.15
# Время обучения: 0:00:50
# ===Training complete===
# SNR: 50
# Epoch [0/200], Loss: 0.030764123424887657
# Epoch [100/200], Loss: 3.0718831112608314e-05
# Epoch [199/200], Loss: 3.550244582584128e-05
# Время расчёта ilc_signal: 0:12:52
# ===Start training===
# Epoch 0000 — train_loss: 0.005855, val_loss: 0.078517, val_NMSE: 0.13
# Epoch 0049 — train_loss: 0.000035, val_loss: 0.078770, val_NMSE: 0.15
# Время обучения: 0:00:49
# ===Training complete===
# SNR: 55
# Epoch [0/200], Loss: 0.030737897381186485
# Epoch [100/200], Loss: 1.080975380318705e-05
# Epoch [199/200], Loss: 1.24079488159623e-05
# Время расчёта ilc_signal: 0:12:53
# ===Start training===
# Epoch 0000 — train_loss: 0.011897, val_loss: 0.077885, val_NMSE: 0.10
# Epoch 0049 — train_loss: 0.000032, val_loss: 0.078628, val_NMSE: 0.14
# Время обучения: 0:00:49
# ===Training complete===
# SNR: 60
# Epoch [0/200], Loss: 0.03074040450155735
# Epoch [100/200], Loss: 3.840132194454782e-06
# Epoch [199/200], Loss: 4.306945356802316e-06
# Время расчёта ilc_signal: 0:12:53
# ===Start training===
# Epoch 0000 — train_loss: 0.019914, val_loss: 0.079024, val_NMSE: 0.16
# Epoch 0049 — train_loss: 0.000039, val_loss: 0.078857, val_NMSE: 0.15
# Время обучения: 0:00:49
# ===Training complete===

# %%
results = snr_metrics_runner.get_results()

snr_range = results["snr_range"]

nmse_dla_list = results["dla"]["nmse"]
acpr_left_dla_list = results["dla"]["acpr_left"]
acpr_right_dla_list = results["dla"]["acpr_right"]

nmse_ila_list = results["ila"]["nmse"]
acpr_left_ila_list = results["ila"]["acpr_left"]
acpr_right_ila_list = results["ila"]["acpr_right"]

nmse_ilc_list = results["ilc"]["nmse"]
acpr_left_ilc_list = results["ilc"]["acpr_left"]
acpr_right_ilc_list = results["ilc"]["acpr_right"]

nmse_uk_list = results["uk"]["nmse"]
acpr_left_uk_list = results["uk"]["acpr_left"]
acpr_right_uk_list = results["uk"]["acpr_right"]

# %%
print(f"snr_range = {snr_range}")
print()

print(f"nmse_dla_list = {(nmse_dla_list)}")
print(f"acpr_left_dla_list = {acpr_left_dla_list}")
print(f"acpr_right_dla_list = {acpr_right_dla_list}")
print()

print(f"nmse_ila_list = {nmse_ila_list}")
print(f"acpr_left_ila_list = {acpr_left_ila_list}")
print(f"acpr_right_ila_list = {acpr_right_ila_list}")
print()

print(f"nmse_ilc_list = {nmse_ilc_list}")
print(f"acpr_left_ilc_list = {acpr_left_ilc_list}")
print(f"acpr_right_ilc_list = {acpr_right_ilc_list}")
print()

print(f"nmse_uk_list = {nmse_uk_list}")
print(f"acpr_left_uk_list = {acpr_left_uk_list}")
print(f"acpr_right_uk_list = {acpr_right_uk_list}")
# Out:
# snr_range = [20, 25, 30, 35, 40, 45, 50, 55, 60]
#
# nmse_dla_list = [-17.137060165405273, -21.96965980529785, -26.81765365600586, -31.505434036254883, -35.57054138183594, -38.63620376586914, -39.113792419433594, -38.6195068359375, -41.02045822143555]
# acpr_left_dla_list = [np.float64(-20.043180907001865), np.float64(-24.997615366869727), np.float64(-29.88420059459173), np.float64(-34.69813351874072), np.float64(-39.11869853930988), np.float64(-42.75941617564841), np.float64(-44.556015439067544), np.float64(-45.50579331757665), np.float64(-45.856063390816914)]
# acpr_right_dla_list = [np.float64(-20.03768970456767), np.float64(-24.98483819339822), np.float64(-29.91008171158717), np.float64(-34.66632986010521), np.float64(-39.092701210139325), np.float64(-42.551257239684695), np.float64(-44.15280496551297), np.float64(-45.29853879521245), np.float64(-46.00348917956039)]
#
# nmse_ila_list = [-16.82413673400879, -21.81842613220215, -26.752714157104492, -31.452070236206055, -35.70893096923828, -34.1090202331543, -38.296993255615234, -42.362709045410156, -40.32441711425781]
# acpr_left_ila_list = [np.float64(-20.023785687838792), np.float64(-24.968133825327367), np.float64(-29.9220537056228), np.float64(-34.73663298010931), np.float64(-39.285517077226885), np.float64(-42.272317716454175), np.float64(-45.529052960204105), np.float64(-46.39092439455998), np.float64(-46.97019574084575)]
# acpr_right_ila_list = [np.float64(-20.04236443802337), np.float64(-24.967847844164556), np.float64(-29.930158880599173), np.float64(-34.71037860355651), np.float64(-39.09866216415605), np.float64(-42.53313727206143), np.float64(-45.0592016756485), np.float64(-46.202775689326614), np.float64(-46.785822396254225)]
#
# nmse_ilc_list = [-17.131040573120117, -21.954679489135742, -26.642658233642578, -31.321826934814453, -34.60251235961914, -36.69697570800781, -40.476158142089844, -40.328155517578125, -37.86528015136719]
# acpr_left_ilc_list = [np.float64(-20.041439926763022), np.float64(-24.98018178024445), np.float64(-29.90596094382148), np.float64(-34.7198795605897), np.float64(-39.09849642641787), np.float64(-42.734134728056745), np.float64(-44.61016376489692), np.float64(-45.886095046946075), np.float64(-45.20230460355427)]
# acpr_right_ilc_list = [np.float64(-20.03591389204505), np.float64(-24.983601560656044), np.float64(-29.898852403931237), np.float64(-34.69865246103277), np.float64(-38.925475334084325), np.float64(-42.519668126525694), np.float64(-44.58589436388985), np.float64(-46.16407721854105), np.float64(-45.20027511956225)]
#
# nmse_uk_list = [-16.650760650634766, -21.20108413696289, -25.709470748901367, -30.13892364501953, -34.560028076171875, -38.97065353393555, -43.37306594848633, -47.847267150878906, -52.516780853271484]
# acpr_left_uk_list = [np.float64(-19.57053145263736), np.float64(-24.238766915316436), np.float64(-28.767465657704133), np.float64(-33.21020709378468), np.float64(-37.55111446111118), np.float64(-41.623037176846275), np.float64(-45.233522332270496), np.float64(-48.03616980610427), np.float64(-49.710646693306025)]
# acpr_right_uk_list = [np.float64(-19.37139645210797), np.float64(-23.91412866517753), np.float64(-28.35717246359855), np.float64(-32.603242175922645), np.float64(-36.812159133826675), np.float64(-40.848836746059774), np.float64(-44.46371444431176), np.float64(-47.20272541386199), np.float64(-48.96696898329389)]

# %%
# # значения в виде списков чтобы не рассчитывать снова все значения

# snr_range = [20, 22, 24, 26, 28, 30, 32, 34, 36, 38, 40, 42, 44, 46, 48, 50, 52, 54, 56, 58, 60]

# nmse_dla_list = [-14.1044340133667, -16.018064498901367, -17.97743797302246, -19.84555435180664, -21.76476287841797, -23.601543426513672, -25.397140502929688, -27.051654815673828, -28.60270118713379, -29.951904296875, -31.10137939453125, -31.99922752380371, -32.693359375, -33.20136260986328, -33.556922912597656, -33.7752571105957, -33.94951248168945, -34.041229248046875, -34.11683654785156, -34.161094665527344, -34.18443298339844]
# acpr_left_dla_list = [-19.98307782854365, -22.044059761313314, -24.047040241882005, -25.981348959580895, -27.975370600038946, -29.942117343851447, -31.96514345661867, -33.80510011678665, -35.72137883607495, -37.63892721922215, -39.546686668811134, -41.14783435664147, -42.72300193647455, -44.1586403570728, -45.36636102368466, -46.3075550113637, -47.042928773938236, -47.62786795374185, -48.053632118082476, -48.26038054693791, -48.41887604347718]
# acpr_right_dla_list = [-20.041831052899113, -21.95478038014439, -23.98363774561688, -25.910596158467115, -27.91143197214374, -29.830851608311, -31.79363647332617, -33.5694401253062, -35.43604753655994, -37.07000947388168, -38.589720264578695, -39.981493718118756, -41.18240060456666, -42.0034433292463, -42.727465426518414, -43.28342016300996, -43.61496527628741, -43.81084719101566, -43.98201861121989, -44.08200476372817, -44.162913038570224]

# nmse_ila_list = [-13.854040145874023, -15.777467727661133, -17.762771606445312, -19.657350540161133, -21.58496856689453, -23.4307918548584, -25.17462730407715, -26.818567276000977, -28.340505599975586, -29.61135482788086, -30.697265625, -31.556087493896484, -32.22067642211914, -32.64470291137695, -32.968238830566406, -33.183040618896484, -33.31875991821289, -33.422943115234375, -33.47233963012695, -33.510684967041016, -33.5294189453125]
# acpr_left_ila_list = [-20.027768364406164, -22.02595135920506, -23.98453820660988, -25.961216816485567, -27.89464166886246, -29.93190200512903, -31.88604293318803, -33.82673998661604, -35.772038392214476, -37.61613725169961, -39.35554674161212, -40.999545012141596, -42.574679365583734, -43.93042452256015, -45.03867510014294, -45.908987401819914, -46.56702971768967, -47.03977254628908, -47.41264367177677, -47.67963051393086, -47.772995960135724]
# acpr_right_ila_list = [-19.930579122305584, -21.869039603483063, -23.92589430272745, -25.8934186825347, -27.89435768624694, -29.824054115245037, -31.657192539039386, -33.574507705349546, -35.29508665583067, -36.91289391444029, -38.35332621280914, -39.531460585547265, -40.53575407057057, -41.37233528658536, -41.93340984815785, -42.33601701225255, -42.63072372715388, -42.78626262772036, -42.906565042070014, -42.98986099019487, -43.06106380151427]

# nmse_ilc_list = [-14.0765962600708, -16.038497924804688, -17.95038604736328, -19.846113204956055, -21.75259017944336, -23.631811141967773, -25.368045806884766, -27.051647186279297, -28.601642608642578, -29.968273162841797, -31.0953426361084, -32.05195999145508, -32.759464263916016, -33.242897033691406, -33.58929443359375, -33.86418914794922, -34.00400924682617, -34.103553771972656, -34.197731018066406, -34.209129333496094, -34.251609802246094]
# acpr_left_ilc_list = [-19.987904634237463, -22.032664265763948, -23.981805945312637, -25.985078180439405, -27.97285318573928, -29.932254292413706, -31.93950622504634, -33.871982256476386, -35.687000986372624, -37.643129058194496, -39.36068479051006, -41.063457267103004, -42.61319314281078, -43.93533817262031, -45.077593707598375, -46.05866500876228, -46.68572673296391, -47.206334708000576, -47.541040851625766, -47.77248651232119, -47.95394808902196]
# acpr_right_ilc_list = [-19.970945068810845, -21.99232485637614, -23.99870022329292, -25.8777047238745, -27.85245425738548, -29.870087979042914, -31.71947716771799, -33.548264032512904, -35.38769115623252, -36.93997367595692, -38.44486643405877, -39.832029876134314, -40.894418612291034, -41.675168206028694, -42.37802985442333, -42.748574412828496, -43.07917614846056, -43.318133130296104, -43.473543736876735, -43.543050561279685, -43.59642567165372]

# nmse_uk_list = [-14.0831298828125, -16.007923126220703, -17.956777572631836, -19.8975887298584, -21.878353118896484, -23.844219207763672, -25.788644790649414, -27.7381649017334, -29.701080322265625, -31.64846420288086, -33.609657287597656, -35.53433609008789, -37.480770111083984, -39.428749084472656, -41.34610366821289, -43.275142669677734, -45.19207000732422, -47.10540771484375, -48.99323654174805, -50.86845397949219, -52.7203369140625]
# acpr_left_uk_list = [-19.998392505893012, -21.96503696465798, -23.970991167027375, -25.9149880083065, -27.92604114808463, -29.87986846158727, -31.819333935519474, -33.75500066095982, -35.68040463397734, -37.580494422986966, -39.43423352610119, -41.25160083392008, -42.91737743348149, -44.5111827081357, -45.92210941660184, -47.14031506566594, -48.14644265515601, -48.92050801676599, -49.54857485864436, -49.93755700347053, -50.273354378725]
# acpr_right_uk_list = [-19.893920065196465, -21.86624051842887, -23.84565607408318, -25.75388263544563, -27.70074723690906, -29.627564553190144, -31.569643994482238, -33.43726278691267, -35.32040951826972, -37.142184428452595, -38.9831850829623, -40.66346961805266, -42.32750364604643, -43.85724713876513, -45.296073869065694, -46.486982373361776, -47.48990958237207, -48.29148483835154, -48.9249656987649, -49.38223862798154, -49.67895177822955]

# %%
markersize = 8
plt.figure(figsize=(9, 5))
plt.plot(snr_range, nmse_dla_list,color='blue', linestyle='-', label="Сигнал с предыскажением DLA",
         marker='o', markersize=markersize)
plt.plot(snr_range, nmse_ila_list, color='orange', linestyle='--', label="Сигнал с предыскажением ILA",
         marker='s', markersize=markersize)
plt.plot(snr_range, nmse_ilc_list, color='green', linestyle='-.', label="Сигнал с предыскажением ILC",
         marker='d', markersize=markersize)
plt.plot(snr_range, nmse_uk_list, color='red', linestyle='-.', label="Оптимальный сигнал ILC",
         marker='*', markersize=markersize)

plt.xlabel("ОСШ, дБ", fontsize=12)
plt.ylabel("NMSE, дБ", fontsize=12)
# plt.title("Зависимость NMSE от ОСШ")
plt.xticks(range(20, 61, 5))
plt.yticks(range(-55, -9, 5))
plt.legend()
plt.grid(True)

plt.show()

# %%
markersize=8
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
# plt.plot(snr_range, acpr_left_dla_list, marker='o', color='blue', linestyle='-', label="Сигнал с предыскажением DLA")
# plt.plot(snr_range, acpr_left_ila_list, marker='s', color='orange', linestyle='--', label="Сигнал с предыскажением ILA")
# plt.plot(snr_range, acpr_left_ilc_list, marker='d', color='green', linestyle='-.', label="Сигнал с предыскажением ILC")
# plt.plot(snr_range, acpr_left_uk_list, marker='*', color='indigo', linestyle='-.', label="Оптимальный сигнал ILC")
plt.plot(snr_range, acpr_left_dla_list, color='blue', linestyle='-', label="Сигнал с предыскажением DLA", 
         marker='o', markersize=markersize)
plt.plot(snr_range, acpr_left_ila_list, color='orange', linestyle='--', label="Сигнал с предыскажением ILA", 
         marker='s', markersize=markersize)
plt.plot(snr_range, acpr_left_ilc_list, color='green', linestyle='-.', label="Сигнал с предыскажением ILC", 
         marker='d', markersize=markersize)
plt.plot(snr_range, acpr_left_uk_list, color='red', linestyle='-.', label="Оптимальный сигнал ILC", 
         marker='*', markersize=markersize)
plt.title('Левый канал', fontsize=12)
plt.xlabel('ОСШ, дБ', fontsize=12)
plt.ylabel('ACPR, дБ', fontsize=12)
plt.xticks(range(20, 61, 5))
plt.yticks(range(-55, -14, 5))
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(snr_range, acpr_right_dla_list, color='blue', linestyle='-', label="Сигнал с предыскажением DLA", 
         marker='o', markersize=markersize)
plt.plot(snr_range, acpr_right_ila_list, color='orange', linestyle='--', label="Сигнал с предыскажением ILA", 
         marker='s', markersize=markersize)
plt.plot(snr_range, acpr_right_ilc_list, color='green', linestyle='-.', label="Сигнал с предыскажением ILC", 
         marker='d', markersize=markersize)
plt.plot(snr_range, acpr_right_uk_list, color='red', linestyle='-.', label="Оптимальный сигнал ILC", 
         marker='*', markersize=markersize)
plt.title('Правый канал', fontsize=12)
plt.xlabel('ОСШ, дБ', fontsize=12)
plt.ylabel('ACPR, дБ', fontsize=12)
plt.xticks(range(20, 61, 5))
plt.yticks(range(-55, -14, 5))
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
