# %%
# %load_ext autoreload
# %autoreload 2

# %%
from modules import data_loader, metrics, learning, plotting, utils, params, pipelines
import matplotlib.pyplot as plt
import numpy as np
import torch
from modules.nn_model import TorchESN, DiffESN
from modules.gmp_model import BatchGMP

# %% [markdown]
# Load data from files and init acpr meter

# %%
data = data_loader.load_data("DPA_200MHz")

config = data["config"]
fs = config["input_signal_fs"]
bw_main_ch = config["bw_main_ch"]
bw_sub_ch = config["bw_sub_ch"]
n_sub_ch = config["n_sub_ch"]
sub_ch = config["sub_ch"]
nperseg = config["nperseg"]

x_train = data["train_input"]
y_train = data["train_output"]
x_val = data["val_input"]
y_val = data["val_output"]

gain = metrics.calculate_gain_complex(x_train, y_train)
print(f"PA gain = {gain:.2f}")
y_train_target = gain * x_train
y_val_target = gain * x_val

data['y_train_target'] = y_train_target
data['y_val_target'] = y_val_target

acpr_meter = metrics.ACPR(
        sample_rate=fs,
        main_measurement_bandwidth=bw_main_ch,
        adjacent_channel_offset=[-sub_ch, sub_ch],
        segment_length=nperseg,
        overlap_percentage=60,
        window='blackmanharris',
        fft_length=nperseg,
        power_units='dBW',
        return_main_power=True,
        return_adjacent_powers=True
    )
# Out:
# PA gain = 2.52

# %%
frame_length = 32
batch_size = 512
batch_size_eval = 2048

pa_train_loader, pa_val_loader = data_loader.build_dataloaders(data_dict=data, frame_length=frame_length, batch_size=batch_size, batch_size_eval=batch_size_eval)
dla_train_loader, dla_val_loader = data_loader.build_dataloaders(data_dict=data, frame_length=frame_length, batch_size=batch_size, batch_size_eval=batch_size_eval, arch="dla")
ila_train_loader, ila_val_loader = data_loader.build_dataloaders(data_dict=data, frame_length=frame_length, batch_size=batch_size, batch_size_eval=batch_size_eval, arch="ila")

criterion_gru = metrics.compute_mse
metric_criterion = metrics.compute_nmse

# %%
# # Получить первый батч
# batch = next(iter(dla_train_loader))

# # Для features и targets (если DataLoader возвращает кортеж)
# features, targets = batch
# print(f"Features shape: {features.shape}") 
# print(f"Targets shape: {targets.shape}")
# print(features)

# %% [markdown]
# PA

# %%
criterion_pa = metrics.compute_nmse

pa_degree = 5
pa_config = params.make_gmp_params(
    Ka=pa_degree,
    La=pa_degree,
    Kb=pa_degree,
    Lb=pa_degree,
    Mb=pa_degree,
    Kc=pa_degree,
    Lc=pa_degree,
    Mc=pa_degree,
)

pa_model = BatchGMP(**pa_config, model_name="pa")


print(f"total_params: {pa_model.count_params()}")

epochs = 10
lr = 0.001

optimizer = torch.optim.Adam(pa_model.parameters(), lr=lr)

if not pa_model.load_weights():
      learning.train(net=pa_model, 
            criterion=criterion_pa, 
            optimizer=optimizer, 
            train_loader=pa_train_loader, 
            val_loader=pa_val_loader, 
            n_epochs=epochs, 
            metric_criterion=metric_criterion)
      pa_model.save_weights()
utils.freeze_pa_model(pa_model)

y_val_pa = learning.net_inference(net=pa_model, x=x_val)
pa_nmse = metrics.compute_nmse(y_val_pa, y_val)
print(f"Model NMSE: {pa_nmse:.2f}")
# Out:
# total_params: 550
# Coefficients loaded from model_params/pa_BatchGMP_Ka5_La5_Kb5_Lb5_Mb5_Kc5_Lc5_Mc5.pt
# Model NMSE: -32.61

# %%
# esn_pa = DiffESN(
#     n_inputs=2,
#     n_outputs=2,
#     n_reservoir=1700,
#     spectral_radius=0.95,
#     model_name="pa",
# )

# print(esn_pa.count_params())

# lr = 0.001
# epochs = 100

# optimizer = torch.optim.Adam(esn_pa.parameters(), lr=lr)

# if not esn_pa.load_weights():
#     learning.train(net=esn_pa, 
#         criterion=criterion_gru, 
#         optimizer=optimizer, 
#         train_loader=pa_train_loader, 
#         val_loader=pa_val_loader, 
#         grad_clip_val=1.0, 
#         n_epochs=epochs, 
#         metric_criterion=metric_criterion)
#     esn_pa.save_weights()

# utils.freeze_pa_model(esn_pa)

# y_val_gru_pa = learning.net_inference(net=esn_pa, x=x_val)
# gru_pa_nmse = metrics.compute_nmse(y_val_gru_pa, y_val)
# print(f"Model NMSE: {gru_pa_nmse:.2f}")
# Out:
# 1006
# No saved weights found at model_params/pa_DiffESN_res500_in2_out2.pt, initializing new parameters.
# ===Start training===
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 17
#      14 optimizer = torch.optim.Adam(esn_pa.parameters(), lr=lr)
#      16 if not esn_pa.load_weights():
# ---> 17     learning.train(net=esn_pa,
#      18         criterion=criterion_gru,
#      19         optimizer=optimizer,
#      20         train_loader=pa_train_loader,
#      21         val_loader=pa_val_loader,
#      22         grad_clip_val=1.0,
#      23         n_epochs=epochs,
#      24         metric_criterion=metric_criterion)
#      25     esn_pa.save_weights()
#      27 utils.freeze_pa_model(esn_pa)
#
# File d:\Учёба\проект\python\DPD_Research\modules\utils.py:119, in timer_decorator.<locals>.wrapper(*args, **kwargs)
#     116 @functools.wraps(func)
#     117 def wrapper(*args, **kwargs):
#     118     start = time.time()
# --> 119     result = func(*args, **kwargs)
#     120     elapsed = time.time() - start
#     121     print(f"Выполнение заняло: {timedelta(seconds=round(elapsed))}")
#
# File d:\Учёба\проект\python\DPD_Research\modules\learning.py:75, in train(net, criterion, optimizer, train_loader, val_loader, n_epochs, metric_criterion, grad_clip_val)
#      73 print("===Start training===")
#      74 for epoch in range(n_epochs):
# ---> 75     net, train_loss = net_train(net=net,
#      76                     optimizer=optimizer,
#      77                     criterion=criterion,
#      78                     dataloader=train_loader,
#      79                     grad_clip_val=grad_clip_val)
#      81     val_loss, val_metric_loss = net_eval(net=net,
#      82                                          criterion=criterion,
#      83                                          dataloader=val_loader,
#      84                                          metric_criterion=metric_criterion)
#      86     if epoch % 1 == 0 or epoch == n_epochs - 1:
#
# File d:\Учёба\проект\python\DPD_Research\modules\learning.py:36, in net_train(net, dataloader, optimizer, criterion, grad_clip_val)
#      34 for features, targets in dataloader:
#      35     optimizer.zero_grad()
# ---> 36     out = net(features)
#      37     loss = criterion(out, targets)
#      38     loss.backward()
#
# File c:\Users\maximp\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File c:\Users\maximp\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File d:\Учёба\проект\python\DPD_Research\modules\utils.py:51, in complex_handler.<locals>.wrapper(self, inputs, *args, **kwargs)
#      48 else:
#      49     inputs = inputs
# ---> 51 result = forward_func(self, inputs, *args, **kwargs)
#      53 if result is None:
#      54     return
#
# File d:\Учёба\проект\python\DPD_Research\modules\nn_model.py:469, in DiffESN.forward(self, x)
#     467 noise_t = noise_vec[:, :, t]
#     468 h = torch.tanh(preact + noise_t)
# --> 469 lin_in = torch.cat([h.T, u_t.T], dim=-1)
#     470 # y_t = self.readout(lin_in)
#     471 y_t = self.W_out(lin_in)
#
# KeyboardInterrupt:

# %%
with torch.autograd.profiler.profile(use_cuda=False) as prof:
    with torch.no_grad():
        output = pa_model.forward(x_val)

print(prof.key_averages().table(sort_by="cpu_time_total", row_limit=20))
# Out:
# ------------------------  ------------  ------------  ------------  ------------  ------------  ------------
#                     Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg    # of Calls
# ------------------------  ------------  ------------  ------------  ------------  ------------  ------------
#             aten::einsum         3.01%       1.259ms        61.41%      25.728ms       2.144ms            12
#            aten::reshape         1.86%     777.600us        49.42%      20.708ms     862.829us            24
#              aten::clone         0.45%     187.200us        48.05%      20.133ms     838.879us            24
#              aten::copy_        47.92%      20.078ms        47.92%      20.078ms     542.635us            37
#                aten::mul        16.29%       6.823ms        16.38%       6.862ms       1.716ms             4
#                aten::pow        10.78%       4.516ms        10.79%       4.519ms     502.122us             9
#                aten::bmm         6.33%       2.653ms         7.68%       3.216ms     267.983us            12
#                aten::sub         2.95%       1.236ms         3.51%       1.471ms     147.140us            10
#             aten::gather         2.80%       1.174ms         2.80%       1.174ms     234.760us             5
#             aten::arange         0.85%     356.800us         2.03%     849.000us     424.500us             2
#                 aten::to         0.05%      22.600us         1.83%     766.900us      31.954us            24
#           aten::_to_copy         0.46%     193.300us         1.78%     744.300us      57.254us            13
#          aten::unsqueeze         0.93%     389.500us         1.10%     460.000us       7.667us            60
#         aten::empty_like         0.53%     222.800us         0.92%     384.300us      16.013us            24
#            aten::permute         0.54%     227.200us         0.66%     277.500us       4.625us            60
#             aten::select         0.50%     209.100us         0.66%     276.300us       4.934us            56
#              aten::clamp         0.49%     203.500us         0.49%     204.900us      40.980us             5
#         aten::as_strided         0.48%     200.600us         0.48%     200.600us       1.034us           194
#                aten::add         0.42%     174.400us         0.46%     191.600us      17.418us            11
#              aten::empty         0.40%     165.900us         0.40%     165.900us       6.636us            25
# ------------------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 41.898ms

# %%
# esn_pa = TorchESN(
#     n_inputs=2,
#     n_outputs=2,
#     n_reservoir=1500,
#     spectral_radius=0.9,
#     sparsity=0.1,
#     noise=0.001,
#     random_state=2,
# )

# esn_pa.fit(x_train, y_train)

# pred_test = esn_pa.forward(x_val)
# pa_nmse = metrics.compute_nmse(pred_test, y_val)
# print(f"Model NMSE: {pa_nmse:.2f}")

# y_val_gru_pa = pred_test

# %%
# with torch.autograd.profiler.profile(use_cuda=False) as prof:
#     with torch.no_grad():
#         output = esn_pa.forward(x_val)

# print(prof.key_averages().table(sort_by="cpu_time_total", row_limit=20))
# Out:
# -----------------------  ------------  ------------  ------------  ------------  ------------  ------------
#                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg    # of Calls
# -----------------------  ------------  ------------  ------------  ------------  ------------  ------------
#            aten::matmul         1.13%      22.662ms        76.03%        1.522s      99.073us         15360
#                aten::mv         2.87%      57.511ms        74.90%        1.499s      97.597us         15360
#            aten::addmv_        70.99%        1.421s        70.99%        1.421s      92.505us         15360
#            aten::select         8.12%     162.549ms         9.61%     192.427ms       3.132us         61444
#              aten::tanh         4.96%      99.234ms         4.96%      99.234ms      12.921us          7680
#               aten::cat         2.95%      59.135ms         2.95%      59.135ms       3.850us         15361
#             aten::copy_         2.25%      45.088ms         2.25%      45.088ms       2.934us         15367
#               aten::add         2.00%      39.969ms         2.00%      39.980ms       5.205us          7681
#              aten::rand         0.00%      16.200us         1.50%      29.972ms      29.972ms             1
#        aten::as_strided         1.49%      29.888ms         1.49%      29.888ms       0.486us         61449
#          aten::uniform_         1.49%      29.878ms         1.49%      29.878ms      29.878ms             1
#             aten::empty         1.04%      20.812ms         1.04%      20.812ms       1.354us         15366
#               aten::mul         0.29%       5.812ms         0.29%       5.883ms       2.941ms             2
#               aten::sub         0.22%       4.388ms         0.22%       4.415ms       4.415ms             1
#             aten::zeros         0.00%      27.900us         0.17%       3.478ms     695.580us             5
#             aten::zero_         0.00%      23.600us         0.17%       3.419ms     683.840us             5
#             aten::fill_         0.17%       3.396ms         0.17%       3.396ms       3.396ms             1
#                aten::to         0.00%      11.700us         0.01%     109.300us      21.860us             5
#          aten::_to_copy         0.00%      39.100us         0.00%      97.600us      19.520us             5
#         aten::unsqueeze         0.00%      28.200us         0.00%      35.500us      17.750us             2
# -----------------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 2.001s

# %%
freqs, spectrum_x_val = metrics.power_spectrum(x_val, fs, nperseg)
_, spectrum_y_val = metrics.power_spectrum(y_val, fs, nperseg)
_, spectrum_gru_pa = metrics.power_spectrum(y_val_pa, fs, nperseg)

xlabel="Частота (МГц)"
ylabel= "Спектральная плотность мощности (дБ)"
fontsize = 12
figsize=(12, 6)

plt.figure(figsize=figsize)

plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_x_val)), color='grey', label='Входной сигнал')
plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_y_val)), color='black', label='Выходной сигнал')
plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_gru_pa)), color='gold', label='Выходной сигнал PA (GRU)')


plt.xlabel(xlabel, fontsize=fontsize)
plt.ylabel(ylabel, fontsize=fontsize)
plt.legend()
plt.grid()
plt.show()
# Out:
# c:\Users\maximp\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\signal\_spectral_py.py:652: UserWarning: Input data is complex, switching to return_onesided=False
#   freqs, Pxx = csd(x, x, fs=fs, window=window, nperseg=nperseg,

# %% [markdown]
# DLA DPD

# %%
esn_dla = DiffESN(
    n_reservoir=100,
    sparsity=0.99,
    model_name='dla'
)

print(f"total_params: {esn_dla.count_params()}")

lr = 0.001
epochs = 10

casc_dla = utils.CascadeModel(model_1=esn_dla, model_2=pa_model)
optimizer = torch.optim.Adam(casc_dla.parameters(), lr=lr)
is_load = esn_dla.load_weights()

if not is_load:
    learning.train(net=casc_dla, 
                    criterion=criterion_gru, 
                    optimizer=optimizer, 
                    train_loader=dla_train_loader, 
                    val_loader=dla_val_loader, 
                    grad_clip_val=1.0, 
                    n_epochs=epochs, 
                    metric_criterion=metric_criterion)
    # esn_dla.save_weights()

y_val_dla = learning.net_inference(net=casc_dla, x=x_val)
dla_nmse = metrics.compute_nmse(y_val_dla, y_val_target)
print(f"Model NMSE: {dla_nmse:.2f}")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 esn_dla = DiffESN(
#       2     n_reservoir=100,
#       3     sparsity=0.999,
#       4     model_name='dla'
#       5 )
#       7 print(f"total_params: {esn_dla.count_params()}")
#       9 lr = 0.001
#
# File d:\Учёба\проект\python\DPD_Research\modules\nn_model.py:410, in DiffESN.__init__(self, n_inputs, n_outputs, n_reservoir, spectral_radius, sparsity, noise, input_scaling, input_shift, random_state, model_name)
#     407 W[mask] = 0.0
#     408 eigs = torch.linalg.eigvals(W).abs()
# --> 410 W *= (spectral_radius / eigs.max().item())
#     411 self.register_buffer('W', W)
#     412 W_in = torch.rand(n_reservoir, n_inputs)*2 - 1
#
# ZeroDivisionError: float division by zero

# %%
freqs, spectrum_x_val = metrics.power_spectrum(x_val, fs, nperseg)
_, spectrum_y_val = metrics.power_spectrum(y_val, fs, nperseg)
_, spectrum_y_val_gru_pa = metrics.power_spectrum(y_val_pa, fs, nperseg)
_, spectrum_lin_dla_nn = metrics.power_spectrum(y_val_dla, fs, nperseg)

xlabel="Частота (МГц)"
ylabel= "Спектральная плотность мощности (дБ)"
fontsize = 12
figsize=(12, 6)

plt.figure(figsize=figsize)

plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_x_val)), color='grey', label='Входной сигнал')
plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_y_val)), color='black', label='Выходной сигнал')
plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_y_val_gru_pa)), color='gold', label='Выходной сигнал PA')
plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_lin_dla_nn)), color='green', label='spectrum_lin_dla_nn')


plt.xlabel(xlabel, fontsize=fontsize)
plt.ylabel(ylabel, fontsize=fontsize)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ILA DPD grad

# %%
esn_ila = DiffESN(
    n_reservoir=500,
    spectral_radius=0.1,
    model_name='ila'
)

lr = 0.001
epochs = 100

casc_gru_ila_train = utils.CascadeModel(model_1=pa_model, model_2=esn_ila, gain=gain, cascade_type="ila")

optimizer_gru = torch.optim.Adam(casc_gru_ila_train.parameters(), lr=lr)
is_load = esn_ila.load_weights()

if not is_load:
    learning.train(net=casc_gru_ila_train, 
                    criterion=criterion_gru, 
                    optimizer=optimizer_gru, 
                    train_loader=ila_train_loader, 
                    val_loader=ila_val_loader, 
                    grad_clip_val=1.0, 
                    n_epochs=epochs, 
                    metric_criterion=metric_criterion)
    esn_ila.save_weights()
    
casc_ila_eval = utils.CascadeModel(model_1=esn_ila, model_2=pa_model)
y_val_ila = learning.net_inference(net=casc_ila_eval, x=x_val)
ila_nmse = metrics.compute_nmse(y_val_ila, y_val_target)
print(f"Model NMSE: {ila_nmse:.2f}")
# Out:
# No saved weights found at model_params/ila_DiffESN_res500_in2_out2.pt, initializing new parameters.
# ===Start training===
# Epoch 0000 — train_loss: 0.004477, val_loss: 0.000746, val_NMSE: -22.16
# Epoch 0001 — train_loss: 0.000533, val_loss: 0.000442, val_NMSE: -24.44
# Epoch 0002 — train_loss: 0.000416, val_loss: 0.000368, val_NMSE: -25.23
# Epoch 0003 — train_loss: 0.000369, val_loss: 0.000323, val_NMSE: -25.80
# Epoch 0004 — train_loss: 0.000338, val_loss: 0.000293, val_NMSE: -26.22
# Epoch 0005 — train_loss: 0.000314, val_loss: 0.000267, val_NMSE: -26.62
# Epoch 0006 — train_loss: 0.000290, val_loss: 0.000244, val_NMSE: -27.01
# Epoch 0076 — train_loss: 0.000104, val_loss: 0.000066, val_NMSE: -32.72
# Epoch 0077 — train_loss: 0.000102, val_loss: 0.000059, val_NMSE: -33.19
# Epoch 0078 — train_loss: 0.000101, val_loss: 0.000067, val_NMSE: -32.63
# Epoch 0079 — train_loss: 0.000100, val_loss: 0.000064, val_NMSE: -32.86
# Epoch 0080 — train_loss: 0.000100, val_loss: 0.000065, val_NMSE: -32.73
# Epoch 0081 — train_loss: 0.000100, val_loss: 0.000070, val_NMSE: -32.43
# Epoch 0082 — train_loss: 0.000100, val_loss: 0.000062, val_NMSE: -33.00
# Epoch 0083 — train_loss: 0.000099, val_loss: 0.000064, val_NMSE: -32.85
# Epoch 0084 — train_loss: 0.000101, val_loss: 0.000068, val_NMSE: -32.59
# Epoch 0085 — train_loss: 0.000099, val_loss: 0.000063, val_NMSE: -32.88
# Epoch 0086 — train_loss: 0.000103, val_loss: 0.000066, val_NMSE: -32.71
# Epoch 0087 — train_loss: 0.000097, val_loss: 0.000062, val_NMSE: -32.93
# Epoch 0088 — train_loss: 0.000097, val_loss: 0.000062, val_NMSE: -32.94
# Epoch 0089 — train_loss: 0.000101, val_loss: 0.000060, val_NMSE: -33.14
# Epoch 0090 — train_loss: 0.000097, val_loss: 0.000057, val_NMSE: -33.31
# Epoch 0091 — train_loss: 0.000098, val_loss: 0.000078, val_NMSE: -31.99
# Epoch 0092 — train_loss: 0.000102, val_loss: 0.000057, val_NMSE: -33.32
# Epoch 0093 — train_loss: 0.000097, val_loss: 0.000057, val_NMSE: -33.31
# Epoch 0094 — train_loss: 0.000097, val_loss: 0.000063, val_NMSE: -32.93
# Epoch 0095 — train_loss: 0.000099, val_loss: 0.000059, val_NMSE: -33.18
# Epoch 0096 — train_loss: 0.000098, val_loss: 0.000060, val_NMSE: -33.08
# Epoch 0097 — train_loss: 0.000099, val_loss: 0.000073, val_NMSE: -32.28
# Epoch 0098 — train_loss: 0.000098, val_loss: 0.000062, val_NMSE: -33.00
# Epoch 0099 — train_loss: 0.000100, val_loss: 0.000060, val_NMSE: -33.14
# ===Training complete===
# Выполнение заняло: 0:20:44
# Model weights saved to model_params/ila_DiffESN_res500_in2_out2.pt
# Model NMSE: -34.50

# %%
freqs, spectrum_x_val = metrics.power_spectrum(x_val, fs, nperseg)
_, spectrum_y_val = metrics.power_spectrum(y_val, fs, nperseg)
_, spectrum_y_val_gru_pa = metrics.power_spectrum(y_val_pa, fs, nperseg)
_, spectrum_y_val_gru_ila = metrics.power_spectrum(y_val_ila, fs, nperseg)
_, spectrum_y_val_target = metrics.power_spectrum(y_val_target, fs, nperseg)

xlabel="Частота (МГц)"
ylabel= "Спектральная плотность мощности (дБ)"
fontsize = 12
figsize=(12, 6)

plt.figure(figsize=figsize)

plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_x_val)), color='grey', label='Входной сигнал')
plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_y_val_gru_pa)), color='gold', label='Выходной сигнал PA')
plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_y_val)), color='black', label='Выходной сигнал')
plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_lin_dla_nn)), color='green', label='spectrum_y_val_gru_ila')
plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_y_val_target)), color='magenta', label='spectrum_y_val_target')


plt.xlabel(xlabel, fontsize=fontsize)
plt.ylabel(ylabel, fontsize=fontsize)
plt.legend()
plt.grid()
plt.show()
# Out:
# c:\Users\maximp\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\signal\_spectral_py.py:652: UserWarning: Input data is complex, switching to return_onesided=False
#   freqs, Pxx = csd(x, x, fs=fs, window=window, nperseg=nperseg,
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 4
#       2 _, spectrum_y_val = metrics.power_spectrum(y_val, fs, nperseg)
#       3 _, spectrum_y_val_gru_pa = metrics.power_spectrum(y_val_pa, fs, nperseg)
# ----> 4 _, spectrum_y_val_gru_ila = metrics.power_spectrum(y_val_ila, fs, nperseg)
#       5 _, spectrum_y_val_target = metrics.power_spectrum(y_val_target, fs, nperseg)
#       7 xlabel="Частота (МГц)"
#
# NameError: name 'y_val_ila' is not defined

# %% [markdown]
# ILC DPD

# %%
u_k_train = learning.ilc_signal(x_train, y_train_target, pa_model, epochs=100, learning_rate=0.01)
u_k_val = learning.ilc_signal(x_val, y_val_target, pa_model, epochs=100, learning_rate=0.01)
u_k_pa = pa_model.forward(u_k_train).detach()

nmse_uk_pa = metrics.compute_nmse(u_k_pa, y_train_target)
print(f"NMSE на выходе усилителя (ILC): {nmse_uk_pa:.2f} db")

data["ilc_train_output"] = u_k_train
data["ilc_val_output"] = u_k_val

ilc_train_loader, ilc_val_loader = data_loader.build_dataloaders(data_dict=data, 
                                                                 frame_length=frame_length, 
                                                                 batch_size=batch_size, 
                                                                 batch_size_eval=batch_size_eval, 
                                                                 arch="ilc")
# Out:
# Epoch [0/100], Loss: 0.03052668645977974
# Epoch [99/100], Loss: 1.24275197777024e-06
# Выполнение заняло: 0:00:30
# Epoch [0/100], Loss: 0.030130784958600998
# Epoch [99/100], Loss: 1.3786484487354755e-06
# Выполнение заняло: 0:00:10
# NMSE на выходе усилителя (ILC): -58.00 db

# %%
esn_ilc = DiffESN(
    n_reservoir=500,
    spectral_radius=0.1,
    model_name='ilc'
)

lr = 0.001
epochs = 100

optimizer_gru = torch.optim.Adam(esn_ilc.parameters(), lr=lr)
is_load = esn_ilc.load_weights()

if not is_load:
    learning.train(net=esn_ilc, 
                    criterion=criterion_gru, 
                    optimizer=optimizer_gru, 
                    train_loader=ilc_train_loader, 
                    val_loader=ilc_val_loader, 
                    grad_clip_val=1.0, 
                    n_epochs=epochs, 
                    metric_criterion=metric_criterion)
    esn_ilc.save_weights()

casc_ilc_eval = utils.CascadeModel(model_1=esn_ilc, model_2=pa_model)
y_val_ilc = learning.net_inference(net=casc_ilc_eval, x=x_val)
ilc_nmse = metrics.compute_nmse(y_val_ilc, y_val_target)
print(f"Model NMSE: {ilc_nmse:.2f}")
# Out:
# No saved weights found at model_params/ilc_DiffESN_res500_in2_out2.pt, initializing new parameters.
# ===Start training===
# Epoch 0000 — train_loss: 0.006381, val_loss: 0.000445, val_NMSE: -22.39
# Epoch 0001 — train_loss: 0.000403, val_loss: 0.000317, val_NMSE: -23.87
# Epoch 0002 — train_loss: 0.000293, val_loss: 0.000253, val_NMSE: -24.86
# Epoch 0073 — train_loss: 0.000057, val_loss: 0.000033, val_NMSE: -33.70
# Epoch 0074 — train_loss: 0.000057, val_loss: 0.000030, val_NMSE: -34.08
# Epoch 0075 — train_loss: 0.000058, val_loss: 0.000029, val_NMSE: -34.30
# Epoch 0076 — train_loss: 0.000057, val_loss: 0.000029, val_NMSE: -34.31
# Epoch 0077 — train_loss: 0.000056, val_loss: 0.000030, val_NMSE: -34.08
# Epoch 0078 — train_loss: 0.000056, val_loss: 0.000028, val_NMSE: -34.47
# Epoch 0079 — train_loss: 0.000056, val_loss: 0.000030, val_NMSE: -34.12
# Epoch 0080 — train_loss: 0.000057, val_loss: 0.000028, val_NMSE: -34.38
# Epoch 0081 — train_loss: 0.000056, val_loss: 0.000028, val_NMSE: -34.46
# Epoch 0082 — train_loss: 0.000055, val_loss: 0.000028, val_NMSE: -34.34
# Epoch 0083 — train_loss: 0.000056, val_loss: 0.000031, val_NMSE: -33.97
# Epoch 0084 — train_loss: 0.000056, val_loss: 0.000039, val_NMSE: -32.94
# Epoch 0085 — train_loss: 0.000055, val_loss: 0.000028, val_NMSE: -34.42
# Epoch 0086 — train_loss: 0.000055, val_loss: 0.000028, val_NMSE: -34.35
# Epoch 0087 — train_loss: 0.000055, val_loss: 0.000027, val_NMSE: -34.53
# Epoch 0088 — train_loss: 0.000055, val_loss: 0.000030, val_NMSE: -34.12
# Epoch 0089 — train_loss: 0.000054, val_loss: 0.000028, val_NMSE: -34.40
# Epoch 0090 — train_loss: 0.000054, val_loss: 0.000026, val_NMSE: -34.67
# Epoch 0091 — train_loss: 0.000054, val_loss: 0.000031, val_NMSE: -33.92
# Epoch 0092 — train_loss: 0.000054, val_loss: 0.000027, val_NMSE: -34.61
# Epoch 0093 — train_loss: 0.000054, val_loss: 0.000029, val_NMSE: -34.33
# Epoch 0094 — train_loss: 0.000054, val_loss: 0.000028, val_NMSE: -34.45
# Epoch 0095 — train_loss: 0.000054, val_loss: 0.000032, val_NMSE: -33.86
# Epoch 0096 — train_loss: 0.000054, val_loss: 0.000027, val_NMSE: -34.59
# Epoch 0097 — train_loss: 0.000055, val_loss: 0.000030, val_NMSE: -34.16
# Epoch 0098 — train_loss: 0.000054, val_loss: 0.000026, val_NMSE: -34.72
# Epoch 0099 — train_loss: 0.000053, val_loss: 0.000026, val_NMSE: -34.74
# ===Training complete===
# Выполнение заняло: 0:15:48
# Model weights saved to model_params/ilc_DiffESN_res500_in2_out2.pt
# Model NMSE: -35.51

# %%
freqs, spectrum_x_val = metrics.power_spectrum(x_val, fs, nperseg)
_, spectrum_y_val = metrics.power_spectrum(y_val, fs, nperseg)
_, spectrum_y_val_pa = metrics.power_spectrum(y_val_pa, fs, nperseg)
_, spectrum_y_val_ilc = metrics.power_spectrum(y_val_ilc, fs, nperseg)
_, spectrum_y_val_target = metrics.power_spectrum(y_val_target, fs, nperseg)
_, spectrum_u_k_pa = metrics.power_spectrum(u_k_pa, fs, nperseg)
# _, spectrum_u_k = metrics.power_spectrum(u_k_train, fs, nperseg)


xlabel="Частота (МГц)"
ylabel= "Спектральная плотность мощности (дБ)"
fontsize = 12
figsize=(12, 6)

plt.figure(figsize=figsize)

plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_x_val)), color='grey', label='Входной сигнал')
plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_y_val)), color='black', label='Выходной сигнал')
plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_y_val_pa)), color='gold', label='Выходной сигнал PA')
plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_y_val_ilc)), color='green', label='spectrum_y_val_ilc')
# plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_u_k)), color='magenta', label='spectrum_u_k')
plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_u_k_pa)), color='red', label='Оптимальный сигнал ILC')


plt.xlabel(xlabel, fontsize=fontsize)
plt.ylabel(ylabel, fontsize=fontsize)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Metrics

# %%
nmse_after_pa = metrics.compute_nmse(y_val_pa, y_val_target)

print(f"NMSE на выходе усилителя (без DPD): {nmse_after_pa:.2f} db")
print(f"NMSE на выходе усилителя (DLA DPD): {dla_nmse:.2f} db")
print(f"NMSE на выходе усилителя (ILA DPD): {ila_nmse:.2f} db")
print(f"NMSE на выходе усилителя (ILC DPD): {ilc_nmse:.2f} db")
# Out:
# NMSE на выходе усилителя (без DPD): -14.13 db
# NMSE на выходе усилителя (DLA DPD): -35.74 db
# NMSE на выходе усилителя (ILA DPD): -34.50 db
# NMSE на выходе усилителя (ILC DPD): -35.51 db

# %%
x_val_acpr = metrics.calculate_acpr(x_val, acpr_meter)
y_val_acpr = metrics.calculate_acpr(y_val, acpr_meter)
y_val_pa_acpr = metrics.calculate_acpr(y_val_pa, acpr_meter)
y_val_target_acpr = metrics.calculate_acpr(y_val_target, acpr_meter)

y_lin_dla_acpr = metrics.calculate_acpr(y_val_dla, acpr_meter)
y_lin_ila_acpr = metrics.calculate_acpr(y_val_ila, acpr_meter)
y_lin_ilc_acpr = metrics.calculate_acpr(y_val_ilc, acpr_meter)

print(f"x_val_acpr: {x_val_acpr}")
print(f"y_val_acpr: {y_val_acpr}")
print(f"y_val_pa_acpr: {y_val_pa_acpr}")
print(f"y_val_target_acpr: {y_val_target_acpr}")

print(f"lin_dla_acpr: {y_lin_dla_acpr}")
print(f"lin_ila_acpr: {y_lin_ila_acpr}")
print(f"lin_ilc_acpr: {y_lin_ilc_acpr}")
# Out:
# x_val_acpr: [-48.08083195 -48.40122574]
# y_val_acpr: [-40.60778184 -38.20237847]
# y_val_pa_acpr: [-43.03155961 -41.35909809]
# y_val_target_acpr: [-48.08083304 -48.40122404]
# lin_dla_acpr: [-45.33944462 -43.93179   ]
# lin_ila_acpr: [-45.21553468 -42.424092  ]
# lin_ilc_acpr: [-45.253617   -43.22465662]

# %%
nmse_uk_pa = metrics.compute_nmse(u_k_pa, y_train_target)
print(f"NMSE на выходе усилителя (ILC): {nmse_uk_pa:.2f} db")

u_k_acpr = metrics.calculate_acpr(u_k_train, acpr_meter)
u_k_pa_acpr = metrics.calculate_acpr(u_k_pa, acpr_meter)

print(f"u_k_acpr: {u_k_acpr}")
print(f"u_k_pa_acpr: {u_k_pa_acpr}")
# Out:
# NMSE на выходе усилителя (ILC): -58.00 db
# u_k_acpr: [-41.08619573 -42.94239365]
# u_k_pa_acpr: [-50.48374203 -50.02097343]

# %% [markdown]
# Spectrum

# %%
freqs, spectrum_x_val = metrics.power_spectrum(x_val, fs, nperseg)
_, spectrum_y_val = metrics.power_spectrum(y_val, fs, nperseg)
_, spectrum_y_val_pa = metrics.power_spectrum(y_val_pa, fs, nperseg)
_, spectrum_y_val_target = metrics.power_spectrum(y_val_target, fs, nperseg)

_, spectrum_y_val_dla = metrics.power_spectrum(y_val_dla, fs, nperseg)
_, spectrum_y_val_ila = metrics.power_spectrum(y_val_ila, fs, nperseg)
_, spectrum_y_val_ilc = metrics.power_spectrum(y_val_ilc, fs, nperseg)

_, spectrum_u_k = metrics.power_spectrum(u_k_train, fs, nperseg)
_, spectrum_u_k_pa = metrics.power_spectrum(u_k_pa, fs, nperseg)

# %%
# построение спектра

xlabel="Частота (МГц)"
ylabel= "Спектральная плотность мощности (дБ)"
fontsize = 12
figsize=(12, 6)

plt.figure(figsize=figsize)

plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_x_val)), color='grey', label='Входной сигнал')
plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_y_val_pa)), color='gold', label='Выходной сигнал модели PA')
plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_u_k_pa)), color='red', label='Оптимальный сигнал ILC')
plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_y_val_dla)), color='darkorange', label='Сигнал с предыскажением DLA')
plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_y_val_ila)), color='limegreen', label='Сигнал с предыскажением ILA')
plt.plot(freqs / 1e6, 10 * np.log10(np.abs(spectrum_y_val_ilc)), color='lightcoral', label='Сигнал с предыскажением ILC')


plt.xlabel(xlabel, fontsize=fontsize)
plt.ylabel(ylabel, fontsize=fontsize)
plt.legend()
plt.grid()
plt.show()

# %%
# moving_average
window_size = 60

freqs_s, spectrum_x_val_s = utils.moving_average(spectrum_x_val, freqs, fs, window_size)
_, spectrum_y_val_s = utils.moving_average(spectrum_y_val, freqs, fs, window_size)
_, spectrum_y_val_pa_s = utils.moving_average(spectrum_y_val_pa, freqs, fs, window_size)
_, spectrum_y_val_target_s = utils.moving_average(spectrum_y_val_target, freqs, fs, window_size)

# _, spectrum_y_val_dla_s = utils.moving_average(spectrum_y_val_dla, freqs, fs, window_size)
# _, spectrum_y_val_ila_s = utils.moving_average(spectrum_y_val_ila, freqs, fs, window_size)
# _, spectrum_y_val_ilc_s = utils.moving_average(spectrum_y_val_ilc, freqs, fs, window_size)

_, spectrum_y_val_dla_s = utils.moving_average(spectrum_y_val_dla, freqs, fs, window_size)
_, spectrum_y_val_ila_s = utils.moving_average(spectrum_y_val_ila, freqs, fs, window_size)
_, spectrum_y_val_ilc_s = utils.moving_average(spectrum_y_val_ilc, freqs, fs, window_size)

_, spectrum_u_k_s = utils.moving_average(spectrum_u_k, freqs, fs, window_size)
_, spectrum_u_k_pa_s = utils.moving_average(spectrum_u_k_pa, freqs, fs, window_size)

# %%
# (сглаженный) построение спектра

xlabel="Частота, МГц"
ylabel= "Спектральная плотность мощности, дБВт/Гц"
fontsize = 12
figsize=(12, 8)
markersize=8

plt.figure(figsize=figsize)

# plt.plot(freqs_s / 1e6, 10 * np.log10(np.abs(spectrum_x_val_s)), 
#          color='grey', label='Входной сигнал',marker = '*', markevery=90, markersize=markersize)
plt.plot(freqs_s / 1e6, 10 * np.log10(np.abs(spectrum_y_val_target_s)), 
         color='black', label='Выходной сигнал\n(линейный усилитель)',marker = '*', markevery=90, markersize=markersize)
plt.plot(freqs_s / 1e6, 10 * np.log10(np.abs(spectrum_y_val_pa_s)), 
         color='gold', label='Выходной сигнал\n(реальный усилитель)', marker='o', markevery=90, markersize=markersize)
plt.plot(freqs_s / 1e6, 10 * np.log10(np.abs(spectrum_u_k_pa_s)), 
         color='red', label='Оптимальный сигнал ILC', marker='v', markevery=95, markersize=markersize)
plt.plot(freqs_s / 1e6, 10 * np.log10(np.abs(spectrum_y_val_dla_s)), 
         color='darkorange', label='Сигнал с предыскажением DLA', marker='D', markevery=90, markersize=markersize)
plt.plot(freqs_s / 1e6, 10 * np.log10(np.abs(spectrum_y_val_ila_s)), 
         color='limegreen', label='Сигнал с предыскажением ILA', marker='X', markevery=110, markersize=markersize)
plt.plot(freqs_s / 1e6, 10 * np.log10(np.abs(spectrum_y_val_ilc_s)), 
         color='lightcoral', label='Сигнал с предыскажением ILC', marker='s', markevery=120, markersize=markersize)

plt.xlabel(xlabel, fontsize=fontsize)
plt.ylabel(ylabel, fontsize=fontsize)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# AM/AM & AM/PM

# %%
y_in_am_am, y_out_am_am = metrics.calculate_am_am(x_val, y_val)
y_in_am_pm, y_in_phase_am_pm = metrics.calculate_am_pm(x_val, y_val)

_, y_pa_am_am = metrics.calculate_am_am(x_val, y_val_gru_pa)
_, y_pa_phase_am_pm = metrics.calculate_am_pm(x_val, y_val_gru_pa)

_, y_val_target_am_am = metrics.calculate_am_am(x_val, y_val_target)
_, y_val_target_phase_am_pm = metrics.calculate_am_pm(x_val, y_val_target)

# x_in_am_am, u_k_am_am = metrics.calculate_am_am(x_in_tensor, u_k)
# x_in_am_pm, u_k_phase_am_pm = metrics.calculate_am_pm(x_in_tensor, u_k)

# _, u_k_pa_am_am = metrics.calculate_am_am(x_in_tensor, u_k_pa)
# _, u_k_pa_phase_am_pm = metrics.calculate_am_pm(x_in_tensor, u_k_pa)

# dpd
# _, y_val_gru_dla_am_am = metrics.calculate_am_am(x_val, y_val_gru_dla)
# _, y_val_gru_dla_phase_am_pm = metrics.calculate_am_pm(x_val, y_val_gru_dla)

# _, y_val_gru_ila_am_am = metrics.calculate_am_am(x_val, y_val_gru_ila)
# _, y_val_gru_ila_phase_am_pm = metrics.calculate_am_pm(x_val, y_val_gru_ila)

# _, y_val_gru_ilc_am_am = metrics.calculate_am_am(x_val, y_val_gru_ilc)
# _, y_val_gru_ilc_phase_am_pm = metrics.calculate_am_pm(x_val, y_val_gru_ilc)

#linearized
_, y_val_gru_dla_am_am = metrics.calculate_am_am(x_val, y_val_gru_dla)
_, y_val_gru_dla_phase_am_pm = metrics.calculate_am_pm(x_val, y_val_gru_dla)

_, y_val_gru_ila_am_am = metrics.calculate_am_am(x_val, y_val_gru_ila)
_, y_val_gru_ila_phase_am_pm = metrics.calculate_am_pm(x_val, y_val_gru_ila)

_, y_val_gru_ilc_am_am = metrics.calculate_am_am(x_val, y_val_gru_ilc)
_, y_val_gru_ilc_phase_am_pm = metrics.calculate_am_pm(x_val, y_val_gru_ilc)

# %%
#DLA

am_am_data = [
    (y_in_am_am, y_pa_am_am, 'gold', 'Выходной сигнал'),
    # (y_in_am_am, y_val_gru_dla_am_am, 'magenta', 'Сигнал на выходе DPD'),
    (y_in_am_am, y_val_gru_dla_am_am, 'darkorange', 'Сигнал с предыскажением'),
]

am_pm_data = [
    (y_in_am_pm, y_pa_phase_am_pm, 'gold', 'Выходной сигнал'),
    (y_in_am_pm, y_val_gru_dla_phase_am_pm, 'darkorange', 'Сигнал с предыскажением'),
]

plotting.plot_am_am_pm(
    am_am_data=am_am_data,
    am_pm_data=am_pm_data,
    figsize=(12, 6),
    titles=("AM/AM DLA", "AM/PM DLA"),
    xlabels=("Амплитуда на входе", "Амплитуда на входе"),
    ylabels=("Амплитуда на выходе", "Фазовый сдвиг на выходе (градусы)")
)

# %%
#ILA

am_am_data = [
    (y_in_am_am, y_pa_am_am, 'gold', 'Выходной сигнал'),
    # (y_in_am_am, y_val_gru_ila_am_am, 'magenta', 'Сигнал на выходе DPD'),
    (y_in_am_am, y_val_gru_ila_am_am, 'darkorange', 'Сигнал с предыскажением'),
]

am_pm_data = [
    (y_in_am_pm, y_pa_phase_am_pm, 'gold', 'Выходной сигнал'),
    (y_in_am_pm, y_val_gru_ila_phase_am_pm, 'darkorange', 'Сигнал с предыскажением'),
]

plotting.plot_am_am_pm(
    am_am_data=am_am_data,
    am_pm_data=am_pm_data,
    figsize=(12, 6),
    titles=("AM/AM ILA", "AM/PM ILA"),
    xlabels=("Амплитуда на входе", "Амплитуда на входе"),
    ylabels=("Амплитуда на выходе", "Фазовый сдвиг на выходе (градусы)")
)

# %%
#ILC

am_am_data = [
    (y_in_am_am, y_pa_am_am, 'gold', 'Выходной сигнал'),
    # (y_in_am_am, y_val_gru_ilc_am_am, 'magenta', 'Сигнал на выходе корректора'),
    (y_in_am_am, y_val_gru_ilc_am_am, 'darkorange', 'Сигнал с предыскажением'),
]

am_pm_data = [
    (y_in_am_pm, y_pa_phase_am_pm, 'gold', 'Выходной сигнал'),
    (y_in_am_pm, y_val_gru_ilc_phase_am_pm, 'darkorange', 'Сигнал с предыскажением'),
]

plotting.plot_am_am_pm(
    am_am_data=am_am_data,
    am_pm_data=am_pm_data,
    figsize=(12, 6),
    titles=("AM/AM ILC", "AM/PM ILC"),
    xlabels=("Амплитуда на входе", "Амплитуда на входе"),
    ylabels=("Амплитуда на выходе", "Фазовый сдвиг на выходе (градусы)")
)

# %% [markdown]
# Add noise

# %%
snr_range = list(range(20, 61, 5))

epochs = 100
lr = 0.001
num_realizations = 200

hidden_size=8
num_layers=1


snr_params = params.make_snr_params(
    snr_range=snr_range,
    num_realizations=num_realizations,
    fs=fs,
    bw_main_ch=bw_main_ch,
    epochs=epochs,
    learning_rate=lr,
    acpr_meter=acpr_meter,
    pa_model=gru_pa,
    gain=gain
)

nn_params = {
    "hidden_size": hidden_size,
    "num_layers": num_layers
}

snr_metrics_runner = pipelines.SnrPipeline(base_model=GRU, 
                                           input_model_params=nn_params, 
                                           data_dict=data, 
                                           snr_params=snr_params)

# %%
snr_metrics_runner.run_dla_noise()
# Out:
# SNR: 20
# ===Start training===
# Epoch 0000 — train_loss: 0.079289, val_loss: 0.016323, val_NMSE: -16.79
# Epoch 0049 — train_loss: 0.014882, val_loss: 0.014754, val_NMSE: -17.23
# Время обучения: 0:01:28
# ===Training complete===
# SNR: 25
# ===Start training===
# Epoch 0000 — train_loss: 0.098993, val_loss: 0.005751, val_NMSE: -21.32
# Epoch 0049 — train_loss: 0.004938, val_loss: 0.005057, val_NMSE: -21.88
# Время обучения: 0:01:29
# ===Training complete===
# SNR: 30
# ===Start training===
# Epoch 0000 — train_loss: 0.070503, val_loss: 0.002585, val_NMSE: -24.80
# Epoch 0049 — train_loss: 0.001667, val_loss: 0.001624, val_NMSE: -26.82
# Время обучения: 0:01:28
# ===Training complete===
# SNR: 35
# ===Start training===
# Epoch 0000 — train_loss: 0.103375, val_loss: 0.002465, val_NMSE: -25.00
# Epoch 0049 — train_loss: 0.000583, val_loss: 0.000549, val_NMSE: -31.53
# Время обучения: 0:01:27
# ===Training complete===
# SNR: 40
# ===Start training===
# Epoch 0000 — train_loss: 0.074668, val_loss: 0.001108, val_NMSE: -28.47
# Epoch 0049 — train_loss: 0.000233, val_loss: 0.000216, val_NMSE: -35.58
# Время обучения: 0:01:26
# ===Training complete===
# SNR: 45
# ===Start training===
# Epoch 0000 — train_loss: 0.099892, val_loss: 0.001489, val_NMSE: -27.19
# Epoch 0049 — train_loss: 0.000140, val_loss: 0.000107, val_NMSE: -38.65
# Время обучения: 0:01:26
# ===Training complete===
# SNR: 50
# ===Start training===
# Epoch 0000 — train_loss: 0.088426, val_loss: 0.001357, val_NMSE: -27.60
# Epoch 0049 — train_loss: 0.000150, val_loss: 0.000096, val_NMSE: -39.10
# Время обучения: 0:01:27
# ===Training complete===
# SNR: 55
# ===Start training===
# Epoch 0000 — train_loss: 0.109540, val_loss: 0.001204, val_NMSE: -28.12
# Epoch 0049 — train_loss: 0.000113, val_loss: 0.000106, val_NMSE: -38.65
# Время обучения: 0:01:26
# ===Training complete===
# SNR: 60
# ===Start training===
# Epoch 0000 — train_loss: 0.064650, val_loss: 0.000958, val_NMSE: -29.11
# Epoch 0049 — train_loss: 0.000095, val_loss: 0.000062, val_NMSE: -41.01
# Время обучения: 0:01:28
# ===Training complete===

# %%
snr_metrics_runner.run_ila_noise()
# Out:
# SNR: 20
# ===Start training===
# Epoch 0000 — train_loss: 0.016766, val_loss: 0.002250, val_NMSE: -17.37
# Epoch 0049 — train_loss: 0.001898, val_loss: 0.001839, val_NMSE: -18.24
# Время обучения: 0:01:08
# ===Training complete===
# SNR: 25
# ===Start training===
# Epoch 0000 — train_loss: 0.014179, val_loss: 0.000916, val_NMSE: -21.27
# Epoch 0049 — train_loss: 0.000684, val_loss: 0.000642, val_NMSE: -22.81
# Время обучения: 0:01:08
# ===Training complete===
# SNR: 30
# ===Start training===
# Epoch 0000 — train_loss: 0.016422, val_loss: 0.000622, val_NMSE: -22.96
# Epoch 0049 — train_loss: 0.000252, val_loss: 0.000237, val_NMSE: -27.15
# Время обучения: 0:01:08
# ===Training complete===
# SNR: 35
# ===Start training===
# Epoch 0000 — train_loss: 0.020940, val_loss: 0.000851, val_NMSE: -21.59
# Epoch 0049 — train_loss: 0.000104, val_loss: 0.000087, val_NMSE: -31.50
# Время обучения: 0:01:08
# ===Training complete===
# SNR: 40
# ===Start training===
# Epoch 0000 — train_loss: 0.026843, val_loss: 0.000824, val_NMSE: -21.73
# Epoch 0049 — train_loss: 0.000046, val_loss: 0.000037, val_NMSE: -35.25
# Время обучения: 0:01:08
# ===Training complete===
# SNR: 45
# ===Start training===
# Epoch 0000 — train_loss: 0.034027, val_loss: 0.000642, val_NMSE: -22.82
# Epoch 0049 — train_loss: 0.000039, val_loss: 0.000045, val_NMSE: -34.36
# Время обучения: 0:01:08
# ===Training complete===
# SNR: 50
# ===Start training===
# Epoch 0000 — train_loss: 0.014051, val_loss: 0.000291, val_NMSE: -26.26
# Epoch 0049 — train_loss: 0.000022, val_loss: 0.000019, val_NMSE: -38.07
# Время обучения: 0:01:08
# ===Training complete===
# SNR: 55
# ===Start training===
# Epoch 0000 — train_loss: 0.005039, val_loss: 0.000200, val_NMSE: -27.89
# Epoch 0049 — train_loss: 0.000019, val_loss: 0.000010, val_NMSE: -40.73
# Время обучения: 0:01:11
# ===Training complete===
# SNR: 60
# ===Start training===
# Epoch 0000 — train_loss: 0.013979, val_loss: 0.000293, val_NMSE: -26.22
# Epoch 0049 — train_loss: 0.000016, val_loss: 0.000013, val_NMSE: -39.90
# Время обучения: 0:01:09
# ===Training complete===

# %%
snr_metrics_runner.run_ilc_noise()
# Out:
# SNR: 20
# Epoch [0/200], Loss: 0.05504428967833519
# Epoch [100/200], Loss: 0.0163440965116024
# Epoch [199/200], Loss: 0.01662500575184822
# Время расчёта ilc_signal: 0:12:49
# ===Start training===
# Epoch 0000 — train_loss: 0.008179, val_loss: 0.072946, val_NMSE: 0.15
# Epoch 0049 — train_loss: 0.000178, val_loss: 0.072638, val_NMSE: 0.13
# Время обучения: 0:00:49
# ===Training complete===
# SNR: 25
# Epoch [0/200], Loss: 0.038476452231407166
# Epoch [100/200], Loss: 0.005731415934860706
# Epoch [199/200], Loss: 0.005766578484326601
# Время расчёта ilc_signal: 0:12:47
# ===Start training===
# Epoch 0000 — train_loss: 0.014055, val_loss: 0.075401, val_NMSE: 0.06
# Epoch 0049 — train_loss: 0.000118, val_loss: 0.076817, val_NMSE: 0.14
# Время обучения: 0:00:50
# ===Training complete===
# SNR: 30
# Epoch [0/200], Loss: 0.03320373594760895
# Epoch [100/200], Loss: 0.0020090616308152676
# Epoch [199/200], Loss: 0.002058345125988126
# Время расчёта ilc_signal: 0:12:51
# ===Start training===
# Epoch 0000 — train_loss: 0.011876, val_loss: 0.077647, val_NMSE: 0.11
# Epoch 0049 — train_loss: 0.000077, val_loss: 0.078057, val_NMSE: 0.13
# Время обучения: 0:00:49
# ===Training complete===
# SNR: 35
# Epoch [0/200], Loss: 0.0314423143863678
# Epoch [100/200], Loss: 0.0007028212421573699
# Epoch [199/200], Loss: 0.0007392372353933752
# Время расчёта ilc_signal: 0:12:51
# ===Start training===
# Epoch 0000 — train_loss: 0.009034, val_loss: 0.078302, val_NMSE: 0.13
# Epoch 0049 — train_loss: 0.000058, val_loss: 0.078815, val_NMSE: 0.16
# Время обучения: 0:00:49
# ===Training complete===
# SNR: 40
# Epoch [0/200], Loss: 0.031012840569019318
# Epoch [100/200], Loss: 0.00025029503740370274
# Epoch [199/200], Loss: 0.0002647075743880123
# Время расчёта ilc_signal: 0:12:52
# ===Start training===
# Epoch 0000 — train_loss: 0.007629, val_loss: 0.079108, val_NMSE: 0.17
# Epoch 0049 — train_loss: 0.000042, val_loss: 0.078628, val_NMSE: 0.14
# Время обучения: 0:00:50
# ===Training complete===
# SNR: 45
# Epoch [0/200], Loss: 0.030800344422459602
# Epoch [100/200], Loss: 8.90527298906818e-05
# Epoch [199/200], Loss: 9.801665146369487e-05
# Время расчёта ilc_signal: 0:12:52
# ===Start training===
# Epoch 0000 — train_loss: 0.012746, val_loss: 0.078164, val_NMSE: 0.11
# Epoch 0049 — train_loss: 0.000035, val_loss: 0.078732, val_NMSE: 0.15
# Время обучения: 0:00:50
# ===Training complete===
# SNR: 50
# Epoch [0/200], Loss: 0.030764123424887657
# Epoch [100/200], Loss: 3.0718831112608314e-05
# Epoch [199/200], Loss: 3.550244582584128e-05
# Время расчёта ilc_signal: 0:12:52
# ===Start training===
# Epoch 0000 — train_loss: 0.005855, val_loss: 0.078517, val_NMSE: 0.13
# Epoch 0049 — train_loss: 0.000035, val_loss: 0.078770, val_NMSE: 0.15
# Время обучения: 0:00:49
# ===Training complete===
# SNR: 55
# Epoch [0/200], Loss: 0.030737897381186485
# Epoch [100/200], Loss: 1.080975380318705e-05
# Epoch [199/200], Loss: 1.24079488159623e-05
# Время расчёта ilc_signal: 0:12:53
# ===Start training===
# Epoch 0000 — train_loss: 0.011897, val_loss: 0.077885, val_NMSE: 0.10
# Epoch 0049 — train_loss: 0.000032, val_loss: 0.078628, val_NMSE: 0.14
# Время обучения: 0:00:49
# ===Training complete===
# SNR: 60
# Epoch [0/200], Loss: 0.03074040450155735
# Epoch [100/200], Loss: 3.840132194454782e-06
# Epoch [199/200], Loss: 4.306945356802316e-06
# Время расчёта ilc_signal: 0:12:53
# ===Start training===
# Epoch 0000 — train_loss: 0.019914, val_loss: 0.079024, val_NMSE: 0.16
# Epoch 0049 — train_loss: 0.000039, val_loss: 0.078857, val_NMSE: 0.15
# Время обучения: 0:00:49
# ===Training complete===

# %%
results = snr_metrics_runner.get_results()

snr_range = results["snr_range"]

nmse_dla_list = results["dla"]["nmse"]
acpr_left_dla_list = results["dla"]["acpr_left"]
acpr_right_dla_list = results["dla"]["acpr_right"]

nmse_ila_list = results["ila"]["nmse"]
acpr_left_ila_list = results["ila"]["acpr_left"]
acpr_right_ila_list = results["ila"]["acpr_right"]

nmse_ilc_list = results["ilc"]["nmse"]
acpr_left_ilc_list = results["ilc"]["acpr_left"]
acpr_right_ilc_list = results["ilc"]["acpr_right"]

nmse_uk_list = results["uk"]["nmse"]
acpr_left_uk_list = results["uk"]["acpr_left"]
acpr_right_uk_list = results["uk"]["acpr_right"]

# %%
print(f"snr_range = {snr_range}")
print()

print(f"nmse_dla_list = {(nmse_dla_list)}")
print(f"acpr_left_dla_list = {acpr_left_dla_list}")
print(f"acpr_right_dla_list = {acpr_right_dla_list}")
print()

print(f"nmse_ila_list = {nmse_ila_list}")
print(f"acpr_left_ila_list = {acpr_left_ila_list}")
print(f"acpr_right_ila_list = {acpr_right_ila_list}")
print()

print(f"nmse_ilc_list = {nmse_ilc_list}")
print(f"acpr_left_ilc_list = {acpr_left_ilc_list}")
print(f"acpr_right_ilc_list = {acpr_right_ilc_list}")
print()

print(f"nmse_uk_list = {nmse_uk_list}")
print(f"acpr_left_uk_list = {acpr_left_uk_list}")
print(f"acpr_right_uk_list = {acpr_right_uk_list}")
# Out:
# snr_range = [20, 25, 30, 35, 40, 45, 50, 55, 60]
#
# nmse_dla_list = [-17.137060165405273, -21.96965980529785, -26.81765365600586, -31.505434036254883, -35.57054138183594, -38.63620376586914, -39.113792419433594, -38.6195068359375, -41.02045822143555]
# acpr_left_dla_list = [np.float64(-20.043180907001865), np.float64(-24.997615366869727), np.float64(-29.88420059459173), np.float64(-34.69813351874072), np.float64(-39.11869853930988), np.float64(-42.75941617564841), np.float64(-44.556015439067544), np.float64(-45.50579331757665), np.float64(-45.856063390816914)]
# acpr_right_dla_list = [np.float64(-20.03768970456767), np.float64(-24.98483819339822), np.float64(-29.91008171158717), np.float64(-34.66632986010521), np.float64(-39.092701210139325), np.float64(-42.551257239684695), np.float64(-44.15280496551297), np.float64(-45.29853879521245), np.float64(-46.00348917956039)]
#
# nmse_ila_list = [-16.82413673400879, -21.81842613220215, -26.752714157104492, -31.452070236206055, -35.70893096923828, -34.1090202331543, -38.296993255615234, -42.362709045410156, -40.32441711425781]
# acpr_left_ila_list = [np.float64(-20.023785687838792), np.float64(-24.968133825327367), np.float64(-29.9220537056228), np.float64(-34.73663298010931), np.float64(-39.285517077226885), np.float64(-42.272317716454175), np.float64(-45.529052960204105), np.float64(-46.39092439455998), np.float64(-46.97019574084575)]
# acpr_right_ila_list = [np.float64(-20.04236443802337), np.float64(-24.967847844164556), np.float64(-29.930158880599173), np.float64(-34.71037860355651), np.float64(-39.09866216415605), np.float64(-42.53313727206143), np.float64(-45.0592016756485), np.float64(-46.202775689326614), np.float64(-46.785822396254225)]
#
# nmse_ilc_list = [-17.131040573120117, -21.954679489135742, -26.642658233642578, -31.321826934814453, -34.60251235961914, -36.69697570800781, -40.476158142089844, -40.328155517578125, -37.86528015136719]
# %%
markersize = 8
plt.figure(figsize=(9, 5))
plt.plot(snr_range, nmse_dla_list,color='blue', linestyle='-', label="Сигнал с предыскажением DLA",
         marker='o', markersize=markersize)
plt.plot(snr_range, nmse_ila_list, color='orange', linestyle='--', label="Сигнал с предыскажением ILA",
         marker='s', markersize=markersize)
plt.plot(snr_range, nmse_ilc_list, color='green', linestyle='-.', label="Сигнал с предыскажением ILC",
         marker='d', markersize=markersize)
plt.plot(snr_range, nmse_uk_list, color='red', linestyle='-.', label="Оптимальный сигнал ILC",
         marker='*', markersize=markersize)

plt.xlabel("ОСШ, дБ", fontsize=12)
plt.ylabel("NMSE, дБ", fontsize=12)
# plt.title("Зависимость NMSE от ОСШ")
plt.xticks(range(20, 61, 5))
plt.yticks(range(-55, -9, 5))
plt.legend()
plt.grid(True)

plt.show()

# %%
markersize=8
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
# plt.plot(snr_range, acpr_left_dla_list, marker='o', color='blue', linestyle='-', label="Сигнал с предыскажением DLA")
# plt.plot(snr_range, acpr_left_ila_list, marker='s', color='orange', linestyle='--', label="Сигнал с предыскажением ILA")
# plt.plot(snr_range, acpr_left_ilc_list, marker='d', color='green', linestyle='-.', label="Сигнал с предыскажением ILC")
# plt.plot(snr_range, acpr_left_uk_list, marker='*', color='indigo', linestyle='-.', label="Оптимальный сигнал ILC")
plt.plot(snr_range, acpr_left_dla_list, color='blue', linestyle='-', label="Сигнал с предыскажением DLA", 
         marker='o', markersize=markersize)
plt.plot(snr_range, acpr_left_ila_list, color='orange', linestyle='--', label="Сигнал с предыскажением ILA", 
         marker='s', markersize=markersize)
plt.plot(snr_range, acpr_left_ilc_list, color='green', linestyle='-.', label="Сигнал с предыскажением ILC", 
         marker='d', markersize=markersize)
plt.plot(snr_range, acpr_left_uk_list, color='red', linestyle='-.', label="Оптимальный сигнал ILC", 
         marker='*', markersize=markersize)
plt.title('Левый канал', fontsize=12)
plt.xlabel('ОСШ, дБ', fontsize=12)
plt.ylabel('ACPR, дБ', fontsize=12)
plt.xticks(range(20, 61, 5))
plt.yticks(range(-55, -14, 5))
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(snr_range, acpr_right_dla_list, color='blue', linestyle='-', label="Сигнал с предыскажением DLA", 
         marker='o', markersize=markersize)
plt.plot(snr_range, acpr_right_ila_list, color='orange', linestyle='--', label="Сигнал с предыскажением ILA", 
         marker='s', markersize=markersize)
plt.plot(snr_range, acpr_right_ilc_list, color='green', linestyle='-.', label="Сигнал с предыскажением ILC", 
         marker='d', markersize=markersize)
plt.plot(snr_range, acpr_right_uk_list, color='red', linestyle='-.', label="Оптимальный сигнал ILC", 
         marker='*', markersize=markersize)
plt.title('Правый канал', fontsize=12)
plt.xlabel('ОСШ, дБ', fontsize=12)
plt.ylabel('ACPR, дБ', fontsize=12)
plt.xticks(range(20, 61, 5))
plt.yticks(range(-55, -14, 5))
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
